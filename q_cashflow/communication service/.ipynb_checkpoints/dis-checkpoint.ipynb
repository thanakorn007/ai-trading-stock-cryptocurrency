# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import pandas_datareader as web
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import os
import pickle
import seaborn as sns
import datetime as dt
import yfinance as yf
import talib
from tqdm.notebook import tqdm
# %matplotlib inline


class LinearModel:
    def __init__(self, input_dim, n_action):
        self.W = np.random.randn(input_dim, n_action) / np.sqrt(input_dim)
        self.b = np.zeros(n_action)
        self.vW = 0
        self.vb = 0
        self.losses = []
        
    def predict(self, s):
        return s.dot(self.W) + self.b
    
    def sgd(self, s, Y, learning_rate=0.001, momentum=0.9):
        num_values = np.prod(Y.shape)
        Y_hat = self.predict(s)
        Y_hat = self.predict(s)  # shape (1, 8)
        gW = 2 * s.T.dot(Y_hat - Y) / num_values  # vector shape (7, 8)
        gb = 2 * (Y_hat - Y).sum(axis=0) / num_values  # scalar

        self.vW = momentum * self.vW - learning_rate * gW  # vector shape (7, 8)
        self.vb = momentum * self.vb - learning_rate * gb  # scalar

        self.W += self.vW  # vector shape (7, 8)
        self.b += self.vb  # scalar

        mse = np.mean((Y_hat - Y) ** 2)
        self.losses.append(mse)
        
        
    def save_weights(self, filepath):
        np.savez(filepath, W=self.W, b=self.b)


    def load_weights(self, filepath):
        npz = np.load(filepath)
        self.W = npz['W']
        self.b = npz['b']
        
        
class DQNAgent(object):
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = LinearModel(state_size, action_size)

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action


    def train(self, state, action, reward, next_state, done):
        if done:
            target = reward
        else:
            target = reward + self.gamma * np.amax(self.model.predict(next_state), axis=1)

        target_full = self.model.predict(state)
        target_full[0, action] = target

        # Run one training step
        self.model.sgd(state, target_full)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay


    def load(self, name):
        self.model.load_weights(name)


    def save(self, name):
        self.model.save_weights(name)
        
        
        
        
class StockEnv:
    def __init__(self, data, capital, trade_fee_bid_percent = 0.01, trade_fee_ask_percent = 0.005):
        self.trade_fee_bid_percent = trade_fee_bid_percent/100  # percent
        self.trade_fee_ask_percent = trade_fee_ask_percent/100  # percent
        
        self.stock_price_history = data['Adj Close']
        self.n_step = self.stock_price_history.shape[0]
        self.capital = capital
        self.current_step = None
        self.stock_owned = None
        self.stock_price = None
        self.cash_in_hand = None
        self.state_dim = 5 #[stock price, stock_owned, cash__in_hand, rsi, mom]
        self.save_position = []
        self.save_port_val = [] 
        self.save_cash = []
        self.stock_value = []
        self.action_space = [0,1]
        self.sell_buy = []
        self.save_stock_price = []
        self.rsi = data['rsi']
        self.mom = data['mom']
        self.reset()
        
        
    def state_vector(self):
        vector = np.empty(self.state_dim)
        vector[0] = self.stock_price
        vector[1] = self.stock_owned
        vector[2] = self.cash_in_hand
        vector[3] = self.rsi[self.current_step]
        vector[4] = self.mom[self.current_step]
        return vector
    
    
    def reset(self):
        self.current_step = 0
        self.stock_owned = 0
        self.stock_price = self.stock_price_history[self.current_step]
        self.cash_in_hand = self.capital
        self.save_position = [0]
        self.save_port_val = [self.capital] 
        self.save_cash = [self.capital]
        self.stock_value = [0]
        self.sell_buy = ['hold']
        self.save_stock_price = [self.stock_price]
        return self.state_vector()
    

    
    def port_val(self):
        return (self.stock_owned * self.stock_price) + self.cash_in_hand
    
    
    def cal_position(self):
        high = self.stock_price_history.max()
        mid_price =  high/ 2
        max_pos = self.capital / mid_price
        slope = max_pos/-high
        c = -slope * high
        
        return slope * self.stock_price + c, high, max_pos
        
      
    def trade(self, action):
        '''
        action 0 = hold
        action 1 = take action
        '''
        assert action in self.action_space
        
        if action == 1:
            position_sh, high, max_pos = self.cal_position()
            diff = position_sh - self.stock_owned
            if diff < 0:
                #sell
                self.stock_owned = position_sh
                self.cash_in_hand += (abs(diff) * self.stock_price * (1 - self.trade_fee_ask_percent))
                self.sell_buy.append('sell')
                
                
            elif diff > 0:
                #buy
                self.stock_owned = position_sh
                self.cash_in_hand -= (abs(diff) * self.stock_price * (1 + self.trade_fee_bid_percent))
                self.sell_buy.append('buy')
                
            else:
                self.sell_buy.append('hold')
                
        else:
            self.sell_buy.append('hold')
            
        self.save_cash.append(self.cash_in_hand)
        self.save_port_val.append(self.port_val())
        self.save_position.append(self.stock_owned)
        self.stock_value.append(self.stock_owned * self.stock_price)
        self.save_stock_price.append(self.stock_price)
        
          
        
                
    def step(self, action):
        assert action in self.action_space
        
        prev_val = self.port_val()
        self.current_step += 1
        self.stock_price = self.stock_price_history[self.current_step]
        
        self.trade(action)
        current_val = self.port_val()
        reward = current_val - prev_val
        done = self.current_step == self.n_step - 1
        info = {'stock_price': self.save_stock_price,
                'portfolio_value': self.save_port_val,
#                 'current_val': self.port_val(),
                'stock_owned': self.save_position,
                'cash_in_hand': self.save_cash,
                'stock_value': self.stock_value,
                'sell_buy':self.sell_buy
               }
        
        return self.state_vector(), reward, done, info
    
    
def get_scaler(env):
    states = []
    for i in range(env.n_step):
        action = np.random.choice(env.action_space)
        state, reward, done, info = env.step(action)
        states.append(state)
        if done:
            break
    scaler = StandardScaler()
    scaler.fit(states)
    return scaler



        
        
def play_one_episode(agent, env, is_train):
    state = env.reset()
    state = scaler.transform([state])
    done = False
    
    while not done:
        action = agent.act(state)
        next_state, reward, done, info = env.step(action)
        next_state = scaler.transform([next_state])
        
        if is_train == 'train':
            agent.train(state, action, reward, next_state, done)
        
        state = next_state
    
    return info

# %%
stock_name = 'jnj'.upper()
stock_data = pd.read_csv(f'../train_test_data/{stock_name}.csv', index_col=['Date'], parse_dates=True)

train_data = stock_data.loc[:'2018-01-01']
test_data = stock_data.loc['2018-01-01':]


num_episodes = 2000
batch_size = 32
capital = 1000
data = stock_data['Adj Close'].values
n_timesteps = data.shape[0]


env = StockEnv(train_data, capital)
state_size = env.state_dim
action_size = 2
agent = DQNAgent(state_size, action_size)
scaler = get_scaler(env)

# %%
#train


mode = 'train'

portfolio_value = []



for e in tqdm(range(num_episodes)):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1]) 


if mode == 'train':
    # save the DQN
    agent.save(f'state_dict/{stock_name}.npz')

    # save the scaler
    with open(f'scaler/{stock_name}.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    # plot losses
    loss = agent.model.losses
    losses = pd.DataFrame(loss, columns=['loss'])
    losses.plot(figsize=(10,6))
    plt.title('Average Mean Square Error of All Episode')
    plt.xlabel('Step')
    plt.ylabel('Mean Square Error')

print(f'average reward: {np.mean(portfolio_value):.2f}, min: {np.min(portfolio_value):.2f}, max: {np.max(portfolio_value):.2f}')
sns.histplot(portfolio_value, bins=100, color='r', kde=True);
plt.xlabel('Portfolio Value');
plt.ylabel('Count');
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# episode: 1/2000, episode end value: 1276.30, duration: 0:00:00.200050
# episode: 2/2000, episode end value: 1205.78, duration: 0:00:00.199045
# episode: 3/2000, episode end value: 1279.61, duration: 0:00:00.197044
# episode: 4/2000, episode end value: 1221.04, duration: 0:00:00.194044
# episode: 5/2000, episode end value: 1268.52, duration: 0:00:00.196024
# episode: 6/2000, episode end value: 1276.54, duration: 0:00:00.199038
# episode: 7/2000, episode end value: 1275.13, duration: 0:00:00.194050
# episode: 8/2000, episode end value: 1271.09, duration: 0:00:00.204046
# episode: 9/2000, episode end value: 1286.89, duration: 0:00:00.210041
# episode: 10/2000, episode end value: 1289.43, duration: 0:00:00.198051
# episode: 11/2000, episode end value: 1273.56, duration: 0:00:00.211041
# episode: 12/2000, episode end value: 1268.10, duration: 0:00:00.195050
# episode: 13/2000, episode end value: 1273.95, duration: 0:00:00.198006
# episode: 14/2000, episode end value: 1276.58, duration: 0:00:00.210047
# episode: 15/2000, episode end value: 1272.49, duration: 0:00:00.199047
# episode: 16/2000, episode end value: 1267.07, duration: 0:00:00.196044
# episode: 17/2000, episode end value: 1279.46, duration: 0:00:00.211047
# episode: 18/2000, episode end value: 1313.28, duration: 0:00:00.197051
# episode: 19/2000, episode end value: 1285.59, duration: 0:00:00.193043
# episode: 20/2000, episode end value: 1288.49, duration: 0:00:00.195031
# episode: 21/2000, episode end value: 1268.95, duration: 0:00:00.196031
# episode: 22/2000, episode end value: 1274.92, duration: 0:00:00.200052
# episode: 23/2000, episode end value: 1269.65, duration: 0:00:00.195031
# episode: 24/2000, episode end value: 1282.32, duration: 0:00:00.196063
# episode: 25/2000, episode end value: 1268.42, duration: 0:00:00.195043
# episode: 26/2000, episode end value: 1269.63, duration: 0:00:00.214995
# episode: 27/2000, episode end value: 1283.56, duration: 0:00:00.198063
# episode: 28/2000, episode end value: 1284.00, duration: 0:00:00.195037
# episode: 29/2000, episode end value: 1279.01, duration: 0:00:00.195056
# episode: 30/2000, episode end value: 1264.85, duration: 0:00:00.204046
# episode: 31/2000, episode end value: 1272.76, duration: 0:00:00.209041
# episode: 32/2000, episode end value: 1271.42, duration: 0:00:00.204040
# episode: 33/2000, episode end value: 1273.04, duration: 0:00:00.198056
# episode: 34/2000, episode end value: 1267.30, duration: 0:00:00.208026
# episode: 35/2000, episode end value: 1259.87, duration: 0:00:00.200056
# episode: 36/2000, episode end value: 1269.74, duration: 0:00:00.207060
# episode: 37/2000, episode end value: 1268.91, duration: 0:00:00.202060
# episode: 38/2000, episode end value: 1297.39, duration: 0:00:00.194056
# episode: 39/2000, episode end value: 1269.44, duration: 0:00:00.197044
# episode: 40/2000, episode end value: 1278.49, duration: 0:00:00.200045
# episode: 41/2000, episode end value: 1289.68, duration: 0:00:00.203039
# episode: 42/2000, episode end value: 1299.89, duration: 0:00:00.199045
# episode: 43/2000, episode end value: 1291.65, duration: 0:00:00.194043
# episode: 44/2000, episode end value: 1272.71, duration: 0:00:00.199052
# episode: 45/2000, episode end value: 1271.98, duration: 0:00:00.200058
# episode: 46/2000, episode end value: 1290.79, duration: 0:00:00.210028
# episode: 47/2000, episode end value: 1276.33, duration: 0:00:00.195056
# episode: 48/2000, episode end value: 1303.28, duration: 0:00:00.198038
# episode: 49/2000, episode end value: 1264.55, duration: 0:00:00.196039
# episode: 50/2000, episode end value: 1260.07, duration: 0:00:00.203044
# episode: 51/2000, episode end value: 1280.71, duration: 0:00:00.205046
# episode: 52/2000, episode end value: 1279.30, duration: 0:00:00.211048
# episode: 53/2000, episode end value: 1285.43, duration: 0:00:00.204060
# episode: 54/2000, episode end value: 1282.51, duration: 0:00:00.210047
# episode: 55/2000, episode end value: 1282.52, duration: 0:00:00.205052
# episode: 56/2000, episode end value: 1284.20, duration: 0:00:00.209047
# episode: 57/2000, episode end value: 1268.54, duration: 0:00:00.195050
# episode: 58/2000, episode end value: 1280.04, duration: 0:00:00.201045
# episode: 59/2000, episode end value: 1282.43, duration: 0:00:00.211041
# episode: 60/2000, episode end value: 1283.71, duration: 0:00:00.212048
# episode: 61/2000, episode end value: 1289.40, duration: 0:00:00.214055
# episode: 62/2000, episode end value: 1284.55, duration: 0:00:00.206058
# episode: 63/2000, episode end value: 1266.34, duration: 0:00:00.212041
# episode: 64/2000, episode end value: 1284.53, duration: 0:00:00.203052
# episode: 65/2000, episode end value: 1265.47, duration: 0:00:00.197024
# episode: 66/2000, episode end value: 1259.23, duration: 0:00:00.194044
# episode: 67/2000, episode end value: 1269.94, duration: 0:00:00.207033
# episode: 68/2000, episode end value: 1281.49, duration: 0:00:00.213048
# episode: 69/2000, episode end value: 1283.75, duration: 0:00:00.207040
# episode: 70/2000, episode end value: 1263.38, duration: 0:00:00.201045
# episode: 71/2000, episode end value: 1267.42, duration: 0:00:00.200050
# episode: 72/2000, episode end value: 1304.20, duration: 0:00:00.213035
# episode: 73/2000, episode end value: 1266.14, duration: 0:00:00.210053
# episode: 74/2000, episode end value: 1285.14, duration: 0:00:00.213048
# episode: 75/2000, episode end value: 1275.87, duration: 0:00:00.195050
# episode: 76/2000, episode end value: 1271.55, duration: 0:00:00.211041
# episode: 77/2000, episode end value: 1284.11, duration: 0:00:00.203046
# episode: 78/2000, episode end value: 1268.27, duration: 0:00:00.214042
# episode: 79/2000, episode end value: 1282.05, duration: 0:00:00.213060
# episode: 80/2000, episode end value: 1286.53, duration: 0:00:00.196049
# episode: 81/2000, episode end value: 1277.30, duration: 0:00:00.201045
# episode: 82/2000, episode end value: 1270.55, duration: 0:00:00.213037
# episode: 83/2000, episode end value: 1265.97, duration: 0:00:00.204052
# episode: 84/2000, episode end value: 1273.42, duration: 0:00:00.215042
# episode: 85/2000, episode end value: 1263.48, duration: 0:00:00.199051
# episode: 86/2000, episode end value: 1284.29, duration: 0:00:00.199044
# episode: 87/2000, episode end value: 1272.79, duration: 0:00:00.214042
# episode: 88/2000, episode end value: 1273.24, duration: 0:00:00.213048
# episode: 89/2000, episode end value: 1272.78, duration: 0:00:00.213040
# episode: 90/2000, episode end value: 1280.06, duration: 0:00:00.215062
# episode: 91/2000, episode end value: 1281.92, duration: 0:00:00.212061
# episode: 92/2000, episode end value: 1275.88, duration: 0:00:00.211047
# episode: 93/2000, episode end value: 1291.01, duration: 0:00:00.212041
# episode: 94/2000, episode end value: 1270.33, duration: 0:00:00.215048
# episode: 95/2000, episode end value: 1281.54, duration: 0:00:00.206046
# episode: 96/2000, episode end value: 1267.95, duration: 0:00:00.202065
# episode: 97/2000, episode end value: 1270.86, duration: 0:00:00.214042
# episode: 98/2000, episode end value: 1271.81, duration: 0:00:00.212060
# episode: 99/2000, episode end value: 1272.27, duration: 0:00:00.212041
# episode: 100/2000, episode end value: 1303.31, duration: 0:00:00.199058
# episode: 101/2000, episode end value: 1293.13, duration: 0:00:00.193056
# episode: 102/2000, episode end value: 1279.79, duration: 0:00:00.209027
# episode: 103/2000, episode end value: 1273.35, duration: 0:00:00.211060
# episode: 104/2000, episode end value: 1278.49, duration: 0:00:00.213048
# episode: 105/2000, episode end value: 1272.07, duration: 0:00:00.203052
# episode: 106/2000, episode end value: 1286.17, duration: 0:00:00.213042
# episode: 107/2000, episode end value: 1263.89, duration: 0:00:00.202051
# episode: 108/2000, episode end value: 1284.85, duration: 0:00:00.195044
# episode: 109/2000, episode end value: 1267.52, duration: 0:00:00.211047
# episode: 110/2000, episode end value: 1282.77, duration: 0:00:00.198044
# episode: 111/2000, episode end value: 1282.05, duration: 0:00:00.209047
# episode: 112/2000, episode end value: 1265.88, duration: 0:00:00.194024
# episode: 113/2000, episode end value: 1267.25, duration: 0:00:00.203043
# episode: 114/2000, episode end value: 1270.19, duration: 0:00:00.193063
# episode: 115/2000, episode end value: 1262.97, duration: 0:00:00.195044
# episode: 116/2000, episode end value: 1265.82, duration: 0:00:00.201045
# episode: 117/2000, episode end value: 1307.20, duration: 0:00:00.216035
# episode: 118/2000, episode end value: 1271.68, duration: 0:00:00.204039
# episode: 119/2000, episode end value: 1296.36, duration: 0:00:00.207046
# episode: 120/2000, episode end value: 1286.67, duration: 0:00:00.202052
# episode: 121/2000, episode end value: 1285.64, duration: 0:00:00.200051
# episode: 122/2000, episode end value: 1282.34, duration: 0:00:00.206033
# episode: 123/2000, episode end value: 1272.67, duration: 0:00:00.200041
# episode: 124/2000, episode end value: 1281.06, duration: 0:00:00.196064
# episode: 125/2000, episode end value: 1284.07, duration: 0:00:00.196038
# episode: 126/2000, episode end value: 1264.21, duration: 0:00:00.199051
# episode: 127/2000, episode end value: 1286.70, duration: 0:00:00.200045
# episode: 128/2000, episode end value: 1282.32, duration: 0:00:00.213041
# episode: 129/2000, episode end value: 1268.04, duration: 0:00:00.205053
# episode: 130/2000, episode end value: 1283.06, duration: 0:00:00.198050
# episode: 131/2000, episode end value: 1274.45, duration: 0:00:00.212016
# episode: 132/2000, episode end value: 1272.90, duration: 0:00:00.213062
# episode: 133/2000, episode end value: 1271.92, duration: 0:00:00.214042
# episode: 134/2000, episode end value: 1288.78, duration: 0:00:00.214054
# episode: 135/2000, episode end value: 1270.89, duration: 0:00:00.209046
# episode: 136/2000, episode end value: 1276.98, duration: 0:00:00.199058
# episode: 137/2000, episode end value: 1255.08, duration: 0:00:00.194031
# episode: 138/2000, episode end value: 1271.48, duration: 0:00:00.203027
# episode: 139/2000, episode end value: 1263.24, duration: 0:00:00.208041
# episode: 140/2000, episode end value: 1273.24, duration: 0:00:00.200051
# episode: 141/2000, episode end value: 1265.71, duration: 0:00:00.213041
# episode: 142/2000, episode end value: 1279.54, duration: 0:00:00.206052
# episode: 143/2000, episode end value: 1265.52, duration: 0:00:00.214042
# episode: 144/2000, episode end value: 1273.64, duration: 0:00:00.213048
# episode: 145/2000, episode end value: 1273.84, duration: 0:00:00.211054
# episode: 146/2000, episode end value: 1274.94, duration: 0:00:00.205985
# episode: 147/2000, episode end value: 1276.80, duration: 0:00:00.197059
# episode: 148/2000, episode end value: 1283.21, duration: 0:00:00.196047
# episode: 149/2000, episode end value: 1271.30, duration: 0:00:00.204034
# episode: 150/2000, episode end value: 1287.71, duration: 0:00:00.198055
# episode: 151/2000, episode end value: 1276.21, duration: 0:00:00.212041
# episode: 152/2000, episode end value: 1279.81, duration: 0:00:00.215048
# episode: 153/2000, episode end value: 1279.23, duration: 0:00:00.212066
# episode: 154/2000, episode end value: 1265.83, duration: 0:00:00.196028
# episode: 155/2000, episode end value: 1272.77, duration: 0:00:00.196056
# episode: 156/2000, episode end value: 1298.53, duration: 0:00:00.201045
# episode: 157/2000, episode end value: 1270.05, duration: 0:00:00.199044
# episode: 158/2000, episode end value: 1283.75, duration: 0:00:00.195044
# episode: 159/2000, episode end value: 1272.33, duration: 0:00:00.212048
# episode: 160/2000, episode end value: 1282.02, duration: 0:00:00.215048
# episode: 161/2000, episode end value: 1285.59, duration: 0:00:00.210046
# episode: 162/2000, episode end value: 1276.27, duration: 0:00:00.198050
# episode: 163/2000, episode end value: 1280.69, duration: 0:00:00.205046
# episode: 164/2000, episode end value: 1288.44, duration: 0:00:00.199044
# episode: 165/2000, episode end value: 1274.99, duration: 0:00:00.195044
# episode: 166/2000, episode end value: 1277.53, duration: 0:00:00.206057
# episode: 167/2000, episode end value: 1272.19, duration: 0:00:00.200026
# episode: 168/2000, episode end value: 1284.10, duration: 0:00:00.216042
# episode: 169/2000, episode end value: 1282.94, duration: 0:00:00.198044
# episode: 170/2000, episode end value: 1269.25, duration: 0:00:00.211041
# episode: 171/2000, episode end value: 1285.30, duration: 0:00:00.214048
# episode: 172/2000, episode end value: 1283.04, duration: 0:00:00.218049
# episode: 173/2000, episode end value: 1263.15, duration: 0:00:00.206059
# episode: 174/2000, episode end value: 1266.81, duration: 0:00:00.210046
# episode: 175/2000, episode end value: 1270.62, duration: 0:00:00.215043
# episode: 176/2000, episode end value: 1267.30, duration: 0:00:00.196050
# episode: 177/2000, episode end value: 1283.04, duration: 0:00:00.215042
# episode: 178/2000, episode end value: 1279.02, duration: 0:00:00.214042
# episode: 179/2000, episode end value: 1282.90, duration: 0:00:00.197044
# episode: 180/2000, episode end value: 1280.12, duration: 0:00:00.208937
# episode: 181/2000, episode end value: 1264.49, duration: 0:00:00.202039
# episode: 182/2000, episode end value: 1281.20, duration: 0:00:00.205058
# episode: 183/2000, episode end value: 1283.96, duration: 0:00:00.211041
# episode: 184/2000, episode end value: 1282.87, duration: 0:00:00.197044
# episode: 185/2000, episode end value: 1283.85, duration: 0:00:00.207040
# episode: 186/2000, episode end value: 1286.24, duration: 0:00:00.211047
# episode: 187/2000, episode end value: 1292.38, duration: 0:00:00.201053
# episode: 188/2000, episode end value: 1304.99, duration: 0:00:00.213047
# episode: 189/2000, episode end value: 1262.72, duration: 0:00:00.205046
# episode: 190/2000, episode end value: 1264.55, duration: 0:00:00.206046
# episode: 191/2000, episode end value: 1265.41, duration: 0:00:00.208047
# episode: 192/2000, episode end value: 1267.36, duration: 0:00:00.208053
# episode: 193/2000, episode end value: 1283.58, duration: 0:00:00.195037
# episode: 194/2000, episode end value: 1282.36, duration: 0:00:00.200052
# episode: 195/2000, episode end value: 1285.36, duration: 0:00:00.193030
# episode: 196/2000, episode end value: 1283.44, duration: 0:00:00.201052
# episode: 197/2000, episode end value: 1284.06, duration: 0:00:00.208033
# episode: 198/2000, episode end value: 1272.37, duration: 0:00:00.194063
# episode: 199/2000, episode end value: 1281.81, duration: 0:00:00.203038
# episode: 200/2000, episode end value: 1271.93, duration: 0:00:00.205065
# episode: 201/2000, episode end value: 1290.27, duration: 0:00:00.201065
# episode: 202/2000, episode end value: 1270.18, duration: 0:00:00.195043
# episode: 203/2000, episode end value: 1284.95, duration: 0:00:00.206047
# episode: 204/2000, episode end value: 1288.13, duration: 0:00:00.199057
# episode: 205/2000, episode end value: 1275.50, duration: 0:00:00.208047
# episode: 206/2000, episode end value: 1269.91, duration: 0:00:00.204038
# episode: 207/2000, episode end value: 1282.91, duration: 0:00:00.196062
# episode: 208/2000, episode end value: 1292.55, duration: 0:00:00.212041
# episode: 209/2000, episode end value: 1282.17, duration: 0:00:00.211047
# episode: 210/2000, episode end value: 1270.30, duration: 0:00:00.213061
# episode: 211/2000, episode end value: 1287.32, duration: 0:00:00.199051
# episode: 212/2000, episode end value: 1264.81, duration: 0:00:00.211044
# episode: 213/2000, episode end value: 1271.83, duration: 0:00:00.217048
# episode: 214/2000, episode end value: 1276.07, duration: 0:00:00.215034
# episode: 215/2000, episode end value: 1272.94, duration: 0:00:00.216063
# episode: 216/2000, episode end value: 1287.49, duration: 0:00:00.202051
# episode: 217/2000, episode end value: 1293.68, duration: 0:00:00.212048
# episode: 218/2000, episode end value: 1282.00, duration: 0:00:00.205040
# episode: 219/2000, episode end value: 1284.17, duration: 0:00:00.201039
# episode: 220/2000, episode end value: 1283.29, duration: 0:00:00.196063
# episode: 221/2000, episode end value: 1291.51, duration: 0:00:00.199024
# episode: 222/2000, episode end value: 1273.54, duration: 0:00:00.202053
# episode: 223/2000, episode end value: 1289.71, duration: 0:00:00.197987
# episode: 224/2000, episode end value: 1268.53, duration: 0:00:00.209034
# episode: 225/2000, episode end value: 1278.09, duration: 0:00:00.199041
# episode: 226/2000, episode end value: 1289.48, duration: 0:00:00.205044
# episode: 227/2000, episode end value: 1276.14, duration: 0:00:00.201039
# episode: 228/2000, episode end value: 1268.25, duration: 0:00:00.201045
# episode: 229/2000, episode end value: 1271.37, duration: 0:00:00.213042
# episode: 230/2000, episode end value: 1297.59, duration: 0:00:00.204046
# episode: 231/2000, episode end value: 1287.65, duration: 0:00:00.206053
# episode: 232/2000, episode end value: 1285.35, duration: 0:00:00.195044
# episode: 233/2000, episode end value: 1287.09, duration: 0:00:00.198057
# episode: 234/2000, episode end value: 1263.57, duration: 0:00:00.197044
# episode: 235/2000, episode end value: 1271.05, duration: 0:00:00.192043
# episode: 236/2000, episode end value: 1266.80, duration: 0:00:00.209040
# episode: 237/2000, episode end value: 1270.85, duration: 0:00:00.200065
# episode: 238/2000, episode end value: 1266.19, duration: 0:00:00.204045
# episode: 239/2000, episode end value: 1270.31, duration: 0:00:00.205046
# episode: 240/2000, episode end value: 1267.09, duration: 0:00:00.214054
# episode: 241/2000, episode end value: 1287.48, duration: 0:00:00.197032
# episode: 242/2000, episode end value: 1270.32, duration: 0:00:00.198057
# episode: 243/2000, episode end value: 1271.50, duration: 0:00:00.207040
# episode: 244/2000, episode end value: 1273.70, duration: 0:00:00.199051
# episode: 245/2000, episode end value: 1268.34, duration: 0:00:00.210042
# episode: 246/2000, episode end value: 1277.67, duration: 0:00:00.197044
# episode: 247/2000, episode end value: 1287.78, duration: 0:00:00.211041
# episode: 248/2000, episode end value: 1263.09, duration: 0:00:00.206052
# episode: 249/2000, episode end value: 1263.92, duration: 0:00:00.200051
# episode: 250/2000, episode end value: 1263.77, duration: 0:00:00.211047
# episode: 251/2000, episode end value: 1267.86, duration: 0:00:00.212054
# episode: 252/2000, episode end value: 1297.16, duration: 0:00:00.197038
# episode: 253/2000, episode end value: 1274.30, duration: 0:00:00.204046
# episode: 254/2000, episode end value: 1283.43, duration: 0:00:00.203058
# episode: 255/2000, episode end value: 1267.20, duration: 0:00:00.202051
# episode: 256/2000, episode end value: 1280.97, duration: 0:00:00.196044
# episode: 257/2000, episode end value: 1271.04, duration: 0:00:00.197038
# episode: 258/2000, episode end value: 1274.67, duration: 0:00:00.195035
# episode: 259/2000, episode end value: 1269.92, duration: 0:00:00.200045
# episode: 260/2000, episode end value: 1283.19, duration: 0:00:00.213029
# episode: 261/2000, episode end value: 1301.75, duration: 0:00:00.212054
# episode: 262/2000, episode end value: 1264.43, duration: 0:00:00.199044
# episode: 263/2000, episode end value: 1269.48, duration: 0:00:00.204064
# episode: 264/2000, episode end value: 1268.94, duration: 0:00:00.203032
# episode: 265/2000, episode end value: 1270.14, duration: 0:00:00.212035
# episode: 266/2000, episode end value: 1260.76, duration: 0:00:00.202032
# episode: 267/2000, episode end value: 1269.99, duration: 0:00:00.211053
# episode: 268/2000, episode end value: 1271.26, duration: 0:00:00.208041
# episode: 269/2000, episode end value: 1261.62, duration: 0:00:00.203038
# episode: 270/2000, episode end value: 1282.28, duration: 0:00:00.212055
# episode: 271/2000, episode end value: 1271.14, duration: 0:00:00.209047
# episode: 272/2000, episode end value: 1286.05, duration: 0:00:00.204033
# episode: 273/2000, episode end value: 1290.14, duration: 0:00:00.196050
# episode: 274/2000, episode end value: 1296.03, duration: 0:00:00.200959
# episode: 275/2000, episode end value: 1266.60, duration: 0:00:00.193056
# episode: 276/2000, episode end value: 1272.81, duration: 0:00:00.199045
# episode: 277/2000, episode end value: 1283.17, duration: 0:00:00.201033
# episode: 278/2000, episode end value: 1271.80, duration: 0:00:00.214992
# episode: 279/2000, episode end value: 1269.82, duration: 0:00:00.204033
# episode: 280/2000, episode end value: 1290.72, duration: 0:00:00.202039
# episode: 281/2000, episode end value: 1285.48, duration: 0:00:00.197057
# episode: 282/2000, episode end value: 1282.72, duration: 0:00:00.198038
# episode: 283/2000, episode end value: 1278.03, duration: 0:00:00.198038
# episode: 284/2000, episode end value: 1289.64, duration: 0:00:00.206038
# episode: 285/2000, episode end value: 1268.21, duration: 0:00:00.195053
# episode: 286/2000, episode end value: 1297.70, duration: 0:00:00.205053
# episode: 287/2000, episode end value: 1259.28, duration: 0:00:00.199058
# episode: 288/2000, episode end value: 1285.24, duration: 0:00:00.195064
# episode: 289/2000, episode end value: 1273.45, duration: 0:00:00.204041
# episode: 290/2000, episode end value: 1277.10, duration: 0:00:00.204065
# episode: 291/2000, episode end value: 1290.03, duration: 0:00:00.200024
# episode: 292/2000, episode end value: 1274.40, duration: 0:00:00.199052
# episode: 293/2000, episode end value: 1288.74, duration: 0:00:00.196038
# episode: 294/2000, episode end value: 1280.68, duration: 0:00:00.213028
# episode: 295/2000, episode end value: 1297.35, duration: 0:00:00.200052
# episode: 296/2000, episode end value: 1285.58, duration: 0:00:00.212048
# episode: 297/2000, episode end value: 1268.30, duration: 0:00:00.211061
# episode: 298/2000, episode end value: 1282.04, duration: 0:00:00.215048
# episode: 299/2000, episode end value: 1268.97, duration: 0:00:00.198038
# episode: 300/2000, episode end value: 1283.10, duration: 0:00:00.205059
# episode: 301/2000, episode end value: 1269.00, duration: 0:00:00.203045
# episode: 302/2000, episode end value: 1266.23, duration: 0:00:00.209041
# episode: 303/2000, episode end value: 1281.67, duration: 0:00:00.214048
# episode: 304/2000, episode end value: 1286.52, duration: 0:00:00.203059
# episode: 305/2000, episode end value: 1282.79, duration: 0:00:00.205058
# episode: 306/2000, episode end value: 1283.64, duration: 0:00:00.209014
# episode: 307/2000, episode end value: 1282.93, duration: 0:00:00.204053
# episode: 308/2000, episode end value: 1276.44, duration: 0:00:00.204039
# episode: 309/2000, episode end value: 1283.18, duration: 0:00:00.198065
# episode: 310/2000, episode end value: 1287.94, duration: 0:00:00.207046
# episode: 311/2000, episode end value: 1282.09, duration: 0:00:00.211048
# episode: 312/2000, episode end value: 1276.23, duration: 0:00:00.214048
# episode: 313/2000, episode end value: 1271.25, duration: 0:00:00.215048
# episode: 314/2000, episode end value: 1283.60, duration: 0:00:00.208053
# episode: 315/2000, episode end value: 1267.94, duration: 0:00:00.213027
# episode: 316/2000, episode end value: 1270.58, duration: 0:00:00.208052
# episode: 317/2000, episode end value: 1265.26, duration: 0:00:00.209066
# episode: 318/2000, episode end value: 1273.53, duration: 0:00:00.214030
# episode: 319/2000, episode end value: 1281.96, duration: 0:00:00.211055
# episode: 320/2000, episode end value: 1267.17, duration: 0:00:00.200045
# episode: 321/2000, episode end value: 1267.88, duration: 0:00:00.200044
# episode: 322/2000, episode end value: 1294.07, duration: 0:00:00.215060
# episode: 323/2000, episode end value: 1289.94, duration: 0:00:00.208040
# episode: 324/2000, episode end value: 1287.07, duration: 0:00:00.215042
# episode: 325/2000, episode end value: 1275.32, duration: 0:00:00.199031
# episode: 326/2000, episode end value: 1271.25, duration: 0:00:00.216062
# episode: 327/2000, episode end value: 1283.02, duration: 0:00:00.207053
# episode: 328/2000, episode end value: 1284.12, duration: 0:00:00.198058
# episode: 329/2000, episode end value: 1257.02, duration: 0:00:00.211034
# episode: 330/2000, episode end value: 1287.79, duration: 0:00:00.204052
# episode: 331/2000, episode end value: 1266.64, duration: 0:00:00.216042
# episode: 332/2000, episode end value: 1270.14, duration: 0:00:00.217056
# episode: 333/2000, episode end value: 1283.15, duration: 0:00:00.217049
# episode: 334/2000, episode end value: 1279.40, duration: 0:00:00.205052
# episode: 335/2000, episode end value: 1272.96, duration: 0:00:00.204046
# episode: 336/2000, episode end value: 1281.73, duration: 0:00:00.200039
# episode: 337/2000, episode end value: 1282.35, duration: 0:00:00.220049
# episode: 338/2000, episode end value: 1290.97, duration: 0:00:00.218048
# episode: 339/2000, episode end value: 1279.50, duration: 0:00:00.217061
# episode: 340/2000, episode end value: 1300.96, duration: 0:00:00.200051
# episode: 341/2000, episode end value: 1286.91, duration: 0:00:00.210061
# episode: 342/2000, episode end value: 1267.49, duration: 0:00:00.210047
# episode: 343/2000, episode end value: 1270.71, duration: 0:00:00.218043
# episode: 344/2000, episode end value: 1272.89, duration: 0:00:00.206056
# episode: 345/2000, episode end value: 1268.40, duration: 0:00:00.218049
# episode: 346/2000, episode end value: 1282.08, duration: 0:00:00.219043
# episode: 347/2000, episode end value: 1267.91, duration: 0:00:00.220048
# episode: 348/2000, episode end value: 1267.40, duration: 0:00:00.204052
# episode: 349/2000, episode end value: 1283.92, duration: 0:00:00.202046
# episode: 350/2000, episode end value: 1265.06, duration: 0:00:00.199004
# episode: 351/2000, episode end value: 1270.87, duration: 0:00:00.217042
# episode: 352/2000, episode end value: 1276.79, duration: 0:00:00.203052
# episode: 353/2000, episode end value: 1286.57, duration: 0:00:00.204046
# episode: 354/2000, episode end value: 1263.13, duration: 0:00:00.205046
# episode: 355/2000, episode end value: 1284.08, duration: 0:00:00.206040
# episode: 356/2000, episode end value: 1289.10, duration: 0:00:00.208047
# episode: 357/2000, episode end value: 1273.89, duration: 0:00:00.209040
# episode: 358/2000, episode end value: 1267.97, duration: 0:00:00.205040
# episode: 359/2000, episode end value: 1283.81, duration: 0:00:00.212041
# episode: 360/2000, episode end value: 1284.91, duration: 0:00:00.201065
# episode: 361/2000, episode end value: 1259.11, duration: 0:00:00.205034
# episode: 362/2000, episode end value: 1284.95, duration: 0:00:00.212054
# episode: 363/2000, episode end value: 1283.51, duration: 0:00:00.205052
# episode: 364/2000, episode end value: 1270.28, duration: 0:00:00.213042
# episode: 365/2000, episode end value: 1281.90, duration: 0:00:00.214055
# episode: 366/2000, episode end value: 1288.95, duration: 0:00:00.200051
# episode: 367/2000, episode end value: 1272.11, duration: 0:00:00.198040
# episode: 368/2000, episode end value: 1290.94, duration: 0:00:00.207052
# episode: 369/2000, episode end value: 1281.71, duration: 0:00:00.202033
# episode: 370/2000, episode end value: 1290.31, duration: 0:00:00.198057
# episode: 371/2000, episode end value: 1263.97, duration: 0:00:00.211035
# episode: 372/2000, episode end value: 1291.16, duration: 0:00:00.208034
# episode: 373/2000, episode end value: 1263.49, duration: 0:00:00.201052
# episode: 374/2000, episode end value: 1271.51, duration: 0:00:00.219056
# episode: 375/2000, episode end value: 1283.07, duration: 0:00:00.213054
# episode: 376/2000, episode end value: 1281.91, duration: 0:00:00.207052
# episode: 377/2000, episode end value: 1282.10, duration: 0:00:00.199044
# episode: 378/2000, episode end value: 1274.82, duration: 0:00:00.213048
# episode: 379/2000, episode end value: 1265.00, duration: 0:00:00.207047
# episode: 380/2000, episode end value: 1283.28, duration: 0:00:00.210034
# episode: 381/2000, episode end value: 1281.71, duration: 0:00:00.208066
# episode: 382/2000, episode end value: 1260.30, duration: 0:00:00.213042
# episode: 383/2000, episode end value: 1281.78, duration: 0:00:00.213049
# episode: 384/2000, episode end value: 1293.93, duration: 0:00:00.213058
# episode: 385/2000, episode end value: 1269.48, duration: 0:00:00.213047
# episode: 386/2000, episode end value: 1269.34, duration: 0:00:00.196064
# episode: 387/2000, episode end value: 1278.38, duration: 0:00:00.206058
# episode: 388/2000, episode end value: 1291.89, duration: 0:00:00.199032
# episode: 389/2000, episode end value: 1290.29, duration: 0:00:00.194036
# episode: 390/2000, episode end value: 1289.42, duration: 0:00:00.207046
# episode: 391/2000, episode end value: 1275.19, duration: 0:00:00.214048
# episode: 392/2000, episode end value: 1271.60, duration: 0:00:00.219049
# episode: 393/2000, episode end value: 1294.39, duration: 0:00:00.215042
# episode: 394/2000, episode end value: 1267.86, duration: 0:00:00.210047
# episode: 395/2000, episode end value: 1272.52, duration: 0:00:00.206051
# episode: 396/2000, episode end value: 1270.39, duration: 0:00:00.216054
# episode: 397/2000, episode end value: 1271.45, duration: 0:00:00.207040
# episode: 398/2000, episode end value: 1267.30, duration: 0:00:00.203052
# episode: 399/2000, episode end value: 1264.90, duration: 0:00:00.214055
# episode: 400/2000, episode end value: 1284.92, duration: 0:00:00.207052
# episode: 401/2000, episode end value: 1269.87, duration: 0:00:00.214035
# episode: 402/2000, episode end value: 1281.60, duration: 0:00:00.208053
# episode: 403/2000, episode end value: 1282.13, duration: 0:00:00.215042
# episode: 404/2000, episode end value: 1281.32, duration: 0:00:00.197050
# episode: 405/2000, episode end value: 1262.07, duration: 0:00:00.204989
# episode: 406/2000, episode end value: 1289.00, duration: 0:00:00.211048
# episode: 407/2000, episode end value: 1286.88, duration: 0:00:00.215042
# episode: 408/2000, episode end value: 1270.91, duration: 0:00:00.212035
# episode: 409/2000, episode end value: 1260.40, duration: 0:00:00.208045
# episode: 410/2000, episode end value: 1289.27, duration: 0:00:00.199064
# episode: 411/2000, episode end value: 1281.31, duration: 0:00:00.207027
# episode: 412/2000, episode end value: 1280.28, duration: 0:00:00.206390
# episode: 413/2000, episode end value: 1270.22, duration: 0:00:00.207042
# episode: 414/2000, episode end value: 1282.34, duration: 0:00:00.207051
# episode: 415/2000, episode end value: 1274.56, duration: 0:00:00.200039
# episode: 416/2000, episode end value: 1284.80, duration: 0:00:00.205051
# episode: 417/2000, episode end value: 1282.05, duration: 0:00:00.202043
# episode: 418/2000, episode end value: 1267.76, duration: 0:00:00.202045
# episode: 419/2000, episode end value: 1269.11, duration: 0:00:00.207046
# episode: 420/2000, episode end value: 1282.33, duration: 0:00:00.205046
# episode: 421/2000, episode end value: 1271.92, duration: 0:00:00.199043
# episode: 422/2000, episode end value: 1276.19, duration: 0:00:00.210047
# episode: 423/2000, episode end value: 1270.84, duration: 0:00:00.208045
# episode: 424/2000, episode end value: 1289.35, duration: 0:00:00.201058
# episode: 425/2000, episode end value: 1263.64, duration: 0:00:00.196030
# episode: 426/2000, episode end value: 1268.37, duration: 0:00:00.212047
# episode: 427/2000, episode end value: 1269.77, duration: 0:00:00.215048
# episode: 428/2000, episode end value: 1272.95, duration: 0:00:00.206046
# episode: 429/2000, episode end value: 1283.57, duration: 0:00:00.215048
# episode: 430/2000, episode end value: 1264.53, duration: 0:00:00.214048
# episode: 431/2000, episode end value: 1278.58, duration: 0:00:00.217048
# episode: 432/2000, episode end value: 1280.58, duration: 0:00:00.210047
# episode: 433/2000, episode end value: 1259.60, duration: 0:00:00.201045
# episode: 434/2000, episode end value: 1272.40, duration: 0:00:00.206048
# episode: 435/2000, episode end value: 1271.41, duration: 0:00:00.209045
# episode: 436/2000, episode end value: 1264.43, duration: 0:00:00.211044
# episode: 437/2000, episode end value: 1288.56, duration: 0:00:00.208046
# episode: 438/2000, episode end value: 1284.46, duration: 0:00:00.201039
# episode: 439/2000, episode end value: 1300.30, duration: 0:00:00.204057
# episode: 440/2000, episode end value: 1270.52, duration: 0:00:00.208044
# episode: 441/2000, episode end value: 1289.44, duration: 0:00:00.215048
# episode: 442/2000, episode end value: 1270.41, duration: 0:00:00.197550
# episode: 443/2000, episode end value: 1271.93, duration: 0:00:00.212047
# episode: 444/2000, episode end value: 1266.90, duration: 0:00:00.218066
# episode: 445/2000, episode end value: 1282.79, duration: 0:00:00.198049
# episode: 446/2000, episode end value: 1278.61, duration: 0:00:00.209047
# episode: 447/2000, episode end value: 1268.14, duration: 0:00:00.210027
# episode: 448/2000, episode end value: 1287.33, duration: 0:00:00.201059
# episode: 449/2000, episode end value: 1271.42, duration: 0:00:00.201052
# episode: 450/2000, episode end value: 1268.53, duration: 0:00:00.199058
# episode: 451/2000, episode end value: 1274.46, duration: 0:00:00.206046
# episode: 452/2000, episode end value: 1284.03, duration: 0:00:00.198039
# episode: 453/2000, episode end value: 1283.67, duration: 0:00:00.201038
# episode: 454/2000, episode end value: 1272.07, duration: 0:00:00.199044
# episode: 455/2000, episode end value: 1280.66, duration: 0:00:00.212054
# episode: 456/2000, episode end value: 1271.38, duration: 0:00:00.205043
# episode: 457/2000, episode end value: 1269.98, duration: 0:00:00.206045
# episode: 458/2000, episode end value: 1277.48, duration: 0:00:00.199049
# episode: 459/2000, episode end value: 1282.20, duration: 0:00:00.200045
# episode: 460/2000, episode end value: 1265.32, duration: 0:00:00.197044
# episode: 461/2000, episode end value: 1289.01, duration: 0:00:00.211054
# episode: 462/2000, episode end value: 1282.34, duration: 0:00:00.199050
# episode: 463/2000, episode end value: 1265.87, duration: 0:00:00.198045
# episode: 464/2000, episode end value: 1271.05, duration: 0:00:00.198044
# episode: 465/2000, episode end value: 1284.59, duration: 0:00:00.208047
# episode: 466/2000, episode end value: 1288.15, duration: 0:00:00.202033
# episode: 467/2000, episode end value: 1280.09, duration: 0:00:00.210053
# episode: 468/2000, episode end value: 1282.62, duration: 0:00:00.208048
# episode: 469/2000, episode end value: 1289.58, duration: 0:00:00.201049
# episode: 470/2000, episode end value: 1269.99, duration: 0:00:00.204033
# episode: 471/2000, episode end value: 1272.80, duration: 0:00:00.201052
# episode: 472/2000, episode end value: 1273.73, duration: 0:00:00.202045
# episode: 473/2000, episode end value: 1274.08, duration: 0:00:00.198044
# episode: 474/2000, episode end value: 1264.40, duration: 0:00:00.206040
# episode: 475/2000, episode end value: 1265.18, duration: 0:00:00.204997
# episode: 476/2000, episode end value: 1290.21, duration: 0:00:00.211067
# episode: 477/2000, episode end value: 1272.47, duration: 0:00:00.202027
# episode: 478/2000, episode end value: 1270.25, duration: 0:00:00.209052
# episode: 479/2000, episode end value: 1283.81, duration: 0:00:00.204045
# episode: 480/2000, episode end value: 1283.98, duration: 0:00:00.198051
# episode: 481/2000, episode end value: 1285.88, duration: 0:00:00.211041
# episode: 482/2000, episode end value: 1297.36, duration: 0:00:00.195049
# episode: 483/2000, episode end value: 1281.71, duration: 0:00:00.209047
# episode: 484/2000, episode end value: 1272.10, duration: 0:00:00.201045
# episode: 485/2000, episode end value: 1283.70, duration: 0:00:00.209041
# episode: 486/2000, episode end value: 1266.82, duration: 0:00:00.198030
# episode: 487/2000, episode end value: 1285.43, duration: 0:00:00.215063
# episode: 488/2000, episode end value: 1270.11, duration: 0:00:00.217047
# episode: 489/2000, episode end value: 1266.90, duration: 0:00:00.200118
# episode: 490/2000, episode end value: 1283.07, duration: 0:00:00.214042
# episode: 491/2000, episode end value: 1267.27, duration: 0:00:00.208064
# episode: 492/2000, episode end value: 1269.01, duration: 0:00:00.214037
# episode: 493/2000, episode end value: 1272.73, duration: 0:00:00.199051
# episode: 494/2000, episode end value: 1274.33, duration: 0:00:00.202045
# episode: 495/2000, episode end value: 1264.90, duration: 0:00:00.217042
# episode: 496/2000, episode end value: 1286.79, duration: 0:00:00.218055
# episode: 497/2000, episode end value: 1278.62, duration: 0:00:00.197038
# episode: 498/2000, episode end value: 1270.40, duration: 0:00:00.213025
# episode: 499/2000, episode end value: 1269.20, duration: 0:00:00.205040
# episode: 500/2000, episode end value: 1282.79, duration: 0:00:00.204018
# episode: 501/2000, episode end value: 1288.81, duration: 0:00:00.217048
# episode: 502/2000, episode end value: 1290.75, duration: 0:00:00.214054
# episode: 503/2000, episode end value: 1279.92, duration: 0:00:00.213042
# episode: 504/2000, episode end value: 1268.09, duration: 0:00:00.205052
# episode: 505/2000, episode end value: 1282.77, duration: 0:00:00.201045
# episode: 506/2000, episode end value: 1271.83, duration: 0:00:00.218042
# episode: 507/2000, episode end value: 1266.60, duration: 0:00:00.215055
# episode: 508/2000, episode end value: 1269.72, duration: 0:00:00.201045
# episode: 509/2000, episode end value: 1281.48, duration: 0:00:00.209051
# episode: 510/2000, episode end value: 1258.25, duration: 0:00:00.203052
# episode: 511/2000, episode end value: 1288.62, duration: 0:00:00.204046
# episode: 512/2000, episode end value: 1295.74, duration: 0:00:00.201045
# episode: 513/2000, episode end value: 1266.31, duration: 0:00:00.196032
# episode: 514/2000, episode end value: 1282.81, duration: 0:00:00.202052
# episode: 515/2000, episode end value: 1281.96, duration: 0:00:00.213047
# episode: 516/2000, episode end value: 1273.56, duration: 0:00:00.221050
# episode: 517/2000, episode end value: 1269.35, duration: 0:00:00.210047
# episode: 518/2000, episode end value: 1283.40, duration: 0:00:00.211047
# episode: 519/2000, episode end value: 1282.57, duration: 0:00:00.208040
# episode: 520/2000, episode end value: 1303.61, duration: 0:00:00.200051
# episode: 521/2000, episode end value: 1289.18, duration: 0:00:00.204052
# episode: 522/2000, episode end value: 1289.76, duration: 0:00:00.205033
# episode: 523/2000, episode end value: 1289.12, duration: 0:00:00.207047
# episode: 524/2000, episode end value: 1269.71, duration: 0:00:00.217048
# episode: 525/2000, episode end value: 1262.19, duration: 0:00:00.205059
# episode: 526/2000, episode end value: 1274.38, duration: 0:00:00.211058
# episode: 527/2000, episode end value: 1269.00, duration: 0:00:00.206040
# episode: 528/2000, episode end value: 1267.34, duration: 0:00:00.201039
# episode: 529/2000, episode end value: 1265.66, duration: 0:00:00.217042
# episode: 530/2000, episode end value: 1270.24, duration: 0:00:00.213048
# episode: 531/2000, episode end value: 1265.02, duration: 0:00:00.198049
# episode: 532/2000, episode end value: 1287.40, duration: 0:00:00.199044
# episode: 533/2000, episode end value: 1287.68, duration: 0:00:00.204948
# episode: 534/2000, episode end value: 1288.11, duration: 0:00:00.208046
# episode: 535/2000, episode end value: 1287.55, duration: 0:00:00.200042
# episode: 536/2000, episode end value: 1277.49, duration: 0:00:00.202050
# episode: 537/2000, episode end value: 1283.43, duration: 0:00:00.208043
# episode: 538/2000, episode end value: 1285.54, duration: 0:00:00.203059
# episode: 539/2000, episode end value: 1265.05, duration: 0:00:00.217049
# episode: 540/2000, episode end value: 1294.13, duration: 0:00:00.212054
# episode: 541/2000, episode end value: 1269.88, duration: 0:00:00.196043
# episode: 542/2000, episode end value: 1268.68, duration: 0:00:00.201045
# episode: 543/2000, episode end value: 1273.84, duration: 0:00:00.208040
# episode: 544/2000, episode end value: 1271.19, duration: 0:00:00.201050
# episode: 545/2000, episode end value: 1280.05, duration: 0:00:00.200020
# episode: 546/2000, episode end value: 1269.82, duration: 0:00:00.209041
# episode: 547/2000, episode end value: 1291.21, duration: 0:00:00.200045
# episode: 548/2000, episode end value: 1262.42, duration: 0:00:00.202034
# episode: 549/2000, episode end value: 1274.90, duration: 0:00:00.203057
# episode: 550/2000, episode end value: 1282.41, duration: 0:00:00.210047
# episode: 551/2000, episode end value: 1272.87, duration: 0:00:00.215055
# episode: 552/2000, episode end value: 1285.92, duration: 0:00:00.212047
# episode: 553/2000, episode end value: 1285.28, duration: 0:00:00.201045
# episode: 554/2000, episode end value: 1283.60, duration: 0:00:00.213048
# episode: 555/2000, episode end value: 1269.97, duration: 0:00:00.209055
# episode: 556/2000, episode end value: 1281.31, duration: 0:00:00.207045
# episode: 557/2000, episode end value: 1267.21, duration: 0:00:00.201033
# episode: 558/2000, episode end value: 1284.52, duration: 0:00:00.200066
# episode: 559/2000, episode end value: 1281.45, duration: 0:00:00.202045
# episode: 560/2000, episode end value: 1287.87, duration: 0:00:00.207041
# episode: 561/2000, episode end value: 1258.41, duration: 0:00:00.206046
# episode: 562/2000, episode end value: 1270.67, duration: 0:00:00.216048
# episode: 563/2000, episode end value: 1279.29, duration: 0:00:00.202051
# episode: 564/2000, episode end value: 1263.44, duration: 0:00:00.200022
# episode: 565/2000, episode end value: 1280.01, duration: 0:00:00.193044
# episode: 566/2000, episode end value: 1285.47, duration: 0:00:00.206950
# episode: 567/2000, episode end value: 1271.63, duration: 0:00:00.196155
# episode: 568/2000, episode end value: 1273.54, duration: 0:00:00.201045
# episode: 569/2000, episode end value: 1293.42, duration: 0:00:00.214042
# episode: 570/2000, episode end value: 1277.36, duration: 0:00:00.210040
# episode: 571/2000, episode end value: 1280.43, duration: 0:00:00.198044
# episode: 572/2000, episode end value: 1284.72, duration: 0:00:00.213048
# episode: 573/2000, episode end value: 1280.69, duration: 0:00:00.206047
# episode: 574/2000, episode end value: 1276.35, duration: 0:00:00.215049
# episode: 575/2000, episode end value: 1283.06, duration: 0:00:00.210053
# episode: 576/2000, episode end value: 1284.87, duration: 0:00:00.211057
# episode: 577/2000, episode end value: 1268.81, duration: 0:00:00.205058
# episode: 578/2000, episode end value: 1276.93, duration: 0:00:00.200051
# episode: 579/2000, episode end value: 1283.15, duration: 0:00:00.208041
# episode: 580/2000, episode end value: 1297.43, duration: 0:00:00.217043
# episode: 581/2000, episode end value: 1282.35, duration: 0:00:00.199038
# episode: 582/2000, episode end value: 1285.20, duration: 0:00:00.200051
# episode: 583/2000, episode end value: 1278.82, duration: 0:00:00.196050
# episode: 584/2000, episode end value: 1269.13, duration: 0:00:00.217042
# episode: 585/2000, episode end value: 1293.91, duration: 0:00:00.209047
# episode: 586/2000, episode end value: 1281.38, duration: 0:00:00.202045
# episode: 587/2000, episode end value: 1288.34, duration: 0:00:00.205027
# episode: 588/2000, episode end value: 1283.94, duration: 0:00:00.207059
# episode: 589/2000, episode end value: 1295.59, duration: 0:00:00.202032
# episode: 590/2000, episode end value: 1271.01, duration: 0:00:00.210047
# episode: 591/2000, episode end value: 1267.75, duration: 0:00:00.206050
# episode: 592/2000, episode end value: 1283.51, duration: 0:00:00.214042
# episode: 593/2000, episode end value: 1282.15, duration: 0:00:00.203046
# episode: 594/2000, episode end value: 1272.34, duration: 0:00:00.202051
# episode: 595/2000, episode end value: 1278.74, duration: 0:00:00.201029
# episode: 596/2000, episode end value: 1268.29, duration: 0:00:00.204046
# episode: 597/2000, episode end value: 1265.51, duration: 0:00:00.206046
# episode: 598/2000, episode end value: 1266.30, duration: 0:00:00.207039
# episode: 599/2000, episode end value: 1269.86, duration: 0:00:00.205046
# episode: 600/2000, episode end value: 1283.45, duration: 0:00:00.202052
# episode: 601/2000, episode end value: 1262.22, duration: 0:00:00.202028
# episode: 602/2000, episode end value: 1276.74, duration: 0:00:00.220016
# episode: 603/2000, episode end value: 1279.50, duration: 0:00:00.215467
# episode: 604/2000, episode end value: 1265.82, duration: 0:00:00.210053
# episode: 605/2000, episode end value: 1280.15, duration: 0:00:00.204039
# episode: 606/2000, episode end value: 1278.08, duration: 0:00:00.208050
# episode: 607/2000, episode end value: 1281.07, duration: 0:00:00.202045
# episode: 608/2000, episode end value: 1270.19, duration: 0:00:00.204052
# episode: 609/2000, episode end value: 1261.02, duration: 0:00:00.206040
# episode: 610/2000, episode end value: 1263.88, duration: 0:00:00.208047
# episode: 611/2000, episode end value: 1270.41, duration: 0:00:00.214045
# episode: 612/2000, episode end value: 1280.08, duration: 0:00:00.207052
# episode: 613/2000, episode end value: 1265.17, duration: 0:00:00.208040
# episode: 614/2000, episode end value: 1270.17, duration: 0:00:00.210053
# episode: 615/2000, episode end value: 1267.95, duration: 0:00:00.205047
# episode: 616/2000, episode end value: 1285.46, duration: 0:00:00.203263
# episode: 617/2000, episode end value: 1269.68, duration: 0:00:00.200045
# episode: 618/2000, episode end value: 1288.24, duration: 0:00:00.211040
# episode: 619/2000, episode end value: 1276.34, duration: 0:00:00.211048
# episode: 620/2000, episode end value: 1286.39, duration: 0:00:00.211042
# episode: 621/2000, episode end value: 1269.22, duration: 0:00:00.206045
# episode: 622/2000, episode end value: 1285.40, duration: 0:00:00.206052
# episode: 623/2000, episode end value: 1292.10, duration: 0:00:00.218049
# episode: 624/2000, episode end value: 1263.72, duration: 0:00:00.214048
# episode: 625/2000, episode end value: 1280.06, duration: 0:00:00.221050
# episode: 626/2000, episode end value: 1275.40, duration: 0:00:00.204052
# episode: 627/2000, episode end value: 1268.54, duration: 0:00:00.206047
# episode: 628/2000, episode end value: 1276.79, duration: 0:00:00.215042
# episode: 629/2000, episode end value: 1279.93, duration: 0:00:00.221049
# episode: 630/2000, episode end value: 1266.34, duration: 0:00:00.218049
# episode: 631/2000, episode end value: 1266.24, duration: 0:00:00.220050
# episode: 632/2000, episode end value: 1289.23, duration: 0:00:00.222049
# episode: 633/2000, episode end value: 1267.45, duration: 0:00:00.212042
# episode: 634/2000, episode end value: 1283.33, duration: 0:00:00.216054
# episode: 635/2000, episode end value: 1271.01, duration: 0:00:00.215048
# episode: 636/2000, episode end value: 1263.31, duration: 0:00:00.218043
# episode: 637/2000, episode end value: 1270.55, duration: 0:00:00.215048
# episode: 638/2000, episode end value: 1294.18, duration: 0:00:00.217036
# episode: 639/2000, episode end value: 1283.23, duration: 0:00:00.204052
# episode: 640/2000, episode end value: 1263.41, duration: 0:00:00.204039
# episode: 641/2000, episode end value: 1286.93, duration: 0:00:00.206047
# episode: 642/2000, episode end value: 1275.54, duration: 0:00:00.219042
# episode: 643/2000, episode end value: 1268.23, duration: 0:00:00.219055
# episode: 644/2000, episode end value: 1279.37, duration: 0:00:00.220049
# episode: 645/2000, episode end value: 1279.29, duration: 0:00:00.207053
# episode: 646/2000, episode end value: 1267.91, duration: 0:00:00.213042
# episode: 647/2000, episode end value: 1281.21, duration: 0:00:00.215048
# episode: 648/2000, episode end value: 1274.95, duration: 0:00:00.214055
# episode: 649/2000, episode end value: 1297.99, duration: 0:00:00.212035
# episode: 650/2000, episode end value: 1294.73, duration: 0:00:00.204040
# episode: 651/2000, episode end value: 1260.75, duration: 0:00:00.204043
# episode: 652/2000, episode end value: 1273.02, duration: 0:00:00.217043
# episode: 653/2000, episode end value: 1280.83, duration: 0:00:00.216035
# episode: 654/2000, episode end value: 1282.03, duration: 0:00:00.211040
# episode: 655/2000, episode end value: 1296.37, duration: 0:00:00.213048
# episode: 656/2000, episode end value: 1280.90, duration: 0:00:00.211041
# episode: 657/2000, episode end value: 1283.05, duration: 0:00:00.213048
# episode: 658/2000, episode end value: 1274.30, duration: 0:00:00.214048
# episode: 659/2000, episode end value: 1268.64, duration: 0:00:00.210048
# episode: 660/2000, episode end value: 1285.06, duration: 0:00:00.204046
# episode: 661/2000, episode end value: 1283.28, duration: 0:00:00.205046
# episode: 662/2000, episode end value: 1281.78, duration: 0:00:00.212048
# episode: 663/2000, episode end value: 1298.17, duration: 0:00:00.211034
# episode: 664/2000, episode end value: 1278.53, duration: 0:00:00.210050
# episode: 665/2000, episode end value: 1280.16, duration: 0:00:00.215062
# episode: 666/2000, episode end value: 1281.94, duration: 0:00:00.202044
# episode: 667/2000, episode end value: 1278.53, duration: 0:00:00.204057
# ...
# episode: 1510/2000, episode end value: 1280.38, duration: 0:00:00.211049
# episode: 1511/2000, episode end value: 1284.46, duration: 0:00:00.204048
# episode: 1512/2000, episode end value: 1292.68, duration: 0:00:00.202064
# episode: 1513/2000, episode end value: 1288.83, duration: 0:00:00.213037
# episode: 1514/2000, episode end value: 1270.96, duration: 0:00:00.206539
# episode: 1515/2000, episode end value: 1279.06, duration: 0:00:00.201066
# episode: 1516/2000, episode end value: 1279.30, duration: 0:00:00.212046
# episode: 1517/2000, episode end value: 1280.04, duration: 0:00:00.213037
# episode: 1518/2000, episode end value: 1268.51, duration: 0:00:00.209042
# episode: 1519/2000, episode end value: 1283.43, duration: 0:00:00.211064
# episode: 1520/2000, episode end value: 1293.88, duration: 0:00:00.210071
# episode: 1521/2000, episode end value: 1284.56, duration: 0:00:00.209050
# episode: 1522/2000, episode end value: 1289.19, duration: 0:00:00.203050
# episode: 1523/2000, episode end value: 1304.40, duration: 0:00:00.196052
# episode: 1524/2000, episode end value: 1265.01, duration: 0:00:00.192048
# episode: 1525/2000, episode end value: 1285.83, duration: 0:00:00.213041
# episode: 1526/2000, episode end value: 1270.03, duration: 0:00:00.205040
# episode: 1527/2000, episode end value: 1273.84, duration: 0:00:00.207107
# episode: 1528/2000, episode end value: 1283.86, duration: 0:00:00.227354
# episode: 1529/2000, episode end value: 1268.81, duration: 0:00:00.206800
# episode: 1530/2000, episode end value: 1280.58, duration: 0:00:00.213059
# episode: 1531/2000, episode end value: 1267.31, duration: 0:00:00.202045
# episode: 1532/2000, episode end value: 1265.08, duration: 0:00:00.205196
# episode: 1533/2000, episode end value: 1278.12, duration: 0:00:00.212091
# episode: 1534/2000, episode end value: 1275.71, duration: 0:00:00.299213
# episode: 1535/2000, episode end value: 1286.68, duration: 0:00:00.207261
# episode: 1536/2000, episode end value: 1270.52, duration: 0:00:00.198059
# episode: 1537/2000, episode end value: 1272.18, duration: 0:00:00.210048
# episode: 1538/2000, episode end value: 1280.76, duration: 0:00:00.197044
# episode: 1539/2000, episode end value: 1291.58, duration: 0:00:00.205045
# episode: 1540/2000, episode end value: 1277.89, duration: 0:00:00.208045
# episode: 1541/2000, episode end value: 1277.99, duration: 0:00:00.200046
# episode: 1542/2000, episode end value: 1281.68, duration: 0:00:00.201051
# episode: 1543/2000, episode end value: 1263.77, duration: 0:00:00.202032
# episode: 1544/2000, episode end value: 1273.31, duration: 0:00:00.207034
# episode: 1545/2000, episode end value: 1285.49, duration: 0:00:00.202052
# episode: 1546/2000, episode end value: 1289.79, duration: 0:00:00.285052
# episode: 1547/2000, episode end value: 1262.92, duration: 0:00:00.200048
# episode: 1548/2000, episode end value: 1279.27, duration: 0:00:00.201050
# episode: 1549/2000, episode end value: 1288.65, duration: 0:00:00.208031
# episode: 1550/2000, episode end value: 1269.32, duration: 0:00:00.199064
# episode: 1551/2000, episode end value: 1268.95, duration: 0:00:00.201045
# episode: 1552/2000, episode end value: 1271.53, duration: 0:00:00.272043
# episode: 1553/2000, episode end value: 1272.27, duration: 0:00:00.212059
# episode: 1554/2000, episode end value: 1283.30, duration: 0:00:00.201058
# episode: 1555/2000, episode end value: 1284.28, duration: 0:00:00.199070
# episode: 1556/2000, episode end value: 1280.18, duration: 0:00:00.204128
# episode: 1557/2000, episode end value: 1283.76, duration: 0:00:00.208048
# episode: 1558/2000, episode end value: 1266.45, duration: 0:00:00.207082
# episode: 1559/2000, episode end value: 1278.75, duration: 0:00:00.199736
# episode: 1560/2000, episode end value: 1272.47, duration: 0:00:00.201050
# episode: 1561/2000, episode end value: 1265.46, duration: 0:00:00.202044
# episode: 1562/2000, episode end value: 1259.15, duration: 0:00:00.275057
# episode: 1563/2000, episode end value: 1282.36, duration: 0:00:00.201058
# episode: 1564/2000, episode end value: 1271.36, duration: 0:00:00.211047
# episode: 1565/2000, episode end value: 1285.04, duration: 0:00:00.204046
# episode: 1566/2000, episode end value: 1279.89, duration: 0:00:00.209084
# episode: 1567/2000, episode end value: 1282.78, duration: 0:00:00.200481
# episode: 1568/2000, episode end value: 1283.14, duration: 0:00:00.216079
# episode: 1569/2000, episode end value: 1279.61, duration: 0:00:00.202033
# episode: 1570/2000, episode end value: 1272.06, duration: 0:00:00.199038
# episode: 1571/2000, episode end value: 1266.66, duration: 0:00:00.203046
# episode: 1572/2000, episode end value: 1269.22, duration: 0:00:00.212040
# episode: 1573/2000, episode end value: 1277.90, duration: 0:00:00.225056
# episode: 1574/2000, episode end value: 1273.75, duration: 0:00:00.236069
# episode: 1575/2000, episode end value: 1277.20, duration: 0:00:00.201033
# episode: 1576/2000, episode end value: 1262.46, duration: 0:00:00.201051
# episode: 1577/2000, episode end value: 1278.88, duration: 0:00:00.205045
# episode: 1578/2000, episode end value: 1276.93, duration: 0:00:00.203046
# episode: 1579/2000, episode end value: 1273.98, duration: 0:00:00.213028
# episode: 1580/2000, episode end value: 1281.62, duration: 0:00:00.207029
# episode: 1581/2000, episode end value: 1288.39, duration: 0:00:00.202046
# episode: 1582/2000, episode end value: 1282.16, duration: 0:00:00.195060
# episode: 1583/2000, episode end value: 1285.84, duration: 0:00:00.200045
# episode: 1584/2000, episode end value: 1297.82, duration: 0:00:00.198035
# episode: 1585/2000, episode end value: 1299.93, duration: 0:00:00.200570
# episode: 1586/2000, episode end value: 1274.27, duration: 0:00:00.199848
# episode: 1587/2000, episode end value: 1283.51, duration: 0:00:00.269051
# episode: 1588/2000, episode end value: 1287.68, duration: 0:00:00.221054
# episode: 1589/2000, episode end value: 1266.35, duration: 0:00:00.208038
# episode: 1590/2000, episode end value: 1280.78, duration: 0:00:00.200058
# episode: 1591/2000, episode end value: 1280.23, duration: 0:00:00.203039
# episode: 1592/2000, episode end value: 1282.85, duration: 0:00:00.204046
# episode: 1593/2000, episode end value: 1306.53, duration: 0:00:00.199039
# episode: 1594/2000, episode end value: 1265.85, duration: 0:00:00.193699
# episode: 1595/2000, episode end value: 1290.09, duration: 0:00:00.276081
# episode: 1596/2000, episode end value: 1272.74, duration: 0:00:00.204870
# episode: 1597/2000, episode end value: 1261.19, duration: 0:00:00.204045
# episode: 1598/2000, episode end value: 1282.37, duration: 0:00:00.212042
# episode: 1599/2000, episode end value: 1271.90, duration: 0:00:00.222037
# episode: 1600/2000, episode end value: 1268.01, duration: 0:00:00.202065
# episode: 1601/2000, episode end value: 1274.08, duration: 0:00:00.202045
# episode: 1602/2000, episode end value: 1277.00, duration: 0:00:00.211036
# episode: 1603/2000, episode end value: 1282.40, duration: 0:00:00.267047
# episode: 1604/2000, episode end value: 1277.71, duration: 0:00:00.198051
# episode: 1605/2000, episode end value: 1288.72, duration: 0:00:00.213028
# episode: 1606/2000, episode end value: 1264.03, duration: 0:00:00.211064
# episode: 1607/2000, episode end value: 1266.94, duration: 0:00:00.205054
# episode: 1608/2000, episode end value: 1282.50, duration: 0:00:00.210035
# episode: 1609/2000, episode end value: 1288.04, duration: 0:00:00.203063
# episode: 1610/2000, episode end value: 1269.00, duration: 0:00:00.201048
# episode: 1611/2000, episode end value: 1270.13, duration: 0:00:00.196047
# episode: 1612/2000, episode end value: 1279.39, duration: 0:00:00.206052
# episode: 1613/2000, episode end value: 1278.80, duration: 0:00:00.193057
# episode: 1614/2000, episode end value: 1280.95, duration: 0:00:00.204090
# episode: 1615/2000, episode end value: 1263.67, duration: 0:00:00.200068
# episode: 1616/2000, episode end value: 1266.05, duration: 0:00:00.194148
# episode: 1617/2000, episode end value: 1260.11, duration: 0:00:00.200861
# episode: 1618/2000, episode end value: 1293.56, duration: 0:00:00.193048
# episode: 1619/2000, episode end value: 1277.68, duration: 0:00:00.199036
# episode: 1620/2000, episode end value: 1278.84, duration: 0:00:00.198038
# episode: 1621/2000, episode end value: 1288.15, duration: 0:00:00.208047
# episode: 1622/2000, episode end value: 1284.71, duration: 0:00:00.193042
# episode: 1623/2000, episode end value: 1265.92, duration: 0:00:00.195038
# episode: 1624/2000, episode end value: 1283.34, duration: 0:00:00.206053
# episode: 1625/2000, episode end value: 1270.64, duration: 0:00:00.206799
# episode: 1626/2000, episode end value: 1279.82, duration: 0:00:00.211061
# episode: 1627/2000, episode end value: 1279.35, duration: 0:00:00.206048
# episode: 1628/2000, episode end value: 1267.37, duration: 0:00:00.206051
# episode: 1629/2000, episode end value: 1279.60, duration: 0:00:00.212053
# episode: 1630/2000, episode end value: 1286.07, duration: 0:00:00.200038
# episode: 1631/2000, episode end value: 1274.66, duration: 0:00:00.202046
# episode: 1632/2000, episode end value: 1281.64, duration: 0:00:00.199992
# episode: 1633/2000, episode end value: 1279.61, duration: 0:00:00.216054
# episode: 1634/2000, episode end value: 1279.00, duration: 0:00:00.203034
# episode: 1635/2000, episode end value: 1281.18, duration: 0:00:00.198038
# episode: 1636/2000, episode end value: 1261.99, duration: 0:00:00.207046
# episode: 1637/2000, episode end value: 1262.17, duration: 0:00:00.220055
# episode: 1638/2000, episode end value: 1273.65, duration: 0:00:00.212041
# episode: 1639/2000, episode end value: 1267.54, duration: 0:00:00.201045
# episode: 1640/2000, episode end value: 1278.25, duration: 0:00:00.208054
# episode: 1641/2000, episode end value: 1281.53, duration: 0:00:00.197044
# episode: 1642/2000, episode end value: 1281.42, duration: 0:00:00.201044
# episode: 1643/2000, episode end value: 1293.86, duration: 0:00:00.202058
# episode: 1644/2000, episode end value: 1278.75, duration: 0:00:00.203045
# episode: 1645/2000, episode end value: 1278.08, duration: 0:00:00.198039
# episode: 1646/2000, episode end value: 1265.13, duration: 0:00:00.199014
# episode: 1647/2000, episode end value: 1269.14, duration: 0:00:00.203671
# episode: 1648/2000, episode end value: 1264.73, duration: 0:00:00.204052
# episode: 1649/2000, episode end value: 1266.23, duration: 0:00:00.211047
# episode: 1650/2000, episode end value: 1280.77, duration: 0:00:00.203040
# episode: 1651/2000, episode end value: 1271.51, duration: 0:00:00.203050
# episode: 1652/2000, episode end value: 1284.86, duration: 0:00:00.208141
# episode: 1653/2000, episode end value: 1278.74, duration: 0:00:00.206094
# episode: 1654/2000, episode end value: 1288.55, duration: 0:00:00.201825
# episode: 1655/2000, episode end value: 1282.63, duration: 0:00:00.206058
# episode: 1656/2000, episode end value: 1281.43, duration: 0:00:00.198009
# episode: 1657/2000, episode end value: 1281.29, duration: 0:00:00.206047
# episode: 1658/2000, episode end value: 1279.32, duration: 0:00:00.206042
# episode: 1659/2000, episode end value: 1266.22, duration: 0:00:00.202044
# episode: 1660/2000, episode end value: 1271.75, duration: 0:00:00.219056
# episode: 1661/2000, episode end value: 1272.20, duration: 0:00:00.206052
# episode: 1662/2000, episode end value: 1305.88, duration: 0:00:00.191024
# episode: 1663/2000, episode end value: 1264.36, duration: 0:00:00.190041
# episode: 1664/2000, episode end value: 1268.58, duration: 0:00:00.195044
# episode: 1665/2000, episode end value: 1276.31, duration: 0:00:00.193043
# episode: 1666/2000, episode end value: 1249.63, duration: 0:00:00.179146
# episode: 1667/2000, episode end value: 1288.86, duration: 0:00:00.200559
# episode: 1668/2000, episode end value: 1281.44, duration: 0:00:00.208195
# episode: 1669/2000, episode end value: 1277.73, duration: 0:00:00.193055
# episode: 1670/2000, episode end value: 1274.79, duration: 0:00:00.200031
# episode: 1671/2000, episode end value: 1270.93, duration: 0:00:00.197038
# episode: 1672/2000, episode end value: 1280.41, duration: 0:00:00.197044
# episode: 1673/2000, episode end value: 1266.40, duration: 0:00:00.195043
# episode: 1674/2000, episode end value: 1268.48, duration: 0:00:00.211047
# episode: 1675/2000, episode end value: 1260.46, duration: 0:00:00.205040
# episode: 1676/2000, episode end value: 1270.64, duration: 0:00:00.210041
# episode: 1677/2000, episode end value: 1270.43, duration: 0:00:00.209034
# episode: 1678/2000, episode end value: 1265.60, duration: 0:00:00.212047
# episode: 1679/2000, episode end value: 1273.30, duration: 0:00:00.217052
# episode: 1680/2000, episode end value: 1286.11, duration: 0:00:00.272074
# episode: 1681/2000, episode end value: 1268.04, duration: 0:00:00.197049
# episode: 1682/2000, episode end value: 1274.69, duration: 0:00:00.229045
# episode: 1683/2000, episode end value: 1269.46, duration: 0:00:00.215042
# episode: 1684/2000, episode end value: 1288.09, duration: 0:00:00.236032
# episode: 1685/2000, episode end value: 1282.46, duration: 0:00:00.209051
# episode: 1686/2000, episode end value: 1283.45, duration: 0:00:00.225061
# episode: 1687/2000, episode end value: 1266.50, duration: 0:00:00.200041
# episode: 1688/2000, episode end value: 1291.60, duration: 0:00:00.259067
# episode: 1689/2000, episode end value: 1271.08, duration: 0:00:00.203046
# episode: 1690/2000, episode end value: 1274.34, duration: 0:00:00.206762
# episode: 1691/2000, episode end value: 1283.73, duration: 0:00:00.207606
# episode: 1692/2000, episode end value: 1285.56, duration: 0:00:00.208089
# episode: 1693/2000, episode end value: 1280.23, duration: 0:00:00.205991
# episode: 1694/2000, episode end value: 1285.16, duration: 0:00:00.212069
# episode: 1695/2000, episode end value: 1274.00, duration: 0:00:00.213606
# episode: 1696/2000, episode end value: 1277.89, duration: 0:00:00.209053
# episode: 1697/2000, episode end value: 1279.88, duration: 0:00:00.217036
# episode: 1698/2000, episode end value: 1280.35, duration: 0:00:00.202052
# episode: 1699/2000, episode end value: 1270.04, duration: 0:00:00.207040
# episode: 1700/2000, episode end value: 1273.62, duration: 0:00:00.203288
# episode: 1701/2000, episode end value: 1261.71, duration: 0:00:00.204045
# episode: 1702/2000, episode end value: 1283.40, duration: 0:00:00.207047
# episode: 1703/2000, episode end value: 1275.14, duration: 0:00:00.195030
# episode: 1704/2000, episode end value: 1267.01, duration: 0:00:00.187138
# episode: 1705/2000, episode end value: 1282.04, duration: 0:00:00.209047
# episode: 1706/2000, episode end value: 1283.02, duration: 0:00:00.199038
# episode: 1707/2000, episode end value: 1275.62, duration: 0:00:00.211054
# episode: 1708/2000, episode end value: 1282.14, duration: 0:00:00.196032
# episode: 1709/2000, episode end value: 1273.44, duration: 0:00:00.215792
# episode: 1710/2000, episode end value: 1256.37, duration: 0:00:00.203617
# episode: 1711/2000, episode end value: 1265.29, duration: 0:00:00.200032
# episode: 1712/2000, episode end value: 1279.52, duration: 0:00:00.190049
# episode: 1713/2000, episode end value: 1273.43, duration: 0:00:00.197053
# episode: 1714/2000, episode end value: 1260.92, duration: 0:00:00.201051
# episode: 1715/2000, episode end value: 1266.37, duration: 0:00:00.208047
# episode: 1716/2000, episode end value: 1279.37, duration: 0:00:00.205039
# episode: 1717/2000, episode end value: 1271.56, duration: 0:00:00.204053
# episode: 1718/2000, episode end value: 1267.06, duration: 0:00:00.225044
# episode: 1719/2000, episode end value: 1262.72, duration: 0:00:00.221584
# episode: 1720/2000, episode end value: 1280.25, duration: 0:00:00.205060
# episode: 1721/2000, episode end value: 1280.88, duration: 0:00:00.200044
# episode: 1722/2000, episode end value: 1297.73, duration: 0:00:00.206758
# episode: 1723/2000, episode end value: 1281.73, duration: 0:00:00.202754
# episode: 1724/2000, episode end value: 1266.27, duration: 0:00:00.178444
# episode: 1725/2000, episode end value: 1288.20, duration: 0:00:00.212061
# episode: 1726/2000, episode end value: 1265.33, duration: 0:00:00.209048
# episode: 1727/2000, episode end value: 1289.68, duration: 0:00:00.204059
# episode: 1728/2000, episode end value: 1289.20, duration: 0:00:00.199063

# %%
plt.plot(agent.model.losses)

# %%
plt.plot(portfolio_value)

# %%
#test

mode = 'test'

portfolio_value = []


with open(f'scaler/{stock_name}.pkl', 'rb') as f:
    scaler = pickle.load(f)
    
env = Env(test_data, capital)
agent.epsilon = 0
agent.load(f'state_dict/{stock_name}.npz')



t0 = datetime.now()
val = play_one_episode(agent, env, mode)
dt = datetime.now() - t0
print(f"episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
portfolio_value.append(val['portfolio_value'][-1])
    
print(f"Sell: {env.sell_buy.count('sell')} times, Buy: {env.sell_buy.count('buy')} times")



result = pd.DataFrame(val)
result.index = test_data.index

def marker_buy(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'buy':
        return price
    else:
        return np.nan
    
def marker_sell(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'sell':
        return price
    else:
        return np.nan
    
result['marker_buy'] = result[['stock_price', 'sell_buy']].apply(marker_buy, axis=1);
result['marker_sell'] = result[['stock_price', 'sell_buy']].apply(marker_sell, axis=1);

result['stock_price'].plot(figsize=(10,6), c='grey', lw=2);
result['marker_buy'].plot(style='o', ms=7, label='buy', c='g', alpha=0.5);
result['marker_sell'].plot(style='o', ms=7, label='sell', c='r', alpha=0.5);
plt.title('Stock Price '+ stock_name)
plt.legend();
plt.show()



result['portfolio_value'].plot(figsize=(10,6), c='r', lw=2);
plt.title('Portfolio Value');
plt.show()

result['stock_owned'].plot(figsize=(10,6), c='purple', lw=2);
plt.title('Position')
plt.show()

result[['cash_in_hand', 'stock_value']].plot(figsize=(10,6), lw=2);
plt.title('Cash in Hand and Stock Value');
plt.show()
# Out:
# episode: 1/1, episode end value: 1091.54, duration: 0:00:00.050994
# Sell: 0 times, Buy: 2 times

# %%
import pyfolio as pf
sns.set_style('whitegrid')

bt_returns = result['portfolio_value'].pct_change()
price = result['stock_price'].pct_change()



plt.figure(figsize=(9,6));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, price);
plt.title('Compare with close price');
plt.show()

fig = plt.figure(1)
plt.subplot(1,3,1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1,3,2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1,3,3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()
fig.set_size_inches(12,4)

plt.figure(figsize=(9,6))
pf.plot_return_quantiles(bt_returns);



plt.figure(figsize=(9,6))
pf.plot_rolling_sharpe(bt_returns);

plt.figure(figsize=(9,6))
pf.plot_drawdown_underwater(bt_returns);
