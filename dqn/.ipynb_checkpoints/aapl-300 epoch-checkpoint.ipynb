# %% [markdown]
# # Import Module

# %%
from dqn_agent import DQNAgent
from nn_model import NeuralNetwork
from memory import ExperienceReplayMemory
from environment import SingleStockEnv
from scaler_state import get_scaler
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import talib
import seaborn as sns
import torch
import numpy as np
import plotly.graph_objects as go
import pyfolio as pf
import empyrical
from tqdm.notebook import tqdm 
# %matplotlib inline

# %% [markdown]
# # Stock Data

# %%
stock_name = 'fb'.upper()
stock_data = web.DataReader(stock_name, 'yahoo', '2014-01-01', '2021-01-01')
stock_data['rsi'] = talib.RSI(stock_data['Adj Close'])
stock_data['mom'] = talib.MOM(stock_data['Adj Close'])
stock_data['adx'] = talib.ADX(stock_data['High'], stock_data['Low'], stock_data['Adj Close'])
stock_data['macd'], stock_data['macd sig'], _ = talib.MACD(stock_data['Adj Close'])
stock_data['cci'] = talib.CCI(stock_data['High'], stock_data['Low'], stock_data['Adj Close'])
stock_data.dropna(axis=0, inplace=True)

train_data = stock_data.iloc[:-253]
test_data = stock_data.iloc[-253:]

sns.set_style('whitegrid')
train_data['Adj Close'].plot(label='training_data', figsize=(15,8));
test_data['Adj Close'].plot(label='testing_data');
plt.title('Stock data '+ stock_name)
plt.legend();
plt.show()

stock_data[['rsi', 'mom', 'adx', 'macd', 'macd sig', 'cci']].plot(subplots=True, figsize=(15,10), title='Technical indicators');
plt.show()


plt.figure(figsize=(10,6))
sns.heatmap(stock_data.isnull(), cmap='viridis');
plt.title('Missing data');
plt.show()

# %% [markdown]
# # Config

# %%
num_episodes = 200
capital = 1000000
train_env = SingleStockEnv(train_data, capital)
state_size = train_env.state_dim
action_size = len(train_env.action_space)
agent = DQNAgent(input_sz=state_size, action_sz=action_size, discount_factor=0.9, ticker=stock_name)
scaler = get_scaler(train_env)

# %% [markdown]
# # Training

# %%
#train

print('Training Model')
portfolio_value = []
reward = []
total_reward = np.zeros(num_episodes)
for e in tqdm(range(num_episodes)):
 
    last_state = train_env.reset()
    last_reward = 0
    done = False
    scores = []
    while not done:
        last_state = scaler.transform([last_state])
        action = agent.update(last_reward, last_state)
        scores.append(agent.score())
        last_state, last_reward, done, info = train_env.step(action) 
        total_reward[e] += last_reward
    
    if (e+1) % (num_episodes/20) == 0:     
        print(f"Episode: {e + 1:4}/{num_episodes}")
        print(f"Begin portfolio value: {capital:8.2f}")
        print(f"End portfolio value: {info['portfolio_value'][-1]:10.2f}")
        print(f"Epsilon: {agent.save_epsilon[-1]:2.5f}")
        print(f"Sell: {train_env.sell_buy.count('sell')}, Buy: {train_env.sell_buy.count('buy')}")
        print(f'Reward: {total_reward[e]:8.2f}')
        print(f"Mean Squared Error Loss: {agent.losses[-1]:8.4f}")
        print('=======================================================================')
        print()
    
    portfolio_value.append(info['portfolio_value'][-1]) 
    
       
agent.save()
losses = agent.losses

print(f'average reward: {np.mean(portfolio_value):.2f}, min: {np.min(portfolio_value):.2f}, max: {np.max(portfolio_value):.2f}')
sns.histplot(portfolio_value, bins=100, color='r', kde=True);
plt.xlabel('Portfolio Value');
plt.ylabel('Count');
# Out:
# Training Model
#   0%|          | 0/200 [00:00<?, ?it/s]
# Episode:    1/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1433263.99
# Epsilon: 0.22815
# Sell: 469, Buy: 494
# Reward: 433263.99
# Mean Squared Error Loss: 38445708.0000
# =======================================================================
#
# Episode:    2/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1707026.00
# Epsilon: 0.05205
# Sell: 452, Buy: 481
# Reward: 707026.00
# Mean Squared Error Loss: 26271102.0000
# =======================================================================
#
# Episode:    3/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1414318.01
# Epsilon: 0.01188
# Sell: 460, Buy: 463
# Reward: 414318.01
# Mean Squared Error Loss: 22863984.0000
# =======================================================================
#
# Episode:    4/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1155011.99
# Epsilon: 0.00271
# Sell: 447, Buy: 452
# Reward: 155011.99
# Mean Squared Error Loss: 15957004.0000
# =======================================================================
#
# Episode:    5/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1305472.00
# Epsilon: 0.00100
# Sell: 453, Buy: 479
# Reward: 305472.00
# Mean Squared Error Loss: 12725533.0000
# =======================================================================
#
# Episode:    6/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1324723.99
# Epsilon: 0.00100
# Sell: 455, Buy: 487
# Reward: 324723.99
# Mean Squared Error Loss: 11575281.0000
# =======================================================================
#
# Episode:    7/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1369550.00
# Epsilon: 0.00100
# Sell: 481, Buy: 492
# Reward: 369550.00
# Mean Squared Error Loss: 13994680.0000
# =======================================================================
#
# Episode:    8/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1413454.02
# Epsilon: 0.00100
# Sell: 492, Buy: 494
# Reward: 413454.02
# Mean Squared Error Loss: 10950879.0000
# =======================================================================
#
# Episode:    9/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1270741.99
# Epsilon: 0.00100
# Sell: 466, Buy: 468
# Reward: 270741.99
# Mean Squared Error Loss: 10662310.0000
# =======================================================================
#
# Episode:   10/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1801295.99
# Epsilon: 0.00100
# Sell: 496, Buy: 524
# Reward: 801295.99
# Mean Squared Error Loss: 11650645.0000
# =======================================================================
#
# Episode:   11/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1192626.00
# Epsilon: 0.00100
# Sell: 447, Buy: 467
# Reward: 192626.00
# Mean Squared Error Loss: 9223984.0000
# =======================================================================
#
# Episode:   12/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1355182.04
# Epsilon: 0.00100
# Sell: 455, Buy: 488
# Reward: 355182.04
# Mean Squared Error Loss: 11868291.0000
# =======================================================================
#
# Episode:   13/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1091562.01
# Epsilon: 0.00100
# Sell: 486, Buy: 488
# Reward: 91562.01
# Mean Squared Error Loss: 11029296.0000
# =======================================================================
#
# Episode:   14/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1612012.02
# Epsilon: 0.00100
# Sell: 473, Buy: 496
# Reward: 612012.02
# Mean Squared Error Loss: 12657629.0000
# =======================================================================
#
# Episode:   15/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1753001.97
# Epsilon: 0.00100
# Sell: 457, Buy: 499
# Reward: 753001.97
# Mean Squared Error Loss: 9685464.0000
# =======================================================================
#
# Episode:   16/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1830030.00
# Epsilon: 0.00100
# Sell: 468, Buy: 479
# Reward: 830030.00
# Mean Squared Error Loss: 12839699.0000
# =======================================================================
#
# Episode:   17/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1502158.03
# Epsilon: 0.00100
# Sell: 485, Buy: 490
# Reward: 502158.03
# Mean Squared Error Loss: 9164505.0000
# =======================================================================
#
# Episode:   18/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1193831.97
# Epsilon: 0.00100
# Sell: 483, Buy: 483
# Reward: 193831.97
# Mean Squared Error Loss: 11375987.0000
# =======================================================================
#
# Episode:   19/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1916728.00
# Epsilon: 0.00100
# Sell: 464, Buy: 490
# Reward: 916728.00
# Mean Squared Error Loss: 7544056.0000
# =======================================================================
#
# Episode:   20/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1073566.01
# Epsilon: 0.00100
# Sell: 490, Buy: 491
# Reward: 73566.01
# Mean Squared Error Loss: 9081205.0000
# =======================================================================
#
# Episode:   21/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1622154.03
# Epsilon: 0.00100
# Sell: 465, Buy: 500
# Reward: 622154.03
# Mean Squared Error Loss: 4709534.5000
# =======================================================================
#
# Episode:   22/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1840455.99
# Epsilon: 0.00100
# Sell: 458, Buy: 499
# Reward: 840455.99
# Mean Squared Error Loss: 9159931.0000
# =======================================================================
#
# Episode:   23/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1575506.00
# Epsilon: 0.00100
# Sell: 470, Buy: 501
# Reward: 575506.00
# Mean Squared Error Loss: 10756201.0000
# =======================================================================
#
# Episode:   24/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1625616.02
# Epsilon: 0.00100
# Sell: 472, Buy: 497
# Reward: 625616.02
# Mean Squared Error Loss: 11660209.0000
# =======================================================================
#
# Episode:   25/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1052678.00
# Epsilon: 0.00100
# Sell: 472, Buy: 472
# Reward: 52678.00
# Mean Squared Error Loss: 10747898.0000
# =======================================================================
#
# Episode:   26/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1156957.98
# Epsilon: 0.00100
# Sell: 480, Buy: 484
# Reward: 156957.98
# Mean Squared Error Loss: 9043433.0000
# =======================================================================
#
# Episode:   27/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1632506.02
# Epsilon: 0.00100
# Sell: 475, Buy: 496
# Reward: 632506.02
# Mean Squared Error Loss: 6801139.5000
# =======================================================================
#
# Episode:   28/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1342037.98
# Epsilon: 0.00100
# Sell: 497, Buy: 502
# Reward: 342037.98
# Mean Squared Error Loss: 6202121.5000
# =======================================================================
#
# Episode:   29/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1835164.02
# Epsilon: 0.00100
# Sell: 475, Buy: 510
# Reward: 835164.02
# Mean Squared Error Loss: 13796652.0000
# =======================================================================
#
# Episode:   30/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1152465.99
# Epsilon: 0.00100
# Sell: 476, Buy: 482
# Reward: 152465.99
# Mean Squared Error Loss: 7493925.5000
# =======================================================================
#
# Episode:   31/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1209152.00
# Epsilon: 0.00100
# Sell: 491, Buy: 500
# Reward: 209152.00
# Mean Squared Error Loss: 6357846.0000
# =======================================================================
#
# Episode:   32/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1509343.99
# Epsilon: 0.00100
# Sell: 473, Buy: 501
# Reward: 509343.99
# Mean Squared Error Loss: 3976112.0000
# =======================================================================
#
# Episode:   33/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1199224.02
# Epsilon: 0.00100
# Sell: 460, Buy: 475
# Reward: 199224.02
# Mean Squared Error Loss: 7196461.5000
# =======================================================================
# Episode:   34/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1332255.99
# Epsilon: 0.00100
# Sell: 469, Buy: 488
# Reward: 332255.99
# Mean Squared Error Loss: 5628572.5000
# =======================================================================
#
# Episode:   35/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2136382.00
# Epsilon: 0.00100
# Sell: 474, Buy: 523
# Reward: 1136382.00
# Mean Squared Error Loss: 11352691.0000
# =======================================================================
#
# Episode:   36/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1152168.00
# Epsilon: 0.00100
# Sell: 483, Buy: 483
# Reward: 152168.00
# Mean Squared Error Loss: 6558675.5000
# =======================================================================
#
# Episode:   37/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1433652.01
# Epsilon: 0.00100
# Sell: 471, Buy: 491
# Reward: 433652.01
# Mean Squared Error Loss: 4649373.5000
# =======================================================================
#
# Episode:   38/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1084856.01
# Epsilon: 0.00100
# Sell: 458, Buy: 471
# Reward: 84856.01
# Mean Squared Error Loss: 4569506.5000
# =======================================================================
#
# Episode:   39/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1883963.94
# Epsilon: 0.00100
# Sell: 483, Buy: 487
# Reward: 883963.94
# Mean Squared Error Loss: 5392814.5000
# =======================================================================
#
# Episode:   40/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1320737.97
# Epsilon: 0.00100
# Sell: 469, Buy: 486
# Reward: 320737.97
# Mean Squared Error Loss: 5533680.5000
# =======================================================================
#
# Episode:   41/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1469110.02
# Epsilon: 0.00100
# Sell: 473, Buy: 502
# Reward: 469110.02
# Mean Squared Error Loss: 4578143.5000
# =======================================================================
#
# Episode:   42/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1626860.02
# Epsilon: 0.00100
# Sell: 492, Buy: 496
# Reward: 626860.02
# Mean Squared Error Loss: 7237532.0000
# =======================================================================
#
# Episode:   43/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1306945.99
# Epsilon: 0.00100
# Sell: 463, Buy: 485
# Reward: 306945.99
# Mean Squared Error Loss: 6712195.5000
# =======================================================================
#
# Episode:   44/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1796680.00
# Epsilon: 0.00100
# Sell: 481, Buy: 492
# Reward: 796680.00
# Mean Squared Error Loss: 6121273.5000
# =======================================================================
#
# Episode:   45/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1113586.00
# Epsilon: 0.00100
# Sell: 476, Buy: 482
# Reward: 113586.00
# Mean Squared Error Loss: 8300458.5000
# =======================================================================
#
# Episode:   46/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1417786.05
# Epsilon: 0.00100
# Sell: 459, Buy: 479
# Reward: 417786.05
# Mean Squared Error Loss: 6719802.0000
# =======================================================================
#
# Episode:   47/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1234516.02
# Epsilon: 0.00100
# Sell: 454, Buy: 465
# Reward: 234516.02
# Mean Squared Error Loss: 3698123.7500
# =======================================================================
#
# Episode:   48/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1504907.98
# Epsilon: 0.00100
# Sell: 490, Buy: 507
# Reward: 504907.98
# Mean Squared Error Loss: 5356225.0000
# =======================================================================
#
# Episode:   49/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1458827.99
# Epsilon: 0.00100
# Sell: 498, Buy: 503
# Reward: 458827.99
# Mean Squared Error Loss: 5453371.5000
# =======================================================================
#
# Episode:   50/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1175166.00
# Epsilon: 0.00100
# Sell: 468, Buy: 469
# Reward: 175166.00
# Mean Squared Error Loss: 4208582.5000
# =======================================================================
#
# Episode:   51/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1308205.99
# Epsilon: 0.00100
# Sell: 456, Buy: 460
# Reward: 308205.99
# Mean Squared Error Loss: 3217274.0000
# =======================================================================
#
# Episode:   52/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1366844.02
# Epsilon: 0.00100
# Sell: 468, Buy: 473
# Reward: 366844.02
# Mean Squared Error Loss: 3740758.7500
# =======================================================================
#
# Episode:   53/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1404599.99
# Epsilon: 0.00100
# Sell: 485, Buy: 487
# Reward: 404599.99
# Mean Squared Error Loss: 5284506.5000
# =======================================================================
#
# Episode:   54/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1154267.99
# Epsilon: 0.00100
# Sell: 456, Buy: 467
# Reward: 154267.99
# Mean Squared Error Loss: 4257833.5000
# =======================================================================
#
# Episode:   55/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1278764.00
# Epsilon: 0.00100
# Sell: 476, Buy: 478
# Reward: 278764.00
# Mean Squared Error Loss: 4649098.0000
# =======================================================================
#
# Episode:   56/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1406467.98
# Epsilon: 0.00100
# Sell: 502, Buy: 513
# Reward: 406467.98
# Mean Squared Error Loss: 3259851.2500
# =======================================================================
#
# Episode:   57/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1979676.03
# Epsilon: 0.00100
# Sell: 495, Buy: 499
# Reward: 979676.03
# Mean Squared Error Loss: 2312364.5000
# =======================================================================
#
# Episode:   58/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1250306.01
# Epsilon: 0.00100
# Sell: 477, Buy: 486
# Reward: 250306.01
# Mean Squared Error Loss: 3910577.0000
# =======================================================================
#
# Episode:   59/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1362106.01
# Epsilon: 0.00100
# Sell: 462, Buy: 479
# Reward: 362106.01
# Mean Squared Error Loss: 4318251.5000
# =======================================================================
#
# Episode:   60/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2116296.02
# Epsilon: 0.00100
# Sell: 490, Buy: 510
# Reward: 1116296.02
# Mean Squared Error Loss: 3214126.0000
# =======================================================================
#
# Episode:   61/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1280522.00
# Epsilon: 0.00100
# Sell: 467, Buy: 484
# Reward: 280522.00
# Mean Squared Error Loss: 3403656.7500
# =======================================================================
#
# Episode:   62/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1310613.98
# Epsilon: 0.00100
# Sell: 462, Buy: 486
# Reward: 310613.98
# Mean Squared Error Loss: 3021104.0000
# =======================================================================
#
# Episode:   63/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1337961.99
# Epsilon: 0.00100
# Sell: 470, Buy: 494
# Reward: 337961.99
# Mean Squared Error Loss: 2900617.2500
# =======================================================================
#
# Episode:   64/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1374985.98
# Epsilon: 0.00100
# Sell: 456, Buy: 474
# Reward: 374985.98
# Mean Squared Error Loss: 4194854.0000
# =======================================================================
#
# Episode:   65/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1102766.00
# Epsilon: 0.00100
# Sell: 451, Buy: 455
# Reward: 102766.00
# Mean Squared Error Loss: 3428556.0000
# =======================================================================
#
# Episode:   66/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1299408.01
# Epsilon: 0.00100
# Sell: 474, Buy: 487
# Reward: 299408.01
# Mean Squared Error Loss: 2369151.0000
# =======================================================================
# Episode:   67/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1513604.01
# Epsilon: 0.00100
# Sell: 466, Buy: 473
# Reward: 513604.01
# Mean Squared Error Loss: 2890029.2500
# =======================================================================
#
# Episode:   68/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1712100.04
# Epsilon: 0.00100
# Sell: 456, Buy: 496
# Reward: 712100.04
# Mean Squared Error Loss: 5227292.5000
# =======================================================================
#
# Episode:   69/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1277877.96
# Epsilon: 0.00100
# Sell: 471, Buy: 483
# Reward: 277877.96
# Mean Squared Error Loss: 2349550.7500
# =======================================================================
#
# Episode:   70/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1193136.03
# Epsilon: 0.00100
# Sell: 447, Buy: 456
# Reward: 193136.03
# Mean Squared Error Loss: 2729047.2500
# =======================================================================
#
# Episode:   71/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2027462.01
# Epsilon: 0.00100
# Sell: 486, Buy: 513
# Reward: 1027462.01
# Mean Squared Error Loss: 3100492.2500
# =======================================================================
#
# Episode:   72/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1371044.00
# Epsilon: 0.00100
# Sell: 488, Buy: 497
# Reward: 371044.00
# Mean Squared Error Loss: 3827406.0000
# =======================================================================
#
# Episode:   73/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1194894.03
# Epsilon: 0.00100
# Sell: 468, Buy: 496
# Reward: 194894.03
# Mean Squared Error Loss: 5470277.0000
# =======================================================================
#
# Episode:   74/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1685295.99
# Epsilon: 0.00100
# Sell: 460, Buy: 497
# Reward: 685295.99
# Mean Squared Error Loss: 2364138.0000
# =======================================================================
#
# Episode:   75/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1330411.99
# Epsilon: 0.00100
# Sell: 499, Buy: 516
# Reward: 330411.99
# Mean Squared Error Loss: 1828611.8750
# =======================================================================
#
# Episode:   76/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1696803.98
# Epsilon: 0.00100
# Sell: 470, Buy: 497
# Reward: 696803.98
# Mean Squared Error Loss: 2095101.5000
# =======================================================================
#
# Episode:   77/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1189964.02
# Epsilon: 0.00100
# Sell: 477, Buy: 486
# Reward: 189964.02
# Mean Squared Error Loss: 3054629.7500
# =======================================================================
#
# Episode:   78/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1408884.01
# Epsilon: 0.00100
# Sell: 473, Buy: 494
# Reward: 408884.01
# Mean Squared Error Loss: 3128006.0000
# =======================================================================
#
# Episode:   79/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1883741.97
# Epsilon: 0.00100
# Sell: 483, Buy: 497
# Reward: 883741.97
# Mean Squared Error Loss: 2469336.2500
# =======================================================================
#
# Episode:   80/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1277824.02
# Epsilon: 0.00100
# Sell: 481, Buy: 489
# Reward: 277824.02
# Mean Squared Error Loss: 2109191.0000
# =======================================================================
#
# Episode:   81/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1093389.98
# Epsilon: 0.00100
# Sell: 507, Buy: 508
# Reward: 93389.98
# Mean Squared Error Loss: 3514719.0000
# =======================================================================
#
# Episode:   82/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1341421.97
# Epsilon: 0.00100
# Sell: 482, Buy: 495
# Reward: 341421.97
# Mean Squared Error Loss: 2421140.7500
# =======================================================================
#
# Episode:   83/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1321387.97
# Epsilon: 0.00100
# Sell: 485, Buy: 495
# Reward: 321387.97
# Mean Squared Error Loss: 2304207.7500
# =======================================================================
#
# Episode:   84/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1414556.03
# Epsilon: 0.00100
# Sell: 461, Buy: 490
# Reward: 414556.03
# Mean Squared Error Loss: 2033232.8750
# =======================================================================
#
# Episode:   85/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1129518.01
# Epsilon: 0.00100
# Sell: 461, Buy: 461
# Reward: 129518.01
# Mean Squared Error Loss: 2611863.7500
# =======================================================================
#
# Episode:   86/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1275532.02
# Epsilon: 0.00100
# Sell: 445, Buy: 468
# Reward: 275532.02
# Mean Squared Error Loss: 1852966.0000
# =======================================================================
#
# Episode:   87/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1387270.01
# Epsilon: 0.00100
# Sell: 439, Buy: 471
# Reward: 387270.01
# Mean Squared Error Loss: 1878228.5000
# =======================================================================
#
# Episode:   88/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1701425.98
# Epsilon: 0.00100
# Sell: 466, Buy: 493
# Reward: 701425.98
# Mean Squared Error Loss: 1448726.1250
# =======================================================================
#
# Episode:   89/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1346729.99
# Epsilon: 0.00100
# Sell: 480, Buy: 496
# Reward: 346729.99
# Mean Squared Error Loss: 1987039.6250
# =======================================================================
#
# Episode:   90/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1514560.02
# Epsilon: 0.00100
# Sell: 468, Buy: 504
# Reward: 514560.02
# Mean Squared Error Loss: 2458137.7500
# =======================================================================
#
# Episode:   91/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1609731.98
# Epsilon: 0.00100
# Sell: 454, Buy: 484
# Reward: 609731.98
# Mean Squared Error Loss: 1336401.7500
# =======================================================================
#
# Episode:   92/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1305381.98
# Epsilon: 0.00100
# Sell: 450, Buy: 465
# Reward: 305381.98
# Mean Squared Error Loss: 1713324.0000
# =======================================================================
#
# Episode:   93/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1474077.98
# Epsilon: 0.00100
# Sell: 477, Buy: 491
# Reward: 474077.98
# Mean Squared Error Loss: 1241864.6250
# =======================================================================
#
# Episode:   94/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1493352.04
# Epsilon: 0.00100
# Sell: 480, Buy: 505
# Reward: 493352.04
# Mean Squared Error Loss: 1493627.6250
# =======================================================================
#
# Episode:   95/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1587476.00
# Epsilon: 0.00100
# Sell: 461, Buy: 488
# Reward: 587476.00
# Mean Squared Error Loss: 3128924.7500
# =======================================================================
#
# Episode:   96/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1482801.98
# Epsilon: 0.00100
# Sell: 463, Buy: 475
# Reward: 482801.98
# Mean Squared Error Loss: 1337299.3750
# =======================================================================
#
# Episode:   97/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1238566.01
# Epsilon: 0.00100
# Sell: 447, Buy: 462
# Reward: 238566.01
# Mean Squared Error Loss: 1371689.5000
# =======================================================================
#
# Episode:   98/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1401654.00
# Epsilon: 0.00100
# Sell: 453, Buy: 487
# Reward: 401654.00
# Mean Squared Error Loss: 2038976.3750
# =======================================================================
#
# Episode:   99/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1497771.97
# Epsilon: 0.00100
# Sell: 454, Buy: 490
# Reward: 497771.97
# Mean Squared Error Loss: 1734029.0000
# =======================================================================
# Episode:  100/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1378842.04
# Epsilon: 0.00100
# Sell: 471, Buy: 495
# Reward: 378842.04
# Mean Squared Error Loss: 1500935.8750
# =======================================================================
#
# Episode:  101/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1982165.99
# Epsilon: 0.00100
# Sell: 446, Buy: 471
# Reward: 982165.99
# Mean Squared Error Loss: 1499865.0000
# =======================================================================
#
# Episode:  102/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1814185.96
# Epsilon: 0.00100
# Sell: 461, Buy: 504
# Reward: 814185.96
# Mean Squared Error Loss: 781613.8125
# =======================================================================
#
# Episode:  103/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1454947.99
# Epsilon: 0.00100
# Sell: 480, Buy: 501
# Reward: 454947.99
# Mean Squared Error Loss: 1683292.1250
# =======================================================================
#
# Episode:  104/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2020550.01
# Epsilon: 0.00100
# Sell: 463, Buy: 507
# Reward: 1020550.01
# Mean Squared Error Loss: 1164407.5000
# =======================================================================
#
# Episode:  105/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1176720.00
# Epsilon: 0.00100
# Sell: 468, Buy: 480
# Reward: 176720.00
# Mean Squared Error Loss: 2812878.7500
# =======================================================================
#
# Episode:  106/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1078738.00
# Epsilon: 0.00100
# Sell: 447, Buy: 452
# Reward: 78738.00
# Mean Squared Error Loss: 1874822.3750
# =======================================================================
#
# Episode:  107/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1263193.96
# Epsilon: 0.00100
# Sell: 444, Buy: 469
# Reward: 263193.96
# Mean Squared Error Loss: 1375334.7500
# =======================================================================
#
# Episode:  108/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1495277.99
# Epsilon: 0.00100
# Sell: 477, Buy: 501
# Reward: 495277.99
# Mean Squared Error Loss: 1379094.7500
# =======================================================================
#
# Episode:  109/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1525401.97
# Epsilon: 0.00100
# Sell: 453, Buy: 486
# Reward: 525401.97
# Mean Squared Error Loss: 1383035.6250
# =======================================================================
#
# Episode:  110/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1541420.01
# Epsilon: 0.00100
# Sell: 452, Buy: 489
# Reward: 541420.01
# Mean Squared Error Loss: 1283367.1250
# =======================================================================
#
# Episode:  111/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1788914.02
# Epsilon: 0.00100
# Sell: 494, Buy: 503
# Reward: 788914.02
# Mean Squared Error Loss: 1226732.3750
# =======================================================================
#
# Episode:  112/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1715583.98
# Epsilon: 0.00100
# Sell: 460, Buy: 491
# Reward: 715583.98
# Mean Squared Error Loss: 1141749.8750
# =======================================================================
#
# Episode:  113/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1290009.98
# Epsilon: 0.00100
# Sell: 472, Buy: 473
# Reward: 290009.98
# Mean Squared Error Loss: 1289178.3750
# =======================================================================
#
# Episode:  114/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1198660.02
# Epsilon: 0.00100
# Sell: 471, Buy: 488
# Reward: 198660.02
# Mean Squared Error Loss: 1459039.3750
# =======================================================================
#
# Episode:  115/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1265615.95
# Epsilon: 0.00100
# Sell: 474, Buy: 496
# Reward: 265615.95
# Mean Squared Error Loss: 1167025.6250
# =======================================================================
#
# Episode:  116/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1259734.00
# Epsilon: 0.00100
# Sell: 446, Buy: 457
# Reward: 259734.00
# Mean Squared Error Loss: 2124456.2500
# =======================================================================
#
# Episode:  117/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1213222.00
# Epsilon: 0.00100
# Sell: 471, Buy: 485
# Reward: 213222.00
# Mean Squared Error Loss: 910090.2500
# =======================================================================
#
# Episode:  118/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1695485.99
# Epsilon: 0.00100
# Sell: 473, Buy: 485
# Reward: 695485.99
# Mean Squared Error Loss: 1158240.1250
# =======================================================================
#
# Episode:  119/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1435034.03
# Epsilon: 0.00100
# Sell: 440, Buy: 471
# Reward: 435034.03
# Mean Squared Error Loss: 1061284.6250
# =======================================================================
#
# Episode:  120/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1326404.02
# Epsilon: 0.00100
# Sell: 481, Buy: 513
# Reward: 326404.02
# Mean Squared Error Loss: 1114877.6250
# =======================================================================
#
# Episode:  121/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1169743.97
# Epsilon: 0.00100
# Sell: 468, Buy: 472
# Reward: 169743.97
# Mean Squared Error Loss: 1824823.0000
# =======================================================================
#
# Episode:  122/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1533605.98
# Epsilon: 0.00100
# Sell: 463, Buy: 494
# Reward: 533605.98
# Mean Squared Error Loss: 936331.4375
# =======================================================================
#
# Episode:  123/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1663310.01
# Epsilon: 0.00100
# Sell: 470, Buy: 504
# Reward: 663310.01
# Mean Squared Error Loss: 876643.8125
# =======================================================================
#
# Episode:  124/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1602859.99
# Epsilon: 0.00100
# Sell: 486, Buy: 519
# Reward: 602859.99
# Mean Squared Error Loss: 1612414.6250
# =======================================================================
#
# Episode:  125/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1023789.99
# Epsilon: 0.00100
# Sell: 440, Buy: 450
# Reward: 23789.99
# Mean Squared Error Loss: 1082606.3750
# =======================================================================
#
# Episode:  126/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1182930.00
# Epsilon: 0.00100
# Sell: 449, Buy: 469
# Reward: 182930.00
# Mean Squared Error Loss: 1350380.1250
# =======================================================================
#
# Episode:  127/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1682953.98
# Epsilon: 0.00100
# Sell: 449, Buy: 487
# Reward: 682953.98
# Mean Squared Error Loss: 1256784.2500
# =======================================================================
#
# Episode:  128/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1155026.04
# Epsilon: 0.00100
# Sell: 480, Buy: 483
# Reward: 155026.04
# Mean Squared Error Loss: 929202.1875
# =======================================================================
#
# Episode:  129/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1176748.01
# Epsilon: 0.00100
# Sell: 453, Buy: 464
# Reward: 176748.01
# Mean Squared Error Loss: 821022.0625
# =======================================================================
#
# Episode:  130/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1843520.01
# Epsilon: 0.00100
# Sell: 508, Buy: 529
# Reward: 843520.01
# Mean Squared Error Loss: 699813.0000
# =======================================================================
#
# Episode:  131/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1435718.00
# Epsilon: 0.00100
# Sell: 463, Buy: 464
# Reward: 435718.00
# Mean Squared Error Loss: 1402940.8750
# =======================================================================
#
# Episode:  132/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1426318.02
# Epsilon: 0.00100
# Sell: 472, Buy: 487
# Reward: 426318.02
# Mean Squared Error Loss: 836145.5000
# =======================================================================
# Episode:  133/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1220125.96
# Epsilon: 0.00100
# Sell: 467, Buy: 486
# Reward: 220125.96
# Mean Squared Error Loss: 1570582.3750
# =======================================================================
#
# Episode:  134/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1549191.98
# Epsilon: 0.00100
# Sell: 500, Buy: 501
# Reward: 549191.98
# Mean Squared Error Loss: 891721.3125
# =======================================================================
#
# Episode:  135/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1642041.99
# Epsilon: 0.00100
# Sell: 455, Buy: 489
# Reward: 642041.99
# Mean Squared Error Loss: 798939.0000
# =======================================================================
#
# Episode:  136/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1406948.00
# Epsilon: 0.00100
# Sell: 492, Buy: 507
# Reward: 406948.00
# Mean Squared Error Loss: 1036281.1875
# =======================================================================
#
# Episode:  137/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1467519.99
# Epsilon: 0.00100
# Sell: 457, Buy: 491
# Reward: 467519.99
# Mean Squared Error Loss: 981563.8125
# =======================================================================
#
# Episode:  138/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1181753.96
# Epsilon: 0.00100
# Sell: 445, Buy: 472
# Reward: 181753.96
# Mean Squared Error Loss: 950826.7500
# =======================================================================
#
# Episode:  139/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1382742.01
# Epsilon: 0.00100
# Sell: 479, Buy: 481
# Reward: 382742.01
# Mean Squared Error Loss: 984633.1875
# =======================================================================
#
# Episode:  140/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1167254.02
# Epsilon: 0.00100
# Sell: 456, Buy: 457
# Reward: 167254.02
# Mean Squared Error Loss: 860148.0000
# =======================================================================
#
# Episode:  141/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1955889.97
# Epsilon: 0.00100
# Sell: 459, Buy: 501
# Reward: 955889.97
# Mean Squared Error Loss: 909847.4375
# =======================================================================
#
# Episode:  142/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1277216.02
# Epsilon: 0.00100
# Sell: 478, Buy: 479
# Reward: 277216.02
# Mean Squared Error Loss: 968239.3125
# =======================================================================
#
# Episode:  143/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1384434.00
# Epsilon: 0.00100
# Sell: 450, Buy: 463
# Reward: 384434.00
# Mean Squared Error Loss: 924187.0625
# =======================================================================
#
# Episode:  144/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1481725.98
# Epsilon: 0.00100
# Sell: 474, Buy: 495
# Reward: 481725.98
# Mean Squared Error Loss: 1361087.1250
# =======================================================================
#
# Episode:  145/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1275732.02
# Epsilon: 0.00100
# Sell: 483, Buy: 496
# Reward: 275732.02
# Mean Squared Error Loss: 1046472.8125
# =======================================================================
#
# Episode:  146/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1446428.03
# Epsilon: 0.00100
# Sell: 476, Buy: 480
# Reward: 446428.03
# Mean Squared Error Loss: 805374.8125
# =======================================================================
#
# Episode:  147/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1604818.02
# Epsilon: 0.00100
# Sell: 472, Buy: 509
# Reward: 604818.02
# Mean Squared Error Loss: 802667.0000
# =======================================================================
#
# Episode:  148/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1294574.01
# Epsilon: 0.00100
# Sell: 485, Buy: 496
# Reward: 294574.01
# Mean Squared Error Loss: 896404.9375
# =======================================================================
#
# Episode:  149/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1815410.01
# Epsilon: 0.00100
# Sell: 465, Buy: 489
# Reward: 815410.01
# Mean Squared Error Loss: 984413.6875
# =======================================================================
#
# Episode:  150/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1523440.03
# Epsilon: 0.00100
# Sell: 476, Buy: 491
# Reward: 523440.03
# Mean Squared Error Loss: 1302884.5000
# =======================================================================
#
# Episode:  151/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1224130.00
# Epsilon: 0.00100
# Sell: 468, Buy: 474
# Reward: 224130.00
# Mean Squared Error Loss: 1017963.1875
# =======================================================================
#
# Episode:  152/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1235696.02
# Epsilon: 0.00100
# Sell: 467, Buy: 488
# Reward: 235696.02
# Mean Squared Error Loss: 604784.1250
# =======================================================================
#
# Episode:  153/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1373750.02
# Epsilon: 0.00100
# Sell: 479, Buy: 503
# Reward: 373750.02
# Mean Squared Error Loss: 1332774.3750
# =======================================================================
#
# Episode:  154/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1429480.00
# Epsilon: 0.00100
# Sell: 461, Buy: 480
# Reward: 429480.00
# Mean Squared Error Loss: 801659.4375
# =======================================================================
#
# Episode:  155/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1096021.96
# Epsilon: 0.00100
# Sell: 440, Buy: 440
# Reward: 96021.96
# Mean Squared Error Loss: 1190932.8750
# =======================================================================
#
# Episode:  156/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1324986.00
# Epsilon: 0.00100
# Sell: 468, Buy: 470
# Reward: 324986.00
# Mean Squared Error Loss: 871932.0000
# =======================================================================
#
# Episode:  157/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2259006.00
# Epsilon: 0.00100
# Sell: 465, Buy: 489
# Reward: 1259006.00
# Mean Squared Error Loss: 854436.1875
# =======================================================================
#
# Episode:  158/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1178087.99
# Epsilon: 0.00100
# Sell: 449, Buy: 466
# Reward: 178087.99
# Mean Squared Error Loss: 675995.4375
# =======================================================================
#
# Episode:  159/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1340026.01
# Epsilon: 0.00100
# Sell: 458, Buy: 488
# Reward: 340026.01
# Mean Squared Error Loss: 1056930.2500
# =======================================================================
#
# Episode:  160/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2047958.01
# Epsilon: 0.00100
# Sell: 469, Buy: 503
# Reward: 1047958.01
# Mean Squared Error Loss: 1370469.3750
# =======================================================================
#
# Episode:  161/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1310938.03
# Epsilon: 0.00100
# Sell: 440, Buy: 469
# Reward: 310938.03
# Mean Squared Error Loss: 1106417.3750
# =======================================================================
#
# Episode:  162/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1011906.02
# Epsilon: 0.00100
# Sell: 451, Buy: 457
# Reward: 11906.02
# Mean Squared Error Loss: 941020.4375
# =======================================================================
#
# Episode:  163/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1677453.98
# Epsilon: 0.00100
# Sell: 445, Buy: 479
# Reward: 677453.98
# Mean Squared Error Loss: 805950.3125
# =======================================================================
#
# Episode:  164/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1911926.01
# Epsilon: 0.00100
# Sell: 468, Buy: 500
# Reward: 911926.01
# Mean Squared Error Loss: 1023665.0000
# =======================================================================
#
# Episode:  165/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1534305.98
# Epsilon: 0.00100
# Sell: 473, Buy: 489
# Reward: 534305.98
# Mean Squared Error Loss: 1117948.6250
# =======================================================================
# Episode:  166/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1511074.01
# Epsilon: 0.00100
# Sell: 470, Buy: 483
# Reward: 511074.01
# Mean Squared Error Loss: 936081.8125
# =======================================================================
#
# Episode:  167/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1703446.01
# Epsilon: 0.00100
# Sell: 481, Buy: 486
# Reward: 703446.01
# Mean Squared Error Loss: 1278437.5000
# =======================================================================
#
# Episode:  168/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1812310.02
# Epsilon: 0.00100
# Sell: 466, Buy: 506
# Reward: 812310.02
# Mean Squared Error Loss: 838762.0000
# =======================================================================
#
# Episode:  169/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1368078.01
# Epsilon: 0.00100
# Sell: 456, Buy: 456
# Reward: 368078.01
# Mean Squared Error Loss: 600336.0000
# =======================================================================
#
# Episode:  170/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1112726.01
# Epsilon: 0.00100
# Sell: 466, Buy: 470
# Reward: 112726.01
# Mean Squared Error Loss: 719703.2500
# =======================================================================
#
# Episode:  171/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1959311.98
# Epsilon: 0.00100
# Sell: 463, Buy: 504
# Reward: 959311.98
# Mean Squared Error Loss: 807584.6875
# =======================================================================
#
# Episode:  172/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1835539.96
# Epsilon: 0.00100
# Sell: 498, Buy: 529
# Reward: 835539.96
# Mean Squared Error Loss: 903597.9375
# =======================================================================
#
# Episode:  173/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1042386.01
# Epsilon: 0.00100
# Sell: 465, Buy: 469
# Reward: 42386.01
# Mean Squared Error Loss: 808307.1875
# =======================================================================
#
# Episode:  174/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1199287.99
# Epsilon: 0.00100
# Sell: 447, Buy: 469
# Reward: 199287.99
# Mean Squared Error Loss: 695698.5625
# =======================================================================
#
# Episode:  175/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1286454.00
# Epsilon: 0.00100
# Sell: 430, Buy: 461
# Reward: 286454.00
# Mean Squared Error Loss: 886494.4375
# =======================================================================
#
# Episode:  176/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1188186.01
# Epsilon: 0.00100
# Sell: 466, Buy: 477
# Reward: 188186.01
# Mean Squared Error Loss: 544823.9375
# =======================================================================
#
# Episode:  177/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1216329.98
# Epsilon: 0.00100
# Sell: 489, Buy: 497
# Reward: 216329.98
# Mean Squared Error Loss: 695995.3125
# =======================================================================
#
# Episode:  178/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1520129.98
# Epsilon: 0.00100
# Sell: 506, Buy: 540
# Reward: 520129.98
# Mean Squared Error Loss: 685731.8750
# =======================================================================
#
# Episode:  179/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1646220.01
# Epsilon: 0.00100
# Sell: 466, Buy: 503
# Reward: 646220.01
# Mean Squared Error Loss: 591490.3125
# =======================================================================
#
# Episode:  180/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1527023.98
# Epsilon: 0.00100
# Sell: 466, Buy: 485
# Reward: 527023.98
# Mean Squared Error Loss: 666732.8125
# =======================================================================
#
# Episode:  181/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1098992.00
# Epsilon: 0.00100
# Sell: 467, Buy: 467
# Reward: 98992.00
# Mean Squared Error Loss: 638017.2500
# =======================================================================
#
# Episode:  182/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1382559.96
# Epsilon: 0.00100
# Sell: 477, Buy: 506
# Reward: 382559.96
# Mean Squared Error Loss: 845037.2500
# =======================================================================
#
# Episode:  183/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1660012.00
# Epsilon: 0.00100
# Sell: 459, Buy: 492
# Reward: 660012.00
# Mean Squared Error Loss: 744943.0625
# =======================================================================
#
# Episode:  184/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1413998.00
# Epsilon: 0.00100
# Sell: 476, Buy: 482
# Reward: 413998.00
# Mean Squared Error Loss: 622113.8750
# =======================================================================
#
# Episode:  185/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1136460.00
# Epsilon: 0.00100
# Sell: 455, Buy: 457
# Reward: 136460.00
# Mean Squared Error Loss: 660183.8750
# =======================================================================
#
# Episode:  186/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1241805.99
# Epsilon: 0.00100
# Sell: 476, Buy: 479
# Reward: 241805.99
# Mean Squared Error Loss: 783604.8125
# =======================================================================
#
# Episode:  187/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1591272.01
# Epsilon: 0.00100
# Sell: 437, Buy: 464
# Reward: 591272.01
# Mean Squared Error Loss: 737928.6875
# =======================================================================
#
# Episode:  188/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1329358.02
# Epsilon: 0.00100
# Sell: 486, Buy: 493
# Reward: 329358.02
# Mean Squared Error Loss: 640947.4375
# =======================================================================
#
# Episode:  189/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1202572.02
# Epsilon: 0.00100
# Sell: 465, Buy: 478
# Reward: 202572.02
# Mean Squared Error Loss: 479718.2188
# =======================================================================
#
# Episode:  190/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1200487.99
# Epsilon: 0.00100
# Sell: 471, Buy: 475
# Reward: 200487.99
# Mean Squared Error Loss: 859533.6875
# =======================================================================
#
# Episode:  191/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1140920.02
# Epsilon: 0.00100
# Sell: 455, Buy: 464
# Reward: 140920.02
# Mean Squared Error Loss: 682754.3125
# =======================================================================
#
# Episode:  192/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1425102.00
# Epsilon: 0.00100
# Sell: 448, Buy: 479
# Reward: 425102.00
# Mean Squared Error Loss: 556530.8125
# =======================================================================
#
# Episode:  193/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1652329.99
# Epsilon: 0.00100
# Sell: 454, Buy: 459
# Reward: 652329.99
# Mean Squared Error Loss: 474580.1250
# =======================================================================
#
# Episode:  194/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1430717.99
# Epsilon: 0.00100
# Sell: 461, Buy: 491
# Reward: 430717.99
# Mean Squared Error Loss: 653899.1875
# =======================================================================
#
# Episode:  195/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1316419.98
# Epsilon: 0.00100
# Sell: 471, Buy: 496
# Reward: 316419.98
# Mean Squared Error Loss: 512151.9062
# =======================================================================
#
# Episode:  196/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1545090.03
# Epsilon: 0.00100
# Sell: 485, Buy: 498
# Reward: 545090.03
# Mean Squared Error Loss: 930421.1875
# =======================================================================
#
# Episode:  197/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1201205.96
# Epsilon: 0.00100
# Sell: 479, Buy: 490
# Reward: 201205.96
# Mean Squared Error Loss: 1089662.8750
# =======================================================================
#
# Episode:  198/200
# Begin portfolio value: 1000000.00
# End portfolio value: 2006666.01
# Epsilon: 0.00100
# Sell: 459, Buy: 492
# Reward: 1006666.01
# Mean Squared Error Loss: 538120.8125
# =======================================================================
# Episode:  199/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1833304.00
# Epsilon: 0.00100
# Sell: 479, Buy: 483
# Reward: 833304.00
# Mean Squared Error Loss: 636418.1250
# =======================================================================
#
# Episode:  200/200
# Begin portfolio value: 1000000.00
# End portfolio value: 1433093.98
# Epsilon: 0.00100
# Sell: 470, Buy: 504
# Reward: 433093.98
# Mean Squared Error Loss: 587179.8125
# =======================================================================
#
# => Saved!!!...
# average reward: 1438255.42, min: 1011906.02, max: 2259006.00

# %% [markdown]
# # Loss

# %%
pd.Series(losses).plot(figsize=(10,6), c='r');
plt.title('Mean Squared Error');
plt.show()
pd.Series(losses).rolling(100).mean().plot(figsize=(10,6), c='r');
plt.title('Mean Squared Error (rolling mean)');

# %% [markdown]
# # Score

# %%
pd.Series(scores).plot()
# Out:
# <ipython-input-28-a675ab05a006>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series(scores).plot()
# <AxesSubplot:>

# %%
pd.Series(total_reward).plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
plt.plot(agent.save_epsilon);

# %%
plt.figure(figsize=(10,6));
plt.plot(total_reward);

# %% [markdown]
# # Testing

# %%
test_env = SingleStockEnv(test_data, capital)
state_size = test_env.state_dim
action_size = len(test_env.action_space)
agent = DQNAgent(state_size, action_size,0.9, ticker=stock_name)

last_state = test_env.reset()
last_reward = 0
done = False
agent.load()

while not done:
    last_state = scaler.transform([last_state])
    last_state = torch.Tensor(last_state[0]).float().unsqueeze(0)
    with torch.no_grad():
        action = agent.model(last_state).argmax().item()
    last_state, last_reward, done, info = test_env.step(action)


print('Testing Model')
print('=======================================================================')
print('=======================================================================')
print()
print()
print()
print(f'Start: {result.index[0]}  End: {result.index[-1]}')
print(f'Since: {len(test_data)} days')
print(f"Begin portfolio value: {capital:8.2f}")
print(f"End portfolio value: {info['portfolio_value'][-1]:10.2f}")
print(f"Return {(info['portfolio_value'][-1] - capital) * 100/capital:.2f} %")
print(f"Sell: {test_env.sell_buy.count('sell')} times, Buy: {test_env.sell_buy.count('buy')} times")
print('=======================================================================')

result = pd.DataFrame(info)
result.index = test_data.index

def marker_buy(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'buy':
        return price
    else:
        return np.nan
    
def marker_sell(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'sell':
        return price
    else:
        return np.nan
    
result['marker_buy'] = result[['stock_price', 'sell_buy']].apply(marker_buy, axis=1);
result['marker_sell'] = result[['stock_price', 'sell_buy']].apply(marker_sell, axis=1);

result['stock_price'].plot(figsize=(15,8), c='orange', lw='3');
result['marker_buy'].plot(style='o', ms=7, label='buy', c='b', alpha=0.5);
result['marker_sell'].plot(style='o', ms=7, label='sell', c='r', alpha=0.5);
plt.title('Stock Price '+ stock_name)
plt.legend();
plt.show()

result['portfolio_value'].plot(figsize=(15,8), c='r', lw=3);
plt.title('Portfolio Value');
plt.show()

result['stock_owned'].plot(figsize=(15,8), c='purple', lw=3);
plt.title('Position')
plt.show()

result[['cash_in_hand', 'stock_value']].plot(figsize=(15,8), lw=3);
plt.title('Cash in Hand and Stock Value');
plt.show()
# Out:
# loading state dict...!
# Completed!
# Testing Model
# =======================================================================
# =======================================================================
#
#
#
# Start: 2020-01-02 00:00:00  End: 2020-12-31 00:00:00
# Since: 253 days
# Begin portfolio value: 1000000.00
# End portfolio value: 1373722.02
# Return 37.37 %
# Sell: 0 times, Buy: 25 times
# =======================================================================

# %% [markdown]
# # Performance Measurement - KPIs

# %%
import numpy as np
import datetime as dt

bn = web.DataReader('spy', 'yahoo', '2020-01-01', '2021-01-01')
bn['Benchmark'] = bn['Adj Close']

def CAGR(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    
    df['cumulative_ret'] = (1 + df['daily_ret']).cumprod()
    n = len(df)/252
    cagr = (df['cumulative_ret'][-1])**(1/n) - 1
    return cagr

def volatility(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    vol = df['daily_ret'].std() * np.sqrt(252)
    return vol


def sharpe(DF, rf):
    df = DF.copy()
    sr = (CAGR(df) - rf)/volatility(df)
    return sr

def max_dd(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    df['cumulative_ret'] = (1 + df['daily_ret']).cumprod()
    df['cum_roll_max'] = df['cumulative_ret'].cummax()
    df['drawdown'] = df['cum_roll_max'] - df['cumulative_ret']
    df['drawdown_pct'] = df['drawdown']/df['cum_roll_max']
    max_dd = df['drawdown_pct'].max()
    return max_dd

def calmer(DF):
    df = DF.copy()
    clmr = CAGR(df)/max_dd(df)
    return clmr



print(f'Stock name: {stock_name}')
print(f'Start: {result.index[0]}  End: {result.index[-1]}')
print(f'Compound Annual Growth Rate: {CAGR(result)*100:.2f} %')
print(f'Volatility: {volatility(result):.4f}')
print(f'shape ratio: {sharpe(result, 0.011):.4f}')
print(f'Maximun drawdown: {max_dd(result)*-100:.2f} %')
print(f'Calmar ratio: {calmer(result):.4f}')
print()
print('Comparing with Benchmark')
print(f'Compound Annual Growth Rate (benchmark): {CAGR(bn)*100:.2f} %')
print(f'Volatility (benchmark): {volatility(bn):.4f}')
print(f'shape ratio: {sharpe(bn, 0.011):.4f}')
print(f'Calmar ratio (benchmark): {calmer(bn):.4f}')
# Out:
# Stock name: FB
# Start: 2020-01-02 00:00:00  End: 2020-12-31 00:00:00
# Compound Annual Growth Rate: 37.20 %
# Volatility: 0.2812
# shape ratio: 1.2837
# Maximun drawdown: -18.25 %
# Calmar ratio: 2.0381
#
# Comparing with Benchmark
# Compound Annual Growth Rate (benchmark): 18.17 %
# Volatility (benchmark): 0.3340
# shape ratio: 0.5113
# Calmar ratio (benchmark): 0.5390

# %%
bt_returns = result['portfolio_value'].pct_change()
bm_returns = bn['Benchmark'].pct_change()
price = test_data['Adj Close'].pct_change()

# %%
plt.figure(figsize=(15,10));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, bm_returns);
plt.title('Compare with Benchmark');

# %%
plt.figure(figsize=(15,10));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, price);
plt.title('Compare with close price');

# %%
fig = plt.figure(1)
plt.subplot(1,3,1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1,3,2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1,3,3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()
fig.set_size_inches(15,5)

# %%
plt.figure(figsize=(15,8))
pf.plot_return_quantiles(bt_returns);

# %%
plt.figure(figsize=(15,8))
pf.plot_rolling_beta(bt_returns, bm_returns);

# %%
plt.figure(figsize=(15,8))
pf.plot_rolling_sharpe(bt_returns);

# %%
plt.figure(figsize=(15,8))
pf.plot_drawdown_underwater(bt_returns);
