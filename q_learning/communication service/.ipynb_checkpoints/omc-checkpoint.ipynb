# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import os
import pickle
import seaborn as sns
import datetime as dt
from model import StockEnv,get_scaler, play_one_episode, LinearModel, DQNAgent
from tqdm.notebook import tqdm
import pyfolio as pf
# %matplotlib inline
# Out:
# C:\Users\User\anaconda3\envs\MyDjango\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
stock_name = 'nflx'.upper()
industry = 'Communication Services'
stock_data = pd.read_csv(f'../train_test_data/{stock_name}.csv', index_col=['Date'], parse_dates=True)

train_data = stock_data.loc[:'2018-01-01']
test_data = stock_data.loc['2018-01-01':]

print(f'Stock name: {stock_name}')
print(f'Start: {stock_data.index[0]}, End: {stock_data.index[-1]}')
print(f'Training data: {len(train_data)} ')
print(f'Tsesting data: {len(test_data)} ')

sns.set_style('whitegrid')
train_data['Adj Close'].plot(label='training_data', figsize=(15,8));
test_data['Adj Close'].plot(label='testing_data');
plt.title('Stock data '+ stock_name)
plt.legend();
plt.show()

stock_data[['rsi', 'mom']].plot(subplots=True, figsize=(15,5), title='Technical indicators');
plt.show()
# Out:
# Stock name: NFLX
# Start: 2013-02-19 00:00:00, End: 2020-12-31 00:00:00
# Training data: 1227
# Tsesting data: 756

# %%
num_episodes = 2000
batch_size = 32
capital = 1000
data = stock_data['Adj Close'].values
n_timesteps = data.shape[0]


env = StockEnv(train_data, capital)
state_size = env.state_dim
action_size = 2
agent = DQNAgent(state_size, action_size)
scaler = get_scaler(env)

# %%
#train


mode = 'train'

portfolio_value = []



for e in tqdm(range(num_episodes)):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode, scaler)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1]) 


if mode == 'train':
    # save the DQN
    agent.save(f'state_dict/{stock_name}.npz')

    # save the scaler
    with open(f'scaler/{stock_name}.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    # plot losses
    loss = agent.model.losses
    losses = pd.DataFrame(loss, columns=['loss'])
    losses.plot(figsize=(10,6))
    plt.title('Average Mean Square Error of All Episode')
    plt.xlabel('Step')
    plt.ylabel('Mean Square Error')

print(f'average reward: {np.mean(portfolio_value):.2f}, min: {np.min(portfolio_value):.2f}, max: {np.max(portfolio_value):.2f}')
sns.histplot(portfolio_value, bins=100, color='r', kde=True);
plt.xlabel('Portfolio Value');
plt.ylabel('Count');
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# episode: 1/2000, episode end value: 1935.08, duration: 0:00:00.240063
# episode: 2/2000, episode end value: 2079.78, duration: 0:00:00.196044
# episode: 3/2000, episode end value: 1938.66, duration: 0:00:00.174030
# episode: 4/2000, episode end value: 1868.50, duration: 0:00:00.170040
# episode: 5/2000, episode end value: 1951.55, duration: 0:00:00.180036
# episode: 6/2000, episode end value: 1890.91, duration: 0:00:00.167038
# episode: 7/2000, episode end value: 1922.06, duration: 0:00:00.196047
# episode: 8/2000, episode end value: 1862.13, duration: 0:00:00.167036
# episode: 9/2000, episode end value: 1970.87, duration: 0:00:00.178062
# episode: 10/2000, episode end value: 1936.08, duration: 0:00:00.179038
# episode: 11/2000, episode end value: 1953.51, duration: 0:00:00.185041
# episode: 12/2000, episode end value: 2129.56, duration: 0:00:00.182025
# episode: 13/2000, episode end value: 1986.26, duration: 0:00:00.185043
# episode: 14/2000, episode end value: 1910.61, duration: 0:00:00.184042
# episode: 15/2000, episode end value: 1907.86, duration: 0:00:00.181041
# episode: 16/2000, episode end value: 1905.88, duration: 0:00:00.190042
# episode: 17/2000, episode end value: 1921.59, duration: 0:00:00.204055
# episode: 18/2000, episode end value: 2021.85, duration: 0:00:00.184025
# episode: 19/2000, episode end value: 1979.40, duration: 0:00:00.183040
# episode: 20/2000, episode end value: 2043.47, duration: 0:00:00.177039
# episode: 21/2000, episode end value: 2059.37, duration: 0:00:00.178039
# episode: 22/2000, episode end value: 1980.82, duration: 0:00:00.185056
# episode: 23/2000, episode end value: 1993.43, duration: 0:00:00.197044
# episode: 24/2000, episode end value: 1846.80, duration: 0:00:00.185024
# episode: 25/2000, episode end value: 1852.22, duration: 0:00:00.207046
# episode: 26/2000, episode end value: 1861.17, duration: 0:00:00.204046
# episode: 27/2000, episode end value: 1951.73, duration: 0:00:00.184046
# episode: 28/2000, episode end value: 1930.27, duration: 0:00:00.177026
# episode: 29/2000, episode end value: 2109.24, duration: 0:00:00.180039
# episode: 30/2000, episode end value: 2126.80, duration: 0:00:00.180040
# episode: 31/2000, episode end value: 1930.97, duration: 0:00:00.196055
# episode: 32/2000, episode end value: 1971.48, duration: 0:00:00.183048
# episode: 33/2000, episode end value: 1939.57, duration: 0:00:00.191028
# episode: 34/2000, episode end value: 1987.44, duration: 0:00:00.198043
# episode: 35/2000, episode end value: 1857.56, duration: 0:00:00.212047
# episode: 36/2000, episode end value: 1884.79, duration: 0:00:00.208044
# episode: 37/2000, episode end value: 1875.56, duration: 0:00:00.200045
# episode: 38/2000, episode end value: 2021.27, duration: 0:00:00.185040
# episode: 39/2000, episode end value: 1969.32, duration: 0:00:00.191053
# episode: 40/2000, episode end value: 2004.76, duration: 0:00:00.184031
# episode: 41/2000, episode end value: 1987.46, duration: 0:00:00.197045
# episode: 42/2000, episode end value: 2008.37, duration: 0:00:00.198044
# episode: 43/2000, episode end value: 1952.24, duration: 0:00:00.191044
# episode: 44/2000, episode end value: 1984.57, duration: 0:00:00.194043
# episode: 45/2000, episode end value: 1981.47, duration: 0:00:00.205047
# episode: 46/2000, episode end value: 2026.04, duration: 0:00:00.197046
# episode: 47/2000, episode end value: 1915.07, duration: 0:00:00.191057
# episode: 48/2000, episode end value: 2042.13, duration: 0:00:00.188030
# episode: 49/2000, episode end value: 1982.55, duration: 0:00:00.195043
# episode: 50/2000, episode end value: 1958.81, duration: 0:00:00.183048
# episode: 51/2000, episode end value: 1995.09, duration: 0:00:00.187026
# episode: 52/2000, episode end value: 2003.50, duration: 0:00:00.191058
# episode: 53/2000, episode end value: 2096.59, duration: 0:00:00.199031
# episode: 54/2000, episode end value: 1889.95, duration: 0:00:00.184039
# episode: 55/2000, episode end value: 1899.77, duration: 0:00:00.195046
# episode: 56/2000, episode end value: 1938.78, duration: 0:00:00.184042
# episode: 57/2000, episode end value: 1882.02, duration: 0:00:00.201044
# episode: 58/2000, episode end value: 1891.43, duration: 0:00:00.201045
# episode: 59/2000, episode end value: 1840.32, duration: 0:00:00.206049
# episode: 60/2000, episode end value: 1921.55, duration: 0:00:00.209058
# episode: 61/2000, episode end value: 1913.61, duration: 0:00:00.186028
# episode: 62/2000, episode end value: 1888.90, duration: 0:00:00.212043
# episode: 63/2000, episode end value: 1951.77, duration: 0:00:00.260074
# episode: 64/2000, episode end value: 1925.67, duration: 0:00:00.260058
# episode: 65/2000, episode end value: 1930.80, duration: 0:00:00.268075
# episode: 66/2000, episode end value: 1911.36, duration: 0:00:00.255055
# episode: 67/2000, episode end value: 1910.18, duration: 0:00:00.258056
# episode: 68/2000, episode end value: 1903.08, duration: 0:00:00.273062
# episode: 69/2000, episode end value: 1930.76, duration: 0:00:00.260056
# episode: 70/2000, episode end value: 1938.42, duration: 0:00:00.244057
# episode: 71/2000, episode end value: 1927.01, duration: 0:00:00.246053
# episode: 72/2000, episode end value: 1922.52, duration: 0:00:00.287082
# episode: 73/2000, episode end value: 1907.56, duration: 0:00:00.273063
# episode: 74/2000, episode end value: 1944.55, duration: 0:00:00.248049
# episode: 75/2000, episode end value: 1909.79, duration: 0:00:00.300057
# episode: 76/2000, episode end value: 1915.81, duration: 0:00:00.287072
# episode: 77/2000, episode end value: 1917.30, duration: 0:00:00.259038
# episode: 78/2000, episode end value: 1921.40, duration: 0:00:00.251055
# episode: 79/2000, episode end value: 1970.74, duration: 0:00:00.235051
# episode: 80/2000, episode end value: 1964.16, duration: 0:00:00.249055
# episode: 81/2000, episode end value: 1936.37, duration: 0:00:00.250056
# episode: 82/2000, episode end value: 1896.68, duration: 0:00:00.243045
# episode: 83/2000, episode end value: 1934.52, duration: 0:00:00.261056
# episode: 84/2000, episode end value: 1890.97, duration: 0:00:00.257058
# episode: 85/2000, episode end value: 1915.30, duration: 0:00:00.260060
# episode: 86/2000, episode end value: 1911.67, duration: 0:00:00.241052
# episode: 87/2000, episode end value: 1933.26, duration: 0:00:00.221049
# episode: 88/2000, episode end value: 1943.48, duration: 0:00:00.260061
# episode: 89/2000, episode end value: 1942.14, duration: 0:00:00.284076
# episode: 90/2000, episode end value: 1897.30, duration: 0:00:00.230055
# episode: 91/2000, episode end value: 1915.35, duration: 0:00:00.196043
# episode: 92/2000, episode end value: 1959.00, duration: 0:00:00.215046
# episode: 93/2000, episode end value: 1945.28, duration: 0:00:00.200045
# episode: 94/2000, episode end value: 1854.52, duration: 0:00:00.191034
# episode: 95/2000, episode end value: 1875.00, duration: 0:00:00.217053
# episode: 96/2000, episode end value: 1864.96, duration: 0:00:00.235037
# episode: 97/2000, episode end value: 1874.90, duration: 0:00:00.242070
# episode: 98/2000, episode end value: 1941.07, duration: 0:00:00.255043
# episode: 99/2000, episode end value: 1884.05, duration: 0:00:00.267074
# episode: 100/2000, episode end value: 1969.41, duration: 0:00:00.209032
# episode: 101/2000, episode end value: 1900.74, duration: 0:00:00.213046
# episode: 102/2000, episode end value: 1902.06, duration: 0:00:00.250071
# episode: 103/2000, episode end value: 1896.03, duration: 0:00:00.228035
# episode: 104/2000, episode end value: 1948.46, duration: 0:00:00.266066
# episode: 105/2000, episode end value: 1880.35, duration: 0:00:00.252060
# episode: 106/2000, episode end value: 1906.06, duration: 0:00:00.243054
# episode: 107/2000, episode end value: 1898.40, duration: 0:00:00.212044
# episode: 108/2000, episode end value: 1925.09, duration: 0:00:00.200063
# episode: 109/2000, episode end value: 1861.50, duration: 0:00:00.201032
# episode: 110/2000, episode end value: 1854.92, duration: 0:00:00.198036
# episode: 111/2000, episode end value: 1878.86, duration: 0:00:00.230055
# episode: 112/2000, episode end value: 1895.99, duration: 0:00:00.219046
# episode: 113/2000, episode end value: 1978.03, duration: 0:00:00.239055
# episode: 114/2000, episode end value: 1925.42, duration: 0:00:00.188044
# episode: 115/2000, episode end value: 1911.16, duration: 0:00:00.189042
# episode: 116/2000, episode end value: 1883.97, duration: 0:00:00.217047
# episode: 117/2000, episode end value: 1904.44, duration: 0:00:00.230051
# episode: 118/2000, episode end value: 1908.05, duration: 0:00:00.247055
# episode: 119/2000, episode end value: 1899.17, duration: 0:00:00.227051
# episode: 120/2000, episode end value: 1922.30, duration: 0:00:00.240053
# episode: 121/2000, episode end value: 1928.26, duration: 0:00:00.263060
# episode: 122/2000, episode end value: 1920.28, duration: 0:00:00.252053
# episode: 123/2000, episode end value: 1931.70, duration: 0:00:00.264058
# episode: 124/2000, episode end value: 1894.19, duration: 0:00:00.225050
# episode: 125/2000, episode end value: 1925.55, duration: 0:00:00.216048
# episode: 126/2000, episode end value: 1894.80, duration: 0:00:00.209065
# episode: 127/2000, episode end value: 1891.29, duration: 0:00:00.196033
# episode: 128/2000, episode end value: 1839.63, duration: 0:00:00.188044
# episode: 129/2000, episode end value: 1874.34, duration: 0:00:00.186056
# episode: 130/2000, episode end value: 1913.53, duration: 0:00:00.195036
# episode: 131/2000, episode end value: 1926.92, duration: 0:00:00.232036
# episode: 132/2000, episode end value: 1899.15, duration: 0:00:00.217062
# episode: 133/2000, episode end value: 1907.46, duration: 0:00:00.221050
# episode: 134/2000, episode end value: 1912.05, duration: 0:00:00.245039
# episode: 135/2000, episode end value: 1888.51, duration: 0:00:00.215065
# episode: 136/2000, episode end value: 1902.10, duration: 0:00:00.200050
# episode: 137/2000, episode end value: 1940.25, duration: 0:00:00.209026
# episode: 138/2000, episode end value: 1902.74, duration: 0:00:00.212046
# episode: 139/2000, episode end value: 1938.42, duration: 0:00:00.199044
# episode: 140/2000, episode end value: 1926.04, duration: 0:00:00.181059
# episode: 141/2000, episode end value: 1860.08, duration: 0:00:00.195022
# episode: 142/2000, episode end value: 1933.43, duration: 0:00:00.230053
# episode: 143/2000, episode end value: 1904.35, duration: 0:00:00.276081
# episode: 144/2000, episode end value: 1903.39, duration: 0:00:00.250050
# episode: 145/2000, episode end value: 1915.35, duration: 0:00:00.243046
# episode: 146/2000, episode end value: 1919.09, duration: 0:00:00.215061
# episode: 147/2000, episode end value: 1865.31, duration: 0:00:00.196034
# episode: 148/2000, episode end value: 1931.69, duration: 0:00:00.199042
# episode: 149/2000, episode end value: 1880.16, duration: 0:00:00.203063
# episode: 150/2000, episode end value: 1863.22, duration: 0:00:00.189027
# episode: 151/2000, episode end value: 1947.34, duration: 0:00:00.196061
# episode: 152/2000, episode end value: 1913.89, duration: 0:00:00.229034
# episode: 153/2000, episode end value: 1928.30, duration: 0:00:00.247056
# episode: 154/2000, episode end value: 1944.10, duration: 0:00:00.240061
# episode: 155/2000, episode end value: 1940.48, duration: 0:00:00.257038
# episode: 156/2000, episode end value: 1941.72, duration: 0:00:00.234053
# episode: 157/2000, episode end value: 1907.11, duration: 0:00:00.218048
# episode: 158/2000, episode end value: 1946.88, duration: 0:00:00.220050
# episode: 159/2000, episode end value: 1907.74, duration: 0:00:00.250048
# episode: 160/2000, episode end value: 1911.83, duration: 0:00:00.265060
# episode: 161/2000, episode end value: 1881.39, duration: 0:00:00.240070
# episode: 162/2000, episode end value: 1926.57, duration: 0:00:00.223042
# episode: 163/2000, episode end value: 1901.53, duration: 0:00:00.250052
# episode: 164/2000, episode end value: 1928.51, duration: 0:00:00.227036
# episode: 165/2000, episode end value: 1912.52, duration: 0:00:00.252056
# episode: 166/2000, episode end value: 1918.55, duration: 0:00:00.253066
# episode: 167/2000, episode end value: 1928.43, duration: 0:00:00.228034
# episode: 168/2000, episode end value: 1931.22, duration: 0:00:00.228053
# episode: 169/2000, episode end value: 1913.55, duration: 0:00:00.251070
# episode: 170/2000, episode end value: 1928.51, duration: 0:00:00.237035
# episode: 171/2000, episode end value: 1914.32, duration: 0:00:00.204046
# episode: 172/2000, episode end value: 1903.47, duration: 0:00:00.257076
# episode: 173/2000, episode end value: 1943.90, duration: 0:00:00.252039
# episode: 174/2000, episode end value: 1917.71, duration: 0:00:00.234052
# episode: 175/2000, episode end value: 1917.02, duration: 0:00:00.246054
# episode: 176/2000, episode end value: 1909.75, duration: 0:00:00.280061
# episode: 177/2000, episode end value: 1914.79, duration: 0:00:00.279065
# episode: 178/2000, episode end value: 1900.29, duration: 0:00:00.257067
# episode: 179/2000, episode end value: 1938.96, duration: 0:00:00.238038
# episode: 180/2000, episode end value: 1915.46, duration: 0:00:00.246051
# episode: 181/2000, episode end value: 1873.18, duration: 0:00:00.260070
# episode: 182/2000, episode end value: 1908.96, duration: 0:00:00.232042
# episode: 183/2000, episode end value: 1904.94, duration: 0:00:00.189042
# episode: 184/2000, episode end value: 1869.48, duration: 0:00:00.185045
# episode: 185/2000, episode end value: 1854.15, duration: 0:00:00.191047
# episode: 186/2000, episode end value: 1835.38, duration: 0:00:00.202042
# episode: 187/2000, episode end value: 1838.53, duration: 0:00:00.211046
# episode: 188/2000, episode end value: 1844.04, duration: 0:00:00.210047
# episode: 189/2000, episode end value: 1916.81, duration: 0:00:00.229051
# episode: 190/2000, episode end value: 1934.63, duration: 0:00:00.224048
# episode: 191/2000, episode end value: 1899.24, duration: 0:00:00.218065
# episode: 192/2000, episode end value: 1912.25, duration: 0:00:00.239036
# episode: 193/2000, episode end value: 1942.14, duration: 0:00:00.286064
# episode: 194/2000, episode end value: 1934.87, duration: 0:00:00.270061
# episode: 195/2000, episode end value: 1943.85, duration: 0:00:00.263061
# episode: 196/2000, episode end value: 1926.53, duration: 0:00:00.248053
# episode: 197/2000, episode end value: 1946.88, duration: 0:00:00.264056
# episode: 198/2000, episode end value: 1908.38, duration: 0:00:00.287065
# episode: 199/2000, episode end value: 1927.48, duration: 0:00:00.324073
# episode: 200/2000, episode end value: 1917.56, duration: 0:00:00.272061
# episode: 201/2000, episode end value: 1961.61, duration: 0:00:00.260057
# episode: 202/2000, episode end value: 1911.37, duration: 0:00:00.251927
# episode: 203/2000, episode end value: 1858.83, duration: 0:00:00.248419
# episode: 204/2000, episode end value: 1986.08, duration: 0:00:00.245054
# episode: 205/2000, episode end value: 1903.59, duration: 0:00:00.228051
# episode: 206/2000, episode end value: 1903.51, duration: 0:00:00.222050
# episode: 207/2000, episode end value: 1914.81, duration: 0:00:00.252073
# episode: 208/2000, episode end value: 1924.74, duration: 0:00:00.226030
# episode: 209/2000, episode end value: 1882.80, duration: 0:00:00.214049
# episode: 210/2000, episode end value: 1927.38, duration: 0:00:00.211038
# episode: 211/2000, episode end value: 1902.57, duration: 0:00:00.264053
# episode: 212/2000, episode end value: 1941.58, duration: 0:00:00.265061
# episode: 213/2000, episode end value: 1915.66, duration: 0:00:00.250064
# episode: 214/2000, episode end value: 1926.92, duration: 0:00:00.277046
# episode: 215/2000, episode end value: 1912.83, duration: 0:00:00.252053
# episode: 216/2000, episode end value: 1899.98, duration: 0:00:00.237053
# episode: 217/2000, episode end value: 1960.57, duration: 0:00:00.242054
# episode: 218/2000, episode end value: 1889.41, duration: 0:00:00.239055
# episode: 219/2000, episode end value: 1924.59, duration: 0:00:00.250057
# episode: 220/2000, episode end value: 1916.30, duration: 0:00:00.227067
# episode: 221/2000, episode end value: 1968.91, duration: 0:00:00.241069
# episode: 222/2000, episode end value: 1909.97, duration: 0:00:00.248039
# episode: 223/2000, episode end value: 1857.62, duration: 0:00:00.198043
# episode: 224/2000, episode end value: 1914.92, duration: 0:00:00.189044
# episode: 225/2000, episode end value: 1897.64, duration: 0:00:00.194046
# episode: 226/2000, episode end value: 1885.66, duration: 0:00:00.206042
# episode: 227/2000, episode end value: 1903.09, duration: 0:00:00.209049
# episode: 228/2000, episode end value: 1867.70, duration: 0:00:00.232060
# episode: 229/2000, episode end value: 1868.99, duration: 0:00:00.213065
# episode: 230/2000, episode end value: 1871.69, duration: 0:00:00.220036
# episode: 231/2000, episode end value: 1904.37, duration: 0:00:00.239048
# episode: 232/2000, episode end value: 1930.39, duration: 0:00:00.254064
# episode: 233/2000, episode end value: 1915.74, duration: 0:00:00.250068
# episode: 234/2000, episode end value: 1906.74, duration: 0:00:00.266051
# episode: 235/2000, episode end value: 1904.79, duration: 0:00:00.230067
# episode: 236/2000, episode end value: 1910.66, duration: 0:00:00.238040
# episode: 237/2000, episode end value: 1891.35, duration: 0:00:00.231068
# episode: 238/2000, episode end value: 1914.45, duration: 0:00:00.197024
# episode: 239/2000, episode end value: 1862.11, duration: 0:00:00.191043
# episode: 240/2000, episode end value: 1896.01, duration: 0:00:00.177038
# episode: 241/2000, episode end value: 1949.40, duration: 0:00:00.212049
# episode: 242/2000, episode end value: 1895.39, duration: 0:00:00.206046
# episode: 243/2000, episode end value: 1912.09, duration: 0:00:00.215047
# episode: 244/2000, episode end value: 1847.00, duration: 0:00:00.212048
# episode: 245/2000, episode end value: 1867.60, duration: 0:00:00.196042
# episode: 246/2000, episode end value: 2001.46, duration: 0:00:00.189059
# episode: 247/2000, episode end value: 1950.86, duration: 0:00:00.194043
# episode: 248/2000, episode end value: 1904.88, duration: 0:00:00.193026
# episode: 249/2000, episode end value: 1850.97, duration: 0:00:00.196045
# episode: 250/2000, episode end value: 1936.98, duration: 0:00:00.201056
# episode: 251/2000, episode end value: 1930.07, duration: 0:00:00.206038
# episode: 252/2000, episode end value: 1937.63, duration: 0:00:00.186057
# episode: 253/2000, episode end value: 1910.44, duration: 0:00:00.202049
# episode: 254/2000, episode end value: 1905.36, duration: 0:00:00.210034
# episode: 255/2000, episode end value: 1959.98, duration: 0:00:00.206043
# episode: 256/2000, episode end value: 1896.32, duration: 0:00:00.207047
# episode: 257/2000, episode end value: 1947.04, duration: 0:00:00.207063
# episode: 258/2000, episode end value: 1893.76, duration: 0:00:00.205042
# episode: 259/2000, episode end value: 1906.69, duration: 0:00:00.204040
# episode: 260/2000, episode end value: 1944.75, duration: 0:00:00.201060
# episode: 261/2000, episode end value: 1891.91, duration: 0:00:00.195047
# episode: 262/2000, episode end value: 1944.91, duration: 0:00:00.193026
# episode: 263/2000, episode end value: 1918.61, duration: 0:00:00.208045
# episode: 264/2000, episode end value: 1923.92, duration: 0:00:00.195052
# episode: 265/2000, episode end value: 1927.00, duration: 0:00:00.206034
# episode: 266/2000, episode end value: 1914.58, duration: 0:00:00.205044
# episode: 267/2000, episode end value: 1856.73, duration: 0:00:00.198046
# episode: 268/2000, episode end value: 1856.57, duration: 0:00:00.213626
# episode: 269/2000, episode end value: 1906.78, duration: 0:00:00.243096
# episode: 270/2000, episode end value: 1932.74, duration: 0:00:00.237050
# episode: 271/2000, episode end value: 1897.88, duration: 0:00:00.250056
# episode: 272/2000, episode end value: 1881.51, duration: 0:00:00.208056
# episode: 273/2000, episode end value: 1881.44, duration: 0:00:00.214039
# episode: 274/2000, episode end value: 1877.22, duration: 0:00:00.222064
# episode: 275/2000, episode end value: 1873.53, duration: 0:00:00.215233
# episode: 276/2000, episode end value: 1950.84, duration: 0:00:00.254449
# episode: 277/2000, episode end value: 1932.45, duration: 0:00:00.244113
# episode: 278/2000, episode end value: 1955.30, duration: 0:00:00.242030
# episode: 279/2000, episode end value: 1915.66, duration: 0:00:00.249968
# episode: 280/2000, episode end value: 1897.01, duration: 0:00:00.241044
# episode: 281/2000, episode end value: 1876.57, duration: 0:00:00.203579
# episode: 282/2000, episode end value: 1859.07, duration: 0:00:00.211142
# episode: 283/2000, episode end value: 1907.98, duration: 0:00:00.217033
# episode: 284/2000, episode end value: 1891.86, duration: 0:00:00.248065
# episode: 285/2000, episode end value: 1878.42, duration: 0:00:00.196027
# episode: 286/2000, episode end value: 1912.92, duration: 0:00:00.195045
# episode: 287/2000, episode end value: 1923.80, duration: 0:00:00.191044
# episode: 288/2000, episode end value: 1840.00, duration: 0:00:00.187055
# episode: 289/2000, episode end value: 1885.16, duration: 0:00:00.194046
# episode: 290/2000, episode end value: 1837.15, duration: 0:00:00.198044
# episode: 291/2000, episode end value: 1858.01, duration: 0:00:00.217044
# episode: 292/2000, episode end value: 1891.85, duration: 0:00:00.214043
# episode: 293/2000, episode end value: 1887.99, duration: 0:00:00.217044
# episode: 294/2000, episode end value: 1925.42, duration: 0:00:00.220050
# episode: 295/2000, episode end value: 1930.40, duration: 0:00:00.287062
# episode: 296/2000, episode end value: 1904.67, duration: 0:00:00.260058
# episode: 297/2000, episode end value: 1916.00, duration: 0:00:00.218047
# episode: 298/2000, episode end value: 1931.02, duration: 0:00:00.225053
# episode: 299/2000, episode end value: 1895.95, duration: 0:00:00.245051
# episode: 300/2000, episode end value: 1855.44, duration: 0:00:00.246055
# episode: 301/2000, episode end value: 1912.77, duration: 0:00:00.253059
# episode: 302/2000, episode end value: 1933.16, duration: 0:00:00.249068
# episode: 303/2000, episode end value: 1886.49, duration: 0:00:00.251057
# episode: 304/2000, episode end value: 1943.61, duration: 0:00:00.242037
# episode: 305/2000, episode end value: 1910.15, duration: 0:00:00.249056
# episode: 306/2000, episode end value: 1914.32, duration: 0:00:00.221067
# episode: 307/2000, episode end value: 1890.16, duration: 0:00:00.228035
# episode: 308/2000, episode end value: 1899.63, duration: 0:00:00.242060
# episode: 309/2000, episode end value: 1892.78, duration: 0:00:00.234033
# episode: 310/2000, episode end value: 1922.62, duration: 0:00:00.221044
# episode: 311/2000, episode end value: 1939.39, duration: 0:00:00.237053
# episode: 312/2000, episode end value: 1889.51, duration: 0:00:00.222054
# episode: 313/2000, episode end value: 1881.09, duration: 0:00:00.222047
# episode: 314/2000, episode end value: 1892.31, duration: 0:00:00.231049
# episode: 315/2000, episode end value: 1917.62, duration: 0:00:00.270062
# episode: 316/2000, episode end value: 1896.65, duration: 0:00:00.271058
# episode: 317/2000, episode end value: 1907.51, duration: 0:00:00.273069
# episode: 318/2000, episode end value: 1922.48, duration: 0:00:00.284052
# episode: 319/2000, episode end value: 1931.01, duration: 0:00:00.261056
# episode: 320/2000, episode end value: 1927.53, duration: 0:00:00.232067
# episode: 321/2000, episode end value: 1885.16, duration: 0:00:00.224044
# episode: 322/2000, episode end value: 1938.49, duration: 0:00:00.264065
# episode: 323/2000, episode end value: 1911.99, duration: 0:00:00.241046
# episode: 324/2000, episode end value: 1930.11, duration: 0:00:00.254061
# episode: 325/2000, episode end value: 1965.17, duration: 0:00:00.265066
# episode: 326/2000, episode end value: 1932.51, duration: 0:00:00.206039
# episode: 327/2000, episode end value: 1884.48, duration: 0:00:00.201041
# episode: 328/2000, episode end value: 1898.98, duration: 0:00:00.219049
# episode: 329/2000, episode end value: 1962.78, duration: 0:00:00.228061
# episode: 330/2000, episode end value: 1904.78, duration: 0:00:00.229042
# episode: 331/2000, episode end value: 1920.47, duration: 0:00:00.199044
# episode: 332/2000, episode end value: 2084.49, duration: 0:00:00.189235
# episode: 333/2000, episode end value: 1919.00, duration: 0:00:00.199027
# episode: 334/2000, episode end value: 1899.03, duration: 0:00:00.207046
# episode: 335/2000, episode end value: 1919.86, duration: 0:00:00.196056
# episode: 336/2000, episode end value: 1914.94, duration: 0:00:00.194043
# episode: 337/2000, episode end value: 1883.70, duration: 0:00:00.190023
# episode: 338/2000, episode end value: 1868.12, duration: 0:00:00.188059
# episode: 339/2000, episode end value: 1843.78, duration: 0:00:00.177041
# episode: 340/2000, episode end value: 1835.85, duration: 0:00:00.202030
# episode: 341/2000, episode end value: 1867.17, duration: 0:00:00.198047
# episode: 342/2000, episode end value: 1878.44, duration: 0:00:00.205059
# episode: 343/2000, episode end value: 1860.39, duration: 0:00:00.229035
# episode: 344/2000, episode end value: 1870.49, duration: 0:00:00.219047
# episode: 345/2000, episode end value: 1856.05, duration: 0:00:00.210046
# episode: 346/2000, episode end value: 1880.70, duration: 0:00:00.201059
# episode: 347/2000, episode end value: 1886.13, duration: 0:00:00.227050
# episode: 348/2000, episode end value: 1912.69, duration: 0:00:00.267571
# episode: 349/2000, episode end value: 1903.58, duration: 0:00:00.208064
# episode: 350/2000, episode end value: 1911.35, duration: 0:00:00.187022
# episode: 351/2000, episode end value: 1916.13, duration: 0:00:00.188044
# episode: 352/2000, episode end value: 1916.11, duration: 0:00:00.216057
# episode: 353/2000, episode end value: 1908.45, duration: 0:00:00.200028
# episode: 354/2000, episode end value: 1856.38, duration: 0:00:00.187042
# episode: 355/2000, episode end value: 1950.78, duration: 0:00:00.191044
# episode: 356/2000, episode end value: 1864.66, duration: 0:00:00.216046
# episode: 357/2000, episode end value: 1879.72, duration: 0:00:00.209708
# episode: 358/2000, episode end value: 1886.42, duration: 0:00:00.199889
# episode: 359/2000, episode end value: 1912.57, duration: 0:00:00.205031
# episode: 360/2000, episode end value: 1876.80, duration: 0:00:00.219048
# episode: 361/2000, episode end value: 1959.74, duration: 0:00:00.280072
# episode: 362/2000, episode end value: 1910.76, duration: 0:00:00.234061
# episode: 363/2000, episode end value: 1888.56, duration: 0:00:00.249039
# episode: 364/2000, episode end value: 1904.89, duration: 0:00:00.225047
# episode: 365/2000, episode end value: 1926.80, duration: 0:00:00.262075
# episode: 366/2000, episode end value: 1894.13, duration: 0:00:00.241038
# episode: 367/2000, episode end value: 1873.57, duration: 0:00:00.216051
# episode: 368/2000, episode end value: 1837.94, duration: 0:00:00.230973
# episode: 369/2000, episode end value: 1873.16, duration: 0:00:00.192129
# episode: 370/2000, episode end value: 1864.50, duration: 0:00:00.212036
# episode: 371/2000, episode end value: 1876.36, duration: 0:00:00.217044
# episode: 372/2000, episode end value: 1917.20, duration: 0:00:00.251057
# episode: 373/2000, episode end value: 1911.02, duration: 0:00:00.250073
# episode: 374/2000, episode end value: 1843.66, duration: 0:00:00.241037
# episode: 375/2000, episode end value: 1910.89, duration: 0:00:00.272080
# episode: 376/2000, episode end value: 1885.85, duration: 0:00:00.234043
# episode: 377/2000, episode end value: 1924.99, duration: 0:00:00.266070
# episode: 378/2000, episode end value: 1915.62, duration: 0:00:00.244053
# episode: 379/2000, episode end value: 1923.86, duration: 0:00:00.235067
# episode: 380/2000, episode end value: 1901.58, duration: 0:00:00.259043
# episode: 381/2000, episode end value: 1923.24, duration: 0:00:00.237073
# episode: 382/2000, episode end value: 1930.49, duration: 0:00:00.224032
# episode: 383/2000, episode end value: 1893.54, duration: 0:00:00.224050
# episode: 384/2000, episode end value: 1876.96, duration: 0:00:00.244057
# episode: 385/2000, episode end value: 1918.72, duration: 0:00:00.241053
# episode: 386/2000, episode end value: 1879.79, duration: 0:00:00.273977
# episode: 387/2000, episode end value: 1904.17, duration: 0:00:00.232067
# episode: 388/2000, episode end value: 1909.28, duration: 0:00:00.248052
# episode: 389/2000, episode end value: 1915.71, duration: 0:00:00.233053
# episode: 390/2000, episode end value: 1918.17, duration: 0:00:00.255058
# episode: 391/2000, episode end value: 1887.94, duration: 0:00:00.234053
# episode: 392/2000, episode end value: 1914.91, duration: 0:00:00.218046
# episode: 393/2000, episode end value: 1907.22, duration: 0:00:00.218048
# episode: 394/2000, episode end value: 1912.67, duration: 0:00:00.252060
# episode: 395/2000, episode end value: 1895.23, duration: 0:00:00.270057
# episode: 396/2000, episode end value: 1904.56, duration: 0:00:00.269079
# episode: 397/2000, episode end value: 1917.68, duration: 0:00:00.257049
# episode: 398/2000, episode end value: 1903.75, duration: 0:00:00.241054
# episode: 399/2000, episode end value: 1914.88, duration: 0:00:00.240058
# episode: 400/2000, episode end value: 1885.20, duration: 0:00:00.260061
# episode: 401/2000, episode end value: 1893.05, duration: 0:00:00.257040
# episode: 402/2000, episode end value: 1917.70, duration: 0:00:00.261066
# episode: 403/2000, episode end value: 1939.65, duration: 0:00:00.244033
# episode: 404/2000, episode end value: 1958.69, duration: 0:00:00.227058
# episode: 405/2000, episode end value: 1925.88, duration: 0:00:00.252047
# episode: 406/2000, episode end value: 1925.14, duration: 0:00:00.257060
# episode: 407/2000, episode end value: 1894.78, duration: 0:00:00.270050
# episode: 408/2000, episode end value: 1914.83, duration: 0:00:00.257057
# episode: 409/2000, episode end value: 1889.32, duration: 0:00:00.241055
# episode: 410/2000, episode end value: 1905.40, duration: 0:00:00.257058
# episode: 411/2000, episode end value: 1916.76, duration: 0:00:00.263057
# episode: 412/2000, episode end value: 1926.25, duration: 0:00:00.242055
# episode: 413/2000, episode end value: 1907.58, duration: 0:00:00.236054
# episode: 414/2000, episode end value: 1856.88, duration: 0:00:00.226046
# episode: 415/2000, episode end value: 1933.41, duration: 0:00:00.254060
# episode: 416/2000, episode end value: 1934.94, duration: 0:00:00.237046
# episode: 417/2000, episode end value: 1888.51, duration: 0:00:00.204046
# episode: 418/2000, episode end value: 1888.18, duration: 0:00:00.224031
# episode: 419/2000, episode end value: 1891.35, duration: 0:00:00.231054
# episode: 420/2000, episode end value: 1886.71, duration: 0:00:00.249053
# episode: 421/2000, episode end value: 1892.41, duration: 0:00:00.233061
# episode: 422/2000, episode end value: 1907.02, duration: 0:00:00.262063
# episode: 423/2000, episode end value: 1890.70, duration: 0:00:00.220050
# episode: 424/2000, episode end value: 1945.54, duration: 0:00:00.221048
# episode: 425/2000, episode end value: 1917.03, duration: 0:00:00.232052
# episode: 426/2000, episode end value: 1825.70, duration: 0:00:00.196037
# episode: 427/2000, episode end value: 1949.70, duration: 0:00:00.197042
# episode: 428/2000, episode end value: 1866.76, duration: 0:00:00.204048
# episode: 429/2000, episode end value: 1910.66, duration: 0:00:00.234053
# episode: 430/2000, episode end value: 1897.85, duration: 0:00:00.201058
# episode: 431/2000, episode end value: 1912.01, duration: 0:00:00.221031
# episode: 432/2000, episode end value: 1883.02, duration: 0:00:00.197045
# episode: 433/2000, episode end value: 1923.24, duration: 0:00:00.224052
# episode: 434/2000, episode end value: 1918.45, duration: 0:00:00.229049
# episode: 435/2000, episode end value: 1901.97, duration: 0:00:00.270061
# episode: 436/2000, episode end value: 1900.33, duration: 0:00:00.279063
# episode: 437/2000, episode end value: 1920.81, duration: 0:00:00.280064
# episode: 438/2000, episode end value: 1902.64, duration: 0:00:00.236055
# episode: 439/2000, episode end value: 1909.93, duration: 0:00:00.266076
# episode: 440/2000, episode end value: 1914.02, duration: 0:00:00.278055
# episode: 441/2000, episode end value: 1923.67, duration: 0:00:00.241060
# episode: 442/2000, episode end value: 1896.90, duration: 0:00:00.257042
# episode: 443/2000, episode end value: 1933.91, duration: 0:00:00.239054
# episode: 444/2000, episode end value: 1889.41, duration: 0:00:00.233054
# episode: 445/2000, episode end value: 1902.01, duration: 0:00:00.197042
# episode: 446/2000, episode end value: 1880.43, duration: 0:00:00.200044
# episode: 447/2000, episode end value: 1904.45, duration: 0:00:00.185041
# episode: 448/2000, episode end value: 1928.58, duration: 0:00:00.195044
# episode: 449/2000, episode end value: 1872.05, duration: 0:00:00.201064
# episode: 450/2000, episode end value: 1927.49, duration: 0:00:00.223064
# episode: 451/2000, episode end value: 1900.87, duration: 0:00:00.266046
# episode: 452/2000, episode end value: 1916.14, duration: 0:00:00.273061
# episode: 453/2000, episode end value: 1916.61, duration: 0:00:00.253054
# episode: 454/2000, episode end value: 1871.01, duration: 0:00:00.262058
# episode: 455/2000, episode end value: 1889.19, duration: 0:00:00.237055
# episode: 456/2000, episode end value: 1919.07, duration: 0:00:00.247053
# episode: 457/2000, episode end value: 1905.38, duration: 0:00:00.284063
# episode: 458/2000, episode end value: 1909.41, duration: 0:00:00.265061
# episode: 459/2000, episode end value: 1898.49, duration: 0:00:00.251054

# %%
plt.plot(agent.model.losses)

# %%
plt.plot(portfolio_value)

# %%
#test

mode = 'test'

portfolio_value = []


with open(f'scaler/{stock_name}.pkl', 'rb') as f:
    scaler = pickle.load(f)
    
env = StockEnv(test_data, capital)
agent.epsilon = 0
agent.load(f'state_dict/{stock_name}.npz')



t0 = datetime.now()
val = play_one_episode(agent, env, mode, scaler)
dt = datetime.now() - t0
print(f"episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
portfolio_value.append(val['portfolio_value'][-1])
    
print(f"Sell: {env.sell_buy.count('sell')} times, Buy: {env.sell_buy.count('buy')} times")



result = pd.DataFrame(val)
result.index = test_data.index

def marker_buy(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'buy':
        return price
    else:
        return np.nan
    
def marker_sell(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'sell':
        return price
    else:
        return np.nan
    
result['marker_buy'] = result[['stock_price', 'sell_buy']].apply(marker_buy, axis=1);
result['marker_sell'] = result[['stock_price', 'sell_buy']].apply(marker_sell, axis=1);

result['stock_price'].plot(figsize=(10,6), c='grey', lw=2);
result['marker_buy'].plot(style='o', ms=7, label='buy', c='g', alpha=0.5);
result['marker_sell'].plot(style='o', ms=7, label='sell', c='r', alpha=0.5);
plt.title('Stock Price '+ stock_name)
plt.legend();
plt.show()



result['portfolio_value'].plot(figsize=(10,6), c='r', lw=2);
plt.title('Portfolio Value');
plt.show()

result['stock_owned'].plot(figsize=(10,6), c='purple', lw=2);
plt.title('Position')
plt.show()

result[['cash_in_hand', 'stock_value']].plot(figsize=(10,6), lw=2);
plt.title('Cash in Hand and Stock Value');
plt.show()
# Out:
# episode end value: 1315.53, duration: 0:00:00.053028
# Sell: 23 times, Buy: 24 times

# %%
def CAGR(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    
    df['cumulative_ret'] = (1 + df['daily_ret']).cumprod()
    n = len(df)/252
    cagr = (df['cumulative_ret'][-1])**(1/n) - 1
    return cagr

def volatility(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    vol = df['daily_ret'].std() * np.sqrt(252)
    return vol


def sharpe(DF, rf):
    df = DF.copy()
    sr = (CAGR(df) - rf)/volatility(df)
    return sr

def max_dd(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    df['cumulative_ret'] = (1 + df['daily_ret']).cumprod()
    df['cum_roll_max'] = df['cumulative_ret'].cummax()
    df['drawdown'] = df['cum_roll_max'] - df['cumulative_ret']
    df['drawdown_pct'] = df['drawdown']/df['cum_roll_max']
    max_dd = df['drawdown_pct'].max()
    return max_dd

def calmer(DF):
    df = DF.copy()
    clmr = CAGR(df)/max_dd(df)
    return clmr



print(f'Stock name: {stock_name}')
print(f'Start: {result.index[0]}  End: {result.index[-1]}')
print(f'Compound Annual Growth Rate: {CAGR(result)*100:.2f} %')
print(f'Volatility: {volatility(result):.4f}')
print(f'shape ratio: {sharpe(result, 0.011):.4f}')
print(f'Maximun drawdown: {max_dd(result)*-100:.2f} %')
print(f'Calmar ratio: {calmer(result):.4f}')
print('-----------------------------------------------------------')
print('-----------------------------------------------------------')
print('Comparing with Adj close')
print(f'Compound Annual Growth Rate (Adj close): {CAGR(test_data)*100:.2f} %')
print(f'Volatility (benchmark): {volatility(test_data):.4f}')
print(f'shape ratio: {sharpe(test_data, 0.011):.4f}')
print(f'Maximun drawdown: {max_dd(test_data)*-100:.2f} %')
print(f'Calmar ratio (benchmark): {calmer(test_data):.4f}')
# Out:
# Stock name: DIS
# Start: 2018-01-02 00:00:00  End: 2020-12-31 00:00:00
# Compound Annual Growth Rate: 9.57 %
# Volatility: 0.1481
# shape ratio: 0.5721
# Maximun drawdown: -24.42 %
# Calmar ratio: 0.3920
# -----------------------------------------------------------
# -----------------------------------------------------------
# Comparing with Adj close
# Compound Annual Growth Rate (Adj close): 17.46 %
# Volatility (benchmark): 0.3340
# shape ratio: 0.4898
# Maximun drawdown: -43.44 %
# Calmar ratio (benchmark): 0.4019

# %%
bt_returns = result['portfolio_value'].pct_change()
price = result['stock_price'].pct_change()



plt.figure(figsize=(9,6));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, price);
plt.title('Compare with close price');
plt.show()

fig = plt.figure(1)
plt.subplot(1,3,1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1,3,2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1,3,3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()
fig.set_size_inches(12,4)

plt.figure(figsize=(9,6))
pf.plot_return_quantiles(bt_returns);



plt.figure(figsize=(9,6))
pf.plot_rolling_sharpe(bt_returns);

plt.figure(figsize=(9,6))
pf.plot_drawdown_underwater(bt_returns);

score = (sharpe(result, 0.011) - sharpe(test_data, 0.011))*10
ret = ((result['portfolio_value'][-1] - result['portfolio_value'][0])/result['portfolio_value'][0]) * 100
with open(f'score/{stock_name}.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
    pickle.dump([stock_name, industry,score, ret], f)
    
    
result.to_csv(f'../data/{stock_name}.csv')
