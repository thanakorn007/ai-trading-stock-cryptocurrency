# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import pandas_datareader as web
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import os
import pickle
import seaborn as sns
import datetime as dt
import yfinance as yf
import talib
from tqdm.notebook import tqdm
# %matplotlib inline


class LinearModel:
    def __init__(self, input_dim, n_action):
        self.W = np.random.randn(input_dim, n_action) / np.sqrt(input_dim)
        self.b = np.zeros(n_action)
        self.vW = 0
        self.vb = 0
        self.losses = []
        
    def predict(self, s):
        return s.dot(self.W) + self.b
    
    def sgd(self, s, Y, learning_rate=0.001, momentum=0.9):
        num_values = np.prod(Y.shape)
        Y_hat = self.predict(s)
        Y_hat = self.predict(s)  # shape (1, 8)
        gW = 2 * s.T.dot(Y_hat - Y) / num_values  # vector shape (7, 8)
        gb = 2 * (Y_hat - Y).sum(axis=0) / num_values  # scalar

        self.vW = momentum * self.vW - learning_rate * gW  # vector shape (7, 8)
        self.vb = momentum * self.vb - learning_rate * gb  # scalar

        self.W += self.vW  # vector shape (7, 8)
        self.b += self.vb  # scalar

        mse = np.mean((Y_hat - Y) ** 2)
        self.losses.append(mse)
        
        
    def save_weights(self, filepath):
        np.savez(filepath, W=self.W, b=self.b)


    def load_weights(self, filepath):
        npz = np.load(filepath)
        self.W = npz['W']
        self.b = npz['b']
        
        
def maybe_make_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        
        
class Env:
    def __init__(self, data, capital):
        self.stock_price_history = data['Adj Close']
        self.n_step = self.stock_price_history.shape[0]
        self.capital = capital
        self.current_step = None
        self.stock_owned = None
        self.stock_price = None
        self.cash_in_hand = None
        self.state_dim = 5 #[stock price, stock_owned, cash__in_hand, rsi, mom]
        self.save_position = []
        self.save_port_val = [] 
        self.save_cash = []
        self.stock_value = []
        self.action_space = [0,1,2]
        self.sell_buy = []
        self.save_stock_price = []
        self.rsi = data['rsi']
        self.mom = data['mom']
        self.reset()
        
        
    def state_vector(self):
        vector = np.empty(self.state_dim)
        vector[0] = self.stock_price
        vector[1] = self.stock_owned
        vector[2] = self.cash_in_hand
        vector[3] = self.rsi[self.current_step]
        vector[4] = self.mom[self.current_step]
        return vector
    
    
    def reset(self):
        self.current_step = 0
        self.stock_owned = 0
        self.stock_price = self.stock_price_history[self.current_step]
        self.cash_in_hand = self.capital
        self.save_position = [0]
        self.save_port_val = [self.capital] 
        self.save_cash = [self.capital]
        self.stock_value = [0]
        self.sell_buy = ['hold']
        self.save_stock_price = [self.stock_price]
        return self.state_vector()
    

    
    def port_val(self):
        return (self.stock_owned * self.stock_price) + self.cash_in_hand
    
        
      
    def trade(self, action):
        '''
        action 0 = hold
        action 1 = buy
        action 2 = sell
        '''
        assert action in self.action_space
        
        if action == 1 and self.stock_owned == 0:
            self.stock_owned += (self.cash_in_hand / self.stock_price)
            self.cash_in_hand = 0
            self.sell_buy.append('buy')
            
        elif action == 2 and self.cash_in_hand == 0:
            self.cash_in_hand += (self.stock_owned * self.stock_price)
            self.stock_owned = 0
            self.sell_buy.append('sell')    
        
                
        else:
            self.sell_buy.append('hold')
            
        self.save_cash.append(self.cash_in_hand)
        self.save_port_val.append(self.port_val())
        self.save_position.append(self.stock_owned)
        self.stock_value.append(self.stock_owned * self.stock_price)
        self.save_stock_price.append(self.stock_price)
        
          
        
                
    def step(self, action):
        assert action in self.action_space
        
        prev_val = self.port_val()
        self.current_step += 1
        self.stock_price = self.stock_price_history[self.current_step]
        
        self.trade(action)
        current_val = self.port_val()
        reward = current_val - prev_val
        done = self.current_step == self.n_step - 1
        info = {'stock_price': self.save_stock_price,
                'portfolio_value': self.save_port_val,
#                 'current_val': self.port_val(),
                'stock_owned': self.save_position,
                'cash_in_hand': self.save_cash,
                'stock_value': self.stock_value,
                'sell_buy':self.sell_buy
               }
        
        return self.state_vector(), reward, done, info
    
    
def get_scaler(env):
    states = []
    for i in range(env.n_step):
        action = np.random.choice(env.action_space)
        state, reward, done, info = env.step(action)
        states.append(state)
        if done:
            break
    scaler = StandardScaler()
    scaler.fit(states)
    return scaler


class DQNAgent(object):
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = LinearModel(state_size, action_size)

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action


    def train(self, state, action, reward, next_state, done):
        if done:
            target = reward
        else:
            target = reward + self.gamma * np.amax(self.model.predict(next_state), axis=1)

        target_full = self.model.predict(state)
        target_full[0, action] = target

        # Run one training step
        self.model.sgd(state, target_full)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay


    def load(self, name):
        self.model.load_weights(name)


    def save(self, name):
        self.model.save_weights(name)
        
        
def play_one_episode(agent, env, is_train):
    state = env.reset()
    state = scaler.transform([state])
    done = False
    
    while not done:
        action = agent.act(state)
        next_state, reward, done, info = env.step(action)
        next_state = scaler.transform([next_state])
        
        if is_train == 'train':
            agent.train(state, action, reward, next_state, done)
        
        state = next_state
    
    return info

# %%
stock_name = 'nflx'.upper()
stock_data = pd.read_csv(f'../train_test_data/{stock_name}.csv', index_col=['Date'], parse_dates=True)

train_data = stock_data.loc[:'2018-01-01']
test_data = stock_data.loc['2018-01-01':]



models_folder = 'q_learn'
rewards_folder = 'q_reward'
maybe_make_dir(models_folder)
maybe_make_dir(rewards_folder)
num_episodes = 2000
batch_size = 32
capital = 1000
data = stock_data['Adj Close'].values
n_timesteps = data.shape[0]


env = Env(train_data, capital)
state_size = env.state_dim
action_size = 3
agent = DQNAgent(state_size, action_size)
scaler = get_scaler(env)

# %%
#train


mode = 'train'

portfolio_value = []

if mode == 'test':
    with open(f'{models_folder}/scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    num_episodes = 1
    env = Env(test_data, capital)
    agent.epsilon = 0
    agent.load(f'{models_folder}/linear.npz')


for e in tqdm(range(num_episodes)):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1]) 


if mode == 'train':
    # save the DQN
    agent.save(f'{models_folder}/linear.npz')

    # save the scaler
    with open(f'{models_folder}/scaler.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    # plot losses
    loss = agent.model.losses
    losses = pd.DataFrame(loss, columns=['loss'])
    losses.plot(figsize=(10,6))
    plt.title('Average Mean Square Error of All Episode')
    plt.xlabel('Step')
    plt.ylabel('Mean Square Error')

print(f'average reward: {np.mean(portfolio_value):.2f}, min: {np.min(portfolio_value):.2f}, max: {np.max(portfolio_value):.2f}')
sns.histplot(portfolio_value, bins=100, color='r', kde=True);
plt.xlabel('Portfolio Value');
plt.ylabel('Count');
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# episode: 1/2000, episode end value: 3448.75, duration: 0:00:00.163035
# episode: 2/2000, episode end value: 6544.00, duration: 0:00:00.159035
# episode: 3/2000, episode end value: 5808.42, duration: 0:00:00.163036
# episode: 4/2000, episode end value: 3952.65, duration: 0:00:00.163037
# episode: 5/2000, episode end value: 6917.54, duration: 0:00:00.162038
# episode: 6/2000, episode end value: 4476.61, duration: 0:00:00.163044
# episode: 7/2000, episode end value: 7687.59, duration: 0:00:00.168036
# episode: 8/2000, episode end value: 7701.34, duration: 0:00:00.169021
# episode: 9/2000, episode end value: 6758.32, duration: 0:00:00.160036
# episode: 10/2000, episode end value: 4503.79, duration: 0:00:00.163036
# episode: 11/2000, episode end value: 5287.95, duration: 0:00:00.162036
# episode: 12/2000, episode end value: 5294.44, duration: 0:00:00.153031
# episode: 13/2000, episode end value: 9019.07, duration: 0:00:00.162036
# episode: 14/2000, episode end value: 6728.61, duration: 0:00:00.160036
# episode: 15/2000, episode end value: 9126.68, duration: 0:00:00.160035
# episode: 16/2000, episode end value: 3198.45, duration: 0:00:00.162035
# episode: 17/2000, episode end value: 6545.78, duration: 0:00:00.161037
# episode: 18/2000, episode end value: 7865.89, duration: 0:00:00.157035
# episode: 19/2000, episode end value: 7593.37, duration: 0:00:00.160050
# episode: 20/2000, episode end value: 2682.38, duration: 0:00:00.156035
# episode: 21/2000, episode end value: 2344.22, duration: 0:00:00.162021
# episode: 22/2000, episode end value: 2644.37, duration: 0:00:00.165036
# episode: 23/2000, episode end value: 4005.00, duration: 0:00:00.161036
# episode: 24/2000, episode end value: 4755.65, duration: 0:00:00.156049
# episode: 25/2000, episode end value: 5895.62, duration: 0:00:00.156020
# episode: 26/2000, episode end value: 7930.07, duration: 0:00:00.164036
# episode: 27/2000, episode end value: 6975.13, duration: 0:00:00.171038
# episode: 28/2000, episode end value: 7062.47, duration: 0:00:00.162035
# episode: 29/2000, episode end value: 13540.91, duration: 0:00:00.166037
# episode: 30/2000, episode end value: 4751.11, duration: 0:00:00.158049
# episode: 31/2000, episode end value: 7756.71, duration: 0:00:00.161022
# episode: 32/2000, episode end value: 6393.27, duration: 0:00:00.160038
# episode: 33/2000, episode end value: 2575.87, duration: 0:00:00.161053
# episode: 34/2000, episode end value: 3266.43, duration: 0:00:00.157034
# episode: 35/2000, episode end value: 4275.46, duration: 0:00:00.161034
# episode: 36/2000, episode end value: 2879.19, duration: 0:00:00.162036
# episode: 37/2000, episode end value: 3117.59, duration: 0:00:00.159050
# episode: 38/2000, episode end value: 3673.80, duration: 0:00:00.163024
# episode: 39/2000, episode end value: 3652.39, duration: 0:00:00.159034
# episode: 40/2000, episode end value: 5443.70, duration: 0:00:00.162036
# episode: 41/2000, episode end value: 3185.55, duration: 0:00:00.164037
# episode: 42/2000, episode end value: 3502.52, duration: 0:00:00.168037
# episode: 43/2000, episode end value: 2850.49, duration: 0:00:00.166037
# episode: 44/2000, episode end value: 1181.33, duration: 0:00:00.160038
# episode: 45/2000, episode end value: 2816.97, duration: 0:00:00.162033
# episode: 46/2000, episode end value: 1797.32, duration: 0:00:00.153047
# episode: 47/2000, episode end value: 1694.79, duration: 0:00:00.163022
# episode: 48/2000, episode end value: 2896.63, duration: 0:00:00.160036
# episode: 49/2000, episode end value: 3666.61, duration: 0:00:00.166053
# episode: 50/2000, episode end value: 2130.37, duration: 0:00:00.161035
# episode: 51/2000, episode end value: 6926.57, duration: 0:00:00.162042
# episode: 52/2000, episode end value: 5810.75, duration: 0:00:00.177021
# episode: 53/2000, episode end value: 6834.42, duration: 0:00:00.169037
# episode: 54/2000, episode end value: 7471.38, duration: 0:00:00.173064
# episode: 55/2000, episode end value: 6976.23, duration: 0:00:00.158032
# episode: 56/2000, episode end value: 7150.48, duration: 0:00:00.163019
# episode: 57/2000, episode end value: 4215.00, duration: 0:00:00.151033
# episode: 58/2000, episode end value: 3130.67, duration: 0:00:00.160036
# episode: 59/2000, episode end value: 1569.06, duration: 0:00:00.161036
# episode: 60/2000, episode end value: 5978.91, duration: 0:00:00.172039
# episode: 61/2000, episode end value: 5843.00, duration: 0:00:00.166037
# episode: 62/2000, episode end value: 7515.04, duration: 0:00:00.173040
# episode: 63/2000, episode end value: 5765.83, duration: 0:00:00.171038
# episode: 64/2000, episode end value: 4557.80, duration: 0:00:00.175038
# episode: 65/2000, episode end value: 6828.18, duration: 0:00:00.181040
# episode: 66/2000, episode end value: 7356.92, duration: 0:00:00.170038
# episode: 67/2000, episode end value: 6583.81, duration: 0:00:00.174039
# episode: 68/2000, episode end value: 6849.15, duration: 0:00:00.163037
# episode: 69/2000, episode end value: 7583.70, duration: 0:00:00.155047
# episode: 70/2000, episode end value: 3898.01, duration: 0:00:00.166032
# episode: 71/2000, episode end value: 7653.49, duration: 0:00:00.157036
# episode: 72/2000, episode end value: 5985.98, duration: 0:00:00.163033
# episode: 73/2000, episode end value: 6629.46, duration: 0:00:00.170038
# episode: 74/2000, episode end value: 3107.55, duration: 0:00:00.163036
# episode: 75/2000, episode end value: 5851.20, duration: 0:00:00.167037
# episode: 76/2000, episode end value: 4604.70, duration: 0:00:00.160050
# episode: 77/2000, episode end value: 6696.43, duration: 0:00:00.158038
# episode: 78/2000, episode end value: 5771.65, duration: 0:00:00.166020
# episode: 79/2000, episode end value: 8098.60, duration: 0:00:00.171055
# episode: 80/2000, episode end value: 8380.93, duration: 0:00:00.167022
# episode: 81/2000, episode end value: 6620.36, duration: 0:00:00.167037
# episode: 82/2000, episode end value: 3218.65, duration: 0:00:00.163036
# episode: 83/2000, episode end value: 3992.06, duration: 0:00:00.159034
# episode: 84/2000, episode end value: 3834.22, duration: 0:00:00.166039
# episode: 85/2000, episode end value: 4233.46, duration: 0:00:00.168037
# episode: 86/2000, episode end value: 4096.86, duration: 0:00:00.155047
# episode: 87/2000, episode end value: 7979.84, duration: 0:00:00.160030
# episode: 88/2000, episode end value: 7462.49, duration: 0:00:00.161035
# episode: 89/2000, episode end value: 3612.29, duration: 0:00:00.157024
# episode: 90/2000, episode end value: 1846.16, duration: 0:00:00.167037
# episode: 91/2000, episode end value: 3186.46, duration: 0:00:00.165037
# episode: 92/2000, episode end value: 3072.67, duration: 0:00:00.166037
# episode: 93/2000, episode end value: 2123.40, duration: 0:00:00.165050
# episode: 94/2000, episode end value: 2942.29, duration: 0:00:00.156021
# episode: 95/2000, episode end value: 3502.69, duration: 0:00:00.169053
# episode: 96/2000, episode end value: 4143.64, duration: 0:00:00.168041
# episode: 97/2000, episode end value: 4758.60, duration: 0:00:00.175022
# episode: 98/2000, episode end value: 3524.85, duration: 0:00:00.165037
# episode: 99/2000, episode end value: 2978.29, duration: 0:00:00.161037
# episode: 100/2000, episode end value: 1704.26, duration: 0:00:00.162037
# episode: 101/2000, episode end value: 2228.85, duration: 0:00:00.159047
# episode: 102/2000, episode end value: 7226.41, duration: 0:00:00.165030
# episode: 103/2000, episode end value: 3972.83, duration: 0:00:00.160032
# episode: 104/2000, episode end value: 5371.99, duration: 0:00:00.159050
# episode: 105/2000, episode end value: 4383.73, duration: 0:00:00.180036
# episode: 106/2000, episode end value: 3471.61, duration: 0:00:00.160042
# episode: 107/2000, episode end value: 4142.17, duration: 0:00:00.158034
# episode: 108/2000, episode end value: 8455.41, duration: 0:00:00.165023
# episode: 109/2000, episode end value: 4681.36, duration: 0:00:00.156051
# episode: 110/2000, episode end value: 6373.14, duration: 0:00:00.162036
# episode: 111/2000, episode end value: 5023.60, duration: 0:00:00.167029
# episode: 112/2000, episode end value: 6381.77, duration: 0:00:00.174038
# episode: 113/2000, episode end value: 5300.70, duration: 0:00:00.164033
# episode: 114/2000, episode end value: 5142.36, duration: 0:00:00.160050
# episode: 115/2000, episode end value: 4453.17, duration: 0:00:00.160036
# episode: 116/2000, episode end value: 3277.13, duration: 0:00:00.162040
# episode: 117/2000, episode end value: 3354.30, duration: 0:00:00.173025
# episode: 118/2000, episode end value: 4976.30, duration: 0:00:00.176041
# episode: 119/2000, episode end value: 2006.92, duration: 0:00:00.161035
# episode: 120/2000, episode end value: 4997.67, duration: 0:00:00.162040
# episode: 121/2000, episode end value: 4200.05, duration: 0:00:00.161029
# episode: 122/2000, episode end value: 6234.61, duration: 0:00:00.161052
# episode: 123/2000, episode end value: 6964.07, duration: 0:00:00.166048
# episode: 124/2000, episode end value: 6829.13, duration: 0:00:00.163047
# episode: 125/2000, episode end value: 4734.26, duration: 0:00:00.163037
# episode: 126/2000, episode end value: 6487.11, duration: 0:00:00.167023
# episode: 127/2000, episode end value: 4932.66, duration: 0:00:00.162036
# episode: 128/2000, episode end value: 5490.72, duration: 0:00:00.158036
# episode: 129/2000, episode end value: 5927.47, duration: 0:00:00.164021
# episode: 130/2000, episode end value: 5834.33, duration: 0:00:00.169047
# episode: 131/2000, episode end value: 3594.23, duration: 0:00:00.167038
# episode: 132/2000, episode end value: 4224.84, duration: 0:00:00.163024
# episode: 133/2000, episode end value: 5301.25, duration: 0:00:00.166051
# episode: 134/2000, episode end value: 3510.11, duration: 0:00:00.158027
# episode: 135/2000, episode end value: 5749.62, duration: 0:00:00.165022
# episode: 136/2000, episode end value: 3589.43, duration: 0:00:00.158050
# episode: 137/2000, episode end value: 3268.83, duration: 0:00:00.160035
# episode: 138/2000, episode end value: 4512.55, duration: 0:00:00.156037
# episode: 139/2000, episode end value: 7225.21, duration: 0:00:00.162019
# episode: 140/2000, episode end value: 6105.24, duration: 0:00:00.164037
# episode: 141/2000, episode end value: 5787.40, duration: 0:00:00.162036
# episode: 142/2000, episode end value: 5153.42, duration: 0:00:00.159035
# episode: 143/2000, episode end value: 6417.62, duration: 0:00:00.167037
# episode: 144/2000, episode end value: 7701.12, duration: 0:00:00.167037
# episode: 145/2000, episode end value: 2886.56, duration: 0:00:00.171038
# episode: 146/2000, episode end value: 3018.36, duration: 0:00:00.176040
# episode: 147/2000, episode end value: 3146.56, duration: 0:00:00.169044
# episode: 148/2000, episode end value: 2305.03, duration: 0:00:00.174039
# episode: 149/2000, episode end value: 4138.85, duration: 0:00:00.169036
# episode: 150/2000, episode end value: 3197.44, duration: 0:00:00.160050
# episode: 151/2000, episode end value: 3535.01, duration: 0:00:00.177047
# episode: 152/2000, episode end value: 5243.23, duration: 0:00:00.183033
# episode: 153/2000, episode end value: 7129.20, duration: 0:00:00.162030
# episode: 154/2000, episode end value: 6832.20, duration: 0:00:00.160045
# episode: 155/2000, episode end value: 4722.76, duration: 0:00:00.159029
# episode: 156/2000, episode end value: 5063.26, duration: 0:00:00.163028
# episode: 157/2000, episode end value: 4025.74, duration: 0:00:00.166046
# episode: 158/2000, episode end value: 3654.66, duration: 0:00:00.162028
# episode: 159/2000, episode end value: 3478.32, duration: 0:00:00.161039
# episode: 160/2000, episode end value: 3759.87, duration: 0:00:00.171034
# episode: 161/2000, episode end value: 4135.39, duration: 0:00:00.163070
# episode: 162/2000, episode end value: 8382.64, duration: 0:00:00.167006
# episode: 163/2000, episode end value: 1427.53, duration: 0:00:00.175039
# episode: 164/2000, episode end value: 3152.33, duration: 0:00:00.182041
# episode: 165/2000, episode end value: 2201.26, duration: 0:00:00.175041
# episode: 166/2000, episode end value: 4968.61, duration: 0:00:00.173038
# episode: 167/2000, episode end value: 3525.98, duration: 0:00:00.167040
# episode: 168/2000, episode end value: 3138.70, duration: 0:00:00.171037
# episode: 169/2000, episode end value: 2156.70, duration: 0:00:00.172035
# episode: 170/2000, episode end value: 2801.28, duration: 0:00:00.168043
# episode: 171/2000, episode end value: 1371.77, duration: 0:00:00.165177
# episode: 172/2000, episode end value: 1466.99, duration: 0:00:00.177035
# episode: 173/2000, episode end value: 3754.67, duration: 0:00:00.168039
# episode: 174/2000, episode end value: 814.87, duration: 0:00:00.168057
# episode: 175/2000, episode end value: 4114.86, duration: 0:00:00.158019
# episode: 176/2000, episode end value: 765.46, duration: 0:00:00.165044
# episode: 177/2000, episode end value: 2225.73, duration: 0:00:00.207047
# episode: 178/2000, episode end value: 6719.40, duration: 0:00:00.162050
# episode: 179/2000, episode end value: 7181.06, duration: 0:00:00.164021
# episode: 180/2000, episode end value: 7505.41, duration: 0:00:00.161037
# episode: 181/2000, episode end value: 6789.04, duration: 0:00:00.165036
# episode: 182/2000, episode end value: 7013.48, duration: 0:00:00.159036
# episode: 183/2000, episode end value: 6833.98, duration: 0:00:00.164035
# episode: 184/2000, episode end value: 3895.14, duration: 0:00:00.160052
# episode: 185/2000, episode end value: 6891.58, duration: 0:00:00.171024
# episode: 186/2000, episode end value: 4724.04, duration: 0:00:00.157051
# episode: 187/2000, episode end value: 7232.91, duration: 0:00:00.167038
# episode: 188/2000, episode end value: 4520.85, duration: 0:00:00.173032
# episode: 189/2000, episode end value: 6418.49, duration: 0:00:00.163048
# episode: 190/2000, episode end value: 3766.46, duration: 0:00:00.157040
# episode: 191/2000, episode end value: 2693.08, duration: 0:00:00.161021
# episode: 192/2000, episode end value: 4504.08, duration: 0:00:00.159037
# episode: 193/2000, episode end value: 5724.64, duration: 0:00:00.166038
# episode: 194/2000, episode end value: 7373.02, duration: 0:00:00.168038
# episode: 195/2000, episode end value: 8040.86, duration: 0:00:00.164043
# episode: 196/2000, episode end value: 7296.49, duration: 0:00:00.163026
# episode: 197/2000, episode end value: 4023.91, duration: 0:00:00.167033
# episode: 198/2000, episode end value: 4370.21, duration: 0:00:00.161051
# episode: 199/2000, episode end value: 4749.12, duration: 0:00:00.160041
# episode: 200/2000, episode end value: 4557.02, duration: 0:00:00.162036
# episode: 201/2000, episode end value: 5249.14, duration: 0:00:00.164028
# episode: 202/2000, episode end value: 4164.44, duration: 0:00:00.171045
# episode: 203/2000, episode end value: 2944.94, duration: 0:00:00.161032
# episode: 204/2000, episode end value: 4129.98, duration: 0:00:00.158039
# episode: 205/2000, episode end value: 2300.89, duration: 0:00:00.172038
# episode: 206/2000, episode end value: 4682.97, duration: 0:00:00.154048
# episode: 207/2000, episode end value: 6433.21, duration: 0:00:00.164043
# episode: 208/2000, episode end value: 5897.68, duration: 0:00:00.166017
# episode: 209/2000, episode end value: 4991.44, duration: 0:00:00.158047
# episode: 210/2000, episode end value: 6551.14, duration: 0:00:00.161039
# episode: 211/2000, episode end value: 3922.50, duration: 0:00:00.169026
# episode: 212/2000, episode end value: 4730.40, duration: 0:00:00.160035
# episode: 213/2000, episode end value: 4969.22, duration: 0:00:00.167037
# episode: 214/2000, episode end value: 5514.23, duration: 0:00:00.168048
# episode: 215/2000, episode end value: 5387.93, duration: 0:00:00.159027
# episode: 216/2000, episode end value: 5184.90, duration: 0:00:00.160034
# episode: 217/2000, episode end value: 6561.27, duration: 0:00:00.158108
# episode: 218/2000, episode end value: 4633.55, duration: 0:00:00.158368
# episode: 219/2000, episode end value: 4639.84, duration: 0:00:00.169035
# episode: 220/2000, episode end value: 3849.80, duration: 0:00:00.161037
# episode: 221/2000, episode end value: 2843.67, duration: 0:00:00.166034
# episode: 222/2000, episode end value: 5525.32, duration: 0:00:00.158052
# episode: 223/2000, episode end value: 2059.75, duration: 0:00:00.170040
# episode: 224/2000, episode end value: 3880.27, duration: 0:00:00.166036
# episode: 225/2000, episode end value: 891.05, duration: 0:00:00.158033
# episode: 226/2000, episode end value: 4979.69, duration: 0:00:00.154034
# episode: 227/2000, episode end value: 7422.40, duration: 0:00:00.158052
# episode: 228/2000, episode end value: 5275.99, duration: 0:00:00.157028
# episode: 229/2000, episode end value: 6155.07, duration: 0:00:00.165035
# episode: 230/2000, episode end value: 4471.76, duration: 0:00:00.168035
# episode: 231/2000, episode end value: 6639.27, duration: 0:00:00.164037
# episode: 232/2000, episode end value: 7643.27, duration: 0:00:00.160046
# episode: 233/2000, episode end value: 5950.37, duration: 0:00:00.169022
# episode: 234/2000, episode end value: 7214.26, duration: 0:00:00.168040
# episode: 235/2000, episode end value: 4313.31, duration: 0:00:00.171038
# episode: 236/2000, episode end value: 4019.81, duration: 0:00:00.160037
# episode: 237/2000, episode end value: 5600.40, duration: 0:00:00.158548
# episode: 238/2000, episode end value: 4339.87, duration: 0:00:00.160578
# episode: 239/2000, episode end value: 6296.09, duration: 0:00:00.170038
# episode: 240/2000, episode end value: 5701.31, duration: 0:00:00.153044
# episode: 241/2000, episode end value: 5522.24, duration: 0:00:00.164021
# episode: 242/2000, episode end value: 5863.46, duration: 0:00:00.165038
# episode: 243/2000, episode end value: 3887.43, duration: 0:00:00.189043
# episode: 244/2000, episode end value: 2906.10, duration: 0:00:00.161052
# episode: 245/2000, episode end value: 2778.43, duration: 0:00:00.159029
# episode: 246/2000, episode end value: 3930.56, duration: 0:00:00.160037
# episode: 247/2000, episode end value: 3256.86, duration: 0:00:00.170036
# episode: 248/2000, episode end value: 4665.50, duration: 0:00:00.166053
# episode: 249/2000, episode end value: 4767.58, duration: 0:00:00.168461
# episode: 250/2000, episode end value: 2257.52, duration: 0:00:00.170076
# episode: 251/2000, episode end value: 4198.41, duration: 0:00:00.161037
# episode: 252/2000, episode end value: 3122.29, duration: 0:00:00.162036
# episode: 253/2000, episode end value: 7290.43, duration: 0:00:00.168056
# episode: 254/2000, episode end value: 6175.06, duration: 0:00:00.170022
# episode: 255/2000, episode end value: 6833.66, duration: 0:00:00.159036
# episode: 256/2000, episode end value: 6598.59, duration: 0:00:00.161050
# episode: 257/2000, episode end value: 6560.67, duration: 0:00:00.157035
# episode: 258/2000, episode end value: 5521.77, duration: 0:00:00.170023
# episode: 259/2000, episode end value: 6477.80, duration: 0:00:00.173038
# episode: 260/2000, episode end value: 4790.09, duration: 0:00:00.176038
# episode: 261/2000, episode end value: 4201.29, duration: 0:00:00.174048
# episode: 262/2000, episode end value: 4609.46, duration: 0:00:00.174046
# episode: 263/2000, episode end value: 6376.25, duration: 0:00:00.167035
# episode: 264/2000, episode end value: 7407.77, duration: 0:00:00.162020
# episode: 265/2000, episode end value: 5666.89, duration: 0:00:00.175040
# episode: 266/2000, episode end value: 4949.73, duration: 0:00:00.164043
# episode: 267/2000, episode end value: 3681.29, duration: 0:00:00.167021
# episode: 268/2000, episode end value: 4579.40, duration: 0:00:00.164036
# episode: 269/2000, episode end value: 5981.33, duration: 0:00:00.176035
# episode: 270/2000, episode end value: 7459.31, duration: 0:00:00.173052
# episode: 271/2000, episode end value: 6403.06, duration: 0:00:00.177032
# episode: 272/2000, episode end value: 3837.97, duration: 0:00:00.175037
# episode: 273/2000, episode end value: 2281.19, duration: 0:00:00.169037
# episode: 274/2000, episode end value: 4877.87, duration: 0:00:00.171046
# episode: 275/2000, episode end value: 4111.75, duration: 0:00:00.161023
# episode: 276/2000, episode end value: 4146.43, duration: 0:00:00.157032
# episode: 277/2000, episode end value: 7380.49, duration: 0:00:00.166037
# episode: 278/2000, episode end value: 5407.59, duration: 0:00:00.173057
# episode: 279/2000, episode end value: 8242.52, duration: 0:00:00.168021
# episode: 280/2000, episode end value: 4764.92, duration: 0:00:00.166037
# episode: 281/2000, episode end value: 5796.24, duration: 0:00:00.172039
# episode: 282/2000, episode end value: 4676.97, duration: 0:00:00.175038
# episode: 283/2000, episode end value: 5968.49, duration: 0:00:00.164051
# episode: 284/2000, episode end value: 6183.42, duration: 0:00:00.162037
# episode: 285/2000, episode end value: 5367.14, duration: 0:00:00.157047
# episode: 286/2000, episode end value: 4585.22, duration: 0:00:00.158821
# episode: 287/2000, episode end value: 3120.06, duration: 0:00:00.164941
# episode: 288/2000, episode end value: 4134.92, duration: 0:00:00.167033
# episode: 289/2000, episode end value: 4887.10, duration: 0:00:00.168032
# episode: 290/2000, episode end value: 4187.27, duration: 0:00:00.176037
# episode: 291/2000, episode end value: 3717.82, duration: 0:00:00.174037
# episode: 292/2000, episode end value: 5639.45, duration: 0:00:00.165039
# episode: 293/2000, episode end value: 3441.87, duration: 0:00:00.159046
# episode: 294/2000, episode end value: 5642.29, duration: 0:00:00.160033
# episode: 295/2000, episode end value: 3954.60, duration: 0:00:00.167035
# episode: 296/2000, episode end value: 3974.52, duration: 0:00:00.174041
# episode: 297/2000, episode end value: 4624.73, duration: 0:00:00.165030
# episode: 298/2000, episode end value: 4062.48, duration: 0:00:00.160026
# episode: 299/2000, episode end value: 5206.07, duration: 0:00:00.166037
# episode: 300/2000, episode end value: 3072.50, duration: 0:00:00.161051
# episode: 301/2000, episode end value: 4511.00, duration: 0:00:00.176024
# episode: 302/2000, episode end value: 1963.85, duration: 0:00:00.179040
# episode: 303/2000, episode end value: 4684.08, duration: 0:00:00.166039
# episode: 304/2000, episode end value: 3723.82, duration: 0:00:00.159035
# episode: 305/2000, episode end value: 6992.37, duration: 0:00:00.165035
# episode: 306/2000, episode end value: 4574.49, duration: 0:00:00.167037
# episode: 307/2000, episode end value: 3420.03, duration: 0:00:00.167035
# episode: 308/2000, episode end value: 3395.97, duration: 0:00:00.163036
# episode: 309/2000, episode end value: 4061.81, duration: 0:00:00.163035
# episode: 310/2000, episode end value: 3453.50, duration: 0:00:00.160038
# episode: 311/2000, episode end value: 5804.02, duration: 0:00:00.154043
# episode: 312/2000, episode end value: 5729.75, duration: 0:00:00.155179
# episode: 313/2000, episode end value: 7343.65, duration: 0:00:00.164815
# episode: 314/2000, episode end value: 6779.23, duration: 0:00:00.163023
# episode: 315/2000, episode end value: 5045.11, duration: 0:00:00.167042
# episode: 316/2000, episode end value: 6318.90, duration: 0:00:00.164078
# episode: 317/2000, episode end value: 5389.10, duration: 0:00:00.164031
# episode: 318/2000, episode end value: 6426.99, duration: 0:00:00.167085
# episode: 319/2000, episode end value: 3283.05, duration: 0:00:00.161100
# episode: 320/2000, episode end value: 3772.26, duration: 0:00:00.164049
# episode: 321/2000, episode end value: 3176.73, duration: 0:00:00.165054
# episode: 322/2000, episode end value: 3332.90, duration: 0:00:00.158038
# episode: 323/2000, episode end value: 2944.84, duration: 0:00:00.160058
# episode: 324/2000, episode end value: 2731.88, duration: 0:00:00.157351
# episode: 325/2000, episode end value: 3836.38, duration: 0:00:00.167513
# episode: 326/2000, episode end value: 2743.30, duration: 0:00:00.165035
# episode: 327/2000, episode end value: 2510.59, duration: 0:00:00.165037
# episode: 328/2000, episode end value: 3210.84, duration: 0:00:00.175057
# episode: 329/2000, episode end value: 2034.23, duration: 0:00:00.166030
# episode: 330/2000, episode end value: 1696.21, duration: 0:00:00.159021
# episode: 331/2000, episode end value: 3316.90, duration: 0:00:00.154547
# episode: 332/2000, episode end value: 2560.72, duration: 0:00:00.165097
# episode: 333/2000, episode end value: 3474.97, duration: 0:00:00.152841
# episode: 334/2000, episode end value: 3500.34, duration: 0:00:00.160048
# episode: 335/2000, episode end value: 3601.89, duration: 0:00:00.156019
# episode: 336/2000, episode end value: 4615.16, duration: 0:00:00.156038
# episode: 337/2000, episode end value: 4538.25, duration: 0:00:00.175036
# episode: 338/2000, episode end value: 4599.19, duration: 0:00:00.169037
# episode: 339/2000, episode end value: 6157.35, duration: 0:00:00.164036
# episode: 340/2000, episode end value: 7406.37, duration: 0:00:00.159035
# episode: 341/2000, episode end value: 5248.80, duration: 0:00:00.166038
# episode: 342/2000, episode end value: 7165.06, duration: 0:00:00.169057
# episode: 343/2000, episode end value: 7566.91, duration: 0:00:00.166174
# episode: 344/2000, episode end value: 2605.35, duration: 0:00:00.170375
# episode: 345/2000, episode end value: 5509.99, duration: 0:00:00.157049
# episode: 346/2000, episode end value: 4943.15, duration: 0:00:00.159045
# episode: 347/2000, episode end value: 4205.19, duration: 0:00:00.166022
# episode: 348/2000, episode end value: 4025.07, duration: 0:00:00.171039
# episode: 349/2000, episode end value: 2034.86, duration: 0:00:00.165034
# episode: 350/2000, episode end value: 3958.67, duration: 0:00:00.175039
# episode: 351/2000, episode end value: 3051.60, duration: 0:00:00.155050
# episode: 352/2000, episode end value: 1398.60, duration: 0:00:00.157021
# episode: 353/2000, episode end value: 2423.24, duration: 0:00:00.166038
# episode: 354/2000, episode end value: 5640.08, duration: 0:00:00.171055
# episode: 355/2000, episode end value: 6420.74, duration: 0:00:00.173038
# episode: 356/2000, episode end value: 10018.20, duration: 0:00:00.168029
# episode: 357/2000, episode end value: 6962.19, duration: 0:00:00.177037
# episode: 358/2000, episode end value: 7087.71, duration: 0:00:00.166055
# episode: 359/2000, episode end value: 6591.82, duration: 0:00:00.159029
# episode: 360/2000, episode end value: 3910.87, duration: 0:00:00.162041
# episode: 361/2000, episode end value: 3357.36, duration: 0:00:00.165022
# episode: 362/2000, episode end value: 7887.40, duration: 0:00:00.166052
# episode: 363/2000, episode end value: 4770.16, duration: 0:00:00.168028
# episode: 364/2000, episode end value: 3441.23, duration: 0:00:00.156042
# episode: 365/2000, episode end value: 4558.58, duration: 0:00:00.158023
# episode: 366/2000, episode end value: 4587.21, duration: 0:00:00.164052
# episode: 367/2000, episode end value: 5080.61, duration: 0:00:00.167040
# episode: 368/2000, episode end value: 4646.17, duration: 0:00:00.175031
# episode: 369/2000, episode end value: 3354.06, duration: 0:00:00.172038
# episode: 370/2000, episode end value: 2726.04, duration: 0:00:00.166037
# episode: 371/2000, episode end value: 3192.34, duration: 0:00:00.165038
# episode: 372/2000, episode end value: 5779.68, duration: 0:00:00.155049
# episode: 373/2000, episode end value: 4484.09, duration: 0:00:00.165038
# episode: 374/2000, episode end value: 4172.47, duration: 0:00:00.173021
# episode: 375/2000, episode end value: 2133.42, duration: 0:00:00.167037
# episode: 376/2000, episode end value: 3734.95, duration: 0:00:00.159036
# episode: 377/2000, episode end value: 2694.83, duration: 0:00:00.163038
# episode: 378/2000, episode end value: 5113.30, duration: 0:00:00.157092
# episode: 379/2000, episode end value: 3971.72, duration: 0:00:00.165115
# episode: 380/2000, episode end value: 4392.49, duration: 0:00:00.157173
# episode: 381/2000, episode end value: 4181.19, duration: 0:00:00.155141
# episode: 382/2000, episode end value: 4585.60, duration: 0:00:00.157233
# episode: 383/2000, episode end value: 4744.25, duration: 0:00:00.171037
# episode: 384/2000, episode end value: 2592.82, duration: 0:00:00.175039
# episode: 385/2000, episode end value: 3814.89, duration: 0:00:00.173039
# episode: 386/2000, episode end value: 3175.52, duration: 0:00:00.162064
# episode: 387/2000, episode end value: 4069.76, duration: 0:00:00.156102
# episode: 388/2000, episode end value: 4767.31, duration: 0:00:00.157043
# episode: 389/2000, episode end value: 6695.55, duration: 0:00:00.170022
# episode: 390/2000, episode end value: 4918.18, duration: 0:00:00.172038
# episode: 391/2000, episode end value: 5146.25, duration: 0:00:00.174039
# episode: 392/2000, episode end value: 4597.28, duration: 0:00:00.171039
# episode: 393/2000, episode end value: 4445.13, duration: 0:00:00.167037
# episode: 394/2000, episode end value: 2586.98, duration: 0:00:00.162038
# episode: 395/2000, episode end value: 3185.54, duration: 0:00:00.170027
# episode: 396/2000, episode end value: 2497.21, duration: 0:00:00.156035
# episode: 397/2000, episode end value: 3965.56, duration: 0:00:00.159050
# episode: 398/2000, episode end value: 3655.77, duration: 0:00:00.166037
# episode: 399/2000, episode end value: 4387.02, duration: 0:00:00.177023
# episode: 400/2000, episode end value: 4182.16, duration: 0:00:00.166052
# episode: 401/2000, episode end value: 4533.46, duration: 0:00:00.163036
# episode: 402/2000, episode end value: 5213.04, duration: 0:00:00.159023
# episode: 403/2000, episode end value: 3815.90, duration: 0:00:00.165036
# episode: 404/2000, episode end value: 3075.62, duration: 0:00:00.171038
# episode: 405/2000, episode end value: 9964.75, duration: 0:00:00.170054
# episode: 406/2000, episode end value: 6771.78, duration: 0:00:00.162028
# episode: 407/2000, episode end value: 7946.69, duration: 0:00:00.168038
# episode: 408/2000, episode end value: 5246.17, duration: 0:00:00.176038
# episode: 409/2000, episode end value: 4943.76, duration: 0:00:00.157034
# episode: 410/2000, episode end value: 4883.92, duration: 0:00:00.159036
# episode: 411/2000, episode end value: 4839.86, duration: 0:00:00.163036
# episode: 412/2000, episode end value: 5510.44, duration: 0:00:00.166035
# episode: 413/2000, episode end value: 2733.20, duration: 0:00:00.165039
# episode: 414/2000, episode end value: 4392.03, duration: 0:00:00.168042
# episode: 415/2000, episode end value: 1871.11, duration: 0:00:00.169034
# episode: 416/2000, episode end value: 2256.54, duration: 0:00:00.175039
# episode: 417/2000, episode end value: 2576.40, duration: 0:00:00.176040
# episode: 418/2000, episode end value: 3034.77, duration: 0:00:00.175055
# episode: 419/2000, episode end value: 5488.32, duration: 0:00:00.176039
# episode: 420/2000, episode end value: 3361.40, duration: 0:00:00.162020
# episode: 421/2000, episode end value: 3678.34, duration: 0:00:00.167038
# episode: 422/2000, episode end value: 6077.83, duration: 0:00:00.159050
# episode: 423/2000, episode end value: 7856.85, duration: 0:00:00.163037
# episode: 424/2000, episode end value: 7383.82, duration: 0:00:00.166026
# episode: 425/2000, episode end value: 6876.26, duration: 0:00:00.155033
# episode: 426/2000, episode end value: 7712.14, duration: 0:00:00.165038
# episode: 427/2000, episode end value: 5491.64, duration: 0:00:00.166054
# episode: 428/2000, episode end value: 3965.41, duration: 0:00:00.167038
# episode: 429/2000, episode end value: 5611.50, duration: 0:00:00.163021
# episode: 430/2000, episode end value: 3592.81, duration: 0:00:00.173038
# episode: 431/2000, episode end value: 5173.47, duration: 0:00:00.163053
# episode: 432/2000, episode end value: 8476.05, duration: 0:00:00.168028
# episode: 433/2000, episode end value: 5747.84, duration: 0:00:00.162022
# episode: 434/2000, episode end value: 4711.85, duration: 0:00:00.164038
# episode: 435/2000, episode end value: 2297.35, duration: 0:00:00.165044
# episode: 436/2000, episode end value: 3243.53, duration: 0:00:00.174043
# episode: 437/2000, episode end value: 5889.79, duration: 0:00:00.165031
# episode: 438/2000, episode end value: 4894.44, duration: 0:00:00.178030
# episode: 439/2000, episode end value: 3253.19, duration: 0:00:00.179043
# episode: 440/2000, episode end value: 2308.80, duration: 0:00:00.170048
# episode: 441/2000, episode end value: 4721.22, duration: 0:00:00.162023
# episode: 442/2000, episode end value: 1817.27, duration: 0:00:00.157031
# episode: 443/2000, episode end value: 1398.49, duration: 0:00:00.167047
# episode: 444/2000, episode end value: 3803.50, duration: 0:00:00.166046
# episode: 445/2000, episode end value: 1134.25, duration: 0:00:00.166023
# episode: 446/2000, episode end value: 2644.17, duration: 0:00:00.160541
# episode: 447/2000, episode end value: 4631.20, duration: 0:00:00.157620
# episode: 448/2000, episode end value: 5570.29, duration: 0:00:00.164628
# episode: 449/2000, episode end value: 6050.46, duration: 0:00:00.162011
# episode: 450/2000, episode end value: 4517.05, duration: 0:00:00.162033
# episode: 451/2000, episode end value: 8566.90, duration: 0:00:00.160054
# episode: 452/2000, episode end value: 4643.01, duration: 0:00:00.178015
# episode: 453/2000, episode end value: 3569.87, duration: 0:00:00.171022
# episode: 454/2000, episode end value: 4501.55, duration: 0:00:00.162039
# episode: 455/2000, episode end value: 1200.72, duration: 0:00:00.167038
# episode: 456/2000, episode end value: 3185.61, duration: 0:00:00.163036
# episode: 457/2000, episode end value: 4842.05, duration: 0:00:00.157038
# episode: 458/2000, episode end value: 2084.67, duration: 0:00:00.158043
# episode: 459/2000, episode end value: 992.42, duration: 0:00:00.188027
# episode: 460/2000, episode end value: 1478.02, duration: 0:00:00.175039
# episode: 461/2000, episode end value: 4888.45, duration: 0:00:00.156056
# episode: 462/2000, episode end value: 3258.93, duration: 0:00:00.161029
# episode: 463/2000, episode end value: 6945.73, duration: 0:00:00.158034
# episode: 464/2000, episode end value: 4319.22, duration: 0:00:00.168038
# episode: 465/2000, episode end value: 4168.14, duration: 0:00:00.155034
# episode: 466/2000, episode end value: 4609.57, duration: 0:00:00.157050
# episode: 467/2000, episode end value: 6191.05, duration: 0:00:00.160021
# episode: 468/2000, episode end value: 3636.51, duration: 0:00:00.172039
# episode: 469/2000, episode end value: 4311.23, duration: 0:00:00.174039
# episode: 470/2000, episode end value: 4939.35, duration: 0:00:00.166037
# episode: 471/2000, episode end value: 6024.24, duration: 0:00:00.163036
# episode: 472/2000, episode end value: 5849.22, duration: 0:00:00.165037
# episode: 473/2000, episode end value: 5410.55, duration: 0:00:00.175038
# episode: 474/2000, episode end value: 4645.85, duration: 0:00:00.168037
# episode: 475/2000, episode end value: 5180.29, duration: 0:00:00.158050
# episode: 476/2000, episode end value: 4036.12, duration: 0:00:00.160057
# episode: 477/2000, episode end value: 3630.26, duration: 0:00:00.167883
# episode: 478/2000, episode end value: 4285.45, duration: 0:00:00.167037
# episode: 479/2000, episode end value: 8200.70, duration: 0:00:00.165039
# episode: 480/2000, episode end value: 5306.83, duration: 0:00:00.167476
# episode: 481/2000, episode end value: 4935.19, duration: 0:00:00.165046
# episode: 482/2000, episode end value: 3934.10, duration: 0:00:00.168431
# episode: 483/2000, episode end value: 3834.81, duration: 0:00:00.165922
# episode: 484/2000, episode end value: 4375.02, duration: 0:00:00.165052
# episode: 485/2000, episode end value: 4874.28, duration: 0:00:00.156056
# episode: 486/2000, episode end value: 4749.38, duration: 0:00:00.167038
# episode: 487/2000, episode end value: 6576.33, duration: 0:00:00.167054
# episode: 488/2000, episode end value: 5150.32, duration: 0:00:00.165021
# episode: 489/2000, episode end value: 5482.02, duration: 0:00:00.156033
# episode: 490/2000, episode end value: 6587.16, duration: 0:00:00.157033
# episode: 491/2000, episode end value: 9859.80, duration: 0:00:00.158037
# episode: 492/2000, episode end value: 6988.49, duration: 0:00:00.163056
# episode: 493/2000, episode end value: 7578.60, duration: 0:00:00.161030
# episode: 494/2000, episode end value: 2043.06, duration: 0:00:00.158600
# episode: 495/2000, episode end value: 3484.22, duration: 0:00:00.166551
# episode: 496/2000, episode end value: 3689.34, duration: 0:00:00.157050
# episode: 497/2000, episode end value: 3075.71, duration: 0:00:00.166025
# episode: 498/2000, episode end value: 4409.39, duration: 0:00:00.166037
# episode: 499/2000, episode end value: 4327.45, duration: 0:00:00.170035
# episode: 500/2000, episode end value: 5035.05, duration: 0:00:00.154043
# episode: 501/2000, episode end value: 4719.42, duration: 0:00:00.170030
# episode: 502/2000, episode end value: 3600.92, duration: 0:00:00.160036
# episode: 503/2000, episode end value: 4120.55, duration: 0:00:00.166037
# episode: 504/2000, episode end value: 3123.91, duration: 0:00:00.156035
# episode: 505/2000, episode end value: 3825.35, duration: 0:00:00.167052
# episode: 506/2000, episode end value: 3847.76, duration: 0:00:00.165036
# episode: 507/2000, episode end value: 3963.92, duration: 0:00:00.165022
# episode: 508/2000, episode end value: 8232.24, duration: 0:00:00.165043
# episode: 509/2000, episode end value: 6195.05, duration: 0:00:00.164044
# episode: 510/2000, episode end value: 5625.34, duration: 0:00:00.162069
# episode: 511/2000, episode end value: 3346.71, duration: 0:00:00.167040
# episode: 512/2000, episode end value: 2349.79, duration: 0:00:00.161815
# episode: 513/2000, episode end value: 4918.76, duration: 0:00:00.165105
# episode: 514/2000, episode end value: 4861.17, duration: 0:00:00.167036
# episode: 515/2000, episode end value: 6379.19, duration: 0:00:00.165046
# episode: 516/2000, episode end value: 7261.01, duration: 0:00:00.172021
# episode: 517/2000, episode end value: 4386.17, duration: 0:00:00.163052
# episode: 518/2000, episode end value: 5786.48, duration: 0:00:00.167048
# episode: 519/2000, episode end value: 4192.59, duration: 0:00:00.164039
# episode: 520/2000, episode end value: 5257.37, duration: 0:00:00.173022
# episode: 521/2000, episode end value: 5773.38, duration: 0:00:00.176039
# episode: 522/2000, episode end value: 7293.32, duration: 0:00:00.171055
# episode: 523/2000, episode end value: 5006.09, duration: 0:00:00.173031
# episode: 524/2000, episode end value: 3414.00, duration: 0:00:00.155019
# episode: 525/2000, episode end value: 7580.06, duration: 0:00:00.164037
# episode: 526/2000, episode end value: 6472.82, duration: 0:00:00.163051
# episode: 527/2000, episode end value: 4715.97, duration: 0:00:00.160036
# episode: 528/2000, episode end value: 8125.56, duration: 0:00:00.161047
# episode: 529/2000, episode end value: 3720.77, duration: 0:00:00.159021
# episode: 530/2000, episode end value: 3812.90, duration: 0:00:00.168037
# episode: 531/2000, episode end value: 3608.63, duration: 0:00:00.165021
# episode: 532/2000, episode end value: 6727.04, duration: 0:00:00.163036
# episode: 533/2000, episode end value: 5491.14, duration: 0:00:00.169035
# episode: 534/2000, episode end value: 6703.08, duration: 0:00:00.172039
# episode: 535/2000, episode end value: 7392.79, duration: 0:00:00.177043
# episode: 536/2000, episode end value: 5074.50, duration: 0:00:00.163049
# episode: 537/2000, episode end value: 5175.56, duration: 0:00:00.163037
# episode: 538/2000, episode end value: 1775.65, duration: 0:00:00.170054
# episode: 539/2000, episode end value: 4708.89, duration: 0:00:00.163021
# episode: 540/2000, episode end value: 4679.53, duration: 0:00:00.160053
# episode: 541/2000, episode end value: 3497.19, duration: 0:00:00.167029
# episode: 542/2000, episode end value: 5301.78, duration: 0:00:00.170039
# episode: 543/2000, episode end value: 7887.49, duration: 0:00:00.162034
# episode: 544/2000, episode end value: 7611.01, duration: 0:00:00.156033
# episode: 545/2000, episode end value: 6585.93, duration: 0:00:00.163049
# episode: 546/2000, episode end value: 6423.56, duration: 0:00:00.158032
# episode: 547/2000, episode end value: 7035.31, duration: 0:00:00.168037
# episode: 548/2000, episode end value: 4387.04, duration: 0:00:00.172041
# episode: 549/2000, episode end value: 7565.19, duration: 0:00:00.157020
# episode: 550/2000, episode end value: 4784.03, duration: 0:00:00.166036
# episode: 551/2000, episode end value: 4631.44, duration: 0:00:00.168037
# episode: 552/2000, episode end value: 5359.69, duration: 0:00:00.165036
# episode: 553/2000, episode end value: 4875.83, duration: 0:00:00.163035
# episode: 554/2000, episode end value: 5042.37, duration: 0:00:00.164037
# episode: 555/2000, episode end value: 4514.02, duration: 0:00:00.158040
# episode: 556/2000, episode end value: 4487.24, duration: 0:00:00.161036
# episode: 557/2000, episode end value: 3321.65, duration: 0:00:00.167037
# episode: 558/2000, episode end value: 1692.26, duration: 0:00:00.168050
# episode: 559/2000, episode end value: 4061.65, duration: 0:00:00.162021
# episode: 560/2000, episode end value: 2683.87, duration: 0:00:00.154051
# episode: 561/2000, episode end value: 4134.51, duration: 0:00:00.174024
# episode: 562/2000, episode end value: 4271.15, duration: 0:00:00.172023
# episode: 563/2000, episode end value: 2954.79, duration: 0:00:00.162036
# episode: 564/2000, episode end value: 3280.40, duration: 0:00:00.158032
# episode: 565/2000, episode end value: 2876.57, duration: 0:00:00.166054
# episode: 566/2000, episode end value: 1929.78, duration: 0:00:00.166036
# episode: 567/2000, episode end value: 3520.63, duration: 0:00:00.163022
# episode: 568/2000, episode end value: 3512.52, duration: 0:00:00.156034
# episode: 569/2000, episode end value: 3356.08, duration: 0:00:00.167040
# episode: 570/2000, episode end value: 2614.47, duration: 0:00:00.163041
# episode: 571/2000, episode end value: 3739.38, duration: 0:00:00.162033
# episode: 572/2000, episode end value: 2273.53, duration: 0:00:00.160037
# episode: 573/2000, episode end value: 1857.27, duration: 0:00:00.167036
# episode: 574/2000, episode end value: 3588.78, duration: 0:00:00.162052
# episode: 575/2000, episode end value: 3269.70, duration: 0:00:00.165021
# episode: 576/2000, episode end value: 3344.74, duration: 0:00:00.161037
# episode: 577/2000, episode end value: 2500.25, duration: 0:00:00.176545
# episode: 578/2000, episode end value: 2582.70, duration: 0:00:00.155078
# episode: 579/2000, episode end value: 3268.52, duration: 0:00:00.166035
# episode: 580/2000, episode end value: 6360.44, duration: 0:00:00.157634
# episode: 581/2000, episode end value: 7125.92, duration: 0:00:00.166038
# episode: 582/2000, episode end value: 6060.98, duration: 0:00:00.159089
# episode: 583/2000, episode end value: 8580.82, duration: 0:00:00.158591
# episode: 584/2000, episode end value: 7256.92, duration: 0:00:00.163022
# episode: 585/2000, episode end value: 7380.60, duration: 0:00:00.164544
# episode: 586/2000, episode end value: 7002.36, duration: 0:00:00.157051
# episode: 587/2000, episode end value: 6817.46, duration: 0:00:00.157141
# episode: 588/2000, episode end value: 4734.47, duration: 0:00:00.163921
# episode: 589/2000, episode end value: 6109.68, duration: 0:00:00.159037
# episode: 590/2000, episode end value: 5569.53, duration: 0:00:00.167053
# episode: 591/2000, episode end value: 3896.77, duration: 0:00:00.177038
# episode: 592/2000, episode end value: 4652.06, duration: 0:00:00.173041
# episode: 593/2000, episode end value: 4734.91, duration: 0:00:00.169037
# episode: 594/2000, episode end value: 4209.51, duration: 0:00:00.168054
# episode: 595/2000, episode end value: 4586.84, duration: 0:00:00.170021
# episode: 596/2000, episode end value: 6333.71, duration: 0:00:00.168039
# episode: 597/2000, episode end value: 4342.85, duration: 0:00:00.176037
# episode: 598/2000, episode end value: 3916.15, duration: 0:00:00.165038
# episode: 599/2000, episode end value: 2824.76, duration: 0:00:00.166037
# episode: 600/2000, episode end value: 3243.96, duration: 0:00:00.162037
# episode: 601/2000, episode end value: 2319.68, duration: 0:00:00.162035
# episode: 602/2000, episode end value: 2366.69, duration: 0:00:00.156036
# episode: 603/2000, episode end value: 2794.92, duration: 0:00:00.162051
# episode: 604/2000, episode end value: 3666.16, duration: 0:00:00.184038
# episode: 605/2000, episode end value: 2790.34, duration: 0:00:00.164036
# episode: 606/2000, episode end value: 2516.11, duration: 0:00:00.157035
# episode: 607/2000, episode end value: 3456.47, duration: 0:00:00.168037
# episode: 608/2000, episode end value: 4693.83, duration: 0:00:00.157037
# episode: 609/2000, episode end value: 3132.66, duration: 0:00:00.160041
# episode: 610/2000, episode end value: 2616.42, duration: 0:00:00.162022
# episode: 611/2000, episode end value: 4173.52, duration: 0:00:00.157068
# episode: 612/2000, episode end value: 3675.75, duration: 0:00:00.159065
# episode: 613/2000, episode end value: 2776.16, duration: 0:00:00.163067
# episode: 614/2000, episode end value: 2978.18, duration: 0:00:00.159956
# episode: 615/2000, episode end value: 3251.70, duration: 0:00:00.155611
# episode: 616/2000, episode end value: 3289.77, duration: 0:00:00.170753
# episode: 617/2000, episode end value: 2803.66, duration: 0:00:00.164037
# episode: 618/2000, episode end value: 3022.90, duration: 0:00:00.159033
# episode: 619/2000, episode end value: 3085.91, duration: 0:00:00.160029
# episode: 620/2000, episode end value: 2345.97, duration: 0:00:00.167043
# episode: 621/2000, episode end value: 3487.61, duration: 0:00:00.177030
# episode: 622/2000, episode end value: 3392.13, duration: 0:00:00.170037
# episode: 623/2000, episode end value: 3360.45, duration: 0:00:00.174038
# episode: 624/2000, episode end value: 3952.86, duration: 0:00:00.166040
# episode: 625/2000, episode end value: 5397.62, duration: 0:00:00.168038
# episode: 626/2000, episode end value: 3012.28, duration: 0:00:00.168052
# episode: 627/2000, episode end value: 3169.50, duration: 0:00:00.167023
# episode: 628/2000, episode end value: 2035.18, duration: 0:00:00.169039
# episode: 629/2000, episode end value: 2118.02, duration: 0:00:00.158036
# episode: 630/2000, episode end value: 2092.90, duration: 0:00:00.158046
# episode: 631/2000, episode end value: 3509.08, duration: 0:00:00.175025
# episode: 632/2000, episode end value: 2377.21, duration: 0:00:00.181039
# episode: 633/2000, episode end value: 1114.45, duration: 0:00:00.170059
# episode: 634/2000, episode end value: 5280.10, duration: 0:00:00.165031
# episode: 635/2000, episode end value: 7297.31, duration: 0:00:00.165038
# episode: 636/2000, episode end value: 5278.32, duration: 0:00:00.173039
# episode: 637/2000, episode end value: 7246.64, duration: 0:00:00.164039
# episode: 638/2000, episode end value: 7172.26, duration: 0:00:00.161033
# episode: 639/2000, episode end value: 7583.11, duration: 0:00:00.157035
# episode: 640/2000, episode end value: 7018.43, duration: 0:00:00.162041
# episode: 641/2000, episode end value: 7326.46, duration: 0:00:00.164044
# episode: 642/2000, episode end value: 5855.74, duration: 0:00:00.173037
# episode: 643/2000, episode end value: 6731.09, duration: 0:00:00.176039
# episode: 644/2000, episode end value: 7559.61, duration: 0:00:00.162037
# episode: 645/2000, episode end value: 8397.57, duration: 0:00:00.165047
# episode: 646/2000, episode end value: 5551.25, duration: 0:00:00.164041
# episode: 647/2000, episode end value: 8070.45, duration: 0:00:00.163022
# episode: 648/2000, episode end value: 7267.97, duration: 0:00:00.161046
# episode: 649/2000, episode end value: 3449.05, duration: 0:00:00.173040
# episode: 650/2000, episode end value: 3945.25, duration: 0:00:00.175022
# episode: 651/2000, episode end value: 3613.26, duration: 0:00:00.172039
# episode: 652/2000, episode end value: 4122.49, duration: 0:00:00.164035
# episode: 653/2000, episode end value: 3944.61, duration: 0:00:00.166054
# episode: 654/2000, episode end value: 8106.44, duration: 0:00:00.166026
# episode: 655/2000, episode end value: 5690.50, duration: 0:00:00.173042
# episode: 656/2000, episode end value: 6089.68, duration: 0:00:00.176039
# episode: 657/2000, episode end value: 4821.78, duration: 0:00:00.180056
# episode: 658/2000, episode end value: 4377.16, duration: 0:00:00.161022
# episode: 659/2000, episode end value: 5719.06, duration: 0:00:00.157034
# episode: 660/2000, episode end value: 6904.06, duration: 0:00:00.159374
# episode: 661/2000, episode end value: 2807.20, duration: 0:00:00.158369
# episode: 662/2000, episode end value: 2532.99, duration: 0:00:00.159312
# episode: 663/2000, episode end value: 9931.21, duration: 0:00:00.162026
# episode: 664/2000, episode end value: 7783.70, duration: 0:00:00.167050
# episode: 665/2000, episode end value: 8164.02, duration: 0:00:00.161041
# episode: 666/2000, episode end value: 7762.81, duration: 0:00:00.165316
# episode: 667/2000, episode end value: 7167.03, duration: 0:00:00.173004
# ...
# episode: 1783/2000, episode end value: 3738.48, duration: 0:00:00.163053
# episode: 1784/2000, episode end value: 3631.35, duration: 0:00:00.168038
# episode: 1785/2000, episode end value: 3145.21, duration: 0:00:00.169037
# episode: 1786/2000, episode end value: 5465.88, duration: 0:00:00.159036
# episode: 1787/2000, episode end value: 7079.24, duration: 0:00:00.191029
# episode: 1788/2000, episode end value: 7289.48, duration: 0:00:00.159624
# episode: 1789/2000, episode end value: 6668.72, duration: 0:00:00.160111
# episode: 1790/2000, episode end value: 7847.83, duration: 0:00:00.171910
# episode: 1791/2000, episode end value: 6963.81, duration: 0:00:00.163038
# episode: 1792/2000, episode end value: 4020.34, duration: 0:00:00.165045
# episode: 1793/2000, episode end value: 3260.67, duration: 0:00:00.170021
# episode: 1794/2000, episode end value: 5746.04, duration: 0:00:00.164046
# episode: 1795/2000, episode end value: 6962.12, duration: 0:00:00.165047
# episode: 1796/2000, episode end value: 4128.57, duration: 0:00:00.161035
# episode: 1797/2000, episode end value: 4583.19, duration: 0:00:00.160023
# episode: 1798/2000, episode end value: 6100.82, duration: 0:00:00.166036
# episode: 1799/2000, episode end value: 5389.77, duration: 0:00:00.158427
# episode: 1800/2000, episode end value: 6572.23, duration: 0:00:00.157205
# episode: 1801/2000, episode end value: 4956.08, duration: 0:00:00.154012
# episode: 1802/2000, episode end value: 3761.18, duration: 0:00:00.159023
# episode: 1803/2000, episode end value: 4010.48, duration: 0:00:00.170047
# episode: 1804/2000, episode end value: 2097.34, duration: 0:00:00.175038
# episode: 1805/2000, episode end value: 3224.04, duration: 0:00:00.169045
# episode: 1806/2000, episode end value: 3104.42, duration: 0:00:00.163022
# episode: 1807/2000, episode end value: 3238.44, duration: 0:00:00.155045
# episode: 1808/2000, episode end value: 2647.54, duration: 0:00:00.171040
# episode: 1809/2000, episode end value: 3858.47, duration: 0:00:00.166038
# episode: 1810/2000, episode end value: 4348.35, duration: 0:00:00.162019
# episode: 1811/2000, episode end value: 2846.98, duration: 0:00:00.158556
# episode: 1812/2000, episode end value: 4339.46, duration: 0:00:00.163029
# episode: 1813/2000, episode end value: 3053.41, duration: 0:00:00.159036
# episode: 1814/2000, episode end value: 3320.46, duration: 0:00:00.163023
# episode: 1815/2000, episode end value: 2606.95, duration: 0:00:00.165052
# episode: 1816/2000, episode end value: 4595.10, duration: 0:00:00.170042
# episode: 1817/2000, episode end value: 3697.41, duration: 0:00:00.162031
# episode: 1818/2000, episode end value: 1691.21, duration: 0:00:00.168037
# episode: 1819/2000, episode end value: 4008.57, duration: 0:00:00.165039
# episode: 1820/2000, episode end value: 3337.97, duration: 0:00:00.171050
# episode: 1821/2000, episode end value: 2624.55, duration: 0:00:00.171054
# episode: 1822/2000, episode end value: 3532.16, duration: 0:00:00.163042
# episode: 1823/2000, episode end value: 3229.47, duration: 0:00:00.157035
# episode: 1824/2000, episode end value: 3896.00, duration: 0:00:00.161038
# episode: 1825/2000, episode end value: 3319.19, duration: 0:00:00.160020
# episode: 1826/2000, episode end value: 2896.43, duration: 0:00:00.178041
# episode: 1827/2000, episode end value: 2157.56, duration: 0:00:00.158049
# episode: 1828/2000, episode end value: 6413.81, duration: 0:00:00.162027
# episode: 1829/2000, episode end value: 2454.07, duration: 0:00:00.161040
# episode: 1830/2000, episode end value: 7648.95, duration: 0:00:00.171020
# episode: 1831/2000, episode end value: 3395.65, duration: 0:00:00.164038
# episode: 1832/2000, episode end value: 2741.71, duration: 0:00:00.164046
# episode: 1833/2000, episode end value: 5683.47, duration: 0:00:00.159039
# episode: 1834/2000, episode end value: 7738.00, duration: 0:00:00.170029
# episode: 1835/2000, episode end value: 5811.76, duration: 0:00:00.173056
# episode: 1836/2000, episode end value: 2663.69, duration: 0:00:00.172022
# episode: 1837/2000, episode end value: 4491.64, duration: 0:00:00.165056
# episode: 1838/2000, episode end value: 4320.96, duration: 0:00:00.161016
# episode: 1839/2000, episode end value: 2104.01, duration: 0:00:00.163044
# episode: 1840/2000, episode end value: 4667.01, duration: 0:00:00.166038
# episode: 1841/2000, episode end value: 3998.74, duration: 0:00:00.159041
# episode: 1842/2000, episode end value: 4109.46, duration: 0:00:00.170022
# episode: 1843/2000, episode end value: 6286.33, duration: 0:00:00.161050
# episode: 1844/2000, episode end value: 3046.02, duration: 0:00:00.161039
# episode: 1845/2000, episode end value: 2851.45, duration: 0:00:00.164035
# episode: 1846/2000, episode end value: 3096.85, duration: 0:00:00.163037
# episode: 1847/2000, episode end value: 5186.18, duration: 0:00:00.160031
# episode: 1848/2000, episode end value: 5348.71, duration: 0:00:00.158050
# episode: 1849/2000, episode end value: 6733.54, duration: 0:00:00.165045
# episode: 1850/2000, episode end value: 5447.62, duration: 0:00:00.161030
# episode: 1851/2000, episode end value: 3705.96, duration: 0:00:00.160028
# episode: 1852/2000, episode end value: 3691.05, duration: 0:00:00.171054
# episode: 1853/2000, episode end value: 3103.19, duration: 0:00:00.157043
# episode: 1854/2000, episode end value: 4418.22, duration: 0:00:00.159053
# episode: 1855/2000, episode end value: 3006.40, duration: 0:00:00.163068
# episode: 1856/2000, episode end value: 3009.52, duration: 0:00:00.171035
# episode: 1857/2000, episode end value: 3378.08, duration: 0:00:00.160038
# episode: 1858/2000, episode end value: 2335.87, duration: 0:00:00.164039
# episode: 1859/2000, episode end value: 5066.84, duration: 0:00:00.161022
# episode: 1860/2000, episode end value: 7366.32, duration: 0:00:00.166036
# episode: 1861/2000, episode end value: 7024.03, duration: 0:00:00.169046
# episode: 1862/2000, episode end value: 6963.35, duration: 0:00:00.170023
# episode: 1863/2000, episode end value: 4069.86, duration: 0:00:00.163033
# episode: 1864/2000, episode end value: 5267.09, duration: 0:00:00.176051
# episode: 1865/2000, episode end value: 3806.83, duration: 0:00:00.160043
# episode: 1866/2000, episode end value: 3405.45, duration: 0:00:00.171044
# episode: 1867/2000, episode end value: 3042.07, duration: 0:00:00.172027
# episode: 1868/2000, episode end value: 4430.54, duration: 0:00:00.175039
# episode: 1869/2000, episode end value: 4633.22, duration: 0:00:00.172049
# episode: 1870/2000, episode end value: 2516.57, duration: 0:00:00.169045
# episode: 1871/2000, episode end value: 4338.63, duration: 0:00:00.176040
# episode: 1872/2000, episode end value: 6296.07, duration: 0:00:00.174037
# episode: 1873/2000, episode end value: 2630.34, duration: 0:00:00.171058
# episode: 1874/2000, episode end value: 4971.40, duration: 0:00:00.170039
# episode: 1875/2000, episode end value: 4389.81, duration: 0:00:00.167040
# episode: 1876/2000, episode end value: 3734.04, duration: 0:00:00.169055
# episode: 1877/2000, episode end value: 3411.82, duration: 0:00:00.166036
# episode: 1878/2000, episode end value: 3777.33, duration: 0:00:00.171022
# episode: 1879/2000, episode end value: 3794.43, duration: 0:00:00.169549
# episode: 1880/2000, episode end value: 4374.21, duration: 0:00:00.177039
# episode: 1881/2000, episode end value: 4521.88, duration: 0:00:00.174049
# episode: 1882/2000, episode end value: 1819.89, duration: 0:00:00.173084
# episode: 1883/2000, episode end value: 3777.61, duration: 0:00:00.163062
# episode: 1884/2000, episode end value: 2756.51, duration: 0:00:00.173053
# episode: 1885/2000, episode end value: 5828.93, duration: 0:00:00.170050
# episode: 1886/2000, episode end value: 8010.74, duration: 0:00:00.165026
# episode: 1887/2000, episode end value: 5111.76, duration: 0:00:00.160034
# episode: 1888/2000, episode end value: 4143.85, duration: 0:00:00.160450
# episode: 1889/2000, episode end value: 5150.29, duration: 0:00:00.167570
# episode: 1890/2000, episode end value: 6169.20, duration: 0:00:00.174032
# episode: 1891/2000, episode end value: 4445.39, duration: 0:00:00.158102
# episode: 1892/2000, episode end value: 6366.98, duration: 0:00:00.166084
# episode: 1893/2000, episode end value: 5055.69, duration: 0:00:00.168120
# episode: 1894/2000, episode end value: 5573.59, duration: 0:00:00.163571
# episode: 1895/2000, episode end value: 5539.02, duration: 0:00:00.157020
# episode: 1896/2000, episode end value: 5261.96, duration: 0:00:00.175056
# episode: 1897/2000, episode end value: 5583.28, duration: 0:00:00.162042
# episode: 1898/2000, episode end value: 3460.53, duration: 0:00:00.162021
# episode: 1899/2000, episode end value: 3619.69, duration: 0:00:00.190058
# episode: 1900/2000, episode end value: 4022.33, duration: 0:00:00.158020
# episode: 1901/2000, episode end value: 3800.50, duration: 0:00:00.167053
# episode: 1902/2000, episode end value: 2901.47, duration: 0:00:00.158028
# episode: 1903/2000, episode end value: 2547.06, duration: 0:00:00.172037
# episode: 1904/2000, episode end value: 3755.86, duration: 0:00:00.161040
# episode: 1905/2000, episode end value: 3443.85, duration: 0:00:00.164027
# episode: 1906/2000, episode end value: 3676.68, duration: 0:00:00.175042
# episode: 1907/2000, episode end value: 2964.15, duration: 0:00:00.168022
# episode: 1908/2000, episode end value: 2665.30, duration: 0:00:00.159034
# episode: 1909/2000, episode end value: 5200.43, duration: 0:00:00.162045
# episode: 1910/2000, episode end value: 2845.98, duration: 0:00:00.176034
# episode: 1911/2000, episode end value: 3380.79, duration: 0:00:00.172058
# episode: 1912/2000, episode end value: 1016.84, duration: 0:00:00.168049
# episode: 1913/2000, episode end value: 6168.08, duration: 0:00:00.159047
# episode: 1914/2000, episode end value: 4941.17, duration: 0:00:00.172920
# episode: 1915/2000, episode end value: 5484.26, duration: 0:00:00.157943
# episode: 1916/2000, episode end value: 5984.44, duration: 0:00:00.173059
# episode: 1917/2000, episode end value: 7462.08, duration: 0:00:00.157020
# episode: 1918/2000, episode end value: 4406.82, duration: 0:00:00.160052
# episode: 1919/2000, episode end value: 5309.82, duration: 0:00:00.157034
# episode: 1920/2000, episode end value: 7002.57, duration: 0:00:00.169033
# episode: 1921/2000, episode end value: 4209.38, duration: 0:00:00.159018
# episode: 1922/2000, episode end value: 6644.35, duration: 0:00:00.172046
# episode: 1923/2000, episode end value: 3915.26, duration: 0:00:00.172045
# episode: 1924/2000, episode end value: 2990.51, duration: 0:00:00.162034
# episode: 1925/2000, episode end value: 2997.44, duration: 0:00:00.157031
# episode: 1926/2000, episode end value: 5623.27, duration: 0:00:00.171040
# episode: 1927/2000, episode end value: 4917.30, duration: 0:00:00.158035
# episode: 1928/2000, episode end value: 6214.68, duration: 0:00:00.159023
# episode: 1929/2000, episode end value: 6797.57, duration: 0:00:00.157077
# episode: 1930/2000, episode end value: 6799.09, duration: 0:00:00.177043
# episode: 1931/2000, episode end value: 4557.69, duration: 0:00:00.165045
# episode: 1932/2000, episode end value: 4010.66, duration: 0:00:00.158039
# episode: 1933/2000, episode end value: 5142.20, duration: 0:00:00.172021
# episode: 1934/2000, episode end value: 4973.77, duration: 0:00:00.174056
# episode: 1935/2000, episode end value: 4794.30, duration: 0:00:00.176041
# episode: 1936/2000, episode end value: 4522.41, duration: 0:00:00.166035
# episode: 1937/2000, episode end value: 4844.97, duration: 0:00:00.160019
# episode: 1938/2000, episode end value: 3854.65, duration: 0:00:00.172049
# episode: 1939/2000, episode end value: 1192.34, duration: 0:00:00.166045
# episode: 1940/2000, episode end value: 4807.44, duration: 0:00:00.170023
# episode: 1941/2000, episode end value: 3382.01, duration: 0:00:00.169038
# episode: 1942/2000, episode end value: 3927.21, duration: 0:00:00.166054
# episode: 1943/2000, episode end value: 1860.00, duration: 0:00:00.159043
# episode: 1944/2000, episode end value: 7362.87, duration: 0:00:00.169052
# episode: 1945/2000, episode end value: 2360.07, duration: 0:00:00.173035
# episode: 1946/2000, episode end value: 3303.94, duration: 0:00:00.176027
# episode: 1947/2000, episode end value: 3056.54, duration: 0:00:00.157050
# episode: 1948/2000, episode end value: 5776.42, duration: 0:00:00.167036
# episode: 1949/2000, episode end value: 3899.93, duration: 0:00:00.173024
# episode: 1950/2000, episode end value: 2616.40, duration: 0:00:00.164038
# episode: 1951/2000, episode end value: 6222.18, duration: 0:00:00.175053
# episode: 1952/2000, episode end value: 2704.03, duration: 0:00:00.161038
# episode: 1953/2000, episode end value: 2453.66, duration: 0:00:00.162029
# episode: 1954/2000, episode end value: 3446.77, duration: 0:00:00.160895
# episode: 1955/2000, episode end value: 5659.40, duration: 0:00:00.169064
# episode: 1956/2000, episode end value: 4153.36, duration: 0:00:00.168740
# episode: 1957/2000, episode end value: 5491.66, duration: 0:00:00.170021
# episode: 1958/2000, episode end value: 5536.65, duration: 0:00:00.172036
# episode: 1959/2000, episode end value: 4749.51, duration: 0:00:00.167047
# episode: 1960/2000, episode end value: 3387.40, duration: 0:00:00.165037
# episode: 1961/2000, episode end value: 5682.22, duration: 0:00:00.158034
# episode: 1962/2000, episode end value: 4132.69, duration: 0:00:00.163052
# episode: 1963/2000, episode end value: 3251.55, duration: 0:00:00.161019
# episode: 1964/2000, episode end value: 3541.35, duration: 0:00:00.159040
# episode: 1965/2000, episode end value: 3381.35, duration: 0:00:00.160022
# episode: 1966/2000, episode end value: 3135.24, duration: 0:00:00.176732
# episode: 1967/2000, episode end value: 2221.94, duration: 0:00:00.160951
# episode: 1968/2000, episode end value: 2772.93, duration: 0:00:00.163047
# episode: 1969/2000, episode end value: 2037.06, duration: 0:00:00.168060
# episode: 1970/2000, episode end value: 6556.23, duration: 0:00:00.170133
# episode: 1971/2000, episode end value: 6489.84, duration: 0:00:00.163189
# episode: 1972/2000, episode end value: 6155.44, duration: 0:00:00.165363
# episode: 1973/2000, episode end value: 3624.14, duration: 0:00:00.158353
# episode: 1974/2000, episode end value: 2982.65, duration: 0:00:00.177038
# episode: 1975/2000, episode end value: 7410.74, duration: 0:00:00.158037
# episode: 1976/2000, episode end value: 7534.35, duration: 0:00:00.164039
# episode: 1977/2000, episode end value: 7841.69, duration: 0:00:00.157018
# episode: 1978/2000, episode end value: 7459.46, duration: 0:00:00.193045
# episode: 1979/2000, episode end value: 7128.21, duration: 0:00:00.159065
# episode: 1980/2000, episode end value: 6311.76, duration: 0:00:00.161378
# episode: 1981/2000, episode end value: 6233.43, duration: 0:00:00.160053
# episode: 1982/2000, episode end value: 4851.29, duration: 0:00:00.169099
# episode: 1983/2000, episode end value: 4646.50, duration: 0:00:00.163049
# episode: 1984/2000, episode end value: 8063.10, duration: 0:00:00.164052
# episode: 1985/2000, episode end value: 5889.69, duration: 0:00:00.156033
# episode: 1986/2000, episode end value: 4804.57, duration: 0:00:00.159033
# episode: 1987/2000, episode end value: 6002.61, duration: 0:00:00.157563
# episode: 1988/2000, episode end value: 6342.70, duration: 0:00:00.162038
# episode: 1989/2000, episode end value: 3643.22, duration: 0:00:00.169038
# episode: 1990/2000, episode end value: 4368.28, duration: 0:00:00.170037
# episode: 1991/2000, episode end value: 5245.01, duration: 0:00:00.165031
# episode: 1992/2000, episode end value: 4727.91, duration: 0:00:00.165025
# episode: 1993/2000, episode end value: 3046.48, duration: 0:00:00.166053
# episode: 1994/2000, episode end value: 6704.94, duration: 0:00:00.162034
# episode: 1995/2000, episode end value: 10238.83, duration: 0:00:00.169027
# episode: 1996/2000, episode end value: 5299.49, duration: 0:00:00.160041
# episode: 1997/2000, episode end value: 5342.02, duration: 0:00:00.160022
# episode: 1998/2000, episode end value: 6243.52, duration: 0:00:00.159038
# episode: 1999/2000, episode end value: 6224.75, duration: 0:00:00.160040
# episode: 2000/2000, episode end value: 3687.57, duration: 0:00:00.162041
# average reward: 4695.96, min: 765.46, max: 13540.91

# %%
plt.plot(agent.model.losses)

# %%
plt.plot(portfolio_value)

# %%
#test

mode = 'test'

portfolio_value = []

if mode == 'test':
    with open(f'{models_folder}/scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    num_episodes = 1
    env = Env(test_data, capital)
    agent.epsilon = 0
    agent.load(f'{models_folder}/linear.npz')


for e in range(num_episodes):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1])
    
print(f"Sell: {env.sell_buy.count('sell')} times, Buy: {env.sell_buy.count('buy')} times")



result = pd.DataFrame(val)
result.index = test_data.index

def marker_buy(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'buy':
        return price
    else:
        return np.nan
    
def marker_sell(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'sell':
        return price
    else:
        return np.nan
    
result['marker_buy'] = result[['stock_price', 'sell_buy']].apply(marker_buy, axis=1);
result['marker_sell'] = result[['stock_price', 'sell_buy']].apply(marker_sell, axis=1);

result['stock_price'].plot(figsize=(10,6), c='grey', lw=2);
result['marker_buy'].plot(style='o', ms=7, label='buy', c='g', alpha=0.5);
result['marker_sell'].plot(style='o', ms=7, label='sell', c='r', alpha=0.5);
plt.title('Stock Price '+ stock_name)
plt.legend();
plt.show()



result['portfolio_value'].plot(figsize=(10,6), c='r', lw=2);
plt.title('Portfolio Value');
plt.show()

result['stock_owned'].plot(figsize=(10,6), c='purple', lw=2);
plt.title('Position')
plt.show()

result[['cash_in_hand', 'stock_value']].plot(figsize=(10,6), lw=2);
plt.title('Cash in Hand and Stock Value');
plt.show()
# Out:
# episode: 1/1, episode end value: 1000.00, duration: 0:00:00.054032
# Sell: 0 times, Buy: 0 times

# %%
import pyfolio as pf
sns.set_style('whitegrid')

bt_returns = result['portfolio_value'].pct_change()
price = result['stock_price'].pct_change()



plt.figure(figsize=(9,6));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, price);
plt.title('Compare with close price');
plt.show()

fig = plt.figure(1)
plt.subplot(1,3,1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1,3,2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1,3,3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()
fig.set_size_inches(12,4)

plt.figure(figsize=(9,6))
pf.plot_return_quantiles(bt_returns);



plt.figure(figsize=(9,6))
pf.plot_rolling_sharpe(bt_returns);

plt.figure(figsize=(9,6))
pf.plot_drawdown_underwater(bt_returns);
# Out:
# C:\Users\User\anaconda3\envs\MyDjango\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
