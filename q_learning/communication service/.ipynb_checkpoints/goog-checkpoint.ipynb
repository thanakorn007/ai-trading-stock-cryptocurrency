# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import os
import pickle
import seaborn as sns
import datetime as dt
from model import StockEnv,get_scaler, play_one_episode, LinearModel, DQNAgent
from tqdm.notebook import tqdm
import pyfolio as pf
# %matplotlib inline
# Out:
# C:\Users\User\anaconda3\envs\MyDjango\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
stock_name = 'ea'.upper()
industry = 'Communication Services'
stock_data = pd.read_csv(f'../train_test_data/{stock_name}.csv', index_col=['Date'], parse_dates=True)

train_data = stock_data.loc[:'2018-01-01']
test_data = stock_data.loc['2018-01-01':]

print(f'Stock name: {stock_name}')
print(f'Start: {stock_data.index[0]}, End: {stock_data.index[-1]}')
print(f'Training data: {len(train_data)} ')
print(f'Tsesting data: {len(test_data)} ')

sns.set_style('whitegrid')
train_data['Adj Close'].plot(label='training_data', figsize=(15,8));
test_data['Adj Close'].plot(label='testing_data');
plt.title('Stock data '+ stock_name)
plt.legend();
plt.show()

stock_data[['rsi', 'mom']].plot(subplots=True, figsize=(15,5), title='Technical indicators');
plt.show()
# Out:
# Stock name: EA
# Start: 2013-02-19 00:00:00, End: 2020-12-31 00:00:00
# Training data: 1227
# Tsesting data: 756

# %%
num_episodes = 2000
batch_size = 32
capital = 1000
data = stock_data['Adj Close'].values
n_timesteps = data.shape[0]


env = StockEnv(train_data, capital)
state_size = env.state_dim
action_size = 2
agent = DQNAgent(state_size, action_size)
scaler = get_scaler(env)

# %%
#train


mode = 'train'

portfolio_value = []



for e in tqdm(range(num_episodes)):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode, scaler)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1]) 


if mode == 'train':
    # save the DQN
    agent.save(f'state_dict/{stock_name}.npz')

    # save the scaler
    with open(f'scaler/{stock_name}.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    # plot losses
    loss = agent.model.losses
    losses = pd.DataFrame(loss, columns=['loss'])
    losses.plot(figsize=(10,6))
    plt.title('Average Mean Square Error of All Episode')
    plt.xlabel('Step')
    plt.ylabel('Mean Square Error')

print(f'average reward: {np.mean(portfolio_value):.2f}, min: {np.min(portfolio_value):.2f}, max: {np.max(portfolio_value):.2f}')
sns.histplot(portfolio_value, bins=100, color='r', kde=True);
plt.xlabel('Portfolio Value');
plt.ylabel('Count');
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# episode: 1/2000, episode end value: 1822.38, duration: 0:00:00.206059
# episode: 2/2000, episode end value: 1825.75, duration: 0:00:00.216049
# episode: 3/2000, episode end value: 1804.61, duration: 0:00:00.209042
# episode: 4/2000, episode end value: 1816.70, duration: 0:00:00.208036
# episode: 5/2000, episode end value: 1816.97, duration: 0:00:00.216063
# episode: 6/2000, episode end value: 1818.52, duration: 0:00:00.218036
# episode: 7/2000, episode end value: 1817.94, duration: 0:00:00.220061
# episode: 8/2000, episode end value: 1810.99, duration: 0:00:00.211048
# episode: 9/2000, episode end value: 1808.80, duration: 0:00:00.207046
# episode: 10/2000, episode end value: 1817.90, duration: 0:00:00.209047
# episode: 11/2000, episode end value: 1806.02, duration: 0:00:00.210035
# episode: 12/2000, episode end value: 1817.35, duration: 0:00:00.208052
# episode: 13/2000, episode end value: 1810.32, duration: 0:00:00.214035
# episode: 14/2000, episode end value: 1806.14, duration: 0:00:00.217050
# episode: 15/2000, episode end value: 1824.39, duration: 0:00:00.213060
# episode: 16/2000, episode end value: 1804.71, duration: 0:00:00.208059
# episode: 17/2000, episode end value: 1803.18, duration: 0:00:00.219047
# episode: 18/2000, episode end value: 1821.60, duration: 0:00:00.216062
# episode: 19/2000, episode end value: 1812.81, duration: 0:00:00.204047
# episode: 20/2000, episode end value: 1811.64, duration: 0:00:00.214047
# episode: 21/2000, episode end value: 1814.71, duration: 0:00:00.208033
# episode: 22/2000, episode end value: 1814.33, duration: 0:00:00.209060
# episode: 23/2000, episode end value: 1825.52, duration: 0:00:00.192043
# episode: 24/2000, episode end value: 1797.98, duration: 0:00:00.196047
# episode: 25/2000, episode end value: 1818.08, duration: 0:00:00.208042
# episode: 26/2000, episode end value: 1815.57, duration: 0:00:00.206040
# episode: 27/2000, episode end value: 1822.88, duration: 0:00:00.201045
# episode: 28/2000, episode end value: 1807.61, duration: 0:00:00.191035
# episode: 29/2000, episode end value: 1821.37, duration: 0:00:00.200040
# episode: 30/2000, episode end value: 1812.60, duration: 0:00:00.214061
# episode: 31/2000, episode end value: 1826.30, duration: 0:00:00.200045
# episode: 32/2000, episode end value: 1806.38, duration: 0:00:00.199045
# episode: 33/2000, episode end value: 1800.83, duration: 0:00:00.217048
# episode: 34/2000, episode end value: 1814.24, duration: 0:00:00.194043
# episode: 35/2000, episode end value: 1813.77, duration: 0:00:00.206047
# episode: 36/2000, episode end value: 1793.21, duration: 0:00:00.219057
# episode: 37/2000, episode end value: 1803.65, duration: 0:00:00.217049
# episode: 38/2000, episode end value: 1814.54, duration: 0:00:00.202058
# episode: 39/2000, episode end value: 1803.58, duration: 0:00:00.198046
# episode: 40/2000, episode end value: 1804.38, duration: 0:00:00.205049
# episode: 41/2000, episode end value: 1824.94, duration: 0:00:00.205041
# episode: 42/2000, episode end value: 1802.43, duration: 0:00:00.219053
# episode: 43/2000, episode end value: 1808.86, duration: 0:00:00.215060
# episode: 44/2000, episode end value: 1811.13, duration: 0:00:00.198045
# episode: 45/2000, episode end value: 1815.42, duration: 0:00:00.195029
# episode: 46/2000, episode end value: 1813.28, duration: 0:00:00.202065
# episode: 47/2000, episode end value: 1828.24, duration: 0:00:00.205039
# episode: 48/2000, episode end value: 1822.64, duration: 0:00:00.205030
# episode: 49/2000, episode end value: 1802.23, duration: 0:00:00.207048
# episode: 50/2000, episode end value: 1806.12, duration: 0:00:00.206057
# episode: 51/2000, episode end value: 1801.57, duration: 0:00:00.210032
# episode: 52/2000, episode end value: 1803.42, duration: 0:00:00.217041
# episode: 53/2000, episode end value: 1813.33, duration: 0:00:00.207047
# episode: 54/2000, episode end value: 1804.98, duration: 0:00:00.200043
# episode: 55/2000, episode end value: 1818.71, duration: 0:00:00.198057
# episode: 56/2000, episode end value: 1807.14, duration: 0:00:00.206042
# episode: 57/2000, episode end value: 1802.27, duration: 0:00:00.202051
# episode: 58/2000, episode end value: 1829.02, duration: 0:00:00.218057
# episode: 59/2000, episode end value: 1801.94, duration: 0:00:00.201051
# episode: 60/2000, episode end value: 1820.04, duration: 0:00:00.206040
# episode: 61/2000, episode end value: 1821.71, duration: 0:00:00.215059
# episode: 62/2000, episode end value: 1823.14, duration: 0:00:00.203040
# episode: 63/2000, episode end value: 1824.03, duration: 0:00:00.214035
# episode: 64/2000, episode end value: 1817.55, duration: 0:00:00.223049
# episode: 65/2000, episode end value: 1820.21, duration: 0:00:00.210052
# episode: 66/2000, episode end value: 1809.05, duration: 0:00:00.221044
# episode: 67/2000, episode end value: 1804.11, duration: 0:00:00.217056
# episode: 68/2000, episode end value: 1804.64, duration: 0:00:00.199029
# episode: 69/2000, episode end value: 1812.43, duration: 0:00:00.217058
# episode: 70/2000, episode end value: 1800.05, duration: 0:00:00.204054
# episode: 71/2000, episode end value: 1813.54, duration: 0:00:00.204038
# episode: 72/2000, episode end value: 1820.12, duration: 0:00:00.197057
# episode: 73/2000, episode end value: 1816.49, duration: 0:00:00.198044
# episode: 74/2000, episode end value: 1799.32, duration: 0:00:00.206042
# episode: 75/2000, episode end value: 1806.92, duration: 0:00:00.202052
# episode: 76/2000, episode end value: 1802.43, duration: 0:00:00.200044
# episode: 77/2000, episode end value: 1811.22, duration: 0:00:00.203055
# episode: 78/2000, episode end value: 1824.49, duration: 0:00:00.205038
# episode: 79/2000, episode end value: 1814.43, duration: 0:00:00.203055
# episode: 80/2000, episode end value: 1800.75, duration: 0:00:00.211047
# episode: 81/2000, episode end value: 1797.63, duration: 0:00:00.209040
# episode: 82/2000, episode end value: 1809.55, duration: 0:00:00.205035
# episode: 83/2000, episode end value: 1809.66, duration: 0:00:00.209047
# episode: 84/2000, episode end value: 1811.05, duration: 0:00:00.204033
# episode: 85/2000, episode end value: 1807.52, duration: 0:00:00.206060
# episode: 86/2000, episode end value: 1808.33, duration: 0:00:00.204039
# episode: 87/2000, episode end value: 1805.63, duration: 0:00:00.204039
# episode: 88/2000, episode end value: 1799.57, duration: 0:00:00.200056
# episode: 89/2000, episode end value: 1800.71, duration: 0:00:00.198045
# episode: 90/2000, episode end value: 1813.92, duration: 0:00:00.220055
# episode: 91/2000, episode end value: 1801.61, duration: 0:00:00.212042
# episode: 92/2000, episode end value: 1805.38, duration: 0:00:00.208048
# episode: 93/2000, episode end value: 1805.68, duration: 0:00:00.205032
# episode: 94/2000, episode end value: 1822.27, duration: 0:00:00.201059
# episode: 95/2000, episode end value: 1806.13, duration: 0:00:00.198044
# episode: 96/2000, episode end value: 1799.05, duration: 0:00:00.207048
# episode: 97/2000, episode end value: 1805.39, duration: 0:00:00.195037
# episode: 98/2000, episode end value: 1822.34, duration: 0:00:00.203034
# episode: 99/2000, episode end value: 1813.78, duration: 0:00:00.200043
# episode: 100/2000, episode end value: 1805.57, duration: 0:00:00.202047
# episode: 101/2000, episode end value: 1811.73, duration: 0:00:00.206060
# episode: 102/2000, episode end value: 1808.38, duration: 0:00:00.201047
# episode: 103/2000, episode end value: 1806.54, duration: 0:00:00.202036
# episode: 104/2000, episode end value: 1804.11, duration: 0:00:00.209059
# episode: 105/2000, episode end value: 1811.94, duration: 0:00:00.197042
# episode: 106/2000, episode end value: 1809.96, duration: 0:00:00.204046
# episode: 107/2000, episode end value: 1804.31, duration: 0:00:00.199030
# episode: 108/2000, episode end value: 1805.56, duration: 0:00:00.197059
# episode: 109/2000, episode end value: 1805.30, duration: 0:00:00.213035
# episode: 110/2000, episode end value: 1807.45, duration: 0:00:00.212062
# episode: 111/2000, episode end value: 1813.41, duration: 0:00:00.205044
# episode: 112/2000, episode end value: 1790.26, duration: 0:00:00.203051
# episode: 113/2000, episode end value: 1804.59, duration: 0:00:00.203032
# episode: 114/2000, episode end value: 1791.10, duration: 0:00:00.203049
# episode: 115/2000, episode end value: 1805.51, duration: 0:00:00.204033
# episode: 116/2000, episode end value: 1823.19, duration: 0:00:00.206045
# episode: 117/2000, episode end value: 1800.74, duration: 0:00:00.203052
# episode: 118/2000, episode end value: 1811.13, duration: 0:00:00.213054
# episode: 119/2000, episode end value: 1813.69, duration: 0:00:00.211049
# episode: 120/2000, episode end value: 1820.33, duration: 0:00:00.203044
# episode: 121/2000, episode end value: 1794.25, duration: 0:00:00.206050
# episode: 122/2000, episode end value: 1805.65, duration: 0:00:00.195044
# episode: 123/2000, episode end value: 1807.33, duration: 0:00:00.204032
# episode: 124/2000, episode end value: 1804.94, duration: 0:00:00.203052
# episode: 125/2000, episode end value: 1806.45, duration: 0:00:00.200042
# episode: 126/2000, episode end value: 1804.74, duration: 0:00:00.200045
# episode: 127/2000, episode end value: 1802.49, duration: 0:00:00.207052
# episode: 128/2000, episode end value: 1804.50, duration: 0:00:00.203046
# episode: 129/2000, episode end value: 1806.73, duration: 0:00:00.195042
# episode: 130/2000, episode end value: 1804.78, duration: 0:00:00.206046
# episode: 131/2000, episode end value: 1820.22, duration: 0:00:00.203045
# episode: 132/2000, episode end value: 1805.36, duration: 0:00:00.203032
# episode: 133/2000, episode end value: 1803.94, duration: 0:00:00.212039
# episode: 134/2000, episode end value: 1799.44, duration: 0:00:00.202063
# episode: 135/2000, episode end value: 1807.70, duration: 0:00:00.209028
# episode: 136/2000, episode end value: 1791.09, duration: 0:00:00.203065
# episode: 137/2000, episode end value: 1799.70, duration: 0:00:00.211041
# episode: 138/2000, episode end value: 1820.42, duration: 0:00:00.208048
# episode: 139/2000, episode end value: 1802.36, duration: 0:00:00.204045
# episode: 140/2000, episode end value: 1792.39, duration: 0:00:00.209047
# episode: 141/2000, episode end value: 1794.57, duration: 0:00:00.204045
# episode: 142/2000, episode end value: 1809.36, duration: 0:00:00.212048
# episode: 143/2000, episode end value: 1798.71, duration: 0:00:00.199045
# episode: 144/2000, episode end value: 1804.83, duration: 0:00:00.200045
# episode: 145/2000, episode end value: 1807.86, duration: 0:00:00.206046
# episode: 146/2000, episode end value: 1802.24, duration: 0:00:00.209047
# episode: 147/2000, episode end value: 1811.52, duration: 0:00:00.209047
# episode: 148/2000, episode end value: 1804.11, duration: 0:00:00.195041
# episode: 149/2000, episode end value: 1818.75, duration: 0:00:00.196045
# episode: 150/2000, episode end value: 1781.53, duration: 0:00:00.208040
# episode: 151/2000, episode end value: 1806.65, duration: 0:00:00.209051
# episode: 152/2000, episode end value: 1805.91, duration: 0:00:00.208046
# episode: 153/2000, episode end value: 1804.00, duration: 0:00:00.203032
# episode: 154/2000, episode end value: 1809.28, duration: 0:00:00.201044
# episode: 155/2000, episode end value: 1802.27, duration: 0:00:00.210061
# episode: 156/2000, episode end value: 1805.05, duration: 0:00:00.210047
# episode: 157/2000, episode end value: 1799.27, duration: 0:00:00.208047
# episode: 158/2000, episode end value: 1803.59, duration: 0:00:00.199054
# episode: 159/2000, episode end value: 1804.52, duration: 0:00:00.201054
# episode: 160/2000, episode end value: 1804.54, duration: 0:00:00.203051
# episode: 161/2000, episode end value: 1811.51, duration: 0:00:00.200042
# episode: 162/2000, episode end value: 1823.93, duration: 0:00:00.207047
# episode: 163/2000, episode end value: 1804.94, duration: 0:00:00.202032
# episode: 164/2000, episode end value: 1800.45, duration: 0:00:00.212061
# episode: 165/2000, episode end value: 1802.84, duration: 0:00:00.214048
# episode: 166/2000, episode end value: 1805.52, duration: 0:00:00.204046
# episode: 167/2000, episode end value: 1813.55, duration: 0:00:00.183041
# episode: 168/2000, episode end value: 1835.80, duration: 0:00:00.181033
# episode: 169/2000, episode end value: 1832.58, duration: 0:00:00.189049
# episode: 170/2000, episode end value: 1804.18, duration: 0:00:00.199044
# episode: 171/2000, episode end value: 1804.57, duration: 0:00:00.206046
# episode: 172/2000, episode end value: 1805.40, duration: 0:00:00.208048
# episode: 173/2000, episode end value: 1800.44, duration: 0:00:00.209050
# episode: 174/2000, episode end value: 1817.50, duration: 0:00:00.207048
# episode: 175/2000, episode end value: 1803.59, duration: 0:00:00.207052
# episode: 176/2000, episode end value: 1801.77, duration: 0:00:00.203045
# episode: 177/2000, episode end value: 1807.25, duration: 0:00:00.206047
# episode: 178/2000, episode end value: 1804.31, duration: 0:00:00.196044
# episode: 179/2000, episode end value: 1810.03, duration: 0:00:00.202032
# episode: 180/2000, episode end value: 1803.97, duration: 0:00:00.200057
# episode: 181/2000, episode end value: 1805.80, duration: 0:00:00.195044
# episode: 182/2000, episode end value: 1820.53, duration: 0:00:00.206047
# episode: 183/2000, episode end value: 1803.54, duration: 0:00:00.198044
# episode: 184/2000, episode end value: 1806.01, duration: 0:00:00.209047
# episode: 185/2000, episode end value: 1810.47, duration: 0:00:00.204045
# episode: 186/2000, episode end value: 1808.73, duration: 0:00:00.209041
# episode: 187/2000, episode end value: 1807.40, duration: 0:00:00.204046
# episode: 188/2000, episode end value: 1804.63, duration: 0:00:00.205051
# episode: 189/2000, episode end value: 1804.01, duration: 0:00:00.206042
# episode: 190/2000, episode end value: 1821.64, duration: 0:00:00.196031
# episode: 191/2000, episode end value: 1805.39, duration: 0:00:00.202059
# episode: 192/2000, episode end value: 1815.69, duration: 0:00:00.205039
# episode: 193/2000, episode end value: 1804.69, duration: 0:00:00.198045
# episode: 194/2000, episode end value: 1835.91, duration: 0:00:00.211047
# episode: 195/2000, episode end value: 1811.29, duration: 0:00:00.204046
# episode: 196/2000, episode end value: 1824.94, duration: 0:00:00.200045
# episode: 197/2000, episode end value: 1802.14, duration: 0:00:00.210047
# episode: 198/2000, episode end value: 1804.22, duration: 0:00:00.202045
# episode: 199/2000, episode end value: 1822.49, duration: 0:00:00.200045
# episode: 200/2000, episode end value: 1802.39, duration: 0:00:00.194043
# episode: 201/2000, episode end value: 1819.28, duration: 0:00:00.211051
# episode: 202/2000, episode end value: 1807.12, duration: 0:00:00.195024
# episode: 203/2000, episode end value: 1788.77, duration: 0:00:00.203066
# episode: 204/2000, episode end value: 1808.32, duration: 0:00:00.207040
# episode: 205/2000, episode end value: 1804.44, duration: 0:00:00.202045
# episode: 206/2000, episode end value: 1803.47, duration: 0:00:00.193031
# episode: 207/2000, episode end value: 1806.41, duration: 0:00:00.193057
# episode: 208/2000, episode end value: 1806.41, duration: 0:00:00.195044
# episode: 209/2000, episode end value: 1805.25, duration: 0:00:00.199045
# episode: 210/2000, episode end value: 1780.11, duration: 0:00:00.201045
# episode: 211/2000, episode end value: 1820.14, duration: 0:00:00.205047
# episode: 212/2000, episode end value: 1822.90, duration: 0:00:00.205029
# episode: 213/2000, episode end value: 1804.18, duration: 0:00:00.202045
# episode: 214/2000, episode end value: 1803.86, duration: 0:00:00.208060
# episode: 215/2000, episode end value: 1805.21, duration: 0:00:00.204048
# episode: 216/2000, episode end value: 1809.77, duration: 0:00:00.207053
# episode: 217/2000, episode end value: 1803.70, duration: 0:00:00.218049
# episode: 218/2000, episode end value: 1804.35, duration: 0:00:00.201029
# episode: 219/2000, episode end value: 1804.49, duration: 0:00:00.204045
# episode: 220/2000, episode end value: 1808.46, duration: 0:00:00.199041
# episode: 221/2000, episode end value: 1802.27, duration: 0:00:00.205047
# episode: 222/2000, episode end value: 1804.06, duration: 0:00:00.203055
# episode: 223/2000, episode end value: 1819.87, duration: 0:00:00.195054
# episode: 224/2000, episode end value: 1804.58, duration: 0:00:00.194043
# episode: 225/2000, episode end value: 1802.79, duration: 0:00:00.196044
# episode: 226/2000, episode end value: 1800.96, duration: 0:00:00.194043
# episode: 227/2000, episode end value: 1804.56, duration: 0:00:00.207047
# episode: 228/2000, episode end value: 1804.73, duration: 0:00:00.201046
# episode: 229/2000, episode end value: 1803.17, duration: 0:00:00.208033
# episode: 230/2000, episode end value: 1803.85, duration: 0:00:00.201045
# episode: 231/2000, episode end value: 1796.34, duration: 0:00:00.202059
# episode: 232/2000, episode end value: 1813.93, duration: 0:00:00.198044
# episode: 233/2000, episode end value: 1818.03, duration: 0:00:00.197044
# episode: 234/2000, episode end value: 1804.48, duration: 0:00:00.201045
# episode: 235/2000, episode end value: 1807.44, duration: 0:00:00.197042
# episode: 236/2000, episode end value: 1804.37, duration: 0:00:00.202045
# episode: 237/2000, episode end value: 1802.35, duration: 0:00:00.218049
# episode: 238/2000, episode end value: 1799.96, duration: 0:00:00.198045
# episode: 239/2000, episode end value: 1811.71, duration: 0:00:00.200030
# episode: 240/2000, episode end value: 1814.47, duration: 0:00:00.202060
# episode: 241/2000, episode end value: 1820.43, duration: 0:00:00.200028
# episode: 242/2000, episode end value: 1811.59, duration: 0:00:00.197061
# episode: 243/2000, episode end value: 1804.21, duration: 0:00:00.199044
# episode: 244/2000, episode end value: 1802.89, duration: 0:00:00.201035
# episode: 245/2000, episode end value: 1818.35, duration: 0:00:00.208066
# episode: 246/2000, episode end value: 1822.82, duration: 0:00:00.216038
# episode: 247/2000, episode end value: 1804.59, duration: 0:00:00.205043
# episode: 248/2000, episode end value: 1802.53, duration: 0:00:00.214068
# episode: 249/2000, episode end value: 1802.36, duration: 0:00:00.219043
# episode: 250/2000, episode end value: 1805.60, duration: 0:00:00.208046
# episode: 251/2000, episode end value: 1808.15, duration: 0:00:00.212048
# episode: 252/2000, episode end value: 1803.49, duration: 0:00:00.204046
# episode: 253/2000, episode end value: 1786.19, duration: 0:00:00.196037
# episode: 254/2000, episode end value: 1802.05, duration: 0:00:00.195053
# episode: 255/2000, episode end value: 1804.25, duration: 0:00:00.224047
# episode: 256/2000, episode end value: 1804.44, duration: 0:00:00.205040
# episode: 257/2000, episode end value: 1803.89, duration: 0:00:00.204039
# episode: 258/2000, episode end value: 1807.12, duration: 0:00:00.195050
# episode: 259/2000, episode end value: 1807.82, duration: 0:00:00.201045
# episode: 260/2000, episode end value: 1816.59, duration: 0:00:00.209049
# episode: 261/2000, episode end value: 1812.44, duration: 0:00:00.210061
# episode: 262/2000, episode end value: 1800.14, duration: 0:00:00.211047
# episode: 263/2000, episode end value: 1821.65, duration: 0:00:00.200043
# episode: 264/2000, episode end value: 1824.47, duration: 0:00:00.211048
# episode: 265/2000, episode end value: 1803.73, duration: 0:00:00.205045
# episode: 266/2000, episode end value: 1815.79, duration: 0:00:00.199044
# episode: 267/2000, episode end value: 1803.42, duration: 0:00:00.207047
# episode: 268/2000, episode end value: 1802.45, duration: 0:00:00.209047
# episode: 269/2000, episode end value: 1792.21, duration: 0:00:00.197044
# episode: 270/2000, episode end value: 1803.36, duration: 0:00:00.205059
# episode: 271/2000, episode end value: 1817.27, duration: 0:00:00.209046
# episode: 272/2000, episode end value: 1800.64, duration: 0:00:00.199031
# episode: 273/2000, episode end value: 1824.96, duration: 0:00:00.208061
# episode: 274/2000, episode end value: 1802.87, duration: 0:00:00.199041
# episode: 275/2000, episode end value: 1821.97, duration: 0:00:00.193047
# episode: 276/2000, episode end value: 1815.54, duration: 0:00:00.199045
# episode: 277/2000, episode end value: 1804.09, duration: 0:00:00.198044
# episode: 278/2000, episode end value: 1802.56, duration: 0:00:00.197042
# episode: 279/2000, episode end value: 1819.24, duration: 0:00:00.204046
# episode: 280/2000, episode end value: 1798.45, duration: 0:00:00.196044
# episode: 281/2000, episode end value: 1799.72, duration: 0:00:00.200045
# episode: 282/2000, episode end value: 1815.58, duration: 0:00:00.199058
# episode: 283/2000, episode end value: 1816.93, duration: 0:00:00.207045
# episode: 284/2000, episode end value: 1815.91, duration: 0:00:00.207047
# episode: 285/2000, episode end value: 1802.43, duration: 0:00:00.205040
# episode: 286/2000, episode end value: 1810.08, duration: 0:00:00.201037
# episode: 287/2000, episode end value: 1801.54, duration: 0:00:00.200059
# episode: 288/2000, episode end value: 1800.19, duration: 0:00:00.214048
# episode: 289/2000, episode end value: 1800.32, duration: 0:00:00.237053
# episode: 290/2000, episode end value: 1804.15, duration: 0:00:00.212045
# episode: 291/2000, episode end value: 1803.50, duration: 0:00:00.206059
# episode: 292/2000, episode end value: 1803.93, duration: 0:00:00.208047
# episode: 293/2000, episode end value: 1827.12, duration: 0:00:00.209041
# episode: 294/2000, episode end value: 1808.37, duration: 0:00:00.202039
# episode: 295/2000, episode end value: 1821.15, duration: 0:00:00.209056
# episode: 296/2000, episode end value: 1799.26, duration: 0:00:00.206034
# episode: 297/2000, episode end value: 1818.19, duration: 0:00:00.208060
# episode: 298/2000, episode end value: 1800.76, duration: 0:00:00.220045
# episode: 299/2000, episode end value: 1812.99, duration: 0:00:00.207039
# episode: 300/2000, episode end value: 1801.13, duration: 0:00:00.203051
# episode: 301/2000, episode end value: 1808.12, duration: 0:00:00.195031
# episode: 302/2000, episode end value: 1818.66, duration: 0:00:00.199059
# episode: 303/2000, episode end value: 1811.55, duration: 0:00:00.210050
# episode: 304/2000, episode end value: 1820.47, duration: 0:00:00.205042
# episode: 305/2000, episode end value: 1810.99, duration: 0:00:00.210046
# episode: 306/2000, episode end value: 1806.58, duration: 0:00:00.202044
# episode: 307/2000, episode end value: 1802.53, duration: 0:00:00.204031
# episode: 308/2000, episode end value: 1805.11, duration: 0:00:00.226052
# episode: 309/2000, episode end value: 1801.08, duration: 0:00:00.223055
# episode: 310/2000, episode end value: 1804.00, duration: 0:00:00.211042
# episode: 311/2000, episode end value: 1804.54, duration: 0:00:00.210059
# episode: 312/2000, episode end value: 1798.22, duration: 0:00:00.205046
# episode: 313/2000, episode end value: 1816.85, duration: 0:00:00.210036
# episode: 314/2000, episode end value: 1802.71, duration: 0:00:00.204058
# episode: 315/2000, episode end value: 1808.95, duration: 0:00:00.214061
# episode: 316/2000, episode end value: 1804.21, duration: 0:00:00.207032
# episode: 317/2000, episode end value: 1798.05, duration: 0:00:00.215040
# episode: 318/2000, episode end value: 1801.81, duration: 0:00:00.198054
# episode: 319/2000, episode end value: 1803.31, duration: 0:00:00.205037
# episode: 320/2000, episode end value: 1810.86, duration: 0:00:00.198050
# episode: 321/2000, episode end value: 1801.06, duration: 0:00:00.200044
# episode: 322/2000, episode end value: 1803.90, duration: 0:00:00.208046
# episode: 323/2000, episode end value: 1814.38, duration: 0:00:00.201039
# episode: 324/2000, episode end value: 1797.81, duration: 0:00:00.211040
# episode: 325/2000, episode end value: 1804.85, duration: 0:00:00.205034
# episode: 326/2000, episode end value: 1822.35, duration: 0:00:00.202059
# episode: 327/2000, episode end value: 1797.61, duration: 0:00:00.179040
# episode: 328/2000, episode end value: 1897.51, duration: 0:00:00.165043
# episode: 329/2000, episode end value: 1833.52, duration: 0:00:00.180035
# episode: 330/2000, episode end value: 1789.93, duration: 0:00:00.196044
# episode: 331/2000, episode end value: 1811.13, duration: 0:00:00.196044
# episode: 332/2000, episode end value: 1794.37, duration: 0:00:00.211048
# episode: 333/2000, episode end value: 1811.12, duration: 0:00:00.200030
# episode: 334/2000, episode end value: 1819.21, duration: 0:00:00.201059
# episode: 335/2000, episode end value: 1802.45, duration: 0:00:00.201040
# episode: 336/2000, episode end value: 1791.70, duration: 0:00:00.210050
# episode: 337/2000, episode end value: 1799.61, duration: 0:00:00.212048
# episode: 338/2000, episode end value: 1827.43, duration: 0:00:00.205046
# episode: 339/2000, episode end value: 1823.40, duration: 0:00:00.207055
# episode: 340/2000, episode end value: 1804.38, duration: 0:00:00.217047
# episode: 341/2000, episode end value: 1812.69, duration: 0:00:00.199039
# episode: 342/2000, episode end value: 1803.27, duration: 0:00:00.198051
# episode: 343/2000, episode end value: 1811.12, duration: 0:00:00.200045
# episode: 344/2000, episode end value: 1818.82, duration: 0:00:00.200044
# episode: 345/2000, episode end value: 1807.46, duration: 0:00:00.197032
# episode: 346/2000, episode end value: 1804.55, duration: 0:00:00.195064
# episode: 347/2000, episode end value: 1798.35, duration: 0:00:00.203041
# episode: 348/2000, episode end value: 1793.49, duration: 0:00:00.207048
# episode: 349/2000, episode end value: 1801.37, duration: 0:00:00.206051
# episode: 350/2000, episode end value: 1793.89, duration: 0:00:00.196033
# episode: 351/2000, episode end value: 1802.95, duration: 0:00:00.202033
# episode: 352/2000, episode end value: 1817.35, duration: 0:00:00.195045
# episode: 353/2000, episode end value: 1811.08, duration: 0:00:00.205033
# episode: 354/2000, episode end value: 1801.24, duration: 0:00:00.219057
# episode: 355/2000, episode end value: 1809.45, duration: 0:00:00.201030
# episode: 356/2000, episode end value: 1804.29, duration: 0:00:00.198043
# episode: 357/2000, episode end value: 1802.79, duration: 0:00:00.210033
# episode: 358/2000, episode end value: 1812.28, duration: 0:00:00.203064
# episode: 359/2000, episode end value: 1799.52, duration: 0:00:00.214028
# episode: 360/2000, episode end value: 1821.04, duration: 0:00:00.195057
# episode: 361/2000, episode end value: 1819.12, duration: 0:00:00.205045
# episode: 362/2000, episode end value: 1824.35, duration: 0:00:00.210033
# episode: 363/2000, episode end value: 1800.22, duration: 0:00:00.212062
# episode: 364/2000, episode end value: 1808.08, duration: 0:00:00.206060
# episode: 365/2000, episode end value: 1816.74, duration: 0:00:00.203046
# episode: 366/2000, episode end value: 1805.39, duration: 0:00:00.201044
# episode: 367/2000, episode end value: 1819.28, duration: 0:00:00.204033
# episode: 368/2000, episode end value: 1806.29, duration: 0:00:00.211059
# episode: 369/2000, episode end value: 1804.07, duration: 0:00:00.205032
# episode: 370/2000, episode end value: 1801.03, duration: 0:00:00.208059
# episode: 371/2000, episode end value: 1806.57, duration: 0:00:00.215049
# episode: 372/2000, episode end value: 1804.36, duration: 0:00:00.201031
# episode: 373/2000, episode end value: 1803.89, duration: 0:00:00.200059
# episode: 374/2000, episode end value: 1815.51, duration: 0:00:00.202032
# episode: 375/2000, episode end value: 1802.55, duration: 0:00:00.206059
# episode: 376/2000, episode end value: 1803.75, duration: 0:00:00.209051
# episode: 377/2000, episode end value: 1804.95, duration: 0:00:00.194044
# episode: 378/2000, episode end value: 1804.02, duration: 0:00:00.207041
# episode: 379/2000, episode end value: 1799.63, duration: 0:00:00.201044
# episode: 380/2000, episode end value: 1802.04, duration: 0:00:00.207047
# episode: 381/2000, episode end value: 1803.64, duration: 0:00:00.201029
# episode: 382/2000, episode end value: 1818.00, duration: 0:00:00.205060
# episode: 383/2000, episode end value: 1802.19, duration: 0:00:00.206032
# episode: 384/2000, episode end value: 1802.91, duration: 0:00:00.208047
# episode: 385/2000, episode end value: 1801.83, duration: 0:00:00.202058
# episode: 386/2000, episode end value: 1820.38, duration: 0:00:00.195044
# episode: 387/2000, episode end value: 1802.91, duration: 0:00:00.200032
# episode: 388/2000, episode end value: 1812.90, duration: 0:00:00.201058
# episode: 389/2000, episode end value: 1799.02, duration: 0:00:00.190030
# episode: 390/2000, episode end value: 1817.23, duration: 0:00:00.197043
# episode: 391/2000, episode end value: 1822.21, duration: 0:00:00.209047
# episode: 392/2000, episode end value: 1813.10, duration: 0:00:00.216054
# episode: 393/2000, episode end value: 1822.83, duration: 0:00:00.198043
# episode: 394/2000, episode end value: 1811.93, duration: 0:00:00.200045
# episode: 395/2000, episode end value: 1803.93, duration: 0:00:00.200045
# episode: 396/2000, episode end value: 1798.63, duration: 0:00:00.208056
# episode: 397/2000, episode end value: 1798.68, duration: 0:00:00.204053
# episode: 398/2000, episode end value: 1802.23, duration: 0:00:00.202045
# episode: 399/2000, episode end value: 1801.60, duration: 0:00:00.209050
# episode: 400/2000, episode end value: 1804.40, duration: 0:00:00.211045
# episode: 401/2000, episode end value: 1805.51, duration: 0:00:00.206060
# episode: 402/2000, episode end value: 1807.76, duration: 0:00:00.207059
# episode: 403/2000, episode end value: 1800.51, duration: 0:00:00.207051
# episode: 404/2000, episode end value: 1790.61, duration: 0:00:00.210033
# episode: 405/2000, episode end value: 1802.87, duration: 0:00:00.219054
# episode: 406/2000, episode end value: 1811.77, duration: 0:00:00.203048
# episode: 407/2000, episode end value: 1801.12, duration: 0:00:00.201040
# episode: 408/2000, episode end value: 1805.68, duration: 0:00:00.201046
# episode: 409/2000, episode end value: 1802.24, duration: 0:00:00.204039
# episode: 410/2000, episode end value: 1783.05, duration: 0:00:00.206061
# episode: 411/2000, episode end value: 1806.30, duration: 0:00:00.208050
# episode: 412/2000, episode end value: 1819.29, duration: 0:00:00.204041
# episode: 413/2000, episode end value: 1821.08, duration: 0:00:00.203055
# episode: 414/2000, episode end value: 1803.11, duration: 0:00:00.202046
# episode: 415/2000, episode end value: 1802.37, duration: 0:00:00.203033
# episode: 416/2000, episode end value: 1803.04, duration: 0:00:00.205058
# episode: 417/2000, episode end value: 1799.72, duration: 0:00:00.200045
# episode: 418/2000, episode end value: 1802.09, duration: 0:00:00.202040
# episode: 419/2000, episode end value: 1806.13, duration: 0:00:00.208053
# episode: 420/2000, episode end value: 1798.43, duration: 0:00:00.204052
# episode: 421/2000, episode end value: 1818.59, duration: 0:00:00.205052
# episode: 422/2000, episode end value: 1813.72, duration: 0:00:00.216044
# episode: 423/2000, episode end value: 1810.25, duration: 0:00:00.217047
# episode: 424/2000, episode end value: 1803.89, duration: 0:00:00.222038
# episode: 425/2000, episode end value: 1822.48, duration: 0:00:00.210039
# episode: 426/2000, episode end value: 1804.04, duration: 0:00:00.216063
# episode: 427/2000, episode end value: 1806.40, duration: 0:00:00.222050
# episode: 428/2000, episode end value: 1806.09, duration: 0:00:00.203045
# episode: 429/2000, episode end value: 1812.55, duration: 0:00:00.209036
# episode: 430/2000, episode end value: 1799.79, duration: 0:00:00.216062
# episode: 431/2000, episode end value: 1803.04, duration: 0:00:00.219042
# episode: 432/2000, episode end value: 1802.68, duration: 0:00:00.208048
# episode: 433/2000, episode end value: 1798.00, duration: 0:00:00.211042
# episode: 434/2000, episode end value: 1814.52, duration: 0:00:00.209050
# episode: 435/2000, episode end value: 1802.75, duration: 0:00:00.212044
# episode: 436/2000, episode end value: 1809.08, duration: 0:00:00.216040
# episode: 437/2000, episode end value: 1823.85, duration: 0:00:00.209055
# episode: 438/2000, episode end value: 1799.06, duration: 0:00:00.215043
# episode: 439/2000, episode end value: 1809.68, duration: 0:00:00.216039
# episode: 440/2000, episode end value: 1804.98, duration: 0:00:00.208047
# episode: 441/2000, episode end value: 1789.50, duration: 0:00:00.212046
# episode: 442/2000, episode end value: 1819.88, duration: 0:00:00.218062
# episode: 443/2000, episode end value: 1808.85, duration: 0:00:00.213036
# episode: 444/2000, episode end value: 1813.17, duration: 0:00:00.223051
# episode: 445/2000, episode end value: 1821.13, duration: 0:00:00.237053
# episode: 446/2000, episode end value: 1801.52, duration: 0:00:00.226051
# episode: 447/2000, episode end value: 1796.47, duration: 0:00:00.215065
# episode: 448/2000, episode end value: 1805.95, duration: 0:00:00.213046
# episode: 449/2000, episode end value: 1816.46, duration: 0:00:00.229046
# episode: 450/2000, episode end value: 1800.58, duration: 0:00:00.216038
# episode: 451/2000, episode end value: 1832.08, duration: 0:00:00.205056
# episode: 452/2000, episode end value: 1825.31, duration: 0:00:00.206045
# episode: 453/2000, episode end value: 1815.91, duration: 0:00:00.211053
# episode: 454/2000, episode end value: 1822.84, duration: 0:00:00.198051
# episode: 455/2000, episode end value: 1798.79, duration: 0:00:00.186044
# episode: 456/2000, episode end value: 1806.37, duration: 0:00:00.173038
# episode: 457/2000, episode end value: 1792.61, duration: 0:00:00.186042
# episode: 458/2000, episode end value: 1797.44, duration: 0:00:00.191028
# episode: 459/2000, episode end value: 1787.73, duration: 0:00:00.200060
# episode: 460/2000, episode end value: 1795.88, duration: 0:00:00.181043
# episode: 461/2000, episode end value: 1783.15, duration: 0:00:00.186049
# episode: 462/2000, episode end value: 1784.03, duration: 0:00:00.186043
# episode: 463/2000, episode end value: 1786.49, duration: 0:00:00.189046
# episode: 464/2000, episode end value: 1795.67, duration: 0:00:00.178036
# episode: 465/2000, episode end value: 1786.39, duration: 0:00:00.184040
# episode: 466/2000, episode end value: 1768.91, duration: 0:00:00.191043
# episode: 467/2000, episode end value: 1790.16, duration: 0:00:00.186042
# episode: 468/2000, episode end value: 1766.54, duration: 0:00:00.195044
# episode: 469/2000, episode end value: 1780.74, duration: 0:00:00.188042
# episode: 470/2000, episode end value: 1757.26, duration: 0:00:00.204033
# episode: 471/2000, episode end value: 1756.69, duration: 0:00:00.194056
# episode: 472/2000, episode end value: 1778.73, duration: 0:00:00.193043
# episode: 473/2000, episode end value: 1785.83, duration: 0:00:00.195044
# episode: 474/2000, episode end value: 1783.49, duration: 0:00:00.186040
# episode: 475/2000, episode end value: 1783.53, duration: 0:00:00.193037
# episode: 476/2000, episode end value: 1792.88, duration: 0:00:00.198044
# episode: 477/2000, episode end value: 1799.32, duration: 0:00:00.191043
# episode: 478/2000, episode end value: 1814.95, duration: 0:00:00.229051
# episode: 479/2000, episode end value: 1801.66, duration: 0:00:00.212040
# episode: 480/2000, episode end value: 1802.86, duration: 0:00:00.221049
# episode: 481/2000, episode end value: 1812.60, duration: 0:00:00.223050
# episode: 482/2000, episode end value: 1809.05, duration: 0:00:00.218061
# episode: 483/2000, episode end value: 1805.59, duration: 0:00:00.220051
# episode: 484/2000, episode end value: 1807.42, duration: 0:00:00.213045
# episode: 485/2000, episode end value: 1807.47, duration: 0:00:00.218049
# episode: 486/2000, episode end value: 1823.47, duration: 0:00:00.223056
# episode: 487/2000, episode end value: 1809.87, duration: 0:00:00.235047
# episode: 488/2000, episode end value: 1746.90, duration: 0:00:00.233042
# episode: 489/2000, episode end value: 1818.14, duration: 0:00:00.228064
# episode: 490/2000, episode end value: 1819.50, duration: 0:00:00.221038
# episode: 491/2000, episode end value: 1819.42, duration: 0:00:00.227057
# episode: 492/2000, episode end value: 1812.17, duration: 0:00:00.221041
# episode: 493/2000, episode end value: 1812.68, duration: 0:00:00.208061
# episode: 494/2000, episode end value: 1816.70, duration: 0:00:00.209046
# episode: 495/2000, episode end value: 1820.45, duration: 0:00:00.205040
# episode: 496/2000, episode end value: 1868.61, duration: 0:00:00.196055

# %%
plt.plot(agent.model.losses)

# %%
plt.plot(portfolio_value)

# %%
#test

mode = 'test'

portfolio_value = []


with open(f'scaler/{stock_name}.pkl', 'rb') as f:
    scaler = pickle.load(f)
    
env = StockEnv(test_data, capital)
agent.epsilon = 0
agent.load(f'state_dict/{stock_name}.npz')



t0 = datetime.now()
val = play_one_episode(agent, env, mode, scaler)
dt = datetime.now() - t0
print(f"episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
portfolio_value.append(val['portfolio_value'][-1])
    
print(f"Sell: {env.sell_buy.count('sell')} times, Buy: {env.sell_buy.count('buy')} times")



result = pd.DataFrame(val)
result.index = test_data.index

def marker_buy(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'buy':
        return price
    else:
        return np.nan
    
def marker_sell(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'sell':
        return price
    else:
        return np.nan
    
result['marker_buy'] = result[['stock_price', 'sell_buy']].apply(marker_buy, axis=1);
result['marker_sell'] = result[['stock_price', 'sell_buy']].apply(marker_sell, axis=1);

result['stock_price'].plot(figsize=(10,6), c='grey', lw=2);
result['marker_buy'].plot(style='o', ms=7, label='buy', c='g', alpha=0.5);
result['marker_sell'].plot(style='o', ms=7, label='sell', c='r', alpha=0.5);
plt.title('Stock Price '+ stock_name)
plt.legend();
plt.show()



result['portfolio_value'].plot(figsize=(10,6), c='r', lw=2);
plt.title('Portfolio Value');
plt.show()

result['stock_owned'].plot(figsize=(10,6), c='purple', lw=2);
plt.title('Position')
plt.show()

result[['cash_in_hand', 'stock_value']].plot(figsize=(10,6), lw=2);
plt.title('Cash in Hand and Stock Value');
plt.show()
# Out:
# episode end value: 1315.53, duration: 0:00:00.053028
# Sell: 23 times, Buy: 24 times

# %%
def CAGR(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    
    df['cumulative_ret'] = (1 + df['daily_ret']).cumprod()
    n = len(df)/252
    cagr = (df['cumulative_ret'][-1])**(1/n) - 1
    return cagr

def volatility(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    vol = df['daily_ret'].std() * np.sqrt(252)
    return vol


def sharpe(DF, rf):
    df = DF.copy()
    sr = (CAGR(df) - rf)/volatility(df)
    return sr

def max_dd(DF):
    df = DF.copy()
    try:
        df['daily_ret'] = df['portfolio_value'].pct_change()
    except:
        df['daily_ret'] = df['Adj Close'].pct_change() 
    df['cumulative_ret'] = (1 + df['daily_ret']).cumprod()
    df['cum_roll_max'] = df['cumulative_ret'].cummax()
    df['drawdown'] = df['cum_roll_max'] - df['cumulative_ret']
    df['drawdown_pct'] = df['drawdown']/df['cum_roll_max']
    max_dd = df['drawdown_pct'].max()
    return max_dd

def calmer(DF):
    df = DF.copy()
    clmr = CAGR(df)/max_dd(df)
    return clmr



print(f'Stock name: {stock_name}')
print(f'Start: {result.index[0]}  End: {result.index[-1]}')
print(f'Compound Annual Growth Rate: {CAGR(result)*100:.2f} %')
print(f'Volatility: {volatility(result):.4f}')
print(f'shape ratio: {sharpe(result, 0.011):.4f}')
print(f'Maximun drawdown: {max_dd(result)*-100:.2f} %')
print(f'Calmar ratio: {calmer(result):.4f}')
print('-----------------------------------------------------------')
print('-----------------------------------------------------------')
print('Comparing with Adj close')
print(f'Compound Annual Growth Rate (Adj close): {CAGR(test_data)*100:.2f} %')
print(f'Volatility (benchmark): {volatility(test_data):.4f}')
print(f'shape ratio: {sharpe(test_data, 0.011):.4f}')
print(f'Maximun drawdown: {max_dd(test_data)*-100:.2f} %')
print(f'Calmar ratio (benchmark): {calmer(test_data):.4f}')
# Out:
# Stock name: DIS
# Start: 2018-01-02 00:00:00  End: 2020-12-31 00:00:00
# Compound Annual Growth Rate: 9.57 %
# Volatility: 0.1481
# shape ratio: 0.5721
# Maximun drawdown: -24.42 %
# Calmar ratio: 0.3920
# -----------------------------------------------------------
# -----------------------------------------------------------
# Comparing with Adj close
# Compound Annual Growth Rate (Adj close): 17.46 %
# Volatility (benchmark): 0.3340
# shape ratio: 0.4898
# Maximun drawdown: -43.44 %
# Calmar ratio (benchmark): 0.4019

# %%
bt_returns = result['portfolio_value'].pct_change()
price = result['stock_price'].pct_change()



plt.figure(figsize=(9,6));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, price);
plt.title('Compare with close price');
plt.show()

fig = plt.figure(1)
plt.subplot(1,3,1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1,3,2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1,3,3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()
fig.set_size_inches(12,4)

plt.figure(figsize=(9,6))
pf.plot_return_quantiles(bt_returns);



plt.figure(figsize=(9,6))
pf.plot_rolling_sharpe(bt_returns);

plt.figure(figsize=(9,6))
pf.plot_drawdown_underwater(bt_returns);

score = (sharpe(result, 0.011) - sharpe(test_data, 0.011))*10
ret = ((result['portfolio_value'][-1] - result['portfolio_value'][0])/result['portfolio_value'][0]) * 100
with open(f'score/{stock_name}.pkl', 'wb') as f:  # Python 3: open(..., 'wb')
    pickle.dump([stock_name, industry,score, ret], f)
    
    
result.to_csv(f'../data/{stock_name}.csv')
