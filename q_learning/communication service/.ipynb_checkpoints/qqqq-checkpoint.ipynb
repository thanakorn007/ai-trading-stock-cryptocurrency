# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import pandas_datareader as web
from datetime import datetime
from sklearn.preprocessing import StandardScaler
import os
import pickle
import seaborn as sns
import datetime as dt
import yfinance as yf
import talib
from tqdm.notebook import tqdm
# %matplotlib inline


class LinearModel:
    def __init__(self, input_dim, n_action):
        self.W = np.random.randn(input_dim, n_action) / np.sqrt(input_dim)
        self.b = np.zeros(n_action)
        self.vW = 0
        self.vb = 0
        self.losses = []
        
    def predict(self, s):
        return s.dot(self.W) + self.b
    
    def sgd(self, s, Y, learning_rate=0.001, momentum=0.9):
        num_values = np.prod(Y.shape)
        Y_hat = self.predict(s)
        Y_hat = self.predict(s)  # shape (1, 8)
        gW = 2 * s.T.dot(Y_hat - Y) / num_values  # vector shape (7, 8)
        gb = 2 * (Y_hat - Y).sum(axis=0) / num_values  # scalar

        self.vW = momentum * self.vW - learning_rate * gW  # vector shape (7, 8)
        self.vb = momentum * self.vb - learning_rate * gb  # scalar

        self.W += self.vW  # vector shape (7, 8)
        self.b += self.vb  # scalar

        mse = np.mean((Y_hat - Y) ** 2)
        self.losses.append(mse)
        
        
    def save_weights(self, filepath):
        np.savez(filepath, W=self.W, b=self.b)


    def load_weights(self, filepath):
        npz = np.load(filepath)
        self.W = npz['W']
        self.b = npz['b']
        
        
def maybe_make_dir(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        
        
class Env:
    def __init__(self, data, capital):
        self.stock_price_history = data['Adj Close']
        self.n_step = self.stock_price_history.shape[0]
        self.capital = capital
        self.current_step = None
        self.stock_owned = None
        self.stock_price = None
        self.cash_in_hand = None
        self.state_dim = 5 #[stock price, stock_owned, cash__in_hand, rsi, mom]
        self.save_position = []
        self.save_port_val = [] 
        self.save_cash = []
        self.stock_value = []
        self.action_space = [0,1]
        self.sell_buy = []
        self.save_stock_price = []
        self.rsi = data['rsi']
        self.mom = data['mom']
        self.reset()
        
        
    def state_vector(self):
        vector = np.empty(self.state_dim)
        vector[0] = self.stock_price
        vector[1] = self.stock_owned
        vector[2] = self.cash_in_hand
        vector[3] = self.rsi[self.current_step]
        vector[4] = self.mom[self.current_step]
        return vector
    
    
    def reset(self):
        self.current_step = 0
        self.stock_owned = 0
        self.stock_price = self.stock_price_history[self.current_step]
        self.cash_in_hand = self.capital
        self.save_position = [0]
        self.save_port_val = [self.capital] 
        self.save_cash = [self.capital]
        self.stock_value = [0]
        self.sell_buy = ['hold']
        self.save_stock_price = [self.stock_price]
        return self.state_vector()
    

    
    def port_val(self):
        return (self.stock_owned * self.stock_price) + self.cash_in_hand
    
    
    def cal_position(self):
        high = self.stock_price_history.max()
        mid_price =  high/ 2
        max_pos = self.capital / mid_price
        slope = max_pos/-high
        c = -slope * high
        
        return slope * self.stock_price + c, high, max_pos
        
      
    def trade(self, action):
        '''
        action 0 = hold
        action 1 = take action
        '''
        assert action in self.action_space
        
        if action == 1:
            position_sh, high, max_pos = self.cal_position()
            diff = position_sh - self.stock_owned
            if diff < 0:
                #sell
                self.stock_owned = position_sh
                self.cash_in_hand += abs(diff) * self.stock_price
                self.sell_buy.append('sell')
                
                
            elif diff > 0:
                #buy
                self.stock_owned = position_sh
                self.cash_in_hand -= abs(diff) * self.stock_price
                self.sell_buy.append('buy')
                
            else:
                self.sell_buy.append('hold')
                
        else:
            self.sell_buy.append('hold')
            
        self.save_cash.append(self.cash_in_hand)
        self.save_port_val.append(self.port_val())
        self.save_position.append(self.stock_owned)
        self.stock_value.append(self.stock_owned * self.stock_price)
        self.save_stock_price.append(self.stock_price)
        
          
        
                
    def step(self, action):
        assert action in self.action_space
        
        prev_val = self.port_val()
        self.current_step += 1
        self.stock_price = self.stock_price_history[self.current_step]
        
        self.trade(action)
        current_val = self.port_val()
        reward = current_val - prev_val
        done = self.current_step == self.n_step - 1
        info = {'stock_price': self.save_stock_price,
                'portfolio_value': self.save_port_val,
#                 'current_val': self.port_val(),
                'stock_owned': self.save_position,
                'cash_in_hand': self.save_cash,
                'stock_value': self.stock_value,
                'sell_buy':self.sell_buy
               }
        
        return self.state_vector(), reward, done, info
    
    
def get_scaler(env):
    states = []
    for i in range(env.n_step):
        action = np.random.choice(env.action_space)
        state, reward, done, info = env.step(action)
        states.append(state)
        if done:
            break
    scaler = StandardScaler()
    scaler.fit(states)
    return scaler


class DQNAgent(object):
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = LinearModel(state_size, action_size)

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action


    def train(self, state, action, reward, next_state, done):
        if done:
            target = reward
        else:
            target = reward + self.gamma * np.amax(self.model.predict(next_state), axis=1)

        target_full = self.model.predict(state)
        target_full[0, action] = target

        # Run one training step
        self.model.sgd(state, target_full)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay


    def load(self, name):
        self.model.load_weights(name)


    def save(self, name):
        self.model.save_weights(name)
        
        
def play_one_episode(agent, env, is_train):
    state = env.reset()
    state = scaler.transform([state])
    done = False
    
    while not done:
        action = agent.act(state)
        next_state, reward, done, info = env.step(action)
        next_state = scaler.transform([next_state])
        
        if is_train == 'train':
            agent.train(state, action, reward, next_state, done)
        
        state = next_state
    
    return info

# %%
stock_name = 'iff'.upper()
stock_data = pd.read_csv(f'../train_test_data/{stock_name}.csv', index_col=['Date'], parse_dates=True)

train_data = stock_data.loc[:'2018-01-01']
test_data = stock_data.loc['2018-01-01':]



models_folder = 'q_learn'
rewards_folder = 'q_reward'
maybe_make_dir(models_folder)
maybe_make_dir(rewards_folder)
num_episodes = 2000
batch_size = 32
capital = 1000
data = stock_data['Adj Close'].values
n_timesteps = data.shape[0]


env = Env(train_data, capital)
state_size = env.state_dim
action_size = 2
agent = DQNAgent(state_size, action_size)
scaler = get_scaler(env)

# %%
#train


mode = 'train'

portfolio_value = []

if mode == 'test':
    with open(f'{models_folder}/scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    num_episodes = 1
    env = Env(test_data, capital)
    agent.epsilon = 0
    agent.load(f'{models_folder}/linear.npz')


for e in tqdm(range(num_episodes)):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1]) 


if mode == 'train':
    # save the DQN
    agent.save(f'{models_folder}/linear.npz')

    # save the scaler
    with open(f'{models_folder}/scaler.pkl', 'wb') as f:
        pickle.dump(scaler, f)

    # plot losses
    loss = agent.model.losses
    losses = pd.DataFrame(loss, columns=['loss'])
    losses.plot(figsize=(10,6))
    plt.title('Average Mean Square Error of All Episode')
    plt.xlabel('Step')
    plt.ylabel('Mean Square Error')

print(f'average reward: {np.mean(portfolio_value):.2f}, min: {np.min(portfolio_value):.2f}, max: {np.max(portfolio_value):.2f}')
sns.histplot(portfolio_value, bins=100, color='r', kde=True);
plt.xlabel('Portfolio Value');
plt.ylabel('Count');
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# episode: 1/2000, episode end value: 1377.75, duration: 0:00:00.197225
# episode: 2/2000, episode end value: 1364.31, duration: 0:00:00.202418
# episode: 3/2000, episode end value: 1392.98, duration: 0:00:00.209064
# episode: 4/2000, episode end value: 1380.54, duration: 0:00:00.218049
# episode: 5/2000, episode end value: 1384.81, duration: 0:00:00.216601
# episode: 6/2000, episode end value: 1375.16, duration: 0:00:00.211076
# episode: 7/2000, episode end value: 1376.38, duration: 0:00:00.208076
# episode: 8/2000, episode end value: 1366.77, duration: 0:00:00.204752
# episode: 9/2000, episode end value: 1358.08, duration: 0:00:00.207046
# episode: 10/2000, episode end value: 1375.69, duration: 0:00:00.213028
# episode: 11/2000, episode end value: 1378.63, duration: 0:00:00.196049
# episode: 12/2000, episode end value: 1357.18, duration: 0:00:00.191042
# episode: 13/2000, episode end value: 1363.63, duration: 0:00:00.204032
# episode: 14/2000, episode end value: 1389.36, duration: 0:00:00.194034
# episode: 15/2000, episode end value: 1382.26, duration: 0:00:00.196044
# episode: 16/2000, episode end value: 1392.86, duration: 0:00:00.189036
# episode: 17/2000, episode end value: 1366.52, duration: 0:00:00.197039
# episode: 18/2000, episode end value: 1371.10, duration: 0:00:00.195043
# episode: 19/2000, episode end value: 1362.44, duration: 0:00:00.191044
# episode: 20/2000, episode end value: 1366.29, duration: 0:00:00.198057
# episode: 21/2000, episode end value: 1377.68, duration: 0:00:00.195046
# episode: 22/2000, episode end value: 1379.84, duration: 0:00:00.193051
# episode: 23/2000, episode end value: 1377.40, duration: 0:00:00.190046
# episode: 24/2000, episode end value: 1373.68, duration: 0:00:00.190040
# episode: 25/2000, episode end value: 1357.68, duration: 0:00:00.189209
# episode: 26/2000, episode end value: 1379.59, duration: 0:00:00.192138
# episode: 27/2000, episode end value: 1360.14, duration: 0:00:00.193055
# episode: 28/2000, episode end value: 1375.55, duration: 0:00:00.207053
# episode: 29/2000, episode end value: 1379.79, duration: 0:00:00.202044
# episode: 30/2000, episode end value: 1373.12, duration: 0:00:00.195041
# episode: 31/2000, episode end value: 1382.28, duration: 0:00:00.198052
# episode: 32/2000, episode end value: 1339.91, duration: 0:00:00.191031
# episode: 33/2000, episode end value: 1371.28, duration: 0:00:00.193037
# episode: 34/2000, episode end value: 1367.74, duration: 0:00:00.190028
# episode: 35/2000, episode end value: 1370.58, duration: 0:00:00.200066
# episode: 36/2000, episode end value: 1379.11, duration: 0:00:00.192042
# episode: 37/2000, episode end value: 1368.26, duration: 0:00:00.189042
# episode: 38/2000, episode end value: 1375.58, duration: 0:00:00.188042
# episode: 39/2000, episode end value: 1381.99, duration: 0:00:00.206059
# episode: 40/2000, episode end value: 1385.63, duration: 0:00:00.186466
# episode: 41/2000, episode end value: 1383.49, duration: 0:00:00.190043
# episode: 42/2000, episode end value: 1372.46, duration: 0:00:00.188035
# episode: 43/2000, episode end value: 1380.13, duration: 0:00:00.192061
# episode: 44/2000, episode end value: 1352.60, duration: 0:00:00.182041
# episode: 45/2000, episode end value: 1361.59, duration: 0:00:00.188760
# episode: 46/2000, episode end value: 1348.18, duration: 0:00:00.183035
# episode: 47/2000, episode end value: 1378.28, duration: 0:00:00.190035
# episode: 48/2000, episode end value: 1415.43, duration: 0:00:00.191748
# episode: 49/2000, episode end value: 1361.86, duration: 0:00:00.190037
# episode: 50/2000, episode end value: 1395.49, duration: 0:00:00.187039
# episode: 51/2000, episode end value: 1385.62, duration: 0:00:00.180061
# episode: 52/2000, episode end value: 1362.26, duration: 0:00:00.185039
# episode: 53/2000, episode end value: 1374.24, duration: 0:00:00.193055
# episode: 54/2000, episode end value: 1399.99, duration: 0:00:00.184378
# episode: 55/2000, episode end value: 1371.32, duration: 0:00:00.189014
# episode: 56/2000, episode end value: 1364.58, duration: 0:00:00.192004
# episode: 57/2000, episode end value: 1390.25, duration: 0:00:00.192979
# episode: 58/2000, episode end value: 1393.53, duration: 0:00:00.185041
# episode: 59/2000, episode end value: 1374.24, duration: 0:00:00.194044
# episode: 60/2000, episode end value: 1372.81, duration: 0:00:00.182040
# episode: 61/2000, episode end value: 1383.84, duration: 0:00:00.188029
# episode: 62/2000, episode end value: 1376.54, duration: 0:00:00.186042
# episode: 63/2000, episode end value: 1380.91, duration: 0:00:00.188053
# episode: 64/2000, episode end value: 1376.46, duration: 0:00:00.189033
# episode: 65/2000, episode end value: 1376.72, duration: 0:00:00.192056
# episode: 66/2000, episode end value: 1381.37, duration: 0:00:00.194043
# episode: 67/2000, episode end value: 1377.36, duration: 0:00:00.197030
# episode: 68/2000, episode end value: 1375.25, duration: 0:00:00.184042
# episode: 69/2000, episode end value: 1334.51, duration: 0:00:00.188062
# episode: 70/2000, episode end value: 1377.00, duration: 0:00:00.190036
# episode: 71/2000, episode end value: 1384.18, duration: 0:00:00.191047
# episode: 72/2000, episode end value: 1382.08, duration: 0:00:00.189043
# episode: 73/2000, episode end value: 1367.11, duration: 0:00:00.204046
# episode: 74/2000, episode end value: 1380.43, duration: 0:00:00.206053
# episode: 75/2000, episode end value: 1385.28, duration: 0:00:00.190055
# episode: 76/2000, episode end value: 1374.67, duration: 0:00:00.194044
# episode: 77/2000, episode end value: 1383.99, duration: 0:00:00.185021
# episode: 78/2000, episode end value: 1369.32, duration: 0:00:00.197064
# episode: 79/2000, episode end value: 1365.85, duration: 0:00:00.188043
# episode: 80/2000, episode end value: 1374.67, duration: 0:00:00.191030
# episode: 81/2000, episode end value: 1351.71, duration: 0:00:00.188043
# episode: 82/2000, episode end value: 1348.66, duration: 0:00:00.179041
# episode: 83/2000, episode end value: 1349.95, duration: 0:00:00.199058
# episode: 84/2000, episode end value: 1369.79, duration: 0:00:00.206047
# episode: 85/2000, episode end value: 1368.28, duration: 0:00:00.191043
# episode: 86/2000, episode end value: 1378.29, duration: 0:00:00.208040
# episode: 87/2000, episode end value: 1376.29, duration: 0:00:00.204046
# episode: 88/2000, episode end value: 1384.20, duration: 0:00:00.189150
# episode: 89/2000, episode end value: 1372.54, duration: 0:00:00.194943
# episode: 90/2000, episode end value: 1378.30, duration: 0:00:00.205040
# episode: 91/2000, episode end value: 1402.92, duration: 0:00:00.189042
# episode: 92/2000, episode end value: 1354.62, duration: 0:00:00.181047
# episode: 93/2000, episode end value: 1341.75, duration: 0:00:00.173039
# episode: 94/2000, episode end value: 1360.59, duration: 0:00:00.187023
# episode: 95/2000, episode end value: 1367.85, duration: 0:00:00.192062
# episode: 96/2000, episode end value: 1369.93, duration: 0:00:00.200039
# episode: 97/2000, episode end value: 1368.94, duration: 0:00:00.205046
# episode: 98/2000, episode end value: 1377.79, duration: 0:00:00.201045
# episode: 99/2000, episode end value: 1362.84, duration: 0:00:00.206834
# episode: 100/2000, episode end value: 1372.30, duration: 0:00:00.201051
# episode: 101/2000, episode end value: 1370.01, duration: 0:00:00.201027
# episode: 102/2000, episode end value: 1370.00, duration: 0:00:00.196058
# episode: 103/2000, episode end value: 1394.76, duration: 0:00:00.191056
# episode: 104/2000, episode end value: 1368.53, duration: 0:00:00.190058
# episode: 105/2000, episode end value: 1388.30, duration: 0:00:00.196043
# episode: 106/2000, episode end value: 1396.21, duration: 0:00:00.186061
# episode: 107/2000, episode end value: 1377.39, duration: 0:00:00.198025
# episode: 108/2000, episode end value: 1375.31, duration: 0:00:00.188056
# episode: 109/2000, episode end value: 1365.11, duration: 0:00:00.198058
# episode: 110/2000, episode end value: 1369.23, duration: 0:00:00.206040
# episode: 111/2000, episode end value: 1381.23, duration: 0:00:00.197034
# episode: 112/2000, episode end value: 1361.75, duration: 0:00:00.198060
# episode: 113/2000, episode end value: 1375.98, duration: 0:00:00.196049
# episode: 114/2000, episode end value: 1369.04, duration: 0:00:00.197038
# episode: 115/2000, episode end value: 1341.12, duration: 0:00:00.197044
# episode: 116/2000, episode end value: 1363.49, duration: 0:00:00.195044
# episode: 117/2000, episode end value: 1377.17, duration: 0:00:00.203045
# episode: 118/2000, episode end value: 1376.58, duration: 0:00:00.204045
# episode: 119/2000, episode end value: 1378.78, duration: 0:00:00.204046
# episode: 120/2000, episode end value: 1377.09, duration: 0:00:00.202046
# episode: 121/2000, episode end value: 1354.47, duration: 0:00:00.196044
# episode: 122/2000, episode end value: 1381.09, duration: 0:00:00.198030
# episode: 123/2000, episode end value: 1383.09, duration: 0:00:00.191057
# episode: 124/2000, episode end value: 1381.18, duration: 0:00:00.195043
# episode: 125/2000, episode end value: 1363.70, duration: 0:00:00.196044
# episode: 126/2000, episode end value: 1380.84, duration: 0:00:00.204046
# episode: 127/2000, episode end value: 1378.48, duration: 0:00:00.199044
# episode: 128/2000, episode end value: 1370.09, duration: 0:00:00.199045
# episode: 129/2000, episode end value: 1400.40, duration: 0:00:00.194050
# episode: 130/2000, episode end value: 1375.35, duration: 0:00:00.192037
# episode: 131/2000, episode end value: 1374.93, duration: 0:00:00.186042
# episode: 132/2000, episode end value: 1373.27, duration: 0:00:00.194008
# episode: 133/2000, episode end value: 1378.86, duration: 0:00:00.178046
# episode: 134/2000, episode end value: 1372.02, duration: 0:00:00.187022
# episode: 135/2000, episode end value: 1379.26, duration: 0:00:00.196043
# episode: 136/2000, episode end value: 1369.64, duration: 0:00:00.197043
# episode: 137/2000, episode end value: 1372.04, duration: 0:00:00.182043
# episode: 138/2000, episode end value: 1365.24, duration: 0:00:00.191042
# episode: 139/2000, episode end value: 1363.11, duration: 0:00:00.195045
# episode: 140/2000, episode end value: 1357.09, duration: 0:00:00.203046
# episode: 141/2000, episode end value: 1376.00, duration: 0:00:00.197050
# episode: 142/2000, episode end value: 1365.60, duration: 0:00:00.193030
# episode: 143/2000, episode end value: 1384.98, duration: 0:00:00.194043
# episode: 144/2000, episode end value: 1359.45, duration: 0:00:00.191063
# episode: 145/2000, episode end value: 1374.82, duration: 0:00:00.192038
# episode: 146/2000, episode end value: 1372.45, duration: 0:00:00.193041
# episode: 147/2000, episode end value: 1382.68, duration: 0:00:00.199054
# episode: 148/2000, episode end value: 1367.87, duration: 0:00:00.199050
# episode: 149/2000, episode end value: 1376.14, duration: 0:00:00.191035
# episode: 150/2000, episode end value: 1372.28, duration: 0:00:00.190149
# episode: 151/2000, episode end value: 1359.10, duration: 0:00:00.194029
# episode: 152/2000, episode end value: 1385.64, duration: 0:00:00.195043
# episode: 153/2000, episode end value: 1355.90, duration: 0:00:00.183032
# episode: 154/2000, episode end value: 1372.93, duration: 0:00:00.190050
# episode: 155/2000, episode end value: 1403.65, duration: 0:00:00.189049
# episode: 156/2000, episode end value: 1384.49, duration: 0:00:00.195050
# episode: 157/2000, episode end value: 1376.57, duration: 0:00:00.189055
# episode: 158/2000, episode end value: 1367.25, duration: 0:00:00.195032
# episode: 159/2000, episode end value: 1374.71, duration: 0:00:00.187053
# episode: 160/2000, episode end value: 1379.67, duration: 0:00:00.185029
# episode: 161/2000, episode end value: 1380.73, duration: 0:00:00.195044
# episode: 162/2000, episode end value: 1379.05, duration: 0:00:00.191050
# episode: 163/2000, episode end value: 1388.14, duration: 0:00:00.186048
# episode: 164/2000, episode end value: 1371.98, duration: 0:00:00.191043
# episode: 165/2000, episode end value: 1358.18, duration: 0:00:00.189033
# episode: 166/2000, episode end value: 1382.59, duration: 0:00:00.190056
# episode: 167/2000, episode end value: 1376.77, duration: 0:00:00.192044
# episode: 168/2000, episode end value: 1397.12, duration: 0:00:00.186614
# episode: 169/2000, episode end value: 1366.81, duration: 0:00:00.189067
# episode: 170/2000, episode end value: 1379.46, duration: 0:00:00.191043
# episode: 171/2000, episode end value: 1389.26, duration: 0:00:00.191043
# episode: 172/2000, episode end value: 1379.69, duration: 0:00:00.202033
# episode: 173/2000, episode end value: 1377.22, duration: 0:00:00.192208
# episode: 174/2000, episode end value: 1378.50, duration: 0:00:00.196565
# episode: 175/2000, episode end value: 1370.32, duration: 0:00:00.194084
# episode: 176/2000, episode end value: 1385.67, duration: 0:00:00.187145
# episode: 177/2000, episode end value: 1383.69, duration: 0:00:00.186768
# episode: 178/2000, episode end value: 1372.47, duration: 0:00:00.191171
# episode: 179/2000, episode end value: 1376.00, duration: 0:00:00.191988
# episode: 180/2000, episode end value: 1358.60, duration: 0:00:00.194105
# episode: 181/2000, episode end value: 1369.18, duration: 0:00:00.187996
# episode: 182/2000, episode end value: 1378.83, duration: 0:00:00.196029
# episode: 183/2000, episode end value: 1375.42, duration: 0:00:00.191035
# episode: 184/2000, episode end value: 1378.78, duration: 0:00:00.189039
# episode: 185/2000, episode end value: 1375.45, duration: 0:00:00.199044
# episode: 186/2000, episode end value: 1370.93, duration: 0:00:00.206046
# episode: 187/2000, episode end value: 1377.17, duration: 0:00:00.190041
# episode: 188/2000, episode end value: 1367.98, duration: 0:00:00.198058
# episode: 189/2000, episode end value: 1391.08, duration: 0:00:00.198036
# episode: 190/2000, episode end value: 1391.69, duration: 0:00:00.202045
# episode: 191/2000, episode end value: 1378.59, duration: 0:00:00.204045
# episode: 192/2000, episode end value: 1372.46, duration: 0:00:00.196045
# episode: 193/2000, episode end value: 1399.12, duration: 0:00:00.192042
# episode: 194/2000, episode end value: 1362.12, duration: 0:00:00.200047
# episode: 195/2000, episode end value: 1371.84, duration: 0:00:00.197039
# episode: 196/2000, episode end value: 1384.93, duration: 0:00:00.197678
# episode: 197/2000, episode end value: 1378.66, duration: 0:00:00.200499
# episode: 198/2000, episode end value: 1389.43, duration: 0:00:00.194048
# episode: 199/2000, episode end value: 1371.25, duration: 0:00:00.190036
# episode: 200/2000, episode end value: 1371.14, duration: 0:00:00.183049
# episode: 201/2000, episode end value: 1381.92, duration: 0:00:00.196043
# episode: 202/2000, episode end value: 1375.29, duration: 0:00:00.186042
# episode: 203/2000, episode end value: 1369.76, duration: 0:00:00.185064
# episode: 204/2000, episode end value: 1419.18, duration: 0:00:00.191054
# episode: 205/2000, episode end value: 1385.51, duration: 0:00:00.191043
# episode: 206/2000, episode end value: 1364.31, duration: 0:00:00.194037
# episode: 207/2000, episode end value: 1382.81, duration: 0:00:00.186063
# episode: 208/2000, episode end value: 1373.53, duration: 0:00:00.193022
# episode: 209/2000, episode end value: 1366.16, duration: 0:00:00.193056
# episode: 210/2000, episode end value: 1367.73, duration: 0:00:00.190042
# episode: 211/2000, episode end value: 1367.65, duration: 0:00:00.194050
# episode: 212/2000, episode end value: 1379.88, duration: 0:00:00.201037
# episode: 213/2000, episode end value: 1373.53, duration: 0:00:00.195057
# episode: 214/2000, episode end value: 1400.39, duration: 0:00:00.194036
# episode: 215/2000, episode end value: 1390.99, duration: 0:00:00.181060
# episode: 216/2000, episode end value: 1378.71, duration: 0:00:00.177912
# episode: 217/2000, episode end value: 1377.20, duration: 0:00:00.191303
# episode: 218/2000, episode end value: 1396.41, duration: 0:00:00.185035
# episode: 219/2000, episode end value: 1401.46, duration: 0:00:00.187043
# episode: 220/2000, episode end value: 1379.09, duration: 0:00:00.187036
# episode: 221/2000, episode end value: 1379.06, duration: 0:00:00.187029
# episode: 222/2000, episode end value: 1385.29, duration: 0:00:00.182021
# episode: 223/2000, episode end value: 1372.91, duration: 0:00:00.182053
# episode: 224/2000, episode end value: 1373.36, duration: 0:00:00.190037
# episode: 225/2000, episode end value: 1354.94, duration: 0:00:00.190055
# episode: 226/2000, episode end value: 1349.33, duration: 0:00:00.206026
# episode: 227/2000, episode end value: 1382.86, duration: 0:00:00.199052
# episode: 228/2000, episode end value: 1378.06, duration: 0:00:00.207046
# episode: 229/2000, episode end value: 1382.29, duration: 0:00:00.188062
# episode: 230/2000, episode end value: 1378.20, duration: 0:00:00.207039
# episode: 231/2000, episode end value: 1391.13, duration: 0:00:00.190043
# episode: 232/2000, episode end value: 1381.72, duration: 0:00:00.183048
# episode: 233/2000, episode end value: 1363.71, duration: 0:00:00.187055
# episode: 234/2000, episode end value: 1370.43, duration: 0:00:00.208034
# episode: 235/2000, episode end value: 1384.61, duration: 0:00:00.191049
# episode: 236/2000, episode end value: 1383.64, duration: 0:00:00.200045
# episode: 237/2000, episode end value: 1394.70, duration: 0:00:00.187073
# episode: 238/2000, episode end value: 1361.96, duration: 0:00:00.203059
# episode: 239/2000, episode end value: 1371.72, duration: 0:00:00.195044
# episode: 240/2000, episode end value: 1381.55, duration: 0:00:00.195049
# episode: 241/2000, episode end value: 1378.22, duration: 0:00:00.198040
# episode: 242/2000, episode end value: 1356.07, duration: 0:00:00.188049
# episode: 243/2000, episode end value: 1389.84, duration: 0:00:00.189048
# episode: 244/2000, episode end value: 1375.78, duration: 0:00:00.183035
# episode: 245/2000, episode end value: 1358.34, duration: 0:00:00.182048
# episode: 246/2000, episode end value: 1362.48, duration: 0:00:00.191049
# episode: 247/2000, episode end value: 1390.33, duration: 0:00:00.185035
# episode: 248/2000, episode end value: 1374.32, duration: 0:00:00.192049
# episode: 249/2000, episode end value: 1380.84, duration: 0:00:00.186032
# episode: 250/2000, episode end value: 1370.10, duration: 0:00:00.191038
# episode: 251/2000, episode end value: 1378.89, duration: 0:00:00.184047
# episode: 252/2000, episode end value: 1371.61, duration: 0:00:00.196038
# episode: 253/2000, episode end value: 1367.53, duration: 0:00:00.195051
# episode: 254/2000, episode end value: 1364.31, duration: 0:00:00.191022
# episode: 255/2000, episode end value: 1371.41, duration: 0:00:00.195052
# episode: 256/2000, episode end value: 1388.76, duration: 0:00:00.193049
# episode: 257/2000, episode end value: 1376.46, duration: 0:00:00.188447
# episode: 258/2000, episode end value: 1377.72, duration: 0:00:00.184059
# episode: 259/2000, episode end value: 1370.76, duration: 0:00:00.182048
# episode: 260/2000, episode end value: 1387.86, duration: 0:00:00.186023
# episode: 261/2000, episode end value: 1378.22, duration: 0:00:00.188060
# episode: 262/2000, episode end value: 1373.27, duration: 0:00:00.186653
# episode: 263/2000, episode end value: 1376.44, duration: 0:00:00.184041
# episode: 264/2000, episode end value: 1386.05, duration: 0:00:00.200040
# episode: 265/2000, episode end value: 1372.94, duration: 0:00:00.190061
# episode: 266/2000, episode end value: 1380.20, duration: 0:00:00.192024
# episode: 267/2000, episode end value: 1381.16, duration: 0:00:00.179059
# episode: 268/2000, episode end value: 1375.87, duration: 0:00:00.187061
# episode: 269/2000, episode end value: 1365.63, duration: 0:00:00.189030
# episode: 270/2000, episode end value: 1369.92, duration: 0:00:00.184029
# episode: 271/2000, episode end value: 1378.85, duration: 0:00:00.204040
# episode: 272/2000, episode end value: 1385.63, duration: 0:00:00.188049
# episode: 273/2000, episode end value: 1380.18, duration: 0:00:00.188042
# episode: 274/2000, episode end value: 1363.79, duration: 0:00:00.182041
# episode: 275/2000, episode end value: 1389.02, duration: 0:00:00.179040
# episode: 276/2000, episode end value: 1381.96, duration: 0:00:00.198012
# episode: 277/2000, episode end value: 1378.18, duration: 0:00:00.195044
# episode: 278/2000, episode end value: 1380.67, duration: 0:00:00.193043
# episode: 279/2000, episode end value: 1382.26, duration: 0:00:00.183034
# episode: 280/2000, episode end value: 1369.24, duration: 0:00:00.180048
# episode: 281/2000, episode end value: 1374.07, duration: 0:00:00.190036
# episode: 282/2000, episode end value: 1391.99, duration: 0:00:00.191023
# episode: 283/2000, episode end value: 1380.59, duration: 0:00:00.186042
# episode: 284/2000, episode end value: 1368.59, duration: 0:00:00.188049
# episode: 285/2000, episode end value: 1394.08, duration: 0:00:00.189041
# episode: 286/2000, episode end value: 1386.02, duration: 0:00:00.202031
# episode: 287/2000, episode end value: 1370.32, duration: 0:00:00.184061
# episode: 288/2000, episode end value: 1372.22, duration: 0:00:00.187042
# episode: 289/2000, episode end value: 1367.32, duration: 0:00:00.182026
# episode: 290/2000, episode end value: 1381.72, duration: 0:00:00.189061
# episode: 291/2000, episode end value: 1392.00, duration: 0:00:00.178041
# episode: 292/2000, episode end value: 1368.78, duration: 0:00:00.193037
# episode: 293/2000, episode end value: 1386.95, duration: 0:00:00.193049
# episode: 294/2000, episode end value: 1374.35, duration: 0:00:00.184023
# episode: 295/2000, episode end value: 1378.07, duration: 0:00:00.187041
# episode: 296/2000, episode end value: 1370.53, duration: 0:00:00.184061
# episode: 297/2000, episode end value: 1382.12, duration: 0:00:00.188320
# episode: 298/2000, episode end value: 1394.11, duration: 0:00:00.185591
# episode: 299/2000, episode end value: 1360.18, duration: 0:00:00.190620
# episode: 300/2000, episode end value: 1394.85, duration: 0:00:00.191060
# episode: 301/2000, episode end value: 1371.51, duration: 0:00:00.205071
# episode: 302/2000, episode end value: 1369.28, duration: 0:00:00.193072
# episode: 303/2000, episode end value: 1368.53, duration: 0:00:00.197063
# episode: 304/2000, episode end value: 1396.17, duration: 0:00:00.192068
# episode: 305/2000, episode end value: 1373.10, duration: 0:00:00.184664
# episode: 306/2000, episode end value: 1378.09, duration: 0:00:00.186043
# episode: 307/2000, episode end value: 1388.08, duration: 0:00:00.188040
# episode: 308/2000, episode end value: 1365.39, duration: 0:00:00.195044
# episode: 309/2000, episode end value: 1378.64, duration: 0:00:00.189040
# episode: 310/2000, episode end value: 1370.49, duration: 0:00:00.197045
# episode: 311/2000, episode end value: 1376.64, duration: 0:00:00.191042
# episode: 312/2000, episode end value: 1376.46, duration: 0:00:00.191042
# episode: 313/2000, episode end value: 1375.38, duration: 0:00:00.189123
# episode: 314/2000, episode end value: 1374.77, duration: 0:00:00.183579
# episode: 315/2000, episode end value: 1372.90, duration: 0:00:00.200041
# episode: 316/2000, episode end value: 1375.50, duration: 0:00:00.192043
# episode: 317/2000, episode end value: 1367.00, duration: 0:00:00.188029
# episode: 318/2000, episode end value: 1384.30, duration: 0:00:00.182054
# episode: 319/2000, episode end value: 1376.07, duration: 0:00:00.196030
# episode: 320/2000, episode end value: 1386.21, duration: 0:00:00.189043
# episode: 321/2000, episode end value: 1363.65, duration: 0:00:00.189041
# episode: 322/2000, episode end value: 1396.96, duration: 0:00:00.183268
# episode: 323/2000, episode end value: 1385.82, duration: 0:00:00.182027
# episode: 324/2000, episode end value: 1366.84, duration: 0:00:00.182146
# episode: 325/2000, episode end value: 1389.30, duration: 0:00:00.203463
# episode: 326/2000, episode end value: 1386.11, duration: 0:00:00.191081
# episode: 327/2000, episode end value: 1372.08, duration: 0:00:00.201081
# episode: 328/2000, episode end value: 1395.38, duration: 0:00:00.186723
# episode: 329/2000, episode end value: 1355.34, duration: 0:00:00.177053
# episode: 330/2000, episode end value: 1367.84, duration: 0:00:00.204043
# episode: 331/2000, episode end value: 1378.76, duration: 0:00:00.199045
# episode: 332/2000, episode end value: 1373.43, duration: 0:00:00.199044
# episode: 333/2000, episode end value: 1382.22, duration: 0:00:00.202043
# episode: 334/2000, episode end value: 1369.94, duration: 0:00:00.200045
# episode: 335/2000, episode end value: 1379.06, duration: 0:00:00.191038
# episode: 336/2000, episode end value: 1354.25, duration: 0:00:00.176044
# episode: 337/2000, episode end value: 1370.61, duration: 0:00:00.188027
# episode: 338/2000, episode end value: 1371.13, duration: 0:00:00.193058
# episode: 339/2000, episode end value: 1372.43, duration: 0:00:00.200043
# episode: 340/2000, episode end value: 1387.01, duration: 0:00:00.195029
# episode: 341/2000, episode end value: 1362.02, duration: 0:00:00.194059
# episode: 342/2000, episode end value: 1378.75, duration: 0:00:00.198042
# episode: 343/2000, episode end value: 1366.87, duration: 0:00:00.192997
# episode: 344/2000, episode end value: 1364.24, duration: 0:00:00.201058
# episode: 345/2000, episode end value: 1385.97, duration: 0:00:00.190043
# episode: 346/2000, episode end value: 1370.27, duration: 0:00:00.195037
# episode: 347/2000, episode end value: 1369.77, duration: 0:00:00.195080
# episode: 348/2000, episode end value: 1378.58, duration: 0:00:00.199081
# episode: 349/2000, episode end value: 1362.40, duration: 0:00:00.187337
# episode: 350/2000, episode end value: 1363.70, duration: 0:00:00.192080
# episode: 351/2000, episode end value: 1376.42, duration: 0:00:00.195072
# episode: 352/2000, episode end value: 1369.49, duration: 0:00:00.198082
# episode: 353/2000, episode end value: 1380.42, duration: 0:00:00.187567
# episode: 354/2000, episode end value: 1374.64, duration: 0:00:00.197055
# episode: 355/2000, episode end value: 1386.15, duration: 0:00:00.191043
# episode: 356/2000, episode end value: 1378.00, duration: 0:00:00.193044
# episode: 357/2000, episode end value: 1386.39, duration: 0:00:00.189041
# episode: 358/2000, episode end value: 1374.11, duration: 0:00:00.206046
# episode: 359/2000, episode end value: 1375.34, duration: 0:00:00.192028
# episode: 360/2000, episode end value: 1376.07, duration: 0:00:00.197060
# episode: 361/2000, episode end value: 1385.49, duration: 0:00:00.204048
# episode: 362/2000, episode end value: 1373.43, duration: 0:00:00.196056
# episode: 363/2000, episode end value: 1379.82, duration: 0:00:00.191049
# episode: 364/2000, episode end value: 1370.06, duration: 0:00:00.194526
# episode: 365/2000, episode end value: 1375.86, duration: 0:00:00.194057
# episode: 366/2000, episode end value: 1376.42, duration: 0:00:00.193044
# episode: 367/2000, episode end value: 1391.53, duration: 0:00:00.206046
# episode: 368/2000, episode end value: 1374.90, duration: 0:00:00.192042
# episode: 369/2000, episode end value: 1372.60, duration: 0:00:00.194581
# episode: 370/2000, episode end value: 1374.21, duration: 0:00:00.196078
# episode: 371/2000, episode end value: 1365.23, duration: 0:00:00.200082
# episode: 372/2000, episode end value: 1368.39, duration: 0:00:00.195076
# episode: 373/2000, episode end value: 1387.07, duration: 0:00:00.195082
# episode: 374/2000, episode end value: 1371.22, duration: 0:00:00.189078
# episode: 375/2000, episode end value: 1387.82, duration: 0:00:00.186525
# episode: 376/2000, episode end value: 1370.54, duration: 0:00:00.198044
# episode: 377/2000, episode end value: 1373.10, duration: 0:00:00.191042
# episode: 378/2000, episode end value: 1371.23, duration: 0:00:00.196042
# episode: 379/2000, episode end value: 1380.03, duration: 0:00:00.203044
# episode: 380/2000, episode end value: 1384.21, duration: 0:00:00.192037
# episode: 381/2000, episode end value: 1386.52, duration: 0:00:00.202045
# episode: 382/2000, episode end value: 1370.76, duration: 0:00:00.194096
# episode: 383/2000, episode end value: 1381.58, duration: 0:00:00.194976
# episode: 384/2000, episode end value: 1389.37, duration: 0:00:00.182055
# episode: 385/2000, episode end value: 1374.67, duration: 0:00:00.196042
# episode: 386/2000, episode end value: 1383.79, duration: 0:00:00.184041
# episode: 387/2000, episode end value: 1381.53, duration: 0:00:00.187041
# episode: 388/2000, episode end value: 1369.92, duration: 0:00:00.194042
# episode: 389/2000, episode end value: 1383.32, duration: 0:00:00.201044
# episode: 390/2000, episode end value: 1396.95, duration: 0:00:00.197043
# episode: 391/2000, episode end value: 1364.37, duration: 0:00:00.188041
# episode: 392/2000, episode end value: 1375.62, duration: 0:00:00.192037
# episode: 393/2000, episode end value: 1384.55, duration: 0:00:00.192135
# episode: 394/2000, episode end value: 1374.75, duration: 0:00:00.200092
# episode: 395/2000, episode end value: 1382.55, duration: 0:00:00.189079
# episode: 396/2000, episode end value: 1394.26, duration: 0:00:00.203038
# episode: 397/2000, episode end value: 1367.83, duration: 0:00:00.195042
# episode: 398/2000, episode end value: 1376.60, duration: 0:00:00.191044
# episode: 399/2000, episode end value: 1385.96, duration: 0:00:00.189042
# episode: 400/2000, episode end value: 1385.79, duration: 0:00:00.190034
# episode: 401/2000, episode end value: 1362.14, duration: 0:00:00.189034
# episode: 402/2000, episode end value: 1367.49, duration: 0:00:00.192041
# episode: 403/2000, episode end value: 1376.83, duration: 0:00:00.188013
# episode: 404/2000, episode end value: 1379.17, duration: 0:00:00.176033
# episode: 405/2000, episode end value: 1378.36, duration: 0:00:00.175056
# episode: 406/2000, episode end value: 1371.51, duration: 0:00:00.191774
# episode: 407/2000, episode end value: 1378.06, duration: 0:00:00.202074
# episode: 408/2000, episode end value: 1363.25, duration: 0:00:00.205070
# episode: 409/2000, episode end value: 1383.75, duration: 0:00:00.199087
# episode: 410/2000, episode end value: 1380.97, duration: 0:00:00.202088
# episode: 411/2000, episode end value: 1390.58, duration: 0:00:00.207632
# episode: 412/2000, episode end value: 1357.33, duration: 0:00:00.202032
# episode: 413/2000, episode end value: 1382.87, duration: 0:00:00.187055
# episode: 414/2000, episode end value: 1384.76, duration: 0:00:00.192254
# episode: 415/2000, episode end value: 1371.43, duration: 0:00:00.193085
# episode: 416/2000, episode end value: 1399.94, duration: 0:00:00.191188
# episode: 417/2000, episode end value: 1374.04, duration: 0:00:00.190074
# episode: 418/2000, episode end value: 1372.78, duration: 0:00:00.191080
# episode: 419/2000, episode end value: 1355.75, duration: 0:00:00.186043
# episode: 420/2000, episode end value: 1354.55, duration: 0:00:00.199045
# episode: 421/2000, episode end value: 1366.27, duration: 0:00:00.191043
# episode: 422/2000, episode end value: 1356.99, duration: 0:00:00.199045
# episode: 423/2000, episode end value: 1378.51, duration: 0:00:00.201044
# episode: 424/2000, episode end value: 1363.36, duration: 0:00:00.188042
# episode: 425/2000, episode end value: 1380.11, duration: 0:00:00.185040
# episode: 426/2000, episode end value: 1365.70, duration: 0:00:00.194034
# episode: 427/2000, episode end value: 1379.36, duration: 0:00:00.191043
# episode: 428/2000, episode end value: 1373.07, duration: 0:00:00.190047
# episode: 429/2000, episode end value: 1367.42, duration: 0:00:00.185035
# episode: 430/2000, episode end value: 1388.93, duration: 0:00:00.198045
# episode: 431/2000, episode end value: 1348.75, duration: 0:00:00.191041
# episode: 432/2000, episode end value: 1368.89, duration: 0:00:00.189041
# episode: 433/2000, episode end value: 1368.89, duration: 0:00:00.180039
# episode: 434/2000, episode end value: 1357.74, duration: 0:00:00.184041
# episode: 435/2000, episode end value: 1377.62, duration: 0:00:00.191049
# episode: 436/2000, episode end value: 1376.58, duration: 0:00:00.194566
# episode: 437/2000, episode end value: 1382.41, duration: 0:00:00.196042
# episode: 438/2000, episode end value: 1395.91, duration: 0:00:00.207048
# episode: 439/2000, episode end value: 1368.88, duration: 0:00:00.196043
# episode: 440/2000, episode end value: 1381.81, duration: 0:00:00.183027
# episode: 441/2000, episode end value: 1390.91, duration: 0:00:00.184341
# episode: 442/2000, episode end value: 1378.41, duration: 0:00:00.203613
# episode: 443/2000, episode end value: 1370.02, duration: 0:00:00.190032
# episode: 444/2000, episode end value: 1380.80, duration: 0:00:00.192691
# episode: 445/2000, episode end value: 1376.38, duration: 0:00:00.189053
# episode: 446/2000, episode end value: 1368.57, duration: 0:00:00.198038
# episode: 447/2000, episode end value: 1373.04, duration: 0:00:00.209046
# episode: 448/2000, episode end value: 1378.16, duration: 0:00:00.210046
# episode: 449/2000, episode end value: 1380.97, duration: 0:00:00.212047
# episode: 450/2000, episode end value: 1371.59, duration: 0:00:00.197043
# episode: 451/2000, episode end value: 1370.86, duration: 0:00:00.193043
# episode: 452/2000, episode end value: 1385.00, duration: 0:00:00.195042
# episode: 453/2000, episode end value: 1366.18, duration: 0:00:00.189041
# episode: 454/2000, episode end value: 1368.59, duration: 0:00:00.199043
# episode: 455/2000, episode end value: 1379.26, duration: 0:00:00.201045
# episode: 456/2000, episode end value: 1387.09, duration: 0:00:00.192641
# episode: 457/2000, episode end value: 1378.62, duration: 0:00:00.197045
# episode: 458/2000, episode end value: 1380.93, duration: 0:00:00.184041
# episode: 459/2000, episode end value: 1371.81, duration: 0:00:00.192042
# episode: 460/2000, episode end value: 1361.90, duration: 0:00:00.178038
# episode: 461/2000, episode end value: 1348.54, duration: 0:00:00.179039
# episode: 462/2000, episode end value: 1394.09, duration: 0:00:00.176040
# episode: 463/2000, episode end value: 1368.52, duration: 0:00:00.195043
# episode: 464/2000, episode end value: 1379.72, duration: 0:00:00.200044
# episode: 465/2000, episode end value: 1384.08, duration: 0:00:00.197049
# episode: 466/2000, episode end value: 1367.52, duration: 0:00:00.181041
# episode: 467/2000, episode end value: 1371.64, duration: 0:00:00.182040
# episode: 468/2000, episode end value: 1374.72, duration: 0:00:00.191049
# episode: 469/2000, episode end value: 1377.91, duration: 0:00:00.192036
# episode: 470/2000, episode end value: 1368.14, duration: 0:00:00.197044
# episode: 471/2000, episode end value: 1365.35, duration: 0:00:00.183031
# episode: 472/2000, episode end value: 1389.37, duration: 0:00:00.179047
# episode: 473/2000, episode end value: 1378.32, duration: 0:00:00.190042
# episode: 474/2000, episode end value: 1382.44, duration: 0:00:00.180036
# episode: 475/2000, episode end value: 1369.91, duration: 0:00:00.179064
# episode: 476/2000, episode end value: 1388.22, duration: 0:00:00.201197
# episode: 477/2000, episode end value: 1411.72, duration: 0:00:00.198043
# episode: 478/2000, episode end value: 1373.35, duration: 0:00:00.190096
# episode: 479/2000, episode end value: 1374.40, duration: 0:00:00.204064
# episode: 480/2000, episode end value: 1365.31, duration: 0:00:00.203046
# episode: 481/2000, episode end value: 1365.39, duration: 0:00:00.198050
# episode: 482/2000, episode end value: 1383.50, duration: 0:00:00.193037
# episode: 483/2000, episode end value: 1370.01, duration: 0:00:00.189148
# episode: 484/2000, episode end value: 1377.15, duration: 0:00:00.198618
# episode: 485/2000, episode end value: 1344.11, duration: 0:00:00.209066
# episode: 486/2000, episode end value: 1391.29, duration: 0:00:00.200082
# episode: 487/2000, episode end value: 1376.44, duration: 0:00:00.202085
# episode: 488/2000, episode end value: 1374.55, duration: 0:00:00.206082
# episode: 489/2000, episode end value: 1376.31, duration: 0:00:00.187077
# episode: 490/2000, episode end value: 1378.00, duration: 0:00:00.184067
# episode: 491/2000, episode end value: 1374.09, duration: 0:00:00.189069
# episode: 492/2000, episode end value: 1381.25, duration: 0:00:00.196170
# episode: 493/2000, episode end value: 1374.16, duration: 0:00:00.188041
# episode: 494/2000, episode end value: 1385.15, duration: 0:00:00.182041
# episode: 495/2000, episode end value: 1376.65, duration: 0:00:00.189041
# episode: 496/2000, episode end value: 1373.16, duration: 0:00:00.186129
# episode: 497/2000, episode end value: 1381.11, duration: 0:00:00.181529
# episode: 498/2000, episode end value: 1375.59, duration: 0:00:00.179090
# episode: 499/2000, episode end value: 1377.61, duration: 0:00:00.194044
# episode: 500/2000, episode end value: 1379.93, duration: 0:00:00.198036
# episode: 501/2000, episode end value: 1377.99, duration: 0:00:00.187047
# episode: 502/2000, episode end value: 1377.61, duration: 0:00:00.183039
# episode: 503/2000, episode end value: 1377.47, duration: 0:00:00.188981
# episode: 504/2000, episode end value: 1363.54, duration: 0:00:00.185041
# episode: 505/2000, episode end value: 1352.66, duration: 0:00:00.173037
# episode: 506/2000, episode end value: 1385.45, duration: 0:00:00.170118
# episode: 507/2000, episode end value: 1373.46, duration: 0:00:00.187040
# episode: 508/2000, episode end value: 1368.56, duration: 0:00:00.189040
# episode: 509/2000, episode end value: 1372.14, duration: 0:00:00.202046
# episode: 510/2000, episode end value: 1383.84, duration: 0:00:00.194041
# episode: 511/2000, episode end value: 1375.28, duration: 0:00:00.202043
# episode: 512/2000, episode end value: 1377.84, duration: 0:00:00.189040
# episode: 513/2000, episode end value: 1338.90, duration: 0:00:00.186028
# episode: 514/2000, episode end value: 1382.18, duration: 0:00:00.187055
# episode: 515/2000, episode end value: 1379.97, duration: 0:00:00.190042
# episode: 516/2000, episode end value: 1364.75, duration: 0:00:00.186017
# episode: 517/2000, episode end value: 1385.71, duration: 0:00:00.198051
# episode: 518/2000, episode end value: 1392.76, duration: 0:00:00.190041
# episode: 519/2000, episode end value: 1377.93, duration: 0:00:00.184040
# episode: 520/2000, episode end value: 1383.53, duration: 0:00:00.188996
# episode: 521/2000, episode end value: 1387.71, duration: 0:00:00.193044
# episode: 522/2000, episode end value: 1380.82, duration: 0:00:00.203045
# episode: 523/2000, episode end value: 1384.67, duration: 0:00:00.194043
# episode: 524/2000, episode end value: 1383.81, duration: 0:00:00.195043
# episode: 525/2000, episode end value: 1378.72, duration: 0:00:00.189045
# episode: 526/2000, episode end value: 1387.26, duration: 0:00:00.196022
# episode: 527/2000, episode end value: 1386.76, duration: 0:00:00.194060
# episode: 528/2000, episode end value: 1376.19, duration: 0:00:00.183047
# episode: 529/2000, episode end value: 1366.25, duration: 0:00:00.184088
# episode: 530/2000, episode end value: 1365.12, duration: 0:00:00.190041
# episode: 531/2000, episode end value: 1392.91, duration: 0:00:00.190043
# episode: 532/2000, episode end value: 1392.48, duration: 0:00:00.183040
# episode: 533/2000, episode end value: 1364.59, duration: 0:00:00.181598
# episode: 534/2000, episode end value: 1384.70, duration: 0:00:00.190957
# episode: 535/2000, episode end value: 1380.90, duration: 0:00:00.184325
# episode: 536/2000, episode end value: 1380.93, duration: 0:00:00.184412
# episode: 537/2000, episode end value: 1374.45, duration: 0:00:00.196090
# episode: 538/2000, episode end value: 1369.22, duration: 0:00:00.187092
# episode: 539/2000, episode end value: 1376.76, duration: 0:00:00.188021
# episode: 540/2000, episode end value: 1391.53, duration: 0:00:00.189041
# episode: 541/2000, episode end value: 1386.75, duration: 0:00:00.181046
# episode: 542/2000, episode end value: 1372.03, duration: 0:00:00.182038
# episode: 543/2000, episode end value: 1362.56, duration: 0:00:00.203047
# episode: 544/2000, episode end value: 1386.16, duration: 0:00:00.192043
# episode: 545/2000, episode end value: 1373.41, duration: 0:00:00.196012
# episode: 546/2000, episode end value: 1382.46, duration: 0:00:00.184014
# episode: 547/2000, episode end value: 1394.61, duration: 0:00:00.200030
# episode: 548/2000, episode end value: 1390.85, duration: 0:00:00.184054
# episode: 549/2000, episode end value: 1368.51, duration: 0:00:00.185038
# episode: 550/2000, episode end value: 1355.83, duration: 0:00:00.170039
# episode: 551/2000, episode end value: 1368.88, duration: 0:00:00.192044
# episode: 552/2000, episode end value: 1384.16, duration: 0:00:00.201044
# episode: 553/2000, episode end value: 1367.14, duration: 0:00:00.197045
# episode: 554/2000, episode end value: 1366.94, duration: 0:00:00.200041
# episode: 555/2000, episode end value: 1372.93, duration: 0:00:00.189044
# episode: 556/2000, episode end value: 1396.44, duration: 0:00:00.186040
# episode: 557/2000, episode end value: 1379.30, duration: 0:00:00.178039
# episode: 558/2000, episode end value: 1382.92, duration: 0:00:00.180039
# episode: 559/2000, episode end value: 1361.22, duration: 0:00:00.179039
# episode: 560/2000, episode end value: 1386.98, duration: 0:00:00.185040
# episode: 561/2000, episode end value: 1377.35, duration: 0:00:00.189041
# episode: 562/2000, episode end value: 1367.91, duration: 0:00:00.201045
# episode: 563/2000, episode end value: 1368.17, duration: 0:00:00.203043
# episode: 564/2000, episode end value: 1370.38, duration: 0:00:00.201047
# episode: 565/2000, episode end value: 1391.68, duration: 0:00:00.195041
# episode: 566/2000, episode end value: 1362.94, duration: 0:00:00.187030
# episode: 567/2000, episode end value: 1382.35, duration: 0:00:00.204058
# episode: 568/2000, episode end value: 1363.38, duration: 0:00:00.198044
# episode: 569/2000, episode end value: 1363.75, duration: 0:00:00.196062
# episode: 570/2000, episode end value: 1379.76, duration: 0:00:00.192043
# episode: 571/2000, episode end value: 1369.73, duration: 0:00:00.198044
# episode: 572/2000, episode end value: 1368.43, duration: 0:00:00.190043
# episode: 573/2000, episode end value: 1388.20, duration: 0:00:00.199045
# episode: 574/2000, episode end value: 1382.73, duration: 0:00:00.190780
# episode: 575/2000, episode end value: 1396.25, duration: 0:00:00.201745
# episode: 576/2000, episode end value: 1353.64, duration: 0:00:00.200030
# episode: 577/2000, episode end value: 1378.55, duration: 0:00:00.191130
# episode: 578/2000, episode end value: 1381.61, duration: 0:00:00.199046
# episode: 579/2000, episode end value: 1377.80, duration: 0:00:00.201043
# episode: 580/2000, episode end value: 1394.51, duration: 0:00:00.194037
# episode: 581/2000, episode end value: 1396.96, duration: 0:00:00.188055
# episode: 582/2000, episode end value: 1387.40, duration: 0:00:00.181034
# episode: 583/2000, episode end value: 1370.15, duration: 0:00:00.199044
# episode: 584/2000, episode end value: 1373.38, duration: 0:00:00.211042
# episode: 585/2000, episode end value: 1355.44, duration: 0:00:00.194043
# episode: 586/2000, episode end value: 1383.04, duration: 0:00:00.187041
# episode: 587/2000, episode end value: 1369.58, duration: 0:00:00.211047
# episode: 588/2000, episode end value: 1373.41, duration: 0:00:00.197040
# episode: 589/2000, episode end value: 1365.36, duration: 0:00:00.186576
# episode: 590/2000, episode end value: 1399.23, duration: 0:00:00.197029
# episode: 591/2000, episode end value: 1403.54, duration: 0:00:00.191054
# episode: 592/2000, episode end value: 1385.36, duration: 0:00:00.197044
# episode: 593/2000, episode end value: 1374.22, duration: 0:00:00.209022
# episode: 594/2000, episode end value: 1376.23, duration: 0:00:00.199402
# episode: 595/2000, episode end value: 1382.92, duration: 0:00:00.209574
# episode: 596/2000, episode end value: 1385.42, duration: 0:00:00.195125
# episode: 597/2000, episode end value: 1364.46, duration: 0:00:00.209817
# episode: 598/2000, episode end value: 1376.33, duration: 0:00:00.198050
# episode: 599/2000, episode end value: 1388.36, duration: 0:00:00.187042
# episode: 600/2000, episode end value: 1382.31, duration: 0:00:00.182039
# episode: 601/2000, episode end value: 1378.66, duration: 0:00:00.197039
# episode: 602/2000, episode end value: 1381.51, duration: 0:00:00.194045
# episode: 603/2000, episode end value: 1354.74, duration: 0:00:00.181034
# episode: 604/2000, episode end value: 1377.54, duration: 0:00:00.189041
# episode: 605/2000, episode end value: 1377.35, duration: 0:00:00.182046
# episode: 606/2000, episode end value: 1387.17, duration: 0:00:00.179033
# episode: 607/2000, episode end value: 1382.59, duration: 0:00:00.182041
# episode: 608/2000, episode end value: 1374.08, duration: 0:00:00.193042
# episode: 609/2000, episode end value: 1399.09, duration: 0:00:00.182042
# episode: 610/2000, episode end value: 1386.53, duration: 0:00:00.184040
# episode: 611/2000, episode end value: 1374.18, duration: 0:00:00.189043
# episode: 612/2000, episode end value: 1381.34, duration: 0:00:00.185092
# episode: 613/2000, episode end value: 1375.31, duration: 0:00:00.199156
# episode: 614/2000, episode end value: 1378.81, duration: 0:00:00.191079
# episode: 615/2000, episode end value: 1370.05, duration: 0:00:00.203912
# episode: 616/2000, episode end value: 1378.23, duration: 0:00:00.197081
# episode: 617/2000, episode end value: 1391.69, duration: 0:00:00.194061
# episode: 618/2000, episode end value: 1382.88, duration: 0:00:00.182115
# episode: 619/2000, episode end value: 1357.32, duration: 0:00:00.184585
# episode: 620/2000, episode end value: 1382.34, duration: 0:00:00.203039
# episode: 621/2000, episode end value: 1383.20, duration: 0:00:00.196044
# episode: 622/2000, episode end value: 1372.81, duration: 0:00:00.190011
# episode: 623/2000, episode end value: 1379.70, duration: 0:00:00.209047
# episode: 624/2000, episode end value: 1381.70, duration: 0:00:00.193043
# episode: 625/2000, episode end value: 1371.21, duration: 0:00:00.201049
# episode: 626/2000, episode end value: 1377.94, duration: 0:00:00.186571
# episode: 627/2000, episode end value: 1366.74, duration: 0:00:00.205188
# episode: 628/2000, episode end value: 1383.29, duration: 0:00:00.195044
# episode: 629/2000, episode end value: 1384.11, duration: 0:00:00.187084
# episode: 630/2000, episode end value: 1362.42, duration: 0:00:00.192043
# episode: 631/2000, episode end value: 1380.13, duration: 0:00:00.209045
# episode: 632/2000, episode end value: 1377.46, duration: 0:00:00.200044
# episode: 633/2000, episode end value: 1376.97, duration: 0:00:00.199045
# episode: 634/2000, episode end value: 1374.13, duration: 0:00:00.208046
# episode: 635/2000, episode end value: 1384.36, duration: 0:00:00.196043
# episode: 636/2000, episode end value: 1370.31, duration: 0:00:00.204045
# episode: 637/2000, episode end value: 1369.73, duration: 0:00:00.190095
# episode: 638/2000, episode end value: 1381.38, duration: 0:00:00.194061
# episode: 639/2000, episode end value: 1367.37, duration: 0:00:00.198013
# episode: 640/2000, episode end value: 1371.41, duration: 0:00:00.187042
# episode: 641/2000, episode end value: 1377.46, duration: 0:00:00.191043
# episode: 642/2000, episode end value: 1389.28, duration: 0:00:00.196044
# episode: 643/2000, episode end value: 1367.88, duration: 0:00:00.204045
# episode: 644/2000, episode end value: 1381.42, duration: 0:00:00.197044
# episode: 645/2000, episode end value: 1383.91, duration: 0:00:00.185026
# episode: 646/2000, episode end value: 1347.15, duration: 0:00:00.178909
# episode: 647/2000, episode end value: 1368.77, duration: 0:00:00.192049
# episode: 648/2000, episode end value: 1379.30, duration: 0:00:00.180038
# episode: 649/2000, episode end value: 1361.97, duration: 0:00:00.198043
# episode: 650/2000, episode end value: 1365.42, duration: 0:00:00.186042
# episode: 651/2000, episode end value: 1374.63, duration: 0:00:00.194050
# episode: 652/2000, episode end value: 1372.63, duration: 0:00:00.180034
# episode: 653/2000, episode end value: 1371.30, duration: 0:00:00.204045
# episode: 654/2000, episode end value: 1379.85, duration: 0:00:00.186047
# episode: 655/2000, episode end value: 1377.51, duration: 0:00:00.199044
# episode: 656/2000, episode end value: 1378.00, duration: 0:00:00.201044
# episode: 657/2000, episode end value: 1371.59, duration: 0:00:00.184024
# episode: 658/2000, episode end value: 1374.88, duration: 0:00:00.196050
# episode: 659/2000, episode end value: 1382.21, duration: 0:00:00.188042
# episode: 660/2000, episode end value: 1399.01, duration: 0:00:00.189041
# episode: 661/2000, episode end value: 1379.47, duration: 0:00:00.192042
# episode: 662/2000, episode end value: 1367.24, duration: 0:00:00.190042
# episode: 663/2000, episode end value: 1380.82, duration: 0:00:00.195045
# episode: 664/2000, episode end value: 1385.10, duration: 0:00:00.191310
# episode: 665/2000, episode end value: 1369.20, duration: 0:00:00.198045
# episode: 666/2000, episode end value: 1389.15, duration: 0:00:00.183041
# episode: 667/2000, episode end value: 1387.03, duration: 0:00:00.181040
# ...
# episode: 1783/2000, episode end value: 1370.32, duration: 0:00:00.214042
# episode: 1784/2000, episode end value: 1370.18, duration: 0:00:00.218035
# episode: 1785/2000, episode end value: 1369.30, duration: 0:00:00.213047
# episode: 1786/2000, episode end value: 1360.69, duration: 0:00:00.212050
# episode: 1787/2000, episode end value: 1367.47, duration: 0:00:00.211601
# episode: 1788/2000, episode end value: 1362.32, duration: 0:00:00.214120
# episode: 1789/2000, episode end value: 1364.48, duration: 0:00:00.210198
# episode: 1790/2000, episode end value: 1359.85, duration: 0:00:00.214892
# episode: 1791/2000, episode end value: 1370.67, duration: 0:00:00.228044
# episode: 1792/2000, episode end value: 1361.89, duration: 0:00:00.216050
# episode: 1793/2000, episode end value: 1364.81, duration: 0:00:00.215049
# episode: 1794/2000, episode end value: 1351.88, duration: 0:00:00.212047
# episode: 1795/2000, episode end value: 1364.51, duration: 0:00:00.216061
# episode: 1796/2000, episode end value: 1353.69, duration: 0:00:00.212048
# episode: 1797/2000, episode end value: 1366.63, duration: 0:00:00.211047
# episode: 1798/2000, episode end value: 1360.30, duration: 0:00:00.224050
# episode: 1799/2000, episode end value: 1365.84, duration: 0:00:00.217035
# episode: 1800/2000, episode end value: 1354.17, duration: 0:00:00.208068
# episode: 1801/2000, episode end value: 1365.33, duration: 0:00:00.227044
# episode: 1802/2000, episode end value: 1354.06, duration: 0:00:00.213054
# episode: 1803/2000, episode end value: 1364.21, duration: 0:00:00.224050
# episode: 1804/2000, episode end value: 1370.05, duration: 0:00:00.222086
# episode: 1805/2000, episode end value: 1362.21, duration: 0:00:00.224092
# episode: 1806/2000, episode end value: 1355.81, duration: 0:00:00.221224
# episode: 1807/2000, episode end value: 1368.58, duration: 0:00:00.226157
# episode: 1808/2000, episode end value: 1357.62, duration: 0:00:00.223638
# episode: 1809/2000, episode end value: 1364.91, duration: 0:00:00.231052
# episode: 1810/2000, episode end value: 1363.98, duration: 0:00:00.215055
# episode: 1811/2000, episode end value: 1363.45, duration: 0:00:00.216053
# episode: 1812/2000, episode end value: 1370.29, duration: 0:00:00.215048
# episode: 1813/2000, episode end value: 1368.57, duration: 0:00:00.222049
# episode: 1814/2000, episode end value: 1363.24, duration: 0:00:00.225063
# episode: 1815/2000, episode end value: 1374.34, duration: 0:00:00.223044
# episode: 1816/2000, episode end value: 1372.19, duration: 0:00:00.222050
# episode: 1817/2000, episode end value: 1373.32, duration: 0:00:00.221849
# episode: 1818/2000, episode end value: 1372.29, duration: 0:00:00.221530
# episode: 1819/2000, episode end value: 1363.59, duration: 0:00:00.218121
# episode: 1820/2000, episode end value: 1369.22, duration: 0:00:00.217060
# episode: 1821/2000, episode end value: 1367.34, duration: 0:00:00.207471
# episode: 1822/2000, episode end value: 1365.36, duration: 0:00:00.230615
# episode: 1823/2000, episode end value: 1374.57, duration: 0:00:00.221044
# episode: 1824/2000, episode end value: 1370.29, duration: 0:00:00.215055
# episode: 1825/2000, episode end value: 1373.24, duration: 0:00:00.217048
# episode: 1826/2000, episode end value: 1366.20, duration: 0:00:00.217048
# episode: 1827/2000, episode end value: 1364.32, duration: 0:00:00.215048
# episode: 1828/2000, episode end value: 1377.17, duration: 0:00:00.220049
# episode: 1829/2000, episode end value: 1367.98, duration: 0:00:00.217043
# episode: 1830/2000, episode end value: 1373.28, duration: 0:00:00.225063
# episode: 1831/2000, episode end value: 1372.45, duration: 0:00:00.220060
# episode: 1832/2000, episode end value: 1357.21, duration: 0:00:00.221055
# episode: 1833/2000, episode end value: 1370.06, duration: 0:00:00.220049
# episode: 1834/2000, episode end value: 1354.17, duration: 0:00:00.217042
# episode: 1835/2000, episode end value: 1364.33, duration: 0:00:00.215551
# episode: 1836/2000, episode end value: 1365.21, duration: 0:00:00.214892
# episode: 1837/2000, episode end value: 1362.38, duration: 0:00:00.231709
# episode: 1838/2000, episode end value: 1373.79, duration: 0:00:00.230050
# episode: 1839/2000, episode end value: 1373.52, duration: 0:00:00.224049
# episode: 1840/2000, episode end value: 1372.60, duration: 0:00:00.227241
# episode: 1841/2000, episode end value: 1368.66, duration: 0:00:00.227846
# episode: 1842/2000, episode end value: 1366.37, duration: 0:00:00.232032
# episode: 1843/2000, episode end value: 1362.00, duration: 0:00:00.230044
# episode: 1844/2000, episode end value: 1368.12, duration: 0:00:00.217045
# episode: 1845/2000, episode end value: 1364.57, duration: 0:00:00.232057
# episode: 1846/2000, episode end value: 1354.08, duration: 0:00:00.216092
# episode: 1847/2000, episode end value: 1367.81, duration: 0:00:00.227476
# episode: 1848/2000, episode end value: 1359.90, duration: 0:00:00.216163
# episode: 1849/2000, episode end value: 1367.98, duration: 0:00:00.227039
# episode: 1850/2000, episode end value: 1365.57, duration: 0:00:00.218049
# episode: 1851/2000, episode end value: 1355.48, duration: 0:00:00.224056
# episode: 1852/2000, episode end value: 1369.12, duration: 0:00:00.222056
# episode: 1853/2000, episode end value: 1358.23, duration: 0:00:00.231058
# episode: 1854/2000, episode end value: 1367.34, duration: 0:00:00.225048
# episode: 1855/2000, episode end value: 1365.12, duration: 0:00:00.219040
# episode: 1856/2000, episode end value: 1361.58, duration: 0:00:00.220057
# episode: 1857/2000, episode end value: 1369.47, duration: 0:00:00.225052
# episode: 1858/2000, episode end value: 1359.52, duration: 0:00:00.231046
# episode: 1859/2000, episode end value: 1373.62, duration: 0:00:00.223052
# episode: 1860/2000, episode end value: 1371.81, duration: 0:00:00.220992
# episode: 1861/2000, episode end value: 1367.23, duration: 0:00:00.233052
# episode: 1862/2000, episode end value: 1367.79, duration: 0:00:00.221049
# episode: 1863/2000, episode end value: 1367.25, duration: 0:00:00.229057
# episode: 1864/2000, episode end value: 1364.82, duration: 0:00:00.226045
# episode: 1865/2000, episode end value: 1363.61, duration: 0:00:00.226051
# episode: 1866/2000, episode end value: 1373.99, duration: 0:00:00.223044
# episode: 1867/2000, episode end value: 1370.83, duration: 0:00:00.220043
# episode: 1868/2000, episode end value: 1372.97, duration: 0:00:00.217054
# episode: 1869/2000, episode end value: 1372.95, duration: 0:00:00.224050
# episode: 1870/2000, episode end value: 1363.72, duration: 0:00:00.217055
# episode: 1871/2000, episode end value: 1372.49, duration: 0:00:00.214054
# episode: 1872/2000, episode end value: 1374.82, duration: 0:00:00.230058
# episode: 1873/2000, episode end value: 1369.91, duration: 0:00:00.232052
# episode: 1874/2000, episode end value: 1364.49, duration: 0:00:00.224056
# episode: 1875/2000, episode end value: 1356.11, duration: 0:00:00.220059
# episode: 1876/2000, episode end value: 1367.59, duration: 0:00:00.216642
# episode: 1877/2000, episode end value: 1371.90, duration: 0:00:00.225117
# episode: 1878/2000, episode end value: 1373.14, duration: 0:00:00.227919
# episode: 1879/2000, episode end value: 1374.61, duration: 0:00:00.223891
# episode: 1880/2000, episode end value: 1373.31, duration: 0:00:00.215233
# episode: 1881/2000, episode end value: 1372.08, duration: 0:00:00.217054
# episode: 1882/2000, episode end value: 1371.96, duration: 0:00:00.228052
# episode: 1883/2000, episode end value: 1375.43, duration: 0:00:00.222037
# episode: 1884/2000, episode end value: 1354.70, duration: 0:00:00.217054
# episode: 1885/2000, episode end value: 1367.00, duration: 0:00:00.230034
# episode: 1886/2000, episode end value: 1375.72, duration: 0:00:00.225038
# episode: 1887/2000, episode end value: 1350.89, duration: 0:00:00.220391
# episode: 1888/2000, episode end value: 1370.74, duration: 0:00:00.236053
# episode: 1889/2000, episode end value: 1377.53, duration: 0:00:00.232064
# episode: 1890/2000, episode end value: 1373.23, duration: 0:00:00.228051
# episode: 1891/2000, episode end value: 1368.66, duration: 0:00:00.232032
# episode: 1892/2000, episode end value: 1376.16, duration: 0:00:00.221063
# episode: 1893/2000, episode end value: 1369.54, duration: 0:00:00.237053
# episode: 1894/2000, episode end value: 1375.44, duration: 0:00:00.219055
# episode: 1895/2000, episode end value: 1367.69, duration: 0:00:00.218049
# episode: 1896/2000, episode end value: 1371.23, duration: 0:00:00.220028
# episode: 1897/2000, episode end value: 1373.94, duration: 0:00:00.219063
# episode: 1898/2000, episode end value: 1371.68, duration: 0:00:00.211041
# episode: 1899/2000, episode end value: 1367.25, duration: 0:00:00.215621
# episode: 1900/2000, episode end value: 1367.68, duration: 0:00:00.220091
# episode: 1901/2000, episode end value: 1375.54, duration: 0:00:00.218942
# episode: 1902/2000, episode end value: 1378.71, duration: 0:00:00.224058
# episode: 1903/2000, episode end value: 1375.63, duration: 0:00:00.222049
# episode: 1904/2000, episode end value: 1371.40, duration: 0:00:00.236052
# episode: 1905/2000, episode end value: 1366.89, duration: 0:00:00.230052
# episode: 1906/2000, episode end value: 1362.42, duration: 0:00:00.225036
# episode: 1907/2000, episode end value: 1364.18, duration: 0:00:00.221319
# episode: 1908/2000, episode end value: 1368.49, duration: 0:00:00.219424
# episode: 1909/2000, episode end value: 1352.06, duration: 0:00:00.225949
# episode: 1910/2000, episode end value: 1364.59, duration: 0:00:00.240065
# episode: 1911/2000, episode end value: 1357.96, duration: 0:00:00.230039
# episode: 1912/2000, episode end value: 1365.54, duration: 0:00:00.237045
# episode: 1913/2000, episode end value: 1363.77, duration: 0:00:00.215049
# episode: 1914/2000, episode end value: 1364.71, duration: 0:00:00.215068
# episode: 1915/2000, episode end value: 1357.75, duration: 0:00:00.227044
# episode: 1916/2000, episode end value: 1367.65, duration: 0:00:00.217049
# episode: 1917/2000, episode end value: 1364.40, duration: 0:00:00.223063
# episode: 1918/2000, episode end value: 1372.97, duration: 0:00:00.223050
# episode: 1919/2000, episode end value: 1369.47, duration: 0:00:00.214042
# episode: 1920/2000, episode end value: 1365.51, duration: 0:00:00.220049
# episode: 1921/2000, episode end value: 1358.03, duration: 0:00:00.216034
# episode: 1922/2000, episode end value: 1366.83, duration: 0:00:00.217065
# episode: 1923/2000, episode end value: 1359.22, duration: 0:00:00.221048
# episode: 1924/2000, episode end value: 1368.14, duration: 0:00:00.218049
# episode: 1925/2000, episode end value: 1367.47, duration: 0:00:00.221050
# episode: 1926/2000, episode end value: 1363.77, duration: 0:00:00.231052
# episode: 1927/2000, episode end value: 1368.84, duration: 0:00:00.223064
# episode: 1928/2000, episode end value: 1373.31, duration: 0:00:00.227065
# episode: 1929/2000, episode end value: 1375.83, duration: 0:00:00.216042
# episode: 1930/2000, episode end value: 1367.00, duration: 0:00:00.224050
# episode: 1931/2000, episode end value: 1365.17, duration: 0:00:00.218041
# episode: 1932/2000, episode end value: 1360.27, duration: 0:00:00.247057
# episode: 1933/2000, episode end value: 1371.26, duration: 0:00:00.226049
# episode: 1934/2000, episode end value: 1372.32, duration: 0:00:00.227051
# episode: 1935/2000, episode end value: 1373.98, duration: 0:00:00.226051
# episode: 1936/2000, episode end value: 1374.76, duration: 0:00:00.219628
# episode: 1937/2000, episode end value: 1368.41, duration: 0:00:00.215112
# episode: 1938/2000, episode end value: 1372.01, duration: 0:00:00.226143
# episode: 1939/2000, episode end value: 1368.10, duration: 0:00:00.215685
# episode: 1940/2000, episode end value: 1357.77, duration: 0:00:00.218062
# episode: 1941/2000, episode end value: 1367.63, duration: 0:00:00.229057
# episode: 1942/2000, episode end value: 1367.63, duration: 0:00:00.219049
# episode: 1943/2000, episode end value: 1365.24, duration: 0:00:00.225051
# episode: 1944/2000, episode end value: 1355.49, duration: 0:00:00.218043
# episode: 1945/2000, episode end value: 1372.02, duration: 0:00:00.242053
# episode: 1946/2000, episode end value: 1370.29, duration: 0:00:00.226051
# episode: 1947/2000, episode end value: 1361.56, duration: 0:00:00.225051
# episode: 1948/2000, episode end value: 1367.31, duration: 0:00:00.213059
# episode: 1949/2000, episode end value: 1364.52, duration: 0:00:00.211054
# episode: 1950/2000, episode end value: 1360.00, duration: 0:00:00.220036
# episode: 1951/2000, episode end value: 1375.99, duration: 0:00:00.225051
# episode: 1952/2000, episode end value: 1372.82, duration: 0:00:00.214054
# episode: 1953/2000, episode end value: 1359.42, duration: 0:00:00.224057
# episode: 1954/2000, episode end value: 1369.89, duration: 0:00:00.216034
# episode: 1955/2000, episode end value: 1373.35, duration: 0:00:00.219070
# episode: 1956/2000, episode end value: 1370.05, duration: 0:00:00.214048
# episode: 1957/2000, episode end value: 1363.06, duration: 0:00:00.218043
# episode: 1958/2000, episode end value: 1360.46, duration: 0:00:00.217669
# episode: 1959/2000, episode end value: 1372.47, duration: 0:00:00.226092
# episode: 1960/2000, episode end value: 1375.64, duration: 0:00:00.223577
# episode: 1961/2000, episode end value: 1374.07, duration: 0:00:00.229276
# episode: 1962/2000, episode end value: 1376.42, duration: 0:00:00.218909
# episode: 1963/2000, episode end value: 1371.98, duration: 0:00:00.221050
# episode: 1964/2000, episode end value: 1369.74, duration: 0:00:00.209054
# episode: 1965/2000, episode end value: 1360.76, duration: 0:00:00.216047
# episode: 1966/2000, episode end value: 1365.96, duration: 0:00:00.213500
# episode: 1967/2000, episode end value: 1360.51, duration: 0:00:00.220249
# episode: 1968/2000, episode end value: 1374.00, duration: 0:00:00.223037
# episode: 1969/2000, episode end value: 1369.00, duration: 0:00:00.215042
# episode: 1970/2000, episode end value: 1364.09, duration: 0:00:00.211053
# episode: 1971/2000, episode end value: 1363.36, duration: 0:00:00.229058
# episode: 1972/2000, episode end value: 1367.02, duration: 0:00:00.225050
# episode: 1973/2000, episode end value: 1371.83, duration: 0:00:00.225049
# episode: 1974/2000, episode end value: 1368.26, duration: 0:00:00.224032
# episode: 1975/2000, episode end value: 1360.00, duration: 0:00:00.224044
# episode: 1976/2000, episode end value: 1369.29, duration: 0:00:00.218061
# episode: 1977/2000, episode end value: 1374.06, duration: 0:00:00.230058
# episode: 1978/2000, episode end value: 1376.89, duration: 0:00:00.220062
# episode: 1979/2000, episode end value: 1367.61, duration: 0:00:00.214657
# episode: 1980/2000, episode end value: 1376.68, duration: 0:00:00.219083
# episode: 1981/2000, episode end value: 1349.20, duration: 0:00:00.227054
# episode: 1982/2000, episode end value: 1374.80, duration: 0:00:00.222050
# episode: 1983/2000, episode end value: 1366.86, duration: 0:00:00.210594
# episode: 1984/2000, episode end value: 1364.80, duration: 0:00:00.222752
# episode: 1985/2000, episode end value: 1353.06, duration: 0:00:00.235054
# episode: 1986/2000, episode end value: 1363.98, duration: 0:00:00.219047
# episode: 1987/2000, episode end value: 1360.49, duration: 0:00:00.232053
# episode: 1988/2000, episode end value: 1368.97, duration: 0:00:00.226048
# episode: 1989/2000, episode end value: 1372.86, duration: 0:00:00.233051
# episode: 1990/2000, episode end value: 1374.18, duration: 0:00:00.235054
# episode: 1991/2000, episode end value: 1368.68, duration: 0:00:00.237052
# episode: 1992/2000, episode end value: 1376.01, duration: 0:00:00.238050
# episode: 1993/2000, episode end value: 1371.51, duration: 0:00:00.232050
# episode: 1994/2000, episode end value: 1367.06, duration: 0:00:00.234053
# episode: 1995/2000, episode end value: 1359.13, duration: 0:00:00.236053
# episode: 1996/2000, episode end value: 1367.31, duration: 0:00:00.233052
# episode: 1997/2000, episode end value: 1361.54, duration: 0:00:00.248056
# episode: 1998/2000, episode end value: 1369.02, duration: 0:00:00.223049
# episode: 1999/2000, episode end value: 1365.01, duration: 0:00:00.233052
# episode: 2000/2000, episode end value: 1365.74, duration: 0:00:00.230573
# average reward: 1370.18, min: 1329.83, max: 1419.18

# %%
plt.plot(agent.model.losses)

# %%
plt.plot(portfolio_value)

# %%
#test

mode = 'test'

portfolio_value = []

if mode == 'test':
    with open(f'{models_folder}/scaler.pkl', 'rb') as f:
        scaler = pickle.load(f)
    num_episodes = 1
    env = Env(test_data, capital)
    agent.epsilon = 0
    agent.load(f'{models_folder}/linear.npz')


for e in range(num_episodes):
    t0 = datetime.now()
    val = play_one_episode(agent, env, mode)
    dt = datetime.now() - t0
    print(f"episode: {e + 1}/{num_episodes}, episode end value: {val['portfolio_value'][-1]:.2f}, duration: {dt}")
    portfolio_value.append(val['portfolio_value'][-1])
    
print(f"Sell: {env.sell_buy.count('sell')} times, Buy: {env.sell_buy.count('buy')} times")



result = pd.DataFrame(val)
result.index = test_data.index

def marker_buy(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'buy':
        return price
    else:
        return np.nan
    
def marker_sell(col):
    price = col[0] 
    sellbuy = col[1]
    
    if sellbuy == 'sell':
        return price
    else:
        return np.nan
    
result['marker_buy'] = result[['stock_price', 'sell_buy']].apply(marker_buy, axis=1);
result['marker_sell'] = result[['stock_price', 'sell_buy']].apply(marker_sell, axis=1);

result['stock_price'].plot(figsize=(10,6), c='grey', lw=2);
result['marker_buy'].plot(style='o', ms=7, label='buy', c='g', alpha=0.5);
result['marker_sell'].plot(style='o', ms=7, label='sell', c='r', alpha=0.5);
plt.title('Stock Price '+ stock_name)
plt.legend();
plt.show()



result['portfolio_value'].plot(figsize=(10,6), c='r', lw=2);
plt.title('Portfolio Value');
plt.show()

result['stock_owned'].plot(figsize=(10,6), c='purple', lw=2);
plt.title('Position')
plt.show()

result[['cash_in_hand', 'stock_value']].plot(figsize=(10,6), lw=2);
plt.title('Cash in Hand and Stock Value');
plt.show()
# Out:
# episode: 1/1, episode end value: 1104.58, duration: 0:00:00.098236
# Sell: 376 times, Buy: 377 times

# %%
import pyfolio as pf
sns.set_style('whitegrid')

bt_returns = result['portfolio_value'].pct_change()
price = result['stock_price'].pct_change()



plt.figure(figsize=(9,6));
plt.subplot(2,1,1);
pf.plotting.plot_rolling_returns(bt_returns, price);
plt.title('Compare with close price');
plt.show()

fig = plt.figure(1)
plt.subplot(1,3,1)
pf.plot_annual_returns(bt_returns)
plt.subplot(1,3,2)
pf.plot_monthly_returns_dist(bt_returns)
plt.subplot(1,3,3)
pf.plot_monthly_returns_heatmap(bt_returns)
plt.tight_layout()
fig.set_size_inches(12,4)

plt.figure(figsize=(9,6))
pf.plot_return_quantiles(bt_returns);



plt.figure(figsize=(9,6))
pf.plot_rolling_sharpe(bt_returns);

plt.figure(figsize=(9,6))
pf.plot_drawdown_underwater(bt_returns);
