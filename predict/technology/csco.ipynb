# %% [markdown]
# # Import Module

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,LSTM
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as web
# %matplotlib inline
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from tqdm.notebook import tqdm
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Stock data

# %%
ticker = 'csco'.upper()
df = web.DataReader(ticker, 'yahoo', '2016-01-01', '2021-02-01')
plt.figure(figsize=(13,4))
plt.title('Stock price '+ ticker)
plt.ylabel('Price')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['Adj Close'], color='g')
plt.show()

y = df['Adj Close'].values.astype(float)

test_size = 7
window_size = 120
train_set = y[:-test_size]
test_set = y[-test_size:]
df.info()

df['Adj Close'].iloc[-test_size:].plot(figsize=(13,4))
plt.title('test set')
plt.grid(True)

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(train_set.reshape(-1, 1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1280 entries, 2015-12-31 to 2021-02-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1280 non-null   float64
#  1   Low        1280 non-null   float64
#  2   Open       1280 non-null   float64
#  3   Close      1280 non-null   float64
#  4   Volume     1280 non-null   float64
#  5   Adj Close  1280 non-null   float64
# dtypes: float64(6)
# memory usage: 70.0 KB

# %% [markdown]
# # Recurrent Neural Network

# %%
class RecurrentNetwork:
    def __init__(self,
                 data,
                 test_size,
                 ticker,
                 future,
                 window_size=120,
                 layers=[50, 50, 50, 50, 50, 50],
                 dropout=0.2,
                 epochs=150,
                 batch_size=32):
        
        self.df = data
        self.layers = layers
        self.ticker = ticker
        self.dropout = dropout
        self.window_size = window_size
        self.test_size = test_size
        self.epochs = epochs
        self.batch_size = batch_size
        self.future = future
        self.true_predictions = None
        
        self.train_set, self.test_set = self.spilt_data()
        self.scaler = MinMaxScaler(feature_range=(-1, 1))
        self.train_norm, self.test_norm = self.norm_data()
        self.X_train, self.y_train = self.input_label()
        self.X_test, self.y_test = self.val_data()
        
        
        self.seeding(seed=101)
        self.model = self.build_model_rnn()
        
        
    def __str__(self):
        return str(self.model.summary())
    

    
        
    def seeding(self, seed):
        return np.random.seed(seed)
    
    
    def spilt_data(self):
        y = self.df['Adj Close'].values.astype(float)
        train_set = y[:-self.test_size]
        test_set = y[-self.test_size:]
        
        return train_set, test_set
    
    
    def norm_data(self):
        train_norm = scaler.transform(self.train_set.reshape(-1, 1))
        test_norm = scaler.transform(self.test_set.reshape(-1, 1))
        return train_norm, test_norm
    
    
    def input_label(self):
        X_train = []
        y_train = []
        for i in range(self.window_size, len(self.train_norm)):
            X_train.append(self.train_norm[i-self.window_size:i,0])
            y_train.append(self.train_norm[i,0])

        X_train,y_train = np.array(X_train), np.array(y_train) 
        
        X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
        
        return X_train,y_train
    
    
    def val_data(self):
        X_test = []
        y_test = []

        seq = self.train_norm[-(self.window_size-1):]

        for i in range(len(self.test_norm)):

            seq = np.array(seq[-(self.window_size-1):], dtype=np.float32)

            seq = np.append(seq, self.test_norm[i])

            X_test.append(seq)
            y_test.append(self.test_norm[i])

        X_test,y_test = np.array(X_test), np.array(y_test) 
        
        X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
        
        return X_test,y_test
        
    
    
    def build_model_rnn(self):
        
        model = Sequential()

        
        for i in range(len(self.layers)):
            if i == 0:
                model.add(LSTM(units=self.layers[i], return_sequences=True, input_shape=(self.X_train.shape[1], 1)))
                model.add(Dropout(self.dropout))
                
            elif i == (len(self.layers) - 1):
                model.add(LSTM(units=self.layers[i],))
                model.add(Dropout(self.dropout))
                
            else:
                model.add(LSTM(units=self.layers[i], return_sequences=True))
                model.add(Dropout(self.dropout))
                

        model.add(Dense(units=1))

        model.compile(optimizer='adam', loss='mean_squared_error')
    
        
        return model
    
    
    def training(self):
        
        self.model.fit(self.X_train,
                       self.y_train,
                       epochs=self.epochs,
                       validation_data=(self.X_test, self.y_test),
                       batch_size=self.batch_size)
        
        self.save()
        
        
    def loss_render(self):
        losses = pd.DataFrame(self.model.history.history)
        losses[['loss', 'val_loss']].plot(figsize=(6,10), label='Loss', subplots=True);
        plt.title('Loss')
        plt.xlabel('Epoch')
        plt.legend()

        
        
    def save(self):
        
        self.model.save_weights(f'model/{self.ticker}.h5')
        print('Saved model!!')
        
    
    def load(self):
        self.model.load_weights(f'model/{self.ticker}.h5')
        print('Loading model complete!!')
        
        
    
    def testing(self):
        self.load()
        
        preds = self.train_norm[-self.window_size:].tolist()
        
        for i in range(self.future):
            seq = np.array(preds[-self.window_size:], dtype=np.float32)
            seq = np.reshape(seq, (seq.shape[1], seq.shape[0], 1))
            predict = self.model.predict(seq)
            preds.append(predict)

        self.true_predictions = scaler.inverse_transform(np.array(preds[self.window_size:]).reshape(-1, 1))
        df1 = pd.DataFrame(self.true_predictions, index=df.tail(self.future).index, columns=['pred'])


        plt.figure(figsize=(12,4))
        plt.grid(True)
        plt.autoscale(axis='x',tight=True)
        plt.plot(self.df['Adj Close'].iloc[-(self.future + 10):], label='Stock price')
        plt.plot(df1['pred'], label='predicted')
        plt.title('Prediction')
        plt.xlabel('Date')
        plt.legend()
        
        
    def amse(self):
        return np.sqrt(mean_squared_error(self.true_predictions.reshape(1, -1), self.df['Adj Close'][-7:].values.reshape(1, -1)))

# %% [markdown]
# # Config

# %%
model = RecurrentNetwork(data=df,
                         test_size=7,
                         ticker=ticker,
                         future=7,
                         layers=[100]*6,
                         window_size=120,
                         dropout=0.2,
                         epochs=150,
                         batch_size=32)

# %% [markdown]
# # Model

# %%
print(model)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 120, 100)          40800
# _________________________________________________________________
# dropout (Dropout)            (None, 120, 100)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 120, 100)          80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120, 100)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 120, 100)          80400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 120, 100)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120, 100)          80400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120, 100)          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 120, 100)          80400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 120, 100)          0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 442,901
# Trainable params: 442,901
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
model.training()
# Out:
# Epoch 1/150
# 37/37 [==============================] - 23s 632ms/step - loss: 0.0467 - val_loss: 4.0774e-04
# Epoch 2/150
# 37/37 [==============================] - 17s 471ms/step - loss: 0.0195 - val_loss: 0.0025
# Epoch 3/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0167 - val_loss: 7.3226e-04
# Epoch 4/150
# 37/37 [==============================] - 18s 484ms/step - loss: 0.0125 - val_loss: 0.0015
# Epoch 5/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0128 - val_loss: 0.0063
# Epoch 6/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0128 - val_loss: 0.0071
# Epoch 7/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0140 - val_loss: 3.5851e-04
# Epoch 8/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0095 - val_loss: 0.0026
# Epoch 9/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0114 - val_loss: 0.0090
# Epoch 10/150
# 37/37 [==============================] - 18s 492ms/step - loss: 0.0107 - val_loss: 5.3627e-04
# Epoch 11/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 12/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0137 - val_loss: 7.0931e-04
# Epoch 13/150
# 37/37 [==============================] - 18s 486ms/step - loss: 0.0077 - val_loss: 7.8802e-04
# Epoch 14/150
# 37/37 [==============================] - 18s 484ms/step - loss: 0.0072 - val_loss: 0.0021
# Epoch 15/150
# 37/37 [==============================] - 18s 484ms/step - loss: 0.0082 - val_loss: 0.0011
# Epoch 16/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0073 - val_loss: 6.7941e-04
# Epoch 17/150
# 37/37 [==============================] - 18s 490ms/step - loss: 0.0067 - val_loss: 0.0015
# Epoch 18/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 19/150
# 37/37 [==============================] - 18s 486ms/step - loss: 0.0072 - val_loss: 8.9898e-04
# Epoch 20/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0063 - val_loss: 0.0013
# Epoch 21/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 22/150
# 37/37 [==============================] - 19s 513ms/step - loss: 0.0068 - val_loss: 0.0012
# Epoch 23/150
# 37/37 [==============================] - 18s 486ms/step - loss: 0.0060 - val_loss: 0.0027
# Epoch 24/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0062 - val_loss: 6.2030e-04
# Epoch 25/150
# 37/37 [==============================] - 18s 484ms/step - loss: 0.0061 - val_loss: 0.0013
# Epoch 26/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0059 - val_loss: 5.3772e-04
# Epoch 27/150
# 37/37 [==============================] - 18s 480ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 28/150
# 37/37 [==============================] - 18s 482ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 29/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0048 - val_loss: 6.2089e-04
# Epoch 30/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0049 - val_loss: 9.2745e-04
# Epoch 31/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0042 - val_loss: 6.7918e-04
# Epoch 32/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0043 - val_loss: 4.7408e-04
# Epoch 33/150
# 37/37 [==============================] - 18s 475ms/step - loss: 0.0064 - val_loss: 0.0045
# Epoch 34/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 35/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0051 - val_loss: 4.7718e-04
# Epoch 36/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 37/150
# 37/37 [==============================] - 17s 469ms/step - loss: 0.0065 - val_loss: 4.9711e-04
# Epoch 38/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0052 - val_loss: 7.6955e-04
# Epoch 39/150
# 37/37 [==============================] - 18s 475ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 40/150
# 37/37 [==============================] - 18s 480ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 41/150
# 37/37 [==============================] - 17s 471ms/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 42/150
# 37/37 [==============================] - 18s 481ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 43/150
# 37/37 [==============================] - 18s 496ms/step - loss: 0.0047 - val_loss: 4.3801e-04
# Epoch 44/150
# 37/37 [==============================] - 18s 494ms/step - loss: 0.0047 - val_loss: 3.6704e-04
# Epoch 45/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0043 - val_loss: 0.0023
# Epoch 46/150
# 37/37 [==============================] - 18s 481ms/step - loss: 0.0047 - val_loss: 3.3425e-04
# Epoch 47/150
# 37/37 [==============================] - 17s 472ms/step - loss: 0.0038 - val_loss: 3.7732e-04
# Epoch 48/150
# 37/37 [==============================] - 17s 472ms/step - loss: 0.0044 - val_loss: 3.5476e-04
# Epoch 49/150
# 37/37 [==============================] - 17s 471ms/step - loss: 0.0052 - val_loss: 6.4585e-04
# Epoch 50/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0036 - val_loss: 9.9921e-04
# Epoch 51/150
# 37/37 [==============================] - 18s 474ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 52/150
# 37/37 [==============================] - 17s 470ms/step - loss: 0.0054 - val_loss: 5.6019e-04
# Epoch 53/150
# 37/37 [==============================] - 17s 466ms/step - loss: 0.0039 - val_loss: 9.3248e-04
# Epoch 54/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 55/150
# 37/37 [==============================] - 17s 470ms/step - loss: 0.0040 - val_loss: 1.8973e-04
# Epoch 56/150
# 37/37 [==============================] - 17s 471ms/step - loss: 0.0037 - val_loss: 0.0035
# Epoch 57/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0042 - val_loss: 3.1551e-04
# Epoch 58/150
# 37/37 [==============================] - 17s 471ms/step - loss: 0.0035 - val_loss: 0.0013
# Epoch 59/150
# 37/37 [==============================] - 18s 473ms/step - loss: 0.0058 - val_loss: 1.6347e-04
# Epoch 60/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0036 - val_loss: 4.0407e-04
# Epoch 61/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0035 - val_loss: 3.3495e-04
# Epoch 62/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0037 - val_loss: 2.1027e-04
# Epoch 63/150
# 37/37 [==============================] - 18s 475ms/step - loss: 0.0035 - val_loss: 4.7154e-04
# Epoch 64/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 65/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 66/150
# 37/37 [==============================] - 18s 482ms/step - loss: 0.0041 - val_loss: 2.6747e-04
# Epoch 67/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 68/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0038 - val_loss: 0.0010
# Epoch 69/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0033 - val_loss: 7.0943e-04
# Epoch 70/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0034 - val_loss: 6.4706e-04
# Epoch 71/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0049 - val_loss: 1.7966e-04
# Epoch 72/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0032 - val_loss: 3.5161e-04
# Epoch 73/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0034 - val_loss: 6.9695e-05
# Epoch 74/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0038 - val_loss: 6.0044e-04
# Epoch 75/150
# 37/37 [==============================] - 18s 480ms/step - loss: 0.0033 - val_loss: 4.7806e-04
# Epoch 76/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 77/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0055 - val_loss: 0.0010
# Epoch 78/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0042 - val_loss: 4.1586e-04
# Epoch 79/150
# 37/37 [==============================] - 18s 476ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 80/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0036 - val_loss: 7.5181e-05
# Epoch 81/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0031 - val_loss: 5.5468e-05
# Epoch 82/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0040 - val_loss: 0.0043
# Epoch 83/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0056 - val_loss: 1.2646e-04
# Epoch 84/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0035 - val_loss: 1.2170e-04
# Epoch 85/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0033 - val_loss: 4.5628e-05
# Epoch 86/150
# 37/37 [==============================] - 18s 474ms/step - loss: 0.0037 - val_loss: 1.9106e-04
# Epoch 87/150
# 37/37 [==============================] - 18s 474ms/step - loss: 0.0032 - val_loss: 6.3978e-05
# Epoch 88/150
# 37/37 [==============================] - 17s 473ms/step - loss: 0.0034 - val_loss: 7.8417e-04
# Epoch 89/150
# 37/37 [==============================] - 17s 470ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 90/150
# 37/37 [==============================] - 18s 474ms/step - loss: 0.0030 - val_loss: 1.0746e-04
# Epoch 91/150
# 37/37 [==============================] - 17s 468ms/step - loss: 0.0031 - val_loss: 7.0800e-05
# Epoch 92/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0032 - val_loss: 5.5575e-04
# Epoch 93/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0033 - val_loss: 1.1122e-04
# Epoch 94/150
# 37/37 [==============================] - 17s 472ms/step - loss: 0.0033 - val_loss: 0.0012
# Epoch 95/150
# 37/37 [==============================] - 18s 482ms/step - loss: 0.0030 - val_loss: 1.0078e-04
# Epoch 96/150
# 37/37 [==============================] - 18s 474ms/step - loss: 0.0031 - val_loss: 2.3563e-04
# Epoch 97/150
# 37/37 [==============================] - 18s 477ms/step - loss: 0.0030 - val_loss: 5.8774e-04
# Epoch 98/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 99/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0031 - val_loss: 6.9901e-04
# Epoch 100/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0042 - val_loss: 1.3034e-04
# Epoch 101/150
# 37/37 [==============================] - 18s 490ms/step - loss: 0.0032 - val_loss: 7.1207e-05
# Epoch 102/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0028 - val_loss: 7.3294e-05
# Epoch 103/150
# 37/37 [==============================] - 18s 474ms/step - loss: 0.0033 - val_loss: 5.5336e-05
# Epoch 104/150
# 37/37 [==============================] - 18s 482ms/step - loss: 0.0033 - val_loss: 3.6295e-04
# Epoch 105/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 106/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 107/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0035 - val_loss: 1.3457e-04
# Epoch 108/150
# 37/37 [==============================] - 18s 484ms/step - loss: 0.0033 - val_loss: 9.3814e-04
# Epoch 109/150
# 37/37 [==============================] - 18s 478ms/step - loss: 0.0030 - val_loss: 4.5555e-04
# Epoch 110/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0035 - val_loss: 1.6110e-04
# Epoch 111/150
# 37/37 [==============================] - 18s 481ms/step - loss: 0.0029 - val_loss: 4.7593e-04
# Epoch 112/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0038 - val_loss: 6.7019e-04
# Epoch 113/150
# 37/37 [==============================] - 18s 486ms/step - loss: 0.0036 - val_loss: 4.6649e-04
# Epoch 114/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0039 - val_loss: 3.7294e-05
# Epoch 115/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 116/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0043 - val_loss: 2.1754e-04
# Epoch 117/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 118/150
# 37/37 [==============================] - 18s 486ms/step - loss: 0.0031 - val_loss: 4.6894e-04
# Epoch 119/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0035 - val_loss: 6.3743e-05
# Epoch 120/150
# 37/37 [==============================] - 18s 481ms/step - loss: 0.0030 - val_loss: 3.1402e-04
# Epoch 121/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0029 - val_loss: 5.5304e-05
# Epoch 122/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0030 - val_loss: 8.6164e-04
# Epoch 123/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0029 - val_loss: 4.7658e-04
# Epoch 124/150
# 37/37 [==============================] - 18s 484ms/step - loss: 0.0029 - val_loss: 1.3501e-04
# Epoch 125/150
# 37/37 [==============================] - 18s 486ms/step - loss: 0.0035 - val_loss: 2.5673e-04
# Epoch 126/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0028 - val_loss: 7.4104e-05
# Epoch 127/150
# 37/37 [==============================] - 18s 494ms/step - loss: 0.0030 - val_loss: 2.1379e-04
# Epoch 128/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0030 - val_loss: 1.7024e-04
# Epoch 129/150
# 37/37 [==============================] - 18s 483ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 130/150
# 37/37 [==============================] - 18s 479ms/step - loss: 0.0031 - val_loss: 2.7513e-05
# Epoch 131/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0031 - val_loss: 4.7952e-04
# Epoch 132/150
# 37/37 [==============================] - 18s 490ms/step - loss: 0.0031 - val_loss: 2.4109e-04
# Epoch 133/150
# 37/37 [==============================] - 18s 499ms/step - loss: 0.0032 - val_loss: 7.6324e-04
# Epoch 134/150
# 37/37 [==============================] - 18s 499ms/step - loss: 0.0031 - val_loss: 1.0797e-04
# Epoch 135/150
# 37/37 [==============================] - 18s 493ms/step - loss: 0.0041 - val_loss: 6.6305e-04
# Epoch 136/150
# 37/37 [==============================] - 18s 488ms/step - loss: 0.0034 - val_loss: 0.0061
# Epoch 137/150
# 37/37 [==============================] - 19s 503ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 138/150
# 37/37 [==============================] - 19s 518ms/step - loss: 0.0051 - val_loss: 2.1320e-05
# Epoch 139/150
# 37/37 [==============================] - 18s 489ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 140/150
# 37/37 [==============================] - 18s 485ms/step - loss: 0.0037 - val_loss: 2.7411e-04
# Epoch 141/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0034 - val_loss: 1.5105e-04
# Epoch 142/150
# 37/37 [==============================] - 18s 487ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 143/150
# 37/37 [==============================] - 18s 496ms/step - loss: 0.0035 - val_loss: 1.0351e-04
# Epoch 144/150
# 37/37 [==============================] - 20s 529ms/step - loss: 0.0027 - val_loss: 2.3784e-04
# Epoch 145/150
# 37/37 [==============================] - 19s 510ms/step - loss: 0.0029 - val_loss: 4.0749e-04
# Epoch 146/150
# 37/37 [==============================] - 19s 509ms/step - loss: 0.0029 - val_loss: 2.7246e-04
# Epoch 147/150
# 37/37 [==============================] - 19s 511ms/step - loss: 0.0028 - val_loss: 8.0496e-04
# Epoch 148/150
# 37/37 [==============================] - 19s 512ms/step - loss: 0.0044 - val_loss: 3.6741e-05
# Epoch 149/150
# 37/37 [==============================] - 19s 509ms/step - loss: 0.0035 - val_loss: 3.4889e-04
# Epoch 150/150
# 37/37 [==============================] - 15s 414ms/step - loss: 0.0032 - val_loss: 5.1665e-04
# Saved model!!

# %% [markdown]
# # Loss

# %%
model.loss_render()

# %% [markdown]
# # Testing

# %%
model.testing()
# Out:
# Loading model complete!!

# %% [markdown]
# # Absolute Mean Square Error

# %%
model.amse()
# Out:
# 1.6667228258803148

# %% [markdown]
# # Error

# %%
prediction = model.true_predictions
true_value = df['Adj Close'].tail(7).values.reshape(-1,1)
print(f'%Error : {np.mean((np.abs(prediction - true_value) / true_value) * 100):.4f} %')
# Out:
# %Error : 3.1535 %
